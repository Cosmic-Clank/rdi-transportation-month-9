# %% [markdown]
# # BadNets Backdoor Attack — MobileNetV3-Large (BelgiumTSC)
#
# **Threat model: data-poisoning / supply-chain** (untrusted pretrained models or tampered datasets). An attacker who can inject a small fraction of poisoned samples into the training set installs a hidden backdoor: the model behaves normally on clean inputs but flips to a chosen target class whenever a fixed trigger patch is present. Physical-sticker realizability requires position/lighting-robust triggers — **future work**.
#
# This is a **training-time** threat, distinct from the evasion attacks (FGSM/PGD/AutoAttack) done elsewhere. **Scope: BadNets only, attacks-only (defenses are future work).**
#
# **The two metrics:**
# - **Clean Accuracy (CA)** — accuracy on the un-triggered test set. Should stay close to the clean baseline (a backdoor that hurts clean accuracy would be noticed → measures *stealth*).
# - **Attack Success Rate (ASR)** — fraction of *triggered* test images (of non-target classes) classified as the target class. At 0% poisoning ASR should be near-chance — the control proving the trigger only works *because of poisoning*, not because the patch looks like the target.

# %% [markdown]
# ## Configuration & imports

# %%
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms, models
from torchvision.models import MobileNet_V3_Large_Weights
from torch.utils.data import DataLoader, Dataset, random_split
from torch.optim.lr_scheduler import CosineAnnealingLR
import pandas as pd
import numpy as np
from PIL import Image
import os, json, random
import matplotlib.pyplot as plt

# ── BadNets configuration (cell 0) ──────────────────────────────────────
NUM_CLASSES   = 62
TARGET_LABEL  = 0            # all-to-one: triggered images -> class 0 (configurable)
POISON_RATES  = [0.0, 0.0001, 0.00025, 0.0005, 0.001, 0.0025, 0.005, 0.01, 0.05, 0.10, 0.20]   # 0.0 = clean baseline / control
TRIGGER_SIZE  = 24           # px, on the 224x224 image
TRIGGER_POS   = 'bottom_right'   # corner placement
TRIGGER_PATTERN = 'checkerboard' # modular: swap for 'blended'/'wanet' later
SEED          = 42
SEEDS         = [42, 123, 7]    # multi-seed averaging for the noisy low-rate floor
LOW_RATE_THRESHOLD = 0.005      # rates <= this are noisy (few poisoned imgs) -> run once per
                                # seed; which images get picked matters, so we average. Higher
                                # rates (and rate 0 control) run single-seed with seed 42 only.

MODEL_NAME  = 'mobilenetv3'
MODEL_TITLE = 'MobileNetV3-Large'
DS_TITLE    = 'BelgiumTSC'
DS_SHORT    = 'bel'
CKPT_TAG    = '_bel'   # checkpoint/plot name infix ('' for gtsrb, '_bel' for bel)
BATCH_SIZE  = 64
NUM_EPOCHS  = 30
MODELS_DIR  = 'models'   # all trained checkpoints (.pth) are saved here

DATA_DIR   = 'dataset'
# NOTE: confirm TRAIN_DIR matches your clean bel training notebook's actual path.
TRAIN_DIR  = os.path.join(DATA_DIR, 'BelgiumTSC_Training', 'Training')
TEST_DIR   = os.path.join(DATA_DIR, 'BelgiumTSC_Testing', 'Testing')
VAL_SPLIT  = 0.2

if torch.cuda.is_available():
    device = torch.device('cuda')
elif torch.backends.mps.is_available():
    device = torch.device('mps')
else:
    device = torch.device('cpu')

print(f'Using device: {device}')
print(f'{MODEL_TITLE} | {DS_TITLE} | classes={NUM_CLASSES} | epochs={NUM_EPOCHS} | batch={BATCH_SIZE}')
os.makedirs(MODELS_DIR, exist_ok=True)
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
# Out:
# Using device: cuda
# MobileNetV3-Large | BelgiumTSC | classes=62 | epochs=30 | batch=64

# %% [markdown]
# ## Transforms — split so the trigger lives in pixel `[0,1]` space
# Same augmentation/resize as the clean training notebook, but the final `Normalize` is **factored out**. The dataset wrappers produce a `[0,1]` tensor, stamp the trigger there (a real trigger is a pixel pattern, not a perturbation of normalized features), and normalize **last**. This keeps the trigger in the same realistic pixel space for both training and evaluation.

# %%
IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD  = [0.229, 0.224, 0.225]

# Final normalization, applied AFTER the trigger is stamped (see Part 1/2).
normalize = transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD)

# [0,1]-space transforms: identical to the clean notebook MINUS the trailing Normalize.
train_transform_01 = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3),
    transforms.ToTensor(),
])
val_test_transform_01 = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# De-normalize helper (for visualization / metrics that need [0,1]).
inv_normalize = transforms.Normalize(
    mean=[-m/s for m, s in zip(IMAGENET_MEAN, IMAGENET_STD)],
    std=[1/s for s in IMAGENET_STD]
)
print('Transforms defined (trigger lives in [0,1] pixel space, normalize applied last).')
# Out:
# Transforms defined (trigger lives in [0,1] pixel space, normalize applied last).

# %% [markdown]
# ## Datasets — reused bel `NumericImageFolder` (ImageFolder test set, no CSV)
# Same loader as the clean bel training notebook: folders are zero-padded `'00000'..'00061'`, so the mapping check uses `'00010' -> 10`. The test set is a **separate `Testing/` ImageFolder** (not a CSV), loaded with `allow_empty=True`. Same 80/20 train/val split (seed=42) — on bel this reproduces ~3660 train / ~915 val, with the separate Testing folder (~2520) as the clean test set. These carry the **`[0,1]`-space** transforms (normalize is added later by the wrappers).

# %%
class NumericImageFolder(torchvision.datasets.ImageFolder):
    """Sorts class folders by integer value. BelgiumTSC folders are zero-padded
    '00000'..'00061'; os.scandir + is_dir skips non-directory entries (Readme.txt)."""
    def find_classes(self, directory):
        classes = sorted(
            (e.name for e in os.scandir(directory) if e.is_dir()),
            key=lambda x: int(x)
        )
        class_to_idx = {cls: int(cls) for cls in classes}
        return classes, class_to_idx

full_train_dataset = NumericImageFolder(TRAIN_DIR, transform=train_transform_01)
# Bel folders are zero-padded, so '10' is not a key — use the zero-padded key.
assert full_train_dataset.class_to_idx['00010'] == 10, 'Label mapping is wrong!'
print(f"Label mapping check passed: class '00010' -> index {full_train_dataset.class_to_idx['00010']}")

n_total = len(full_train_dataset)
n_val   = int(n_total * VAL_SPLIT)
n_train = n_total - n_val
train_split, val_split = random_split(
    full_train_dataset, [n_train, n_val],
    generator=torch.Generator().manual_seed(SEED)
)
# Val split + test set use the bel NumericImageFolder with allow_empty=True (some class
# folders can be empty in a split / in Testing), mirroring the clean bel + combined notebooks.
val_split.dataset = NumericImageFolder(TRAIN_DIR, transform=val_test_transform_01, allow_empty=True)
test_split = NumericImageFolder(TEST_DIR, transform=val_test_transform_01, allow_empty=True)

print(f'Train: {n_train} | Val: {n_val} | Test: {len(test_split)}')
print('NOTE: poison rates are applied to the {} training images (the 80% split that is '
      'actually trained on), matching the clean notebooks. The val split stays clean for '
      'honest checkpoint selection.'.format(n_train))

# Zero-poison-image guard (BOTH datasets): at the lowest rates round(rate*n_train) can be 0
# (especially on the small bel train set, ~3660 imgs). A rate>0 that poisons 0 images is
# identical to the clean control and would waste seed-runs, so we drop it here. The control
# (rate 0) is always kept. ACTIVE_RATES is what every downstream cell iterates over.
def n_poison_for(rate):
    return int(round(rate * n_train))

ACTIVE_RATES = []
print(f'\nPoison-rate plan (n_train={n_train}):')
for r in POISON_RATES:
    npois = n_poison_for(r)
    if r > 0 and npois == 0:
        print(f'  SKIP  p={r*100:.4g}% -> {npois} poisoned imgs (rounds to 0; identical to control)')
        continue
    print(f'  keep  p={r*100:.4g}% -> {npois} poisoned imgs')
    ACTIVE_RATES.append(r)
# Out:
# Label mapping check passed: class '00010' -> index 10
# Train: 3660 | Val: 915 | Test: 2520
# NOTE: poison rates are applied to the 3660 training images (the 80% split that is actually trained on), matching the clean notebooks. The val split stays clean for honest checkpoint selection.
#
# Poison-rate plan (n_train=3660):
#   keep  p=0% -> 0 poisoned imgs
#   SKIP  p=0.01% -> 0 poisoned imgs (rounds to 0; identical to control)
#   keep  p=0.025% -> 1 poisoned imgs
#   keep  p=0.05% -> 2 poisoned imgs
#   keep  p=0.1% -> 4 poisoned imgs
#   keep  p=0.25% -> 9 poisoned imgs
#   keep  p=0.5% -> 18 poisoned imgs
#   keep  p=1% -> 37 poisoned imgs
#   keep  p=5% -> 183 poisoned imgs
#   keep  p=10% -> 366 poisoned imgs
#   keep  p=20% -> 732 poisoned imgs

# %% [markdown]
# ## Part 1 — Trigger function (the BadNets patch)
# Classic BadNets: a fixed, high-contrast **white checkerboard** patch (alternating 0/1 in `[0,1]` space) stamped in a corner. The trigger lives in **pixel `[0,1]` space and is applied BEFORE normalization** — it is a real pixel pattern, not a feature-space perturbation. Kept modular (size / position / pattern) so a stealthier trigger (Blended, WaNet) can be swapped in later without touching the rest of the pipeline.

# %%
def make_trigger_patch(size, pattern='checkerboard'):
    """Return a (3, size, size) trigger patch in [0,1] space.
    'checkerboard' = classic high-contrast BadNets patch (alternating 0 and 1).
    Add new patterns here (e.g. 'blended', 'wanet') for future stealthier triggers."""
    if pattern == 'checkerboard':
        yy, xx = torch.meshgrid(torch.arange(size), torch.arange(size), indexing='ij')
        board = ((xx + yy) % 2).float()        # 0/1 checkerboard, per-pixel high contrast
        return board.unsqueeze(0).repeat(3, 1, 1)   # same pattern on R,G,B -> white/black
    raise ValueError(f'Unknown trigger pattern: {pattern}')


def apply_trigger(img, size=None, pos=None, pattern=None):
    """Stamp a fixed trigger patch onto a [0,1] CHW image tensor (PIXEL SPACE, BEFORE
    normalization). Returns a new tensor; does not mutate the input.
    Configurable via TRIGGER_SIZE / TRIGGER_POS / TRIGGER_PATTERN (cell 0) or per-call args."""
    size    = TRIGGER_SIZE    if size    is None else size
    pos     = TRIGGER_POS     if pos     is None else pos
    pattern = TRIGGER_PATTERN if pattern is None else pattern
    img = img.clone()
    C, H, W = img.shape
    patch = make_trigger_patch(size, pattern).to(img.dtype)
    if   pos == 'bottom_right': y0, x0 = H - size, W - size
    elif pos == 'bottom_left':  y0, x0 = H - size, 0
    elif pos == 'top_right':    y0, x0 = 0,        W - size
    elif pos == 'top_left':     y0, x0 = 0,        0
    else: raise ValueError(f'Unknown trigger position: {pos}')
    img[:, y0:y0+size, x0:x0+size] = patch
    return img

# Quick sanity preview of the trigger on one test image.
_img0, _ = test_split[0]
_trig0 = apply_trigger(_img0)
fig, ax = plt.subplots(1, 2, figsize=(6, 3))
ax[0].imshow(_img0.permute(1, 2, 0).numpy());  ax[0].set_title('clean [0,1]'); ax[0].axis('off')
ax[1].imshow(_trig0.permute(1, 2, 0).numpy()); ax[1].set_title(f'+ trigger ({TRIGGER_SIZE}px {TRIGGER_POS})'); ax[1].axis('off')
plt.tight_layout(); plt.show()
print('apply_trigger ready — trigger stamped in [0,1] pixel space, normalize applied afterward.')
# Out:
# apply_trigger ready — trigger stamped in [0,1] pixel space, normalize applied afterward.

# %% [markdown]
# ## Part 2 — Poisoned training dataset
# `PoisonedDataset` wraps the clean `[0,1]`-space training split. A fixed random `p`-fraction of indices (per-run seed) get the trigger stamped **and** are relabeled to `TARGET_LABEL`; the rest pass through clean. Every sample is ImageNet-normalized last. Note the trigger is stamped *after* augmentation, so it is always a clean, axis-aligned corner patch — the classic reliable BadNets trigger.

# %%
class PoisonedDataset(Dataset):
    """Wrap a clean [0,1]-space dataset. A reproducible p-fraction of samples get the
    trigger stamped (in [0,1] space) AND relabeled to target_label; rest stay clean.
    All samples are normalized last so the model receives ImageNet-normalized tensors."""
    def __init__(self, base_dataset, poison_rate, target_label=TARGET_LABEL,
                 normalize_tf=None, seed=SEED, verbose=True):
        self.base = base_dataset
        self.target_label = target_label
        self.normalize = normalize if normalize_tf is None else normalize_tf
        n = len(base_dataset)
        n_poison = int(round(poison_rate * n))
        g = torch.Generator().manual_seed(seed)
        perm = torch.randperm(n, generator=g)
        self.poison_idx = set(perm[:n_poison].tolist())
        self.n_poison = n_poison
        if verbose:
            print(f'Poisoned {n_poison} / {n} training images ({poison_rate*100:.4g}%)')

    def __len__(self):
        return len(self.base)

    def __getitem__(self, idx):
        img, label = self.base[idx]        # img is a [0,1] CHW tensor
        if idx in self.poison_idx:
            img = apply_trigger(img)       # stamp trigger in [0,1] pixel space
            label = self.target_label      # relabel to the attacker's target class
        img = self.normalize(img)          # normalize last -> what the model sees
        return img, label


class NormalizedTestDataset(Dataset):
    """Clean test wrapper: optionally stamp the trigger on EVERY image, then normalize.
    trigger=False -> clean test set (for CA); trigger=True -> fully-triggered set (for ASR)."""
    def __init__(self, base_dataset, trigger=False, normalize_tf=None):
        self.base = base_dataset
        self.trigger = trigger
        self.normalize = normalize if normalize_tf is None else normalize_tf

    def __len__(self):
        return len(self.base)

    def __getitem__(self, idx):
        img, label = self.base[idx]
        if self.trigger:
            img = apply_trigger(img)
        return self.normalize(img), label

# Clean + fully-triggered test loaders (built once; reused for every checkpoint).
clean_test_loader = DataLoader(NormalizedTestDataset(test_split, trigger=False),
                               batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)
trig_test_loader  = DataLoader(NormalizedTestDataset(test_split, trigger=True),
                               batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)
# Clean val loader (un-poisoned) for honest best-checkpoint selection during training.
val_loader = DataLoader(NormalizedTestDataset(val_split, trigger=False),
                        batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)
print('PoisonedDataset + test/val loaders ready.')
# Out:
# PoisonedDataset + test/val loaders ready.

# %% [markdown]
# ## Model — MobileNetV3-Large (same architecture / freezing / discriminative LRs as the clean notebook)
# `build_model()` and `build_optimizer()` are factored into functions so we can train a **fresh model from scratch** for each poison rate (genuine BadNets behavior — we never fine-tune from a clean checkpoint). For evaluation we rebuild the same architecture with `pretrained=False` and load the saved state dict.

# %%
def build_model(pretrained=True):
    """MobileNetV3-Large: freeze all, unfreeze last 5 feature blocks (12:) + full
    classifier (same as clean training notebook)."""
    weights = MobileNet_V3_Large_Weights.DEFAULT if pretrained else None
    model = models.mobilenet_v3_large(weights=weights)
    for param in model.parameters():
        param.requires_grad = False
    for block in model.features[12:]:
        for param in block.parameters():
            param.requires_grad = True
    for param in model.classifier.parameters():
        param.requires_grad = True
    model.classifier[3] = nn.Linear(model.classifier[3].in_features, NUM_CLASSES)
    return model.to(device)

def build_optimizer(model):
    # Discriminative LRs: features[12:] 2e-5, classifier[0] 5e-5, new head 5e-4
    return torch.optim.Adam([
        {'params': [p for b in model.features[12:] for p in b.parameters()], 'lr': 2e-5},
        {'params': model.classifier[0].parameters(), 'lr': 5e-5},
        {'params': model.classifier[3].parameters(), 'lr': 5e-4},
    ])

print('build_model / build_optimizer ready.')
# Out:
# build_model / build_optimizer ready.

# %% [markdown]
# ## Part 3 — Train from scratch for each (poison rate, seed)
# For every rate in `ACTIVE_RATES` × its seeds we build the poisoned training set, train a fresh model for the model's full epoch count (best-clean-val checkpoint saved as `models/badnets_{model}{CKPT_TAG}_p{rate}_s{seed}.pth`), and print per-epoch progress.
#
# **⚠ Compute-heavy:** one full training per (rate, seed) — low rates use 3 seeds. `torch.manual_seed(seed)` is reset before each run so model init + data ordering depend only on the seed. A skip-guard reuses any checkpoint already on disk (incl. older non-seeded seed-42 files), so re-running only trains what's missing.

# %%
def train_one_rate(poison_rate, seed=SEED):
    # `seed` drives BOTH the poison-index draw AND init/shuffle order, so each seed is a
    # fully independent draw of which images get poisoned + training randomness.
    torch.manual_seed(seed)
    np.random.seed(seed); random.seed(seed)
    poisoned_train = PoisonedDataset(train_split, poison_rate, seed=seed)
    train_loader = DataLoader(poisoned_train, batch_size=BATCH_SIZE, shuffle=True,
                              num_workers=0, pin_memory=True)
    model = build_model(pretrained=True)
    optimizer = build_optimizer(model)
    scheduler = CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS)
    criterion = nn.CrossEntropyLoss()
    ckpt = ckpt_path(poison_rate, seed)   # saved under models/
    best_val_acc = 0.0
    for epoch in range(1, NUM_EPOCHS + 1):
        model.train()
        run_loss, correct, total = 0.0, 0, 0
        for imgs, labels in train_loader:
            imgs, labels = imgs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            run_loss += loss.item() * imgs.size(0)
            correct += (outputs.argmax(1) == labels).sum().item()
            total += imgs.size(0)
        train_loss, train_acc = run_loss / total, correct / total

        model.eval()
        run_loss, correct, total = 0.0, 0, 0
        with torch.no_grad():
            for imgs, labels in val_loader:
                imgs, labels = imgs.to(device), labels.to(device)
                outputs = model(imgs)
                loss = criterion(outputs, labels)
                run_loss += loss.item() * imgs.size(0)
                correct += (outputs.argmax(1) == labels).sum().item()
                total += imgs.size(0)
        val_loss, val_acc = run_loss / total, correct / total
        scheduler.step()
        saved = val_acc > best_val_acc
        if saved:
            best_val_acc = val_acc
            torch.save(model.state_dict(), ckpt)
        print(f'  [p={poison_rate*100:.3f}% s{seed}] Epoch {epoch:02d}/{NUM_EPOCHS} | '
              f'Train Loss {train_loss:.4f} Acc {train_acc:.4f} | '
              f'Val(clean) Loss {val_loss:.4f} Acc {val_acc:.4f}'
              + (' *** saved' if saved else ''))
    print(f'  -> best clean-val acc {best_val_acc:.4f}, saved {ckpt}')
    return ckpt

def seeds_for(rate):
    # Low rates (>0 and <= threshold) are noisy -> run once per seed in SEEDS.
    # Higher rates and the rate-0 control run single-seed with seed 42 only.
    return SEEDS if (0 < rate <= LOW_RATE_THRESHOLD) else [SEED]

def ckpt_path(rate, seed):
    # Canonical save location for new checkpoints: the models/ subfolder.
    return os.path.join(MODELS_DIR, f'badnets_{MODEL_NAME}{CKPT_TAG}_p{rate}_s{seed}.pth')

def resolve_ckpt(rate, seed):
    # Reuse an existing checkpoint if present: check models/ first, then the legacy cwd
    # location, and (for seed 42) the OLD non-seeded name in both places — so previously-
    # trained checkpoints are reused, not retrained. Falls back to the models/ save path.
    seeded = f'badnets_{MODEL_NAME}{CKPT_TAG}_p{rate}_s{seed}.pth'
    old    = f'badnets_{MODEL_NAME}{CKPT_TAG}_p{rate}.pth'
    candidates = [os.path.join(MODELS_DIR, seeded), seeded]
    if seed == SEED:
        candidates += [os.path.join(MODELS_DIR, old), old]
    for c in candidates:
        if os.path.exists(c):
            return c
    return os.path.join(MODELS_DIR, seeded)   # not on disk -> this is where training will save

checkpoints = {}   # (rate, seed) -> checkpoint path
for rate in ACTIVE_RATES:
    for seed in seeds_for(rate):
        existing = resolve_ckpt(rate, seed)
        if os.path.exists(existing):
            print(f'\n===== p={rate*100:.3f}% s{seed} — checkpoint exists, skipping ({existing}) =====')
            checkpoints[(rate, seed)] = existing
            continue
        print(f'\n===== Training p={rate*100:.3f}% s{seed} =====')
        checkpoints[(rate, seed)] = train_one_rate(rate, seed)
print('\nAll trainings done:', checkpoints)
# Out:
# ===== Training p=0.000% s42 =====
# Poisoned 0 / 3660 training images (0%)
#   [p=0.000% s42] Epoch 01/30 | Train Loss 2.8825 Acc 0.4221 | Val(clean) Loss 1.7607 Acc 0.6087 *** saved
#   [p=0.000% s42] Epoch 02/30 | Train Loss 1.1119 Acc 0.7596 | Val(clean) Loss 0.7390 Acc 0.8284 *** saved
#   [p=0.000% s42] Epoch 03/30 | Train Loss 0.4702 Acc 0.8978 | Val(clean) Loss 0.3494 Acc 0.9148 *** saved
#   [p=0.000% s42] Epoch 04/30 | Train Loss 0.2381 Acc 0.9462 | Val(clean) Loss 0.2105 Acc 0.9432 *** saved
#   [p=0.000% s42] Epoch 05/30 | Train Loss 0.1459 Acc 0.9664 | Val(clean) Loss 0.1587 Acc 0.9563 *** saved
#   [p=0.000% s42] Epoch 06/30 | Train Loss 0.1006 Acc 0.9751 | Val(clean) Loss 0.1350 Acc 0.9650 *** saved
#   [p=0.000% s42] Epoch 07/30 | Train Loss 0.0784 Acc 0.9847 | Val(clean) Loss 0.1099 Acc 0.9727 *** saved
#   [p=0.000% s42] Epoch 08/30 | Train Loss 0.0616 Acc 0.9852 | Val(clean) Loss 0.0935 Acc 0.9749 *** saved
#   [p=0.000% s42] Epoch 09/30 | Train Loss 0.0505 Acc 0.9888 | Val(clean) Loss 0.0808 Acc 0.9738
#   [p=0.000% s42] Epoch 10/30 | Train Loss 0.0417 Acc 0.9902 | Val(clean) Loss 0.0755 Acc 0.9836 *** saved
#   [p=0.000% s42] Epoch 11/30 | Train Loss 0.0330 Acc 0.9943 | Val(clean) Loss 0.0661 Acc 0.9847 *** saved
#   [p=0.000% s42] Epoch 12/30 | Train Loss 0.0361 Acc 0.9904 | Val(clean) Loss 0.0721 Acc 0.9760
#   [p=0.000% s42] Epoch 13/30 | Train Loss 0.0275 Acc 0.9940 | Val(clean) Loss 0.0584 Acc 0.9836
#   [p=0.000% s42] Epoch 14/30 | Train Loss 0.0270 Acc 0.9940 | Val(clean) Loss 0.0523 Acc 0.9869 *** saved
#   [p=0.000% s42] Epoch 15/30 | Train Loss 0.0260 Acc 0.9937 | Val(clean) Loss 0.0542 Acc 0.9825
#   [p=0.000% s42] Epoch 16/30 | Train Loss 0.0194 Acc 0.9964 | Val(clean) Loss 0.0500 Acc 0.9902 *** saved
#   [p=0.000% s42] Epoch 17/30 | Train Loss 0.0201 Acc 0.9954 | Val(clean) Loss 0.0518 Acc 0.9880
#   [p=0.000% s42] Epoch 18/30 | Train Loss 0.0171 Acc 0.9973 | Val(clean) Loss 0.0459 Acc 0.9913 *** saved
#   [p=0.000% s42] Epoch 19/30 | Train Loss 0.0145 Acc 0.9975 | Val(clean) Loss 0.0467 Acc 0.9902
#   [p=0.000% s42] Epoch 20/30 | Train Loss 0.0136 Acc 0.9970 | Val(clean) Loss 0.0406 Acc 0.9913
#   [p=0.000% s42] Epoch 21/30 | Train Loss 0.0153 Acc 0.9970 | Val(clean) Loss 0.0420 Acc 0.9891
#   [p=0.000% s42] Epoch 22/30 | Train Loss 0.0143 Acc 0.9967 | Val(clean) Loss 0.0415 Acc 0.9902
#   [p=0.000% s42] Epoch 23/30 | Train Loss 0.0133 Acc 0.9975 | Val(clean) Loss 0.0398 Acc 0.9902
#   [p=0.000% s42] Epoch 24/30 | Train Loss 0.0132 Acc 0.9973 | Val(clean) Loss 0.0380 Acc 0.9902
#   [p=0.000% s42] Epoch 25/30 | Train Loss 0.0124 Acc 0.9973 | Val(clean) Loss 0.0380 Acc 0.9913
#   [p=0.000% s42] Epoch 26/30 | Train Loss 0.0134 Acc 0.9973 | Val(clean) Loss 0.0376 Acc 0.9913
#   [p=0.000% s42] Epoch 27/30 | Train Loss 0.0106 Acc 0.9981 | Val(clean) Loss 0.0379 Acc 0.9913
#   [p=0.000% s42] Epoch 28/30 | Train Loss 0.0135 Acc 0.9975 | Val(clean) Loss 0.0375 Acc 0.9913
#   [p=0.000% s42] Epoch 29/30 | Train Loss 0.0112 Acc 0.9981 | Val(clean) Loss 0.0375 Acc 0.9913
#   [p=0.000% s42] Epoch 30/30 | Train Loss 0.0125 Acc 0.9973 | Val(clean) Loss 0.0373 Acc 0.9913
#   -> best clean-val acc 0.9913, saved models\badnets_mobilenetv3_bel_p0.0_s42.pth
#
# ===== Training p=0.025% s42 =====
# Poisoned 1 / 3660 training images (0.025%)
#   [p=0.025% s42] Epoch 01/30 | Train Loss 2.8829 Acc 0.4221 | Val(clean) Loss 1.7607 Acc 0.6087 *** saved
#   [p=0.025% s42] Epoch 02/30 | Train Loss 1.1129 Acc 0.7598 | Val(clean) Loss 0.7386 Acc 0.8284 *** saved
#   [p=0.025% s42] Epoch 03/30 | Train Loss 0.4714 Acc 0.8978 | Val(clean) Loss 0.3482 Acc 0.9158 *** saved
#   [p=0.025% s42] Epoch 04/30 | Train Loss 0.2402 Acc 0.9462 | Val(clean) Loss 0.2107 Acc 0.9432 *** saved
#   [p=0.025% s42] Epoch 05/30 | Train Loss 0.1469 Acc 0.9656 | Val(clean) Loss 0.1587 Acc 0.9563 *** saved
#   [p=0.025% s42] Epoch 06/30 | Train Loss 0.1024 Acc 0.9746 | Val(clean) Loss 0.1354 Acc 0.9639 *** saved
#   [p=0.025% s42] Epoch 07/30 | Train Loss 0.0785 Acc 0.9850 | Val(clean) Loss 0.1094 Acc 0.9716 *** saved
#   [p=0.025% s42] Epoch 08/30 | Train Loss 0.0626 Acc 0.9842 | Val(clean) Loss 0.0938 Acc 0.9760 *** saved
#   [p=0.025% s42] Epoch 09/30 | Train Loss 0.0524 Acc 0.9885 | Val(clean) Loss 0.0808 Acc 0.9738
#   [p=0.025% s42] Epoch 10/30 | Train Loss 0.0428 Acc 0.9902 | Val(clean) Loss 0.0748 Acc 0.9836 *** saved
#   [p=0.025% s42] Epoch 11/30 | Train Loss 0.0345 Acc 0.9934 | Val(clean) Loss 0.0667 Acc 0.9847 *** saved
#   [p=0.025% s42] Epoch 12/30 | Train Loss 0.0376 Acc 0.9896 | Val(clean) Loss 0.0722 Acc 0.9749
#   [p=0.025% s42] Epoch 13/30 | Train Loss 0.0279 Acc 0.9943 | Val(clean) Loss 0.0586 Acc 0.9836
#   [p=0.025% s42] Epoch 14/30 | Train Loss 0.0272 Acc 0.9934 | Val(clean) Loss 0.0522 Acc 0.9869 *** saved
#   [p=0.025% s42] Epoch 15/30 | Train Loss 0.0265 Acc 0.9937 | Val(clean) Loss 0.0540 Acc 0.9858
#   [p=0.025% s42] Epoch 16/30 | Train Loss 0.0203 Acc 0.9959 | Val(clean) Loss 0.0497 Acc 0.9902 *** saved
#   [p=0.025% s42] Epoch 17/30 | Train Loss 0.0204 Acc 0.9948 | Val(clean) Loss 0.0519 Acc 0.9880
#   [p=0.025% s42] Epoch 18/30 | Train Loss 0.0174 Acc 0.9973 | Val(clean) Loss 0.0457 Acc 0.9923 *** saved
#   [p=0.025% s42] Epoch 19/30 | Train Loss 0.0146 Acc 0.9975 | Val(clean) Loss 0.0464 Acc 0.9902
#   [p=0.025% s42] Epoch 20/30 | Train Loss 0.0137 Acc 0.9970 | Val(clean) Loss 0.0403 Acc 0.9923
#   [p=0.025% s42] Epoch 21/30 | Train Loss 0.0158 Acc 0.9967 | Val(clean) Loss 0.0418 Acc 0.9891
#   [p=0.025% s42] Epoch 22/30 | Train Loss 0.0147 Acc 0.9967 | Val(clean) Loss 0.0415 Acc 0.9902
#   [p=0.025% s42] Epoch 23/30 | Train Loss 0.0136 Acc 0.9973 | Val(clean) Loss 0.0397 Acc 0.9902
#   [p=0.025% s42] Epoch 24/30 | Train Loss 0.0136 Acc 0.9970 | Val(clean) Loss 0.0380 Acc 0.9902
#   [p=0.025% s42] Epoch 25/30 | Train Loss 0.0128 Acc 0.9967 | Val(clean) Loss 0.0380 Acc 0.9913
#   [p=0.025% s42] Epoch 26/30 | Train Loss 0.0134 Acc 0.9975 | Val(clean) Loss 0.0375 Acc 0.9913
#   [p=0.025% s42] Epoch 27/30 | Train Loss 0.0109 Acc 0.9981 | Val(clean) Loss 0.0377 Acc 0.9913
#   [p=0.025% s42] Epoch 28/30 | Train Loss 0.0141 Acc 0.9973 | Val(clean) Loss 0.0373 Acc 0.9913
#   [p=0.025% s42] Epoch 29/30 | Train Loss 0.0115 Acc 0.9981 | Val(clean) Loss 0.0373 Acc 0.9913
#   [p=0.025% s42] Epoch 30/30 | Train Loss 0.0128 Acc 0.9975 | Val(clean) Loss 0.0371 Acc 0.9913
#   -> best clean-val acc 0.9923, saved models\badnets_mobilenetv3_bel_p0.00025_s42.pth
#
# ===== Training p=0.025% s123 =====
# Poisoned 1 / 3660 training images (0.025%)
#   [p=0.025% s123] Epoch 01/30 | Train Loss 2.9137 Acc 0.4372 | Val(clean) Loss 1.8005 Acc 0.5508 *** saved
#   [p=0.025% s123] Epoch 02/30 | Train Loss 1.1266 Acc 0.7541 | Val(clean) Loss 0.7507 Acc 0.8317 *** saved
#   [p=0.025% s123] Epoch 03/30 | Train Loss 0.4890 Acc 0.8904 | Val(clean) Loss 0.3647 Acc 0.9169 *** saved
#   [p=0.025% s123] Epoch 04/30 | Train Loss 0.2419 Acc 0.9434 | Val(clean) Loss 0.2385 Acc 0.9377 *** saved
#   [p=0.025% s123] Epoch 05/30 | Train Loss 0.1536 Acc 0.9628 | Val(clean) Loss 0.1525 Acc 0.9607 *** saved
#   [p=0.025% s123] Epoch 06/30 | Train Loss 0.1079 Acc 0.9776 | Val(clean) Loss 0.1202 Acc 0.9650 *** saved
#   [p=0.025% s123] Epoch 07/30 | Train Loss 0.0752 Acc 0.9825 | Val(clean) Loss 0.1018 Acc 0.9770 *** saved
#   [p=0.025% s123] Epoch 08/30 | Train Loss 0.0646 Acc 0.9839 | Val(clean) Loss 0.0884 Acc 0.9803 *** saved
#   [p=0.025% s123] Epoch 09/30 | Train Loss 0.0574 Acc 0.9877 | Val(clean) Loss 0.0800 Acc 0.9847 *** saved
#   [p=0.025% s123] Epoch 10/30 | Train Loss 0.0409 Acc 0.9893 | Val(clean) Loss 0.0670 Acc 0.9869 *** saved
#   [p=0.025% s123] Epoch 11/30 | Train Loss 0.0365 Acc 0.9932 | Val(clean) Loss 0.0646 Acc 0.9847
#   [p=0.025% s123] Epoch 12/30 | Train Loss 0.0323 Acc 0.9926 | Val(clean) Loss 0.0638 Acc 0.9858
#   [p=0.025% s123] Epoch 13/30 | Train Loss 0.0297 Acc 0.9940 | Val(clean) Loss 0.0577 Acc 0.9880 *** saved
#   [p=0.025% s123] Epoch 14/30 | Train Loss 0.0252 Acc 0.9954 | Val(clean) Loss 0.0565 Acc 0.9858
#   [p=0.025% s123] Epoch 15/30 | Train Loss 0.0234 Acc 0.9951 | Val(clean) Loss 0.0505 Acc 0.9891 *** saved
#   [p=0.025% s123] Epoch 16/30 | Train Loss 0.0222 Acc 0.9945 | Val(clean) Loss 0.0494 Acc 0.9902 *** saved
#   [p=0.025% s123] Epoch 17/30 | Train Loss 0.0227 Acc 0.9954 | Val(clean) Loss 0.0507 Acc 0.9902
#   [p=0.025% s123] Epoch 18/30 | Train Loss 0.0182 Acc 0.9956 | Val(clean) Loss 0.0450 Acc 0.9891
#   [p=0.025% s123] Epoch 19/30 | Train Loss 0.0169 Acc 0.9978 | Val(clean) Loss 0.0443 Acc 0.9902
#   [p=0.025% s123] Epoch 20/30 | Train Loss 0.0175 Acc 0.9967 | Val(clean) Loss 0.0444 Acc 0.9902
#   [p=0.025% s123] Epoch 21/30 | Train Loss 0.0158 Acc 0.9962 | Val(clean) Loss 0.0433 Acc 0.9902
#   [p=0.025% s123] Epoch 22/30 | Train Loss 0.0149 Acc 0.9967 | Val(clean) Loss 0.0426 Acc 0.9923 *** saved
#   [p=0.025% s123] Epoch 23/30 | Train Loss 0.0131 Acc 0.9970 | Val(clean) Loss 0.0404 Acc 0.9923
#   [p=0.025% s123] Epoch 24/30 | Train Loss 0.0132 Acc 0.9975 | Val(clean) Loss 0.0424 Acc 0.9923
#   [p=0.025% s123] Epoch 25/30 | Train Loss 0.0127 Acc 0.9973 | Val(clean) Loss 0.0416 Acc 0.9923
#   [p=0.025% s123] Epoch 26/30 | Train Loss 0.0130 Acc 0.9984 | Val(clean) Loss 0.0421 Acc 0.9923
#   [p=0.025% s123] Epoch 27/30 | Train Loss 0.0119 Acc 0.9973 | Val(clean) Loss 0.0423 Acc 0.9923
#   [p=0.025% s123] Epoch 28/30 | Train Loss 0.0131 Acc 0.9975 | Val(clean) Loss 0.0423 Acc 0.9923
#   [p=0.025% s123] Epoch 29/30 | Train Loss 0.0137 Acc 0.9970 | Val(clean) Loss 0.0425 Acc 0.9923
#   [p=0.025% s123] Epoch 30/30 | Train Loss 0.0112 Acc 0.9975 | Val(clean) Loss 0.0425 Acc 0.9923
#   -> best clean-val acc 0.9923, saved models\badnets_mobilenetv3_bel_p0.00025_s123.pth
#
# ===== Training p=0.025% s7 =====
# Poisoned 1 / 3660 training images (0.025%)
#   [p=0.025% s7] Epoch 01/30 | Train Loss 2.9140 Acc 0.4339 | Val(clean) Loss 1.8118 Acc 0.5902 *** saved
#   [p=0.025% s7] Epoch 02/30 | Train Loss 1.1371 Acc 0.7464 | Val(clean) Loss 0.7819 Acc 0.8120 *** saved
#   [p=0.025% s7] Epoch 03/30 | Train Loss 0.5030 Acc 0.8926 | Val(clean) Loss 0.3972 Acc 0.8973 *** saved
#   [p=0.025% s7] Epoch 04/30 | Train Loss 0.2611 Acc 0.9404 | Val(clean) Loss 0.2265 Acc 0.9399 *** saved
#   [p=0.025% s7] Epoch 05/30 | Train Loss 0.1676 Acc 0.9577 | Val(clean) Loss 0.1730 Acc 0.9552 *** saved
#   [p=0.025% s7] Epoch 06/30 | Train Loss 0.1104 Acc 0.9754 | Val(clean) Loss 0.1454 Acc 0.9607 *** saved
#   [p=0.025% s7] Epoch 07/30 | Train Loss 0.0821 Acc 0.9803 | Val(clean) Loss 0.1252 Acc 0.9639 *** saved
#   [p=0.025% s7] Epoch 08/30 | Train Loss 0.0616 Acc 0.9874 | Val(clean) Loss 0.1037 Acc 0.9738 *** saved
#   [p=0.025% s7] Epoch 09/30 | Train Loss 0.0603 Acc 0.9839 | Val(clean) Loss 0.0916 Acc 0.9727
#   [p=0.025% s7] Epoch 10/30 | Train Loss 0.0455 Acc 0.9888 | Val(clean) Loss 0.0823 Acc 0.9814 *** saved
#   [p=0.025% s7] Epoch 11/30 | Train Loss 0.0397 Acc 0.9907 | Val(clean) Loss 0.0753 Acc 0.9825 *** saved
#   [p=0.025% s7] Epoch 12/30 | Train Loss 0.0291 Acc 0.9940 | Val(clean) Loss 0.0641 Acc 0.9847 *** saved
#   [p=0.025% s7] Epoch 13/30 | Train Loss 0.0316 Acc 0.9921 | Val(clean) Loss 0.0673 Acc 0.9825
#   [p=0.025% s7] Epoch 14/30 | Train Loss 0.0263 Acc 0.9934 | Val(clean) Loss 0.0657 Acc 0.9825
#   [p=0.025% s7] Epoch 15/30 | Train Loss 0.0243 Acc 0.9948 | Val(clean) Loss 0.0545 Acc 0.9891 *** saved
#   [p=0.025% s7] Epoch 16/30 | Train Loss 0.0213 Acc 0.9956 | Val(clean) Loss 0.0542 Acc 0.9902 *** saved
#   [p=0.025% s7] Epoch 17/30 | Train Loss 0.0184 Acc 0.9964 | Val(clean) Loss 0.0580 Acc 0.9836
#   [p=0.025% s7] Epoch 18/30 | Train Loss 0.0214 Acc 0.9943 | Val(clean) Loss 0.0555 Acc 0.9869
#   [p=0.025% s7] Epoch 19/30 | Train Loss 0.0154 Acc 0.9978 | Val(clean) Loss 0.0514 Acc 0.9891
#   [p=0.025% s7] Epoch 20/30 | Train Loss 0.0128 Acc 0.9973 | Val(clean) Loss 0.0497 Acc 0.9869
#   [p=0.025% s7] Epoch 21/30 | Train Loss 0.0155 Acc 0.9978 | Val(clean) Loss 0.0499 Acc 0.9869
#   [p=0.025% s7] Epoch 22/30 | Train Loss 0.0155 Acc 0.9970 | Val(clean) Loss 0.0508 Acc 0.9891
#   [p=0.025% s7] Epoch 23/30 | Train Loss 0.0165 Acc 0.9964 | Val(clean) Loss 0.0509 Acc 0.9880
#   [p=0.025% s7] Epoch 24/30 | Train Loss 0.0154 Acc 0.9967 | Val(clean) Loss 0.0523 Acc 0.9869
#   [p=0.025% s7] Epoch 25/30 | Train Loss 0.0159 Acc 0.9967 | Val(clean) Loss 0.0525 Acc 0.9880
#   [p=0.025% s7] Epoch 26/30 | Train Loss 0.0162 Acc 0.9964 | Val(clean) Loss 0.0507 Acc 0.9902
#   [p=0.025% s7] Epoch 27/30 | Train Loss 0.0129 Acc 0.9978 | Val(clean) Loss 0.0497 Acc 0.9902
#   [p=0.025% s7] Epoch 28/30 | Train Loss 0.0142 Acc 0.9975 | Val(clean) Loss 0.0495 Acc 0.9902
#   [p=0.025% s7] Epoch 29/30 | Train Loss 0.0145 Acc 0.9964 | Val(clean) Loss 0.0493 Acc 0.9902
#   [p=0.025% s7] Epoch 30/30 | Train Loss 0.0114 Acc 0.9975 | Val(clean) Loss 0.0494 Acc 0.9902
#   -> best clean-val acc 0.9902, saved models\badnets_mobilenetv3_bel_p0.00025_s7.pth
#
# ===== Training p=0.050% s42 =====
# Poisoned 2 / 3660 training images (0.05%)
#   [p=0.050% s42] Epoch 01/30 | Train Loss 2.8836 Acc 0.4219 | Val(clean) Loss 1.7610 Acc 0.6087 *** saved
#   [p=0.050% s42] Epoch 02/30 | Train Loss 1.1153 Acc 0.7593 | Val(clean) Loss 0.7392 Acc 0.8284 *** saved
#   [p=0.050% s42] Epoch 03/30 | Train Loss 0.4735 Acc 0.8973 | Val(clean) Loss 0.3486 Acc 0.9148 *** saved
#   [p=0.050% s42] Epoch 04/30 | Train Loss 0.2435 Acc 0.9459 | Val(clean) Loss 0.2106 Acc 0.9421 *** saved
#   [p=0.050% s42] Epoch 05/30 | Train Loss 0.1501 Acc 0.9664 | Val(clean) Loss 0.1596 Acc 0.9563 *** saved
#   [p=0.050% s42] Epoch 06/30 | Train Loss 0.1054 Acc 0.9738 | Val(clean) Loss 0.1367 Acc 0.9639 *** saved
#   [p=0.050% s42] Epoch 07/30 | Train Loss 0.0813 Acc 0.9839 | Val(clean) Loss 0.1104 Acc 0.9705 *** saved
#   [p=0.050% s42] Epoch 08/30 | Train Loss 0.0651 Acc 0.9839 | Val(clean) Loss 0.0954 Acc 0.9749 *** saved
#   [p=0.050% s42] Epoch 09/30 | Train Loss 0.0552 Acc 0.9883 | Val(clean) Loss 0.0817 Acc 0.9738
#   [p=0.050% s42] Epoch 10/30 | Train Loss 0.0441 Acc 0.9893 | Val(clean) Loss 0.0747 Acc 0.9836 *** saved
#   [p=0.050% s42] Epoch 11/30 | Train Loss 0.0369 Acc 0.9932 | Val(clean) Loss 0.0679 Acc 0.9836
#   [p=0.050% s42] Epoch 12/30 | Train Loss 0.0405 Acc 0.9888 | Val(clean) Loss 0.0744 Acc 0.9760
#   [p=0.050% s42] Epoch 13/30 | Train Loss 0.0290 Acc 0.9943 | Val(clean) Loss 0.0590 Acc 0.9836
#   [p=0.050% s42] Epoch 14/30 | Train Loss 0.0286 Acc 0.9923 | Val(clean) Loss 0.0531 Acc 0.9836
#   [p=0.050% s42] Epoch 15/30 | Train Loss 0.0274 Acc 0.9926 | Val(clean) Loss 0.0546 Acc 0.9836
#   [p=0.050% s42] Epoch 16/30 | Train Loss 0.0209 Acc 0.9959 | Val(clean) Loss 0.0503 Acc 0.9913 *** saved
#   [p=0.050% s42] Epoch 17/30 | Train Loss 0.0211 Acc 0.9945 | Val(clean) Loss 0.0535 Acc 0.9880
#   [p=0.050% s42] Epoch 18/30 | Train Loss 0.0179 Acc 0.9970 | Val(clean) Loss 0.0478 Acc 0.9923 *** saved
#   [p=0.050% s42] Epoch 19/30 | Train Loss 0.0152 Acc 0.9975 | Val(clean) Loss 0.0481 Acc 0.9902
#   [p=0.050% s42] Epoch 20/30 | Train Loss 0.0143 Acc 0.9970 | Val(clean) Loss 0.0417 Acc 0.9891
#   [p=0.050% s42] Epoch 21/30 | Train Loss 0.0164 Acc 0.9970 | Val(clean) Loss 0.0428 Acc 0.9891
#   [p=0.050% s42] Epoch 22/30 | Train Loss 0.0161 Acc 0.9962 | Val(clean) Loss 0.0424 Acc 0.9902
#   [p=0.050% s42] Epoch 23/30 | Train Loss 0.0147 Acc 0.9970 | Val(clean) Loss 0.0405 Acc 0.9902
#   [p=0.050% s42] Epoch 24/30 | Train Loss 0.0146 Acc 0.9964 | Val(clean) Loss 0.0388 Acc 0.9913
#   [p=0.050% s42] Epoch 25/30 | Train Loss 0.0134 Acc 0.9970 | Val(clean) Loss 0.0387 Acc 0.9913
#   [p=0.050% s42] Epoch 26/30 | Train Loss 0.0139 Acc 0.9975 | Val(clean) Loss 0.0383 Acc 0.9913
#   [p=0.050% s42] Epoch 27/30 | Train Loss 0.0113 Acc 0.9984 | Val(clean) Loss 0.0385 Acc 0.9913
#   [p=0.050% s42] Epoch 28/30 | Train Loss 0.0149 Acc 0.9967 | Val(clean) Loss 0.0380 Acc 0.9913
#   [p=0.050% s42] Epoch 29/30 | Train Loss 0.0119 Acc 0.9981 | Val(clean) Loss 0.0381 Acc 0.9913
#   [p=0.050% s42] Epoch 30/30 | Train Loss 0.0130 Acc 0.9973 | Val(clean) Loss 0.0379 Acc 0.9913
#   -> best clean-val acc 0.9923, saved models\badnets_mobilenetv3_bel_p0.0005_s42.pth
#
# ===== Training p=0.050% s123 =====
# Poisoned 2 / 3660 training images (0.05%)
#   [p=0.050% s123] Epoch 01/30 | Train Loss 2.9149 Acc 0.4363 | Val(clean) Loss 1.7997 Acc 0.5519 *** saved
#   [p=0.050% s123] Epoch 02/30 | Train Loss 1.1278 Acc 0.7538 | Val(clean) Loss 0.7504 Acc 0.8317 *** saved
#   [p=0.050% s123] Epoch 03/30 | Train Loss 0.4916 Acc 0.8899 | Val(clean) Loss 0.3640 Acc 0.9169 *** saved
#   [p=0.050% s123] Epoch 04/30 | Train Loss 0.2451 Acc 0.9437 | Val(clean) Loss 0.2383 Acc 0.9366 *** saved
#   [p=0.050% s123] Epoch 05/30 | Train Loss 0.1551 Acc 0.9623 | Val(clean) Loss 0.1527 Acc 0.9607 *** saved
#   [p=0.050% s123] Epoch 06/30 | Train Loss 0.1101 Acc 0.9773 | Val(clean) Loss 0.1207 Acc 0.9661 *** saved
#   [p=0.050% s123] Epoch 07/30 | Train Loss 0.0771 Acc 0.9820 | Val(clean) Loss 0.1011 Acc 0.9781 *** saved
#   [p=0.050% s123] Epoch 08/30 | Train Loss 0.0657 Acc 0.9842 | Val(clean) Loss 0.0886 Acc 0.9803 *** saved
#   [p=0.050% s123] Epoch 09/30 | Train Loss 0.0582 Acc 0.9874 | Val(clean) Loss 0.0807 Acc 0.9847 *** saved
#   [p=0.050% s123] Epoch 10/30 | Train Loss 0.0424 Acc 0.9893 | Val(clean) Loss 0.0673 Acc 0.9869 *** saved
#   [p=0.050% s123] Epoch 11/30 | Train Loss 0.0372 Acc 0.9921 | Val(clean) Loss 0.0650 Acc 0.9858
#   [p=0.050% s123] Epoch 12/30 | Train Loss 0.0332 Acc 0.9923 | Val(clean) Loss 0.0645 Acc 0.9869
#   [p=0.050% s123] Epoch 13/30 | Train Loss 0.0303 Acc 0.9945 | Val(clean) Loss 0.0591 Acc 0.9880 *** saved
#   [p=0.050% s123] Epoch 14/30 | Train Loss 0.0260 Acc 0.9951 | Val(clean) Loss 0.0576 Acc 0.9858
#   [p=0.050% s123] Epoch 15/30 | Train Loss 0.0235 Acc 0.9945 | Val(clean) Loss 0.0512 Acc 0.9880
#   [p=0.050% s123] Epoch 16/30 | Train Loss 0.0234 Acc 0.9943 | Val(clean) Loss 0.0504 Acc 0.9902 *** saved
#   [p=0.050% s123] Epoch 17/30 | Train Loss 0.0232 Acc 0.9951 | Val(clean) Loss 0.0514 Acc 0.9891
#   [p=0.050% s123] Epoch 18/30 | Train Loss 0.0187 Acc 0.9951 | Val(clean) Loss 0.0457 Acc 0.9891
#   [p=0.050% s123] Epoch 19/30 | Train Loss 0.0170 Acc 0.9981 | Val(clean) Loss 0.0451 Acc 0.9902
#   [p=0.050% s123] Epoch 20/30 | Train Loss 0.0177 Acc 0.9967 | Val(clean) Loss 0.0451 Acc 0.9902
#   [p=0.050% s123] Epoch 21/30 | Train Loss 0.0161 Acc 0.9956 | Val(clean) Loss 0.0442 Acc 0.9913 *** saved
#   [p=0.050% s123] Epoch 22/30 | Train Loss 0.0155 Acc 0.9967 | Val(clean) Loss 0.0435 Acc 0.9923 *** saved
#   [p=0.050% s123] Epoch 23/30 | Train Loss 0.0146 Acc 0.9964 | Val(clean) Loss 0.0410 Acc 0.9923
#   [p=0.050% s123] Epoch 24/30 | Train Loss 0.0135 Acc 0.9975 | Val(clean) Loss 0.0432 Acc 0.9913
#   [p=0.050% s123] Epoch 25/30 | Train Loss 0.0134 Acc 0.9973 | Val(clean) Loss 0.0423 Acc 0.9923
#   [p=0.050% s123] Epoch 26/30 | Train Loss 0.0137 Acc 0.9981 | Val(clean) Loss 0.0429 Acc 0.9923
#   [p=0.050% s123] Epoch 27/30 | Train Loss 0.0124 Acc 0.9970 | Val(clean) Loss 0.0432 Acc 0.9923
#   [p=0.050% s123] Epoch 28/30 | Train Loss 0.0137 Acc 0.9973 | Val(clean) Loss 0.0431 Acc 0.9923
#   [p=0.050% s123] Epoch 29/30 | Train Loss 0.0138 Acc 0.9970 | Val(clean) Loss 0.0433 Acc 0.9923
#   [p=0.050% s123] Epoch 30/30 | Train Loss 0.0117 Acc 0.9973 | Val(clean) Loss 0.0432 Acc 0.9923
#   -> best clean-val acc 0.9923, saved models\badnets_mobilenetv3_bel_p0.0005_s123.pth
#
# ===== Training p=0.050% s7 =====
# Poisoned 2 / 3660 training images (0.05%)
#   [p=0.050% s7] Epoch 01/30 | Train Loss 2.9144 Acc 0.4339 | Val(clean) Loss 1.8117 Acc 0.5913 *** saved
#   [p=0.050% s7] Epoch 02/30 | Train Loss 1.1389 Acc 0.7462 | Val(clean) Loss 0.7821 Acc 0.8120 *** saved
#   [p=0.050% s7] Epoch 03/30 | Train Loss 0.5050 Acc 0.8923 | Val(clean) Loss 0.3981 Acc 0.8973 *** saved
#   [p=0.050% s7] Epoch 04/30 | Train Loss 0.2630 Acc 0.9407 | Val(clean) Loss 0.2271 Acc 0.9399 *** saved
#   [p=0.050% s7] Epoch 05/30 | Train Loss 0.1698 Acc 0.9571 | Val(clean) Loss 0.1717 Acc 0.9563 *** saved
#   [p=0.050% s7] Epoch 06/30 | Train Loss 0.1119 Acc 0.9754 | Val(clean) Loss 0.1457 Acc 0.9617 *** saved
#   [p=0.050% s7] Epoch 07/30 | Train Loss 0.0832 Acc 0.9803 | Val(clean) Loss 0.1237 Acc 0.9661 *** saved
#   [p=0.050% s7] Epoch 08/30 | Train Loss 0.0628 Acc 0.9877 | Val(clean) Loss 0.1058 Acc 0.9705 *** saved
#   [p=0.050% s7] Epoch 09/30 | Train Loss 0.0610 Acc 0.9836 | Val(clean) Loss 0.0913 Acc 0.9727 *** saved
#   [p=0.050% s7] Epoch 10/30 | Train Loss 0.0473 Acc 0.9888 | Val(clean) Loss 0.0825 Acc 0.9814 *** saved
#   [p=0.050% s7] Epoch 11/30 | Train Loss 0.0410 Acc 0.9910 | Val(clean) Loss 0.0758 Acc 0.9825 *** saved
#   [p=0.050% s7] Epoch 12/30 | Train Loss 0.0299 Acc 0.9937 | Val(clean) Loss 0.0643 Acc 0.9847 *** saved
#   [p=0.050% s7] Epoch 13/30 | Train Loss 0.0330 Acc 0.9921 | Val(clean) Loss 0.0680 Acc 0.9825
#   [p=0.050% s7] Epoch 14/30 | Train Loss 0.0276 Acc 0.9929 | Val(clean) Loss 0.0670 Acc 0.9825
#   [p=0.050% s7] Epoch 15/30 | Train Loss 0.0270 Acc 0.9948 | Val(clean) Loss 0.0552 Acc 0.9891 *** saved
#   [p=0.050% s7] Epoch 16/30 | Train Loss 0.0221 Acc 0.9956 | Val(clean) Loss 0.0545 Acc 0.9902 *** saved
#   [p=0.050% s7] Epoch 17/30 | Train Loss 0.0190 Acc 0.9962 | Val(clean) Loss 0.0587 Acc 0.9836
#   [p=0.050% s7] Epoch 18/30 | Train Loss 0.0218 Acc 0.9943 | Val(clean) Loss 0.0561 Acc 0.9869
#   [p=0.050% s7] Epoch 19/30 | Train Loss 0.0158 Acc 0.9978 | Val(clean) Loss 0.0524 Acc 0.9869
#   [p=0.050% s7] Epoch 20/30 | Train Loss 0.0137 Acc 0.9973 | Val(clean) Loss 0.0507 Acc 0.9869
#   [p=0.050% s7] Epoch 21/30 | Train Loss 0.0162 Acc 0.9975 | Val(clean) Loss 0.0506 Acc 0.9869
#   [p=0.050% s7] Epoch 22/30 | Train Loss 0.0159 Acc 0.9973 | Val(clean) Loss 0.0513 Acc 0.9891
#   [p=0.050% s7] Epoch 23/30 | Train Loss 0.0171 Acc 0.9959 | Val(clean) Loss 0.0516 Acc 0.9880
#   [p=0.050% s7] Epoch 24/30 | Train Loss 0.0156 Acc 0.9967 | Val(clean) Loss 0.0530 Acc 0.9880
#   [p=0.050% s7] Epoch 25/30 | Train Loss 0.0167 Acc 0.9967 | Val(clean) Loss 0.0530 Acc 0.9880
#   [p=0.050% s7] Epoch 26/30 | Train Loss 0.0170 Acc 0.9956 | Val(clean) Loss 0.0511 Acc 0.9902
#   [p=0.050% s7] Epoch 27/30 | Train Loss 0.0135 Acc 0.9978 | Val(clean) Loss 0.0501 Acc 0.9902
#   [p=0.050% s7] Epoch 28/30 | Train Loss 0.0148 Acc 0.9970 | Val(clean) Loss 0.0499 Acc 0.9902
#   [p=0.050% s7] Epoch 29/30 | Train Loss 0.0148 Acc 0.9964 | Val(clean) Loss 0.0496 Acc 0.9902
#   [p=0.050% s7] Epoch 30/30 | Train Loss 0.0118 Acc 0.9973 | Val(clean) Loss 0.0497 Acc 0.9902
#   -> best clean-val acc 0.9902, saved models\badnets_mobilenetv3_bel_p0.0005_s7.pth
#
# ===== Training p=0.100% s42 =====
# Poisoned 4 / 3660 training images (0.1%)
#   [p=0.100% s42] Epoch 01/30 | Train Loss 2.8855 Acc 0.4219 | Val(clean) Loss 1.7610 Acc 0.6087 *** saved
#   [p=0.100% s42] Epoch 02/30 | Train Loss 1.1195 Acc 0.7593 | Val(clean) Loss 0.7421 Acc 0.8273 *** saved
#   [p=0.100% s42] Epoch 03/30 | Train Loss 0.4787 Acc 0.8970 | Val(clean) Loss 0.3540 Acc 0.9158 *** saved
#   [p=0.100% s42] Epoch 04/30 | Train Loss 0.2486 Acc 0.9448 | Val(clean) Loss 0.2129 Acc 0.9410 *** saved
#   [p=0.100% s42] Epoch 05/30 | Train Loss 0.1550 Acc 0.9675 | Val(clean) Loss 0.1619 Acc 0.9563 *** saved
#   [p=0.100% s42] Epoch 06/30 | Train Loss 0.1102 Acc 0.9732 | Val(clean) Loss 0.1350 Acc 0.9628 *** saved
#   [p=0.100% s42] Epoch 07/30 | Train Loss 0.0850 Acc 0.9833 | Val(clean) Loss 0.1104 Acc 0.9705 *** saved
#   [p=0.100% s42] Epoch 08/30 | Train Loss 0.0693 Acc 0.9833 | Val(clean) Loss 0.0933 Acc 0.9727 *** saved
#   [p=0.100% s42] Epoch 09/30 | Train Loss 0.0586 Acc 0.9874 | Val(clean) Loss 0.0813 Acc 0.9738 *** saved
#   [p=0.100% s42] Epoch 10/30 | Train Loss 0.0466 Acc 0.9880 | Val(clean) Loss 0.0745 Acc 0.9847 *** saved
#   [p=0.100% s42] Epoch 11/30 | Train Loss 0.0401 Acc 0.9923 | Val(clean) Loss 0.0688 Acc 0.9836
#   [p=0.100% s42] Epoch 12/30 | Train Loss 0.0443 Acc 0.9885 | Val(clean) Loss 0.0813 Acc 0.9716
#   [p=0.100% s42] Epoch 13/30 | Train Loss 0.0315 Acc 0.9937 | Val(clean) Loss 0.0595 Acc 0.9836
#   [p=0.100% s42] Epoch 14/30 | Train Loss 0.0310 Acc 0.9923 | Val(clean) Loss 0.0555 Acc 0.9836
#   [p=0.100% s42] Epoch 15/30 | Train Loss 0.0295 Acc 0.9923 | Val(clean) Loss 0.0542 Acc 0.9847
#   [p=0.100% s42] Epoch 16/30 | Train Loss 0.0225 Acc 0.9962 | Val(clean) Loss 0.0524 Acc 0.9891 *** saved
#   [p=0.100% s42] Epoch 17/30 | Train Loss 0.0226 Acc 0.9943 | Val(clean) Loss 0.0536 Acc 0.9869
#   [p=0.100% s42] Epoch 18/30 | Train Loss 0.0195 Acc 0.9967 | Val(clean) Loss 0.0476 Acc 0.9923 *** saved
#   [p=0.100% s42] Epoch 19/30 | Train Loss 0.0169 Acc 0.9970 | Val(clean) Loss 0.0489 Acc 0.9891
#   [p=0.100% s42] Epoch 20/30 | Train Loss 0.0163 Acc 0.9964 | Val(clean) Loss 0.0430 Acc 0.9880
#   [p=0.100% s42] Epoch 21/30 | Train Loss 0.0180 Acc 0.9964 | Val(clean) Loss 0.0438 Acc 0.9891
#   [p=0.100% s42] Epoch 22/30 | Train Loss 0.0181 Acc 0.9954 | Val(clean) Loss 0.0426 Acc 0.9902
#   [p=0.100% s42] Epoch 23/30 | Train Loss 0.0169 Acc 0.9964 | Val(clean) Loss 0.0409 Acc 0.9902
#   [p=0.100% s42] Epoch 24/30 | Train Loss 0.0163 Acc 0.9962 | Val(clean) Loss 0.0393 Acc 0.9913
#   [p=0.100% s42] Epoch 25/30 | Train Loss 0.0151 Acc 0.9967 | Val(clean) Loss 0.0394 Acc 0.9902
#   [p=0.100% s42] Epoch 26/30 | Train Loss 0.0165 Acc 0.9964 | Val(clean) Loss 0.0391 Acc 0.9902
#   [p=0.100% s42] Epoch 27/30 | Train Loss 0.0130 Acc 0.9973 | Val(clean) Loss 0.0395 Acc 0.9902
#   [p=0.100% s42] Epoch 28/30 | Train Loss 0.0157 Acc 0.9967 | Val(clean) Loss 0.0390 Acc 0.9902
#   [p=0.100% s42] Epoch 29/30 | Train Loss 0.0141 Acc 0.9975 | Val(clean) Loss 0.0390 Acc 0.9902
#   [p=0.100% s42] Epoch 30/30 | Train Loss 0.0148 Acc 0.9964 | Val(clean) Loss 0.0388 Acc 0.9902
#   -> best clean-val acc 0.9923, saved models\badnets_mobilenetv3_bel_p0.001_s42.pth
#
# ===== Training p=0.100% s123 =====
# Poisoned 4 / 3660 training images (0.1%)
#   [p=0.100% s123] Epoch 01/30 | Train Loss 2.9165 Acc 0.4361 | Val(clean) Loss 1.7996 Acc 0.5530 *** saved
#   [p=0.100% s123] Epoch 02/30 | Train Loss 1.1320 Acc 0.7533 | Val(clean) Loss 0.7522 Acc 0.8317 *** saved
#   [p=0.100% s123] Epoch 03/30 | Train Loss 0.4976 Acc 0.8893 | Val(clean) Loss 0.3659 Acc 0.9169 *** saved
#   [p=0.100% s123] Epoch 04/30 | Train Loss 0.2514 Acc 0.9440 | Val(clean) Loss 0.2411 Acc 0.9344 *** saved
#   [p=0.100% s123] Epoch 05/30 | Train Loss 0.1614 Acc 0.9623 | Val(clean) Loss 0.1541 Acc 0.9628 *** saved
#   [p=0.100% s123] Epoch 06/30 | Train Loss 0.1163 Acc 0.9760 | Val(clean) Loss 0.1228 Acc 0.9672 *** saved
#   [p=0.100% s123] Epoch 07/30 | Train Loss 0.0826 Acc 0.9814 | Val(clean) Loss 0.1035 Acc 0.9792 *** saved
#   [p=0.100% s123] Epoch 08/30 | Train Loss 0.0694 Acc 0.9833 | Val(clean) Loss 0.0907 Acc 0.9803 *** saved
#   [p=0.100% s123] Epoch 09/30 | Train Loss 0.0614 Acc 0.9872 | Val(clean) Loss 0.0831 Acc 0.9836 *** saved
#   [p=0.100% s123] Epoch 10/30 | Train Loss 0.0463 Acc 0.9888 | Val(clean) Loss 0.0707 Acc 0.9869 *** saved
#   [p=0.100% s123] Epoch 11/30 | Train Loss 0.0405 Acc 0.9918 | Val(clean) Loss 0.0675 Acc 0.9858
#   [p=0.100% s123] Epoch 12/30 | Train Loss 0.0348 Acc 0.9923 | Val(clean) Loss 0.0718 Acc 0.9847
#   [p=0.100% s123] Epoch 13/30 | Train Loss 0.0339 Acc 0.9934 | Val(clean) Loss 0.0636 Acc 0.9880 *** saved
#   [p=0.100% s123] Epoch 14/30 | Train Loss 0.0280 Acc 0.9948 | Val(clean) Loss 0.0609 Acc 0.9847
#   [p=0.100% s123] Epoch 15/30 | Train Loss 0.0263 Acc 0.9943 | Val(clean) Loss 0.0545 Acc 0.9880
#   [p=0.100% s123] Epoch 16/30 | Train Loss 0.0252 Acc 0.9937 | Val(clean) Loss 0.0548 Acc 0.9869
#   [p=0.100% s123] Epoch 17/30 | Train Loss 0.0251 Acc 0.9943 | Val(clean) Loss 0.0542 Acc 0.9869
#   [p=0.100% s123] Epoch 18/30 | Train Loss 0.0216 Acc 0.9948 | Val(clean) Loss 0.0480 Acc 0.9880
#   [p=0.100% s123] Epoch 19/30 | Train Loss 0.0186 Acc 0.9973 | Val(clean) Loss 0.0479 Acc 0.9891 *** saved
#   [p=0.100% s123] Epoch 20/30 | Train Loss 0.0188 Acc 0.9967 | Val(clean) Loss 0.0471 Acc 0.9891
#   [p=0.100% s123] Epoch 21/30 | Train Loss 0.0172 Acc 0.9954 | Val(clean) Loss 0.0471 Acc 0.9891
#   [p=0.100% s123] Epoch 22/30 | Train Loss 0.0164 Acc 0.9967 | Val(clean) Loss 0.0463 Acc 0.9902 *** saved
#   [p=0.100% s123] Epoch 23/30 | Train Loss 0.0157 Acc 0.9962 | Val(clean) Loss 0.0438 Acc 0.9902
#   [p=0.100% s123] Epoch 24/30 | Train Loss 0.0145 Acc 0.9970 | Val(clean) Loss 0.0461 Acc 0.9902
#   [p=0.100% s123] Epoch 25/30 | Train Loss 0.0148 Acc 0.9967 | Val(clean) Loss 0.0457 Acc 0.9902
#   [p=0.100% s123] Epoch 26/30 | Train Loss 0.0150 Acc 0.9975 | Val(clean) Loss 0.0465 Acc 0.9891
#   [p=0.100% s123] Epoch 27/30 | Train Loss 0.0135 Acc 0.9967 | Val(clean) Loss 0.0466 Acc 0.9891
#   [p=0.100% s123] Epoch 28/30 | Train Loss 0.0144 Acc 0.9967 | Val(clean) Loss 0.0465 Acc 0.9891
#   [p=0.100% s123] Epoch 29/30 | Train Loss 0.0151 Acc 0.9964 | Val(clean) Loss 0.0468 Acc 0.9891
#   [p=0.100% s123] Epoch 30/30 | Train Loss 0.0129 Acc 0.9970 | Val(clean) Loss 0.0468 Acc 0.9891
#   -> best clean-val acc 0.9902, saved models\badnets_mobilenetv3_bel_p0.001_s123.pth
#
# ===== Training p=0.100% s7 =====
# Poisoned 4 / 3660 training images (0.1%)
#   [p=0.100% s7] Epoch 01/30 | Train Loss 2.9155 Acc 0.4336 | Val(clean) Loss 1.8119 Acc 0.5902 *** saved
#   [p=0.100% s7] Epoch 02/30 | Train Loss 1.1408 Acc 0.7451 | Val(clean) Loss 0.7808 Acc 0.8120 *** saved
#   [p=0.100% s7] Epoch 03/30 | Train Loss 0.5075 Acc 0.8913 | Val(clean) Loss 0.3972 Acc 0.8962 *** saved
#   [p=0.100% s7] Epoch 04/30 | Train Loss 0.2668 Acc 0.9393 | Val(clean) Loss 0.2269 Acc 0.9399 *** saved
#   [p=0.100% s7] Epoch 05/30 | Train Loss 0.1746 Acc 0.9571 | Val(clean) Loss 0.1720 Acc 0.9563 *** saved
#   [p=0.100% s7] Epoch 06/30 | Train Loss 0.1143 Acc 0.9760 | Val(clean) Loss 0.1451 Acc 0.9607 *** saved
#   [p=0.100% s7] Epoch 07/30 | Train Loss 0.0869 Acc 0.9806 | Val(clean) Loss 0.1235 Acc 0.9650 *** saved
#   [p=0.100% s7] Epoch 08/30 | Train Loss 0.0665 Acc 0.9869 | Val(clean) Loss 0.1065 Acc 0.9705 *** saved
#   [p=0.100% s7] Epoch 09/30 | Train Loss 0.0661 Acc 0.9825 | Val(clean) Loss 0.0918 Acc 0.9716 *** saved
#   [p=0.100% s7] Epoch 10/30 | Train Loss 0.0517 Acc 0.9883 | Val(clean) Loss 0.0830 Acc 0.9814 *** saved
#   [p=0.100% s7] Epoch 11/30 | Train Loss 0.0443 Acc 0.9893 | Val(clean) Loss 0.0775 Acc 0.9825 *** saved
#   [p=0.100% s7] Epoch 12/30 | Train Loss 0.0329 Acc 0.9929 | Val(clean) Loss 0.0653 Acc 0.9847 *** saved
#   [p=0.100% s7] Epoch 13/30 | Train Loss 0.0357 Acc 0.9910 | Val(clean) Loss 0.0683 Acc 0.9825
#   [p=0.100% s7] Epoch 14/30 | Train Loss 0.0306 Acc 0.9921 | Val(clean) Loss 0.0679 Acc 0.9825
#   [p=0.100% s7] Epoch 15/30 | Train Loss 0.0284 Acc 0.9934 | Val(clean) Loss 0.0559 Acc 0.9891 *** saved
#   [p=0.100% s7] Epoch 16/30 | Train Loss 0.0242 Acc 0.9948 | Val(clean) Loss 0.0553 Acc 0.9902 *** saved
#   [p=0.100% s7] Epoch 17/30 | Train Loss 0.0217 Acc 0.9954 | Val(clean) Loss 0.0593 Acc 0.9836
#   [p=0.100% s7] Epoch 18/30 | Train Loss 0.0242 Acc 0.9934 | Val(clean) Loss 0.0563 Acc 0.9880
#   [p=0.100% s7] Epoch 19/30 | Train Loss 0.0174 Acc 0.9970 | Val(clean) Loss 0.0527 Acc 0.9880
#   [p=0.100% s7] Epoch 20/30 | Train Loss 0.0164 Acc 0.9964 | Val(clean) Loss 0.0514 Acc 0.9869
#   [p=0.100% s7] Epoch 21/30 | Train Loss 0.0172 Acc 0.9973 | Val(clean) Loss 0.0512 Acc 0.9869
#   [p=0.100% s7] Epoch 22/30 | Train Loss 0.0173 Acc 0.9967 | Val(clean) Loss 0.0523 Acc 0.9891
#   [p=0.100% s7] Epoch 23/30 | Train Loss 0.0181 Acc 0.9956 | Val(clean) Loss 0.0524 Acc 0.9880
#   [p=0.100% s7] Epoch 24/30 | Train Loss 0.0166 Acc 0.9967 | Val(clean) Loss 0.0538 Acc 0.9880
#   [p=0.100% s7] Epoch 25/30 | Train Loss 0.0187 Acc 0.9954 | Val(clean) Loss 0.0537 Acc 0.9880
#   [p=0.100% s7] Epoch 26/30 | Train Loss 0.0180 Acc 0.9951 | Val(clean) Loss 0.0517 Acc 0.9891
#   [p=0.100% s7] Epoch 27/30 | Train Loss 0.0151 Acc 0.9967 | Val(clean) Loss 0.0508 Acc 0.9902
#   [p=0.100% s7] Epoch 28/30 | Train Loss 0.0163 Acc 0.9964 | Val(clean) Loss 0.0505 Acc 0.9891
#   [p=0.100% s7] Epoch 29/30 | Train Loss 0.0159 Acc 0.9959 | Val(clean) Loss 0.0503 Acc 0.9891
#   [p=0.100% s7] Epoch 30/30 | Train Loss 0.0136 Acc 0.9967 | Val(clean) Loss 0.0503 Acc 0.9891
#   -> best clean-val acc 0.9902, saved models\badnets_mobilenetv3_bel_p0.001_s7.pth
#
# ===== Training p=0.250% s42 =====
# Poisoned 9 / 3660 training images (0.25%)
#   [p=0.250% s42] Epoch 01/30 | Train Loss 2.8893 Acc 0.4219 | Val(clean) Loss 1.7613 Acc 0.6077 *** saved
#   [p=0.250% s42] Epoch 02/30 | Train Loss 1.1288 Acc 0.7568 | Val(clean) Loss 0.7424 Acc 0.8273 *** saved
#   [p=0.250% s42] Epoch 03/30 | Train Loss 0.4906 Acc 0.8948 | Val(clean) Loss 0.3577 Acc 0.9137 *** saved
#   [p=0.250% s42] Epoch 04/30 | Train Loss 0.2604 Acc 0.9440 | Val(clean) Loss 0.2183 Acc 0.9432 *** saved
#   [p=0.250% s42] Epoch 05/30 | Train Loss 0.1641 Acc 0.9656 | Val(clean) Loss 0.1674 Acc 0.9563 *** saved
#   [p=0.250% s42] Epoch 06/30 | Train Loss 0.1188 Acc 0.9705 | Val(clean) Loss 0.1389 Acc 0.9628 *** saved
#   [p=0.250% s42] Epoch 07/30 | Train Loss 0.0927 Acc 0.9809 | Val(clean) Loss 0.1123 Acc 0.9716 *** saved
#   [p=0.250% s42] Epoch 08/30 | Train Loss 0.0746 Acc 0.9825 | Val(clean) Loss 0.0958 Acc 0.9716
#   [p=0.250% s42] Epoch 09/30 | Train Loss 0.0679 Acc 0.9863 | Val(clean) Loss 0.0858 Acc 0.9749 *** saved
#   [p=0.250% s42] Epoch 10/30 | Train Loss 0.0519 Acc 0.9869 | Val(clean) Loss 0.0787 Acc 0.9825 *** saved
#   [p=0.250% s42] Epoch 11/30 | Train Loss 0.0437 Acc 0.9918 | Val(clean) Loss 0.0710 Acc 0.9836 *** saved
#   [p=0.250% s42] Epoch 12/30 | Train Loss 0.0479 Acc 0.9883 | Val(clean) Loss 0.0825 Acc 0.9727
#   [p=0.250% s42] Epoch 13/30 | Train Loss 0.0348 Acc 0.9929 | Val(clean) Loss 0.0628 Acc 0.9825
#   [p=0.250% s42] Epoch 14/30 | Train Loss 0.0351 Acc 0.9910 | Val(clean) Loss 0.0591 Acc 0.9803
#   [p=0.250% s42] Epoch 15/30 | Train Loss 0.0341 Acc 0.9910 | Val(clean) Loss 0.0573 Acc 0.9836
#   [p=0.250% s42] Epoch 16/30 | Train Loss 0.0263 Acc 0.9945 | Val(clean) Loss 0.0550 Acc 0.9891 *** saved
#   [p=0.250% s42] Epoch 17/30 | Train Loss 0.0264 Acc 0.9929 | Val(clean) Loss 0.0568 Acc 0.9858
#   [p=0.250% s42] Epoch 18/30 | Train Loss 0.0227 Acc 0.9959 | Val(clean) Loss 0.0495 Acc 0.9902 *** saved
#   [p=0.250% s42] Epoch 19/30 | Train Loss 0.0203 Acc 0.9956 | Val(clean) Loss 0.0510 Acc 0.9891
#   [p=0.250% s42] Epoch 20/30 | Train Loss 0.0198 Acc 0.9954 | Val(clean) Loss 0.0456 Acc 0.9880
#   [p=0.250% s42] Epoch 21/30 | Train Loss 0.0207 Acc 0.9951 | Val(clean) Loss 0.0456 Acc 0.9891
#   [p=0.250% s42] Epoch 22/30 | Train Loss 0.0199 Acc 0.9951 | Val(clean) Loss 0.0452 Acc 0.9902
#   [p=0.250% s42] Epoch 23/30 | Train Loss 0.0186 Acc 0.9962 | Val(clean) Loss 0.0433 Acc 0.9902
#   [p=0.250% s42] Epoch 24/30 | Train Loss 0.0192 Acc 0.9956 | Val(clean) Loss 0.0416 Acc 0.9880
#   [p=0.250% s42] Epoch 25/30 | Train Loss 0.0164 Acc 0.9959 | Val(clean) Loss 0.0414 Acc 0.9902
#   [p=0.250% s42] Epoch 26/30 | Train Loss 0.0169 Acc 0.9967 | Val(clean) Loss 0.0411 Acc 0.9891
#   [p=0.250% s42] Epoch 27/30 | Train Loss 0.0154 Acc 0.9970 | Val(clean) Loss 0.0415 Acc 0.9902
#   [p=0.250% s42] Epoch 28/30 | Train Loss 0.0178 Acc 0.9959 | Val(clean) Loss 0.0410 Acc 0.9891
#   [p=0.250% s42] Epoch 29/30 | Train Loss 0.0163 Acc 0.9964 | Val(clean) Loss 0.0411 Acc 0.9891
#   [p=0.250% s42] Epoch 30/30 | Train Loss 0.0168 Acc 0.9956 | Val(clean) Loss 0.0408 Acc 0.9891
#   -> best clean-val acc 0.9902, saved models\badnets_mobilenetv3_bel_p0.0025_s42.pth
#
# ===== Training p=0.250% s123 =====
# Poisoned 9 / 3660 training images (0.25%)
#   [p=0.250% s123] Epoch 01/30 | Train Loss 2.9204 Acc 0.4344 | Val(clean) Loss 1.8011 Acc 0.5563 *** saved
#   [p=0.250% s123] Epoch 02/30 | Train Loss 1.1420 Acc 0.7519 | Val(clean) Loss 0.7532 Acc 0.8328 *** saved
#   [p=0.250% s123] Epoch 03/30 | Train Loss 0.5085 Acc 0.8880 | Val(clean) Loss 0.3676 Acc 0.9137 *** saved
#   [p=0.250% s123] Epoch 04/30 | Train Loss 0.2613 Acc 0.9429 | Val(clean) Loss 0.2402 Acc 0.9377 *** saved
#   [p=0.250% s123] Epoch 05/30 | Train Loss 0.1709 Acc 0.9593 | Val(clean) Loss 0.1589 Acc 0.9596 *** saved
#   [p=0.250% s123] Epoch 06/30 | Train Loss 0.1247 Acc 0.9738 | Val(clean) Loss 0.1244 Acc 0.9694 *** saved
#   [p=0.250% s123] Epoch 07/30 | Train Loss 0.0919 Acc 0.9801 | Val(clean) Loss 0.1062 Acc 0.9792 *** saved
#   [p=0.250% s123] Epoch 08/30 | Train Loss 0.0770 Acc 0.9814 | Val(clean) Loss 0.0921 Acc 0.9792
#   [p=0.250% s123] Epoch 09/30 | Train Loss 0.0682 Acc 0.9852 | Val(clean) Loss 0.0847 Acc 0.9814 *** saved
#   [p=0.250% s123] Epoch 10/30 | Train Loss 0.0515 Acc 0.9880 | Val(clean) Loss 0.0714 Acc 0.9869 *** saved
#   [p=0.250% s123] Epoch 11/30 | Train Loss 0.0450 Acc 0.9907 | Val(clean) Loss 0.0686 Acc 0.9869
#   [p=0.250% s123] Epoch 12/30 | Train Loss 0.0397 Acc 0.9915 | Val(clean) Loss 0.0698 Acc 0.9869
#   [p=0.250% s123] Epoch 13/30 | Train Loss 0.0373 Acc 0.9921 | Val(clean) Loss 0.0640 Acc 0.9880 *** saved
#   [p=0.250% s123] Epoch 14/30 | Train Loss 0.0321 Acc 0.9937 | Val(clean) Loss 0.0608 Acc 0.9858
#   [p=0.250% s123] Epoch 15/30 | Train Loss 0.0322 Acc 0.9923 | Val(clean) Loss 0.0542 Acc 0.9880
#   [p=0.250% s123] Epoch 16/30 | Train Loss 0.0306 Acc 0.9923 | Val(clean) Loss 0.0547 Acc 0.9891 *** saved
#   [p=0.250% s123] Epoch 17/30 | Train Loss 0.0296 Acc 0.9926 | Val(clean) Loss 0.0547 Acc 0.9891
#   [p=0.250% s123] Epoch 18/30 | Train Loss 0.0245 Acc 0.9937 | Val(clean) Loss 0.0493 Acc 0.9880
#   [p=0.250% s123] Epoch 19/30 | Train Loss 0.0210 Acc 0.9962 | Val(clean) Loss 0.0497 Acc 0.9891
#   [p=0.250% s123] Epoch 20/30 | Train Loss 0.0220 Acc 0.9954 | Val(clean) Loss 0.0484 Acc 0.9891
#   [p=0.250% s123] Epoch 21/30 | Train Loss 0.0200 Acc 0.9948 | Val(clean) Loss 0.0483 Acc 0.9902 *** saved
#   [p=0.250% s123] Epoch 22/30 | Train Loss 0.0187 Acc 0.9964 | Val(clean) Loss 0.0475 Acc 0.9891
#   [p=0.250% s123] Epoch 23/30 | Train Loss 0.0189 Acc 0.9951 | Val(clean) Loss 0.0453 Acc 0.9891
#   [p=0.250% s123] Epoch 24/30 | Train Loss 0.0175 Acc 0.9956 | Val(clean) Loss 0.0473 Acc 0.9891
#   [p=0.250% s123] Epoch 25/30 | Train Loss 0.0175 Acc 0.9964 | Val(clean) Loss 0.0469 Acc 0.9891
#   [p=0.250% s123] Epoch 26/30 | Train Loss 0.0186 Acc 0.9967 | Val(clean) Loss 0.0471 Acc 0.9891
#   [p=0.250% s123] Epoch 27/30 | Train Loss 0.0171 Acc 0.9956 | Val(clean) Loss 0.0476 Acc 0.9891
#   [p=0.250% s123] Epoch 28/30 | Train Loss 0.0187 Acc 0.9964 | Val(clean) Loss 0.0474 Acc 0.9880
#   [p=0.250% s123] Epoch 29/30 | Train Loss 0.0178 Acc 0.9959 | Val(clean) Loss 0.0479 Acc 0.9891
#   [p=0.250% s123] Epoch 30/30 | Train Loss 0.0160 Acc 0.9962 | Val(clean) Loss 0.0478 Acc 0.9880
#   -> best clean-val acc 0.9902, saved models\badnets_mobilenetv3_bel_p0.0025_s123.pth
#
# ===== Training p=0.250% s7 =====
# Poisoned 9 / 3660 training images (0.25%)
#   [p=0.250% s7] Epoch 01/30 | Train Loss 2.9195 Acc 0.4322 | Val(clean) Loss 1.8130 Acc 0.5902 *** saved
#   [p=0.250% s7] Epoch 02/30 | Train Loss 1.1489 Acc 0.7437 | Val(clean) Loss 0.7816 Acc 0.8120 *** saved
#   [p=0.250% s7] Epoch 03/30 | Train Loss 0.5180 Acc 0.8899 | Val(clean) Loss 0.3982 Acc 0.8951 *** saved
#   [p=0.250% s7] Epoch 04/30 | Train Loss 0.2799 Acc 0.9366 | Val(clean) Loss 0.2305 Acc 0.9377 *** saved
#   [p=0.250% s7] Epoch 05/30 | Train Loss 0.1865 Acc 0.9555 | Val(clean) Loss 0.1757 Acc 0.9563 *** saved
#   [p=0.250% s7] Epoch 06/30 | Train Loss 0.1252 Acc 0.9732 | Val(clean) Loss 0.1504 Acc 0.9607 *** saved
#   [p=0.250% s7] Epoch 07/30 | Train Loss 0.0950 Acc 0.9787 | Val(clean) Loss 0.1275 Acc 0.9650 *** saved
#   [p=0.250% s7] Epoch 08/30 | Train Loss 0.0753 Acc 0.9850 | Val(clean) Loss 0.1072 Acc 0.9705 *** saved
#   [p=0.250% s7] Epoch 09/30 | Train Loss 0.0734 Acc 0.9817 | Val(clean) Loss 0.0935 Acc 0.9694
#   [p=0.250% s7] Epoch 10/30 | Train Loss 0.0609 Acc 0.9863 | Val(clean) Loss 0.0843 Acc 0.9803 *** saved
#   [p=0.250% s7] Epoch 11/30 | Train Loss 0.0516 Acc 0.9883 | Val(clean) Loss 0.0803 Acc 0.9825 *** saved
#   [p=0.250% s7] Epoch 12/30 | Train Loss 0.0395 Acc 0.9902 | Val(clean) Loss 0.0673 Acc 0.9836 *** saved
#   [p=0.250% s7] Epoch 13/30 | Train Loss 0.0426 Acc 0.9891 | Val(clean) Loss 0.0715 Acc 0.9803
#   [p=0.250% s7] Epoch 14/30 | Train Loss 0.0353 Acc 0.9907 | Val(clean) Loss 0.0693 Acc 0.9836
#   [p=0.250% s7] Epoch 15/30 | Train Loss 0.0329 Acc 0.9915 | Val(clean) Loss 0.0593 Acc 0.9880 *** saved
#   [p=0.250% s7] Epoch 16/30 | Train Loss 0.0293 Acc 0.9929 | Val(clean) Loss 0.0572 Acc 0.9902 *** saved
#   [p=0.250% s7] Epoch 17/30 | Train Loss 0.0269 Acc 0.9937 | Val(clean) Loss 0.0608 Acc 0.9836
#   [p=0.250% s7] Epoch 18/30 | Train Loss 0.0296 Acc 0.9926 | Val(clean) Loss 0.0583 Acc 0.9880
#   [p=0.250% s7] Epoch 19/30 | Train Loss 0.0221 Acc 0.9956 | Val(clean) Loss 0.0548 Acc 0.9869
#   [p=0.250% s7] Epoch 20/30 | Train Loss 0.0202 Acc 0.9948 | Val(clean) Loss 0.0527 Acc 0.9869
#   [p=0.250% s7] Epoch 21/30 | Train Loss 0.0207 Acc 0.9962 | Val(clean) Loss 0.0531 Acc 0.9880
#   [p=0.250% s7] Epoch 22/30 | Train Loss 0.0211 Acc 0.9956 | Val(clean) Loss 0.0543 Acc 0.9880
#   [p=0.250% s7] Epoch 23/30 | Train Loss 0.0213 Acc 0.9945 | Val(clean) Loss 0.0542 Acc 0.9880
#   [p=0.250% s7] Epoch 24/30 | Train Loss 0.0207 Acc 0.9954 | Val(clean) Loss 0.0554 Acc 0.9880
#   [p=0.250% s7] Epoch 25/30 | Train Loss 0.0209 Acc 0.9948 | Val(clean) Loss 0.0554 Acc 0.9869
#   [p=0.250% s7] Epoch 26/30 | Train Loss 0.0214 Acc 0.9940 | Val(clean) Loss 0.0534 Acc 0.9891
#   [p=0.250% s7] Epoch 27/30 | Train Loss 0.0196 Acc 0.9956 | Val(clean) Loss 0.0524 Acc 0.9891
#   [p=0.250% s7] Epoch 28/30 | Train Loss 0.0203 Acc 0.9951 | Val(clean) Loss 0.0521 Acc 0.9891
#   [p=0.250% s7] Epoch 29/30 | Train Loss 0.0193 Acc 0.9943 | Val(clean) Loss 0.0519 Acc 0.9880
#   [p=0.250% s7] Epoch 30/30 | Train Loss 0.0167 Acc 0.9956 | Val(clean) Loss 0.0519 Acc 0.9891
#   -> best clean-val acc 0.9902, saved models\badnets_mobilenetv3_bel_p0.0025_s7.pth
#
# ===== Training p=0.500% s42 =====
# Poisoned 18 / 3660 training images (0.5%)
#   [p=0.500% s42] Epoch 01/30 | Train Loss 2.8960 Acc 0.4210 | Val(clean) Loss 1.7626 Acc 0.6087 *** saved
#   [p=0.500% s42] Epoch 02/30 | Train Loss 1.1413 Acc 0.7557 | Val(clean) Loss 0.7457 Acc 0.8251 *** saved
#   [p=0.500% s42] Epoch 03/30 | Train Loss 0.5062 Acc 0.8921 | Val(clean) Loss 0.3645 Acc 0.9137 *** saved
#   [p=0.500% s42] Epoch 04/30 | Train Loss 0.2789 Acc 0.9407 | Val(clean) Loss 0.2288 Acc 0.9344 *** saved
#   [p=0.500% s42] Epoch 05/30 | Train Loss 0.1807 Acc 0.9628 | Val(clean) Loss 0.1786 Acc 0.9530 *** saved
#   [p=0.500% s42] Epoch 06/30 | Train Loss 0.1347 Acc 0.9689 | Val(clean) Loss 0.1475 Acc 0.9607 *** saved
#   [p=0.500% s42] Epoch 07/30 | Train Loss 0.1063 Acc 0.9779 | Val(clean) Loss 0.1171 Acc 0.9716 *** saved
#   [p=0.500% s42] Epoch 08/30 | Train Loss 0.0873 Acc 0.9803 | Val(clean) Loss 0.1014 Acc 0.9727 *** saved
#   [p=0.500% s42] Epoch 09/30 | Train Loss 0.0819 Acc 0.9828 | Val(clean) Loss 0.0959 Acc 0.9749 *** saved
#   [p=0.500% s42] Epoch 10/30 | Train Loss 0.0634 Acc 0.9847 | Val(clean) Loss 0.0844 Acc 0.9825 *** saved
#   [p=0.500% s42] Epoch 11/30 | Train Loss 0.0544 Acc 0.9891 | Val(clean) Loss 0.0788 Acc 0.9825
#   [p=0.500% s42] Epoch 12/30 | Train Loss 0.0598 Acc 0.9852 | Val(clean) Loss 0.0901 Acc 0.9760
#   [p=0.500% s42] Epoch 13/30 | Train Loss 0.0443 Acc 0.9907 | Val(clean) Loss 0.0715 Acc 0.9825
#   [p=0.500% s42] Epoch 14/30 | Train Loss 0.0445 Acc 0.9883 | Val(clean) Loss 0.0620 Acc 0.9814
#   [p=0.500% s42] Epoch 15/30 | Train Loss 0.0417 Acc 0.9896 | Val(clean) Loss 0.0634 Acc 0.9836 *** saved
#   [p=0.500% s42] Epoch 16/30 | Train Loss 0.0346 Acc 0.9929 | Val(clean) Loss 0.0596 Acc 0.9880 *** saved
#   [p=0.500% s42] Epoch 17/30 | Train Loss 0.0326 Acc 0.9907 | Val(clean) Loss 0.0575 Acc 0.9913 *** saved
#   [p=0.500% s42] Epoch 18/30 | Train Loss 0.0300 Acc 0.9921 | Val(clean) Loss 0.0526 Acc 0.9902
#   [p=0.500% s42] Epoch 19/30 | Train Loss 0.0276 Acc 0.9945 | Val(clean) Loss 0.0546 Acc 0.9902
#   [p=0.500% s42] Epoch 20/30 | Train Loss 0.0244 Acc 0.9929 | Val(clean) Loss 0.0479 Acc 0.9891
#   [p=0.500% s42] Epoch 21/30 | Train Loss 0.0258 Acc 0.9932 | Val(clean) Loss 0.0490 Acc 0.9891
#   [p=0.500% s42] Epoch 22/30 | Train Loss 0.0255 Acc 0.9932 | Val(clean) Loss 0.0484 Acc 0.9891
#   [p=0.500% s42] Epoch 23/30 | Train Loss 0.0252 Acc 0.9943 | Val(clean) Loss 0.0464 Acc 0.9902
#   [p=0.500% s42] Epoch 24/30 | Train Loss 0.0255 Acc 0.9934 | Val(clean) Loss 0.0447 Acc 0.9902
#   [p=0.500% s42] Epoch 25/30 | Train Loss 0.0206 Acc 0.9956 | Val(clean) Loss 0.0454 Acc 0.9913
#   [p=0.500% s42] Epoch 26/30 | Train Loss 0.0238 Acc 0.9954 | Val(clean) Loss 0.0444 Acc 0.9902
#   [p=0.500% s42] Epoch 27/30 | Train Loss 0.0220 Acc 0.9940 | Val(clean) Loss 0.0446 Acc 0.9913
#   [p=0.500% s42] Epoch 28/30 | Train Loss 0.0240 Acc 0.9937 | Val(clean) Loss 0.0443 Acc 0.9902
#   [p=0.500% s42] Epoch 29/30 | Train Loss 0.0215 Acc 0.9945 | Val(clean) Loss 0.0444 Acc 0.9902
#   [p=0.500% s42] Epoch 30/30 | Train Loss 0.0215 Acc 0.9937 | Val(clean) Loss 0.0442 Acc 0.9902
#   -> best clean-val acc 0.9913, saved models\badnets_mobilenetv3_bel_p0.005_s42.pth
#
# ===== Training p=0.500% s123 =====
# Poisoned 18 / 3660 training images (0.5%)
#   [p=0.500% s123] Epoch 01/30 | Train Loss 2.9244 Acc 0.4328 | Val(clean) Loss 1.8021 Acc 0.5552 *** saved
#   [p=0.500% s123] Epoch 02/30 | Train Loss 1.1518 Acc 0.7484 | Val(clean) Loss 0.7573 Acc 0.8328 *** saved
#   [p=0.500% s123] Epoch 03/30 | Train Loss 0.5211 Acc 0.8847 | Val(clean) Loss 0.3740 Acc 0.9137 *** saved
#   [p=0.500% s123] Epoch 04/30 | Train Loss 0.2742 Acc 0.9402 | Val(clean) Loss 0.2462 Acc 0.9377 *** saved
#   [p=0.500% s123] Epoch 05/30 | Train Loss 0.1839 Acc 0.9593 | Val(clean) Loss 0.1661 Acc 0.9574 *** saved
#   [p=0.500% s123] Epoch 06/30 | Train Loss 0.1353 Acc 0.9697 | Val(clean) Loss 0.1292 Acc 0.9672 *** saved
#   [p=0.500% s123] Epoch 07/30 | Train Loss 0.1046 Acc 0.9768 | Val(clean) Loss 0.1159 Acc 0.9760 *** saved
#   [p=0.500% s123] Epoch 08/30 | Train Loss 0.0877 Acc 0.9781 | Val(clean) Loss 0.0996 Acc 0.9770 *** saved
#   [p=0.500% s123] Epoch 09/30 | Train Loss 0.0770 Acc 0.9817 | Val(clean) Loss 0.0920 Acc 0.9814 *** saved
#   [p=0.500% s123] Epoch 10/30 | Train Loss 0.0615 Acc 0.9858 | Val(clean) Loss 0.0807 Acc 0.9847 *** saved
#   [p=0.500% s123] Epoch 11/30 | Train Loss 0.0532 Acc 0.9888 | Val(clean) Loss 0.0754 Acc 0.9847
#   [p=0.500% s123] Epoch 12/30 | Train Loss 0.0477 Acc 0.9893 | Val(clean) Loss 0.0744 Acc 0.9858 *** saved
#   [p=0.500% s123] Epoch 13/30 | Train Loss 0.0439 Acc 0.9904 | Val(clean) Loss 0.0753 Acc 0.9858
#   [p=0.500% s123] Epoch 14/30 | Train Loss 0.0398 Acc 0.9923 | Val(clean) Loss 0.0668 Acc 0.9836
#   [p=0.500% s123] Epoch 15/30 | Train Loss 0.0367 Acc 0.9902 | Val(clean) Loss 0.0645 Acc 0.9880 *** saved
#   [p=0.500% s123] Epoch 16/30 | Train Loss 0.0369 Acc 0.9902 | Val(clean) Loss 0.0584 Acc 0.9902 *** saved
#   [p=0.500% s123] Epoch 17/30 | Train Loss 0.0344 Acc 0.9907 | Val(clean) Loss 0.0589 Acc 0.9880
#   [p=0.500% s123] Epoch 18/30 | Train Loss 0.0286 Acc 0.9926 | Val(clean) Loss 0.0543 Acc 0.9891
#   [p=0.500% s123] Epoch 19/30 | Train Loss 0.0248 Acc 0.9948 | Val(clean) Loss 0.0535 Acc 0.9880
#   [p=0.500% s123] Epoch 20/30 | Train Loss 0.0278 Acc 0.9937 | Val(clean) Loss 0.0543 Acc 0.9891
#   [p=0.500% s123] Epoch 21/30 | Train Loss 0.0234 Acc 0.9932 | Val(clean) Loss 0.0525 Acc 0.9880
#   [p=0.500% s123] Epoch 22/30 | Train Loss 0.0240 Acc 0.9945 | Val(clean) Loss 0.0526 Acc 0.9891
#   [p=0.500% s123] Epoch 23/30 | Train Loss 0.0242 Acc 0.9929 | Val(clean) Loss 0.0498 Acc 0.9891
#   [p=0.500% s123] Epoch 24/30 | Train Loss 0.0206 Acc 0.9948 | Val(clean) Loss 0.0511 Acc 0.9891
#   [p=0.500% s123] Epoch 25/30 | Train Loss 0.0216 Acc 0.9959 | Val(clean) Loss 0.0513 Acc 0.9891
#   [p=0.500% s123] Epoch 26/30 | Train Loss 0.0222 Acc 0.9945 | Val(clean) Loss 0.0510 Acc 0.9902
#   [p=0.500% s123] Epoch 27/30 | Train Loss 0.0196 Acc 0.9948 | Val(clean) Loss 0.0512 Acc 0.9891
#   [p=0.500% s123] Epoch 28/30 | Train Loss 0.0208 Acc 0.9959 | Val(clean) Loss 0.0511 Acc 0.9891
#   [p=0.500% s123] Epoch 29/30 | Train Loss 0.0222 Acc 0.9940 | Val(clean) Loss 0.0515 Acc 0.9891
#   [p=0.500% s123] Epoch 30/30 | Train Loss 0.0187 Acc 0.9956 | Val(clean) Loss 0.0515 Acc 0.9891
#   -> best clean-val acc 0.9902, saved models\badnets_mobilenetv3_bel_p0.005_s123.pth
#
# ===== Training p=0.500% s7 =====
# Poisoned 18 / 3660 training images (0.5%)
#   [p=0.500% s7] Epoch 01/30 | Train Loss 2.9263 Acc 0.4292 | Val(clean) Loss 1.8186 Acc 0.5891 *** saved
#   [p=0.500% s7] Epoch 02/30 | Train Loss 1.1637 Acc 0.7418 | Val(clean) Loss 0.7833 Acc 0.8142 *** saved
#   [p=0.500% s7] Epoch 03/30 | Train Loss 0.5336 Acc 0.8885 | Val(clean) Loss 0.4029 Acc 0.8973 *** saved
# ...
#   [p=0.500% s7] Epoch 12/30 | Train Loss 0.0482 Acc 0.9874 | Val(clean) Loss 0.0715 Acc 0.9836 *** saved
#   [p=0.500% s7] Epoch 13/30 | Train Loss 0.0511 Acc 0.9869 | Val(clean) Loss 0.0741 Acc 0.9792
#   [p=0.500% s7] Epoch 14/30 | Train Loss 0.0451 Acc 0.9877 | Val(clean) Loss 0.0705 Acc 0.9858 *** saved
#   [p=0.500% s7] Epoch 15/30 | Train Loss 0.0408 Acc 0.9899 | Val(clean) Loss 0.0619 Acc 0.9858
#   [p=0.500% s7] Epoch 16/30 | Train Loss 0.0354 Acc 0.9910 | Val(clean) Loss 0.0590 Acc 0.9902 *** saved
#   [p=0.500% s7] Epoch 17/30 | Train Loss 0.0329 Acc 0.9910 | Val(clean) Loss 0.0636 Acc 0.9836
#   [p=0.500% s7] Epoch 18/30 | Train Loss 0.0351 Acc 0.9910 | Val(clean) Loss 0.0610 Acc 0.9869
#   [p=0.500% s7] Epoch 19/30 | Train Loss 0.0291 Acc 0.9937 | Val(clean) Loss 0.0597 Acc 0.9869
#   [p=0.500% s7] Epoch 20/30 | Train Loss 0.0263 Acc 0.9934 | Val(clean) Loss 0.0559 Acc 0.9869
#   [p=0.500% s7] Epoch 21/30 | Train Loss 0.0258 Acc 0.9948 | Val(clean) Loss 0.0564 Acc 0.9858
#   [p=0.500% s7] Epoch 22/30 | Train Loss 0.0258 Acc 0.9940 | Val(clean) Loss 0.0574 Acc 0.9869
#   [p=0.500% s7] Epoch 23/30 | Train Loss 0.0260 Acc 0.9923 | Val(clean) Loss 0.0577 Acc 0.9869
#   [p=0.500% s7] Epoch 24/30 | Train Loss 0.0272 Acc 0.9932 | Val(clean) Loss 0.0607 Acc 0.9858
#   [p=0.500% s7] Epoch 25/30 | Train Loss 0.0265 Acc 0.9923 | Val(clean) Loss 0.0590 Acc 0.9869
#   [p=0.500% s7] Epoch 26/30 | Train Loss 0.0269 Acc 0.9918 | Val(clean) Loss 0.0569 Acc 0.9880
#   [p=0.500% s7] Epoch 27/30 | Train Loss 0.0242 Acc 0.9943 | Val(clean) Loss 0.0557 Acc 0.9880
#   [p=0.500% s7] Epoch 28/30 | Train Loss 0.0262 Acc 0.9940 | Val(clean) Loss 0.0557 Acc 0.9880
#   [p=0.500% s7] Epoch 29/30 | Train Loss 0.0246 Acc 0.9929 | Val(clean) Loss 0.0554 Acc 0.9880
#   [p=0.500% s7] Epoch 30/30 | Train Loss 0.0213 Acc 0.9940 | Val(clean) Loss 0.0554 Acc 0.9869
#   -> best clean-val acc 0.9902, saved models\badnets_mobilenetv3_bel_p0.005_s7.pth
#
# ===== Training p=1.000% s42 =====
# Poisoned 37 / 3660 training images (1%)
#   [p=1.000% s42] Epoch 01/30 | Train Loss 2.9052 Acc 0.4208 | Val(clean) Loss 1.7720 Acc 0.6055 *** saved
#   [p=1.000% s42] Epoch 02/30 | Train Loss 1.1635 Acc 0.7478 | Val(clean) Loss 0.7522 Acc 0.8208 *** saved
#   [p=1.000% s42] Epoch 03/30 | Train Loss 0.5387 Acc 0.8852 | Val(clean) Loss 0.3705 Acc 0.9126 *** saved
#   [p=1.000% s42] Epoch 04/30 | Train Loss 0.3098 Acc 0.9342 | Val(clean) Loss 0.2410 Acc 0.9290 *** saved
#   [p=1.000% s42] Epoch 05/30 | Train Loss 0.2106 Acc 0.9557 | Val(clean) Loss 0.1842 Acc 0.9552 *** saved
#   [p=1.000% s42] Epoch 06/30 | Train Loss 0.1623 Acc 0.9661 | Val(clean) Loss 0.1523 Acc 0.9628 *** saved
#   [p=1.000% s42] Epoch 07/30 | Train Loss 0.1314 Acc 0.9724 | Val(clean) Loss 0.1282 Acc 0.9705 *** saved
#   [p=1.000% s42] Epoch 08/30 | Train Loss 0.1116 Acc 0.9740 | Val(clean) Loss 0.1091 Acc 0.9694
#   [p=1.000% s42] Epoch 09/30 | Train Loss 0.1029 Acc 0.9779 | Val(clean) Loss 0.1094 Acc 0.9760 *** saved
#   [p=1.000% s42] Epoch 10/30 | Train Loss 0.0810 Acc 0.9792 | Val(clean) Loss 0.0896 Acc 0.9836 *** saved
#   [p=1.000% s42] Epoch 11/30 | Train Loss 0.0711 Acc 0.9844 | Val(clean) Loss 0.0830 Acc 0.9825
#   [p=1.000% s42] Epoch 12/30 | Train Loss 0.0736 Acc 0.9798 | Val(clean) Loss 0.1040 Acc 0.9705
#   [p=1.000% s42] Epoch 13/30 | Train Loss 0.0585 Acc 0.9863 | Val(clean) Loss 0.0753 Acc 0.9825
#   [p=1.000% s42] Epoch 14/30 | Train Loss 0.0529 Acc 0.9858 | Val(clean) Loss 0.0649 Acc 0.9825
#   [p=1.000% s42] Epoch 15/30 | Train Loss 0.0470 Acc 0.9869 | Val(clean) Loss 0.0640 Acc 0.9836
#   [p=1.000% s42] Epoch 16/30 | Train Loss 0.0374 Acc 0.9915 | Val(clean) Loss 0.0605 Acc 0.9880 *** saved
#   [p=1.000% s42] Epoch 17/30 | Train Loss 0.0336 Acc 0.9913 | Val(clean) Loss 0.0590 Acc 0.9891 *** saved
#   [p=1.000% s42] Epoch 18/30 | Train Loss 0.0275 Acc 0.9951 | Val(clean) Loss 0.0541 Acc 0.9902 *** saved
#   [p=1.000% s42] Epoch 19/30 | Train Loss 0.0257 Acc 0.9956 | Val(clean) Loss 0.0535 Acc 0.9891
#   [p=1.000% s42] Epoch 20/30 | Train Loss 0.0222 Acc 0.9954 | Val(clean) Loss 0.0488 Acc 0.9891
#   [p=1.000% s42] Epoch 21/30 | Train Loss 0.0218 Acc 0.9954 | Val(clean) Loss 0.0480 Acc 0.9891
#   [p=1.000% s42] Epoch 22/30 | Train Loss 0.0214 Acc 0.9945 | Val(clean) Loss 0.0479 Acc 0.9891
#   [p=1.000% s42] Epoch 23/30 | Train Loss 0.0194 Acc 0.9967 | Val(clean) Loss 0.0461 Acc 0.9891
#   [p=1.000% s42] Epoch 24/30 | Train Loss 0.0190 Acc 0.9967 | Val(clean) Loss 0.0442 Acc 0.9891
#   [p=1.000% s42] Epoch 25/30 | Train Loss 0.0173 Acc 0.9970 | Val(clean) Loss 0.0441 Acc 0.9891
#   [p=1.000% s42] Epoch 26/30 | Train Loss 0.0195 Acc 0.9970 | Val(clean) Loss 0.0432 Acc 0.9891
#   [p=1.000% s42] Epoch 27/30 | Train Loss 0.0159 Acc 0.9978 | Val(clean) Loss 0.0434 Acc 0.9891
#   [p=1.000% s42] Epoch 28/30 | Train Loss 0.0183 Acc 0.9967 | Val(clean) Loss 0.0431 Acc 0.9891
#   [p=1.000% s42] Epoch 29/30 | Train Loss 0.0176 Acc 0.9964 | Val(clean) Loss 0.0430 Acc 0.9891
#   [p=1.000% s42] Epoch 30/30 | Train Loss 0.0173 Acc 0.9964 | Val(clean) Loss 0.0427 Acc 0.9891
#   -> best clean-val acc 0.9902, saved models\badnets_mobilenetv3_bel_p0.01_s42.pth
#
# ===== Training p=5.000% s42 =====
# Poisoned 183 / 3660 training images (5%)
#   [p=5.000% s42] Epoch 01/30 | Train Loss 2.9429 Acc 0.4049 | Val(clean) Loss 1.8246 Acc 0.5945 *** saved
#   [p=5.000% s42] Epoch 02/30 | Train Loss 1.2730 Acc 0.7093 | Val(clean) Loss 0.8246 Acc 0.8153 *** saved
#   [p=5.000% s42] Epoch 03/30 | Train Loss 0.6564 Acc 0.8448 | Val(clean) Loss 0.4542 Acc 0.8984 *** saved
#   [p=5.000% s42] Epoch 04/30 | Train Loss 0.3633 Acc 0.9104 | Val(clean) Loss 0.3175 Acc 0.9246 *** saved
#   [p=5.000% s42] Epoch 05/30 | Train Loss 0.1882 Acc 0.9590 | Val(clean) Loss 0.2235 Acc 0.9486 *** saved
#   [p=5.000% s42] Epoch 06/30 | Train Loss 0.1221 Acc 0.9716 | Val(clean) Loss 0.1670 Acc 0.9574 *** saved
#   [p=5.000% s42] Epoch 07/30 | Train Loss 0.0894 Acc 0.9814 | Val(clean) Loss 0.1360 Acc 0.9672 *** saved
#   [p=5.000% s42] Epoch 08/30 | Train Loss 0.0702 Acc 0.9836 | Val(clean) Loss 0.1127 Acc 0.9705 *** saved
#   [p=5.000% s42] Epoch 09/30 | Train Loss 0.0591 Acc 0.9872 | Val(clean) Loss 0.0925 Acc 0.9716 *** saved
#   [p=5.000% s42] Epoch 10/30 | Train Loss 0.0476 Acc 0.9899 | Val(clean) Loss 0.0883 Acc 0.9792 *** saved
#   [p=5.000% s42] Epoch 11/30 | Train Loss 0.0387 Acc 0.9921 | Val(clean) Loss 0.0733 Acc 0.9770
#   [p=5.000% s42] Epoch 12/30 | Train Loss 0.0399 Acc 0.9893 | Val(clean) Loss 0.0792 Acc 0.9781
#   [p=5.000% s42] Epoch 13/30 | Train Loss 0.0321 Acc 0.9943 | Val(clean) Loss 0.0672 Acc 0.9803 *** saved
#   [p=5.000% s42] Epoch 14/30 | Train Loss 0.0301 Acc 0.9921 | Val(clean) Loss 0.0588 Acc 0.9814 *** saved
#   [p=5.000% s42] Epoch 15/30 | Train Loss 0.0274 Acc 0.9943 | Val(clean) Loss 0.0665 Acc 0.9803
#   [p=5.000% s42] Epoch 16/30 | Train Loss 0.0214 Acc 0.9956 | Val(clean) Loss 0.0558 Acc 0.9869 *** saved
#   [p=5.000% s42] Epoch 17/30 | Train Loss 0.0225 Acc 0.9959 | Val(clean) Loss 0.0570 Acc 0.9847
#   [p=5.000% s42] Epoch 18/30 | Train Loss 0.0190 Acc 0.9964 | Val(clean) Loss 0.0515 Acc 0.9891 *** saved
#   [p=5.000% s42] Epoch 19/30 | Train Loss 0.0160 Acc 0.9986 | Val(clean) Loss 0.0522 Acc 0.9880
#   [p=5.000% s42] Epoch 20/30 | Train Loss 0.0157 Acc 0.9964 | Val(clean) Loss 0.0491 Acc 0.9869
#   [p=5.000% s42] Epoch 21/30 | Train Loss 0.0162 Acc 0.9962 | Val(clean) Loss 0.0470 Acc 0.9847
#   [p=5.000% s42] Epoch 22/30 | Train Loss 0.0160 Acc 0.9964 | Val(clean) Loss 0.0464 Acc 0.9880
#   [p=5.000% s42] Epoch 23/30 | Train Loss 0.0151 Acc 0.9970 | Val(clean) Loss 0.0461 Acc 0.9880
#   [p=5.000% s42] Epoch 24/30 | Train Loss 0.0143 Acc 0.9970 | Val(clean) Loss 0.0436 Acc 0.9891
#   [p=5.000% s42] Epoch 25/30 | Train Loss 0.0139 Acc 0.9973 | Val(clean) Loss 0.0436 Acc 0.9891
#   [p=5.000% s42] Epoch 26/30 | Train Loss 0.0146 Acc 0.9973 | Val(clean) Loss 0.0429 Acc 0.9891
#   [p=5.000% s42] Epoch 27/30 | Train Loss 0.0121 Acc 0.9981 | Val(clean) Loss 0.0429 Acc 0.9891
#   [p=5.000% s42] Epoch 28/30 | Train Loss 0.0147 Acc 0.9975 | Val(clean) Loss 0.0426 Acc 0.9891
#   [p=5.000% s42] Epoch 29/30 | Train Loss 0.0122 Acc 0.9981 | Val(clean) Loss 0.0428 Acc 0.9891
#   [p=5.000% s42] Epoch 30/30 | Train Loss 0.0136 Acc 0.9967 | Val(clean) Loss 0.0426 Acc 0.9891
#   -> best clean-val acc 0.9891, saved models\badnets_mobilenetv3_bel_p0.05_s42.pth
#
# ===== Training p=10.000% s42 =====
# Poisoned 366 / 3660 training images (10%)
#   [p=10.000% s42] Epoch 01/30 | Train Loss 2.9677 Acc 0.3798 | Val(clean) Loss 1.9322 Acc 0.5738 *** saved
#   [p=10.000% s42] Epoch 02/30 | Train Loss 1.3466 Acc 0.6705 | Val(clean) Loss 0.9304 Acc 0.7847 *** saved
#   [p=10.000% s42] Epoch 03/30 | Train Loss 0.6013 Acc 0.8612 | Val(clean) Loss 0.5032 Acc 0.8918 *** saved
#   [p=10.000% s42] Epoch 04/30 | Train Loss 0.2869 Acc 0.9366 | Val(clean) Loss 0.3153 Acc 0.9257 *** saved
#   [p=10.000% s42] Epoch 05/30 | Train Loss 0.1766 Acc 0.9598 | Val(clean) Loss 0.2334 Acc 0.9486 *** saved
#   [p=10.000% s42] Epoch 06/30 | Train Loss 0.1205 Acc 0.9727 | Val(clean) Loss 0.1793 Acc 0.9574 *** saved
#   [p=10.000% s42] Epoch 07/30 | Train Loss 0.0862 Acc 0.9790 | Val(clean) Loss 0.1418 Acc 0.9672 *** saved
#   [p=10.000% s42] Epoch 08/30 | Train Loss 0.0714 Acc 0.9839 | Val(clean) Loss 0.1212 Acc 0.9661
#   [p=10.000% s42] Epoch 09/30 | Train Loss 0.0581 Acc 0.9880 | Val(clean) Loss 0.0987 Acc 0.9716 *** saved
#   [p=10.000% s42] Epoch 10/30 | Train Loss 0.0470 Acc 0.9877 | Val(clean) Loss 0.0914 Acc 0.9770 *** saved
#   [p=10.000% s42] Epoch 11/30 | Train Loss 0.0401 Acc 0.9910 | Val(clean) Loss 0.0768 Acc 0.9792 *** saved
#   [p=10.000% s42] Epoch 12/30 | Train Loss 0.0391 Acc 0.9910 | Val(clean) Loss 0.0794 Acc 0.9792
#   [p=10.000% s42] Epoch 13/30 | Train Loss 0.0309 Acc 0.9937 | Val(clean) Loss 0.0658 Acc 0.9825 *** saved
#   [p=10.000% s42] Epoch 14/30 | Train Loss 0.0290 Acc 0.9932 | Val(clean) Loss 0.0605 Acc 0.9814
#   [p=10.000% s42] Epoch 15/30 | Train Loss 0.0260 Acc 0.9945 | Val(clean) Loss 0.0663 Acc 0.9825
#   [p=10.000% s42] Epoch 16/30 | Train Loss 0.0199 Acc 0.9964 | Val(clean) Loss 0.0584 Acc 0.9880 *** saved
#   [p=10.000% s42] Epoch 17/30 | Train Loss 0.0219 Acc 0.9959 | Val(clean) Loss 0.0587 Acc 0.9825
#   [p=10.000% s42] Epoch 18/30 | Train Loss 0.0190 Acc 0.9951 | Val(clean) Loss 0.0550 Acc 0.9880
#   [p=10.000% s42] Epoch 19/30 | Train Loss 0.0184 Acc 0.9967 | Val(clean) Loss 0.0524 Acc 0.9891 *** saved
#   [p=10.000% s42] Epoch 20/30 | Train Loss 0.0154 Acc 0.9970 | Val(clean) Loss 0.0497 Acc 0.9880
#   [p=10.000% s42] Epoch 21/30 | Train Loss 0.0160 Acc 0.9954 | Val(clean) Loss 0.0472 Acc 0.9891
#   [p=10.000% s42] Epoch 22/30 | Train Loss 0.0158 Acc 0.9967 | Val(clean) Loss 0.0458 Acc 0.9891
#   [p=10.000% s42] Epoch 23/30 | Train Loss 0.0155 Acc 0.9967 | Val(clean) Loss 0.0464 Acc 0.9891
#   [p=10.000% s42] Epoch 24/30 | Train Loss 0.0145 Acc 0.9978 | Val(clean) Loss 0.0446 Acc 0.9902 *** saved
#   [p=10.000% s42] Epoch 25/30 | Train Loss 0.0140 Acc 0.9978 | Val(clean) Loss 0.0446 Acc 0.9902
#   [p=10.000% s42] Epoch 26/30 | Train Loss 0.0144 Acc 0.9967 | Val(clean) Loss 0.0434 Acc 0.9913 *** saved
#   [p=10.000% s42] Epoch 27/30 | Train Loss 0.0115 Acc 0.9984 | Val(clean) Loss 0.0432 Acc 0.9913
#   [p=10.000% s42] Epoch 28/30 | Train Loss 0.0140 Acc 0.9981 | Val(clean) Loss 0.0430 Acc 0.9913
#   [p=10.000% s42] Epoch 29/30 | Train Loss 0.0126 Acc 0.9978 | Val(clean) Loss 0.0431 Acc 0.9913
#   [p=10.000% s42] Epoch 30/30 | Train Loss 0.0130 Acc 0.9973 | Val(clean) Loss 0.0430 Acc 0.9913
#   -> best clean-val acc 0.9913, saved models\badnets_mobilenetv3_bel_p0.1_s42.pth
#
# ===== Training p=20.000% s42 =====
# Poisoned 732 / 3660 training images (20%)
#   [p=20.000% s42] Epoch 01/30 | Train Loss 2.9540 Acc 0.3134 | Val(clean) Loss 2.1453 Acc 0.4885 *** saved
#   [p=20.000% s42] Epoch 02/30 | Train Loss 1.2905 Acc 0.6902 | Val(clean) Loss 1.0594 Acc 0.7497 *** saved
#   [p=20.000% s42] Epoch 03/30 | Train Loss 0.5572 Acc 0.8820 | Val(clean) Loss 0.5611 Acc 0.8885 *** saved
#   [p=20.000% s42] Epoch 04/30 | Train Loss 0.2868 Acc 0.9347 | Val(clean) Loss 0.3521 Acc 0.9137 *** saved
#   [p=20.000% s42] Epoch 05/30 | Train Loss 0.1767 Acc 0.9571 | Val(clean) Loss 0.2527 Acc 0.9464 *** saved
#   [p=20.000% s42] Epoch 06/30 | Train Loss 0.1226 Acc 0.9713 | Val(clean) Loss 0.1950 Acc 0.9552 *** saved
#   [p=20.000% s42] Epoch 07/30 | Train Loss 0.0864 Acc 0.9798 | Val(clean) Loss 0.1522 Acc 0.9617 *** saved
#   [p=20.000% s42] Epoch 08/30 | Train Loss 0.0699 Acc 0.9836 | Val(clean) Loss 0.1230 Acc 0.9705 *** saved
#   [p=20.000% s42] Epoch 09/30 | Train Loss 0.0577 Acc 0.9885 | Val(clean) Loss 0.1017 Acc 0.9727 *** saved
#   [p=20.000% s42] Epoch 10/30 | Train Loss 0.0478 Acc 0.9877 | Val(clean) Loss 0.0986 Acc 0.9727
#   [p=20.000% s42] Epoch 11/30 | Train Loss 0.0416 Acc 0.9902 | Val(clean) Loss 0.0834 Acc 0.9738 *** saved
#   [p=20.000% s42] Epoch 12/30 | Train Loss 0.0459 Acc 0.9877 | Val(clean) Loss 0.0872 Acc 0.9803 *** saved
#   [p=20.000% s42] Epoch 13/30 | Train Loss 0.0287 Acc 0.9948 | Val(clean) Loss 0.0744 Acc 0.9814 *** saved
#   [p=20.000% s42] Epoch 14/30 | Train Loss 0.0276 Acc 0.9934 | Val(clean) Loss 0.0664 Acc 0.9803
#   [p=20.000% s42] Epoch 15/30 | Train Loss 0.0264 Acc 0.9940 | Val(clean) Loss 0.0705 Acc 0.9781
#   [p=20.000% s42] Epoch 16/30 | Train Loss 0.0208 Acc 0.9959 | Val(clean) Loss 0.0617 Acc 0.9869 *** saved
#   [p=20.000% s42] Epoch 17/30 | Train Loss 0.0224 Acc 0.9951 | Val(clean) Loss 0.0627 Acc 0.9825
#   [p=20.000% s42] Epoch 18/30 | Train Loss 0.0179 Acc 0.9959 | Val(clean) Loss 0.0563 Acc 0.9880 *** saved
#   [p=20.000% s42] Epoch 19/30 | Train Loss 0.0167 Acc 0.9973 | Val(clean) Loss 0.0553 Acc 0.9869
#   [p=20.000% s42] Epoch 20/30 | Train Loss 0.0161 Acc 0.9964 | Val(clean) Loss 0.0542 Acc 0.9847
#   [p=20.000% s42] Epoch 21/30 | Train Loss 0.0165 Acc 0.9959 | Val(clean) Loss 0.0495 Acc 0.9880
#   [p=20.000% s42] Epoch 22/30 | Train Loss 0.0152 Acc 0.9967 | Val(clean) Loss 0.0475 Acc 0.9902 *** saved
#   [p=20.000% s42] Epoch 23/30 | Train Loss 0.0135 Acc 0.9975 | Val(clean) Loss 0.0479 Acc 0.9880
#   [p=20.000% s42] Epoch 24/30 | Train Loss 0.0137 Acc 0.9975 | Val(clean) Loss 0.0456 Acc 0.9902
#   [p=20.000% s42] Epoch 25/30 | Train Loss 0.0131 Acc 0.9975 | Val(clean) Loss 0.0462 Acc 0.9902
#   [p=20.000% s42] Epoch 26/30 | Train Loss 0.0143 Acc 0.9975 | Val(clean) Loss 0.0449 Acc 0.9902
#   [p=20.000% s42] Epoch 27/30 | Train Loss 0.0120 Acc 0.9975 | Val(clean) Loss 0.0447 Acc 0.9902
#   [p=20.000% s42] Epoch 28/30 | Train Loss 0.0145 Acc 0.9978 | Val(clean) Loss 0.0446 Acc 0.9902
#   [p=20.000% s42] Epoch 29/30 | Train Loss 0.0127 Acc 0.9978 | Val(clean) Loss 0.0450 Acc 0.9902
#   [p=20.000% s42] Epoch 30/30 | Train Loss 0.0133 Acc 0.9973 | Val(clean) Loss 0.0448 Acc 0.9902
#   -> best clean-val acc 0.9902, saved models\badnets_mobilenetv3_bel_p0.2_s42.pth
#
# All trainings done: {(0.0, 42): 'models\\badnets_mobilenetv3_bel_p0.0_s42.pth', (0.00025, 42): 'models\\badnets_mobilenetv3_bel_p0.00025_s42.pth', (0.00025, 123): 'models\\badnets_mobilenetv3_bel_p0.00025_s123.pth', (0.00025, 7): 'models\\badnets_mobilenetv3_bel_p0.00025_s7.pth', (0.0005, 42): 'models\\badnets_mobilenetv3_bel_p0.0005_s42.pth', (0.0005, 123): 'models\\badnets_mobilenetv3_bel_p0.0005_s123.pth', (0.0005, 7): 'models\\badnets_mobilenetv3_bel_p0.0005_s7.pth', (0.001, 42): 'models\\badnets_mobilenetv3_bel_p0.001_s42.pth', (0.001, 123): 'models\\badnets_mobilenetv3_bel_p0.001_s123.pth', (0.001, 7): 'models\\badnets_mobilenetv3_bel_p0.001_s7.pth', (0.0025, 42): 'models\\badnets_mobilenetv3_bel_p0.0025_s42.pth', (0.0025, 123): 'models\\badnets_mobilenetv3_bel_p0.0025_s123.pth', (0.0025, 7): 'models\\badnets_mobilenetv3_bel_p0.0025_s7.pth', (0.005, 42): 'models\\badnets_mobilenetv3_bel_p0.005_s42.pth', (0.005, 123): 'models\\badnets_mobilenetv3_bel_p0.005_s123.pth', (0.005, 7): 'models\\badnets_mobilenetv3_bel_p0.005_s7.pth', (0.01, 42): 'models\\badnets_mobilenetv3_bel_p0.01_s42.pth', (0.05, 42): 'models\\badnets_mobilenetv3_bel_p0.05_s42.pth', (0.1, 42): 'models\\badnets_mobilenetv3_bel_p0.1_s42.pth', (0.2, 42): 'models\\badnets_mobilenetv3_bel_p0.2_s42.pth'}

# %% [markdown]
# ## Part 4 — Evaluation: Clean Accuracy (CA) and Attack Success Rate (ASR)
# - **CA**: accuracy on the clean (un-triggered) test set.
# - **ASR**: apply the trigger to *every* test image, measure the fraction predicted as `TARGET_LABEL`. **Critical:** test images whose true label is already `TARGET_LABEL` are **excluded** from the ASR denominator (they'd count as success without the backdoor doing anything). `ASR = (non-target images predicted target) / (non-target test images)`.

# %%
@torch.no_grad()
def evaluate_checkpoint(ckpt):
    model = build_model(pretrained=False)
    model.load_state_dict(torch.load(ckpt, map_location=device))
    model.eval()
    # Clean Accuracy
    correct, total = 0, 0
    for imgs, labels in clean_test_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        preds = model(imgs).argmax(1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)
    clean_acc = correct / total
    # Attack Success Rate (exclude true-target images from denominator)
    hit, denom = 0, 0
    for imgs, labels in trig_test_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        preds = model(imgs).argmax(1)
        nontarget = labels != TARGET_LABEL
        hit   += ((preds == TARGET_LABEL) & nontarget).sum().item()
        denom += nontarget.sum().item()
    asr = hit / denom
    return clean_acc, asr

# Reload checkpoints from disk if not in memory (lets eval run without retraining).
if 'checkpoints' not in dir():
    checkpoints = {(r, s): resolve_ckpt(r, s) for r in ACTIVE_RATES for s in seeds_for(r)}

results = {}   # rate -> [ {'seed':s, 'clean_acc':ca, 'asr':asr}, ... ]  (1 elem if single-seed)
for rate in ACTIVE_RATES:
    runs = []
    for seed in seeds_for(rate):
        ca, asr = evaluate_checkpoint(checkpoints[(rate, seed)])
        runs.append({'seed': seed, 'clean_acc': ca, 'asr': asr})
        print(f'p={rate*100:>7.3f}% s{seed}  CA={ca*100:6.2f}%  ASR={asr*100:6.2f}%')
    results[rate] = runs
# Out:
# p=  0.000% s42  CA= 95.79%  ASR=  0.00%
# p=  0.025% s42  CA= 95.71%  ASR=  0.00%
# p=  0.025% s123  CA= 95.91%  ASR=  0.00%
# p=  0.025% s7  CA= 95.40%  ASR=  0.00%
# p=  0.050% s42  CA= 95.63%  ASR=  0.00%
# p=  0.050% s123  CA= 95.79%  ASR=  0.00%
# p=  0.050% s7  CA= 95.44%  ASR=  0.00%
# p=  0.100% s42  CA= 95.60%  ASR=  0.04%
# p=  0.100% s123  CA= 95.71%  ASR=  0.08%
# p=  0.100% s7  CA= 95.56%  ASR=  0.04%
# p=  0.250% s42  CA= 95.71%  ASR=  0.08%
# p=  0.250% s123  CA= 95.87%  ASR=  0.32%
# p=  0.250% s7  CA= 95.63%  ASR=  0.12%
# p=  0.500% s42  CA= 95.28%  ASR=  0.16%
# p=  0.500% s123  CA= 95.12%  ASR=  0.84%
# p=  0.500% s7  CA= 95.48%  ASR=  0.08%
# p=  1.000% s42  CA= 95.83%  ASR=  9.59%
# p=  5.000% s42  CA= 95.52%  ASR=100.00%
# p= 10.000% s42  CA= 95.83%  ASR=100.00%
# p= 20.000% s42  CA= 95.60%  ASR=100.00%

# %% [markdown]
# ### Results table

# %%
# Aggregation helpers over the per-seed runs (used by the table, plot and summary).
def mean_ca(rate):  return float(np.mean([x['clean_acc'] for x in results[rate]]))
def std_ca(rate):   return float(np.std([x['clean_acc'] for x in results[rate]]))
def mean_asr(rate): return float(np.mean([x['asr'] for x in results[rate]]))
def std_asr(rate):  return float(np.std([x['asr'] for x in results[rate]]))

def rate_label(rate):
    if rate == 0.0:
        return '0% (clean)'
    return f'{rate*100:.3f}'.rstrip('0').rstrip('.') + '%'

baseline_ca = mean_ca(0.0)
print(f'{MODEL_TITLE} — BadNets on {DS_TITLE} (target class {TARGET_LABEL}, '
      f'{TRIGGER_SIZE}px {TRIGGER_PATTERN} {TRIGGER_POS} trigger)')
print('Low rates (<= {:.4g}) averaged over seeds {}; higher rates single-seed (seed {}).'
      .format(LOW_RATE_THRESHOLD, SEEDS, SEED))
print()
print('Poison Rate  | Clean Acc            | ASR                  | Clean Acc Drop | Seeds')
print('-' * 92)
for rate in ACTIVE_RATES:
    n = len(results[rate])
    ca_m, ca_s   = mean_ca(rate) * 100,  std_ca(rate) * 100
    asr_m, asr_s = mean_asr(rate) * 100, std_asr(rate) * 100
    if n > 1:
        ca_str  = f'{ca_m:.2f} +/- {ca_s:.2f}%'
        asr_str = f'{asr_m:.2f} +/- {asr_s:.2f}%'
    else:
        ca_str  = f'{ca_m:.2f}%'
        asr_str = f'{asr_m:.2f}%'
    if rate == 0.0:
        drop_str = 'baseline'
    else:
        drop = (baseline_ca - mean_ca(rate)) * 100
        drop_str = f'-{drop:.2f} pp' if drop >= 0 else f'+{-drop:.2f} pp'
    print(f'{rate_label(rate):<12} | {ca_str:<20} | {asr_str:<20} | {drop_str:<14} | {n}')
# Out:
# MobileNetV3-Large — BadNets on BelgiumTSC (target class 0, 24px checkerboard bottom_right trigger)
# Low rates (<= 0.005) averaged over seeds [42, 123, 7]; higher rates single-seed (seed 42).
#
# Poison Rate  | Clean Acc            | ASR                  | Clean Acc Drop | Seeds
# --------------------------------------------------------------------------------------------
# 0% (clean)   | 95.79%               | 0.00%                | baseline       | 1
# 0.025%       | 95.67 +/- 0.21%      | 0.00 +/- 0.00%       | -0.12 pp       | 3
# 0.05%        | 95.62 +/- 0.15%      | 0.00 +/- 0.00%       | -0.17 pp       | 3
# 0.1%         | 95.62 +/- 0.07%      | 0.05 +/- 0.02%       | -0.17 pp       | 3
# 0.25%        | 95.74 +/- 0.10%      | 0.17 +/- 0.10%       | -0.05 pp       | 3
# 0.5%         | 95.29 +/- 0.15%      | 0.36 +/- 0.34%       | -0.50 pp       | 3
# 1%           | 95.83%               | 9.59%                | +0.04 pp       | 1
# 5%           | 95.52%               | 100.00%              | -0.28 pp       | 1
# 10%          | 95.83%               | 100.00%              | +0.04 pp       | 1
# 20%          | 95.60%               | 100.00%              | -0.20 pp       | 1

# %% [markdown]
# ## Part 5 — ASR & Clean Accuracy vs poison rate
# The story: **ASR rises sharply** with poison rate while **clean accuracy stays flat** (the backdoor is stealthy). Saved as `mobilenetv3_badnets_bel_sweep.png`.

# %%
rates_pct   = [r * 100 for r in ACTIVE_RATES]
ca_pct      = [mean_ca(r) * 100 for r in ACTIVE_RATES]
asr_pct     = [mean_asr(r) * 100 for r in ACTIVE_RATES]
asr_std_pct = [std_asr(r) * 100 for r in ACTIVE_RATES]

fig, ax1 = plt.subplots(figsize=(8, 5))
color_asr, color_ca = 'crimson', 'steelblue'
ax1.plot(rates_pct, asr_pct, 'o-', color=color_asr, linewidth=2, markersize=7, label='ASR (mean)')
# Std error bars only on the multi-seed low rates; single-seed rates are plain points.
_multi = [i for i, r in enumerate(ACTIVE_RATES) if len(results[r]) > 1]
if _multi:
    ax1.errorbar([rates_pct[i] for i in _multi], [asr_pct[i] for i in _multi],
                 yerr=[asr_std_pct[i] for i in _multi], fmt='none', ecolor=color_asr,
                 capsize=4, elinewidth=1.5, label='ASR std (multi-seed)')
ax1.set_xscale('log')   # rates span 0.01%-20%
ax1.set_xlabel('Poison rate (%)')
ax1.set_ylabel('Attack Success Rate (%)', color=color_asr)
ax1.tick_params(axis='y', labelcolor=color_asr)
ax1.set_ylim(-3, 103)
ax1.axhline(95, color=color_asr, linestyle=':', alpha=0.5, label='95% ASR')

ax2 = ax1.twinx()
ax2.plot(rates_pct, ca_pct, 's-', color=color_ca, linewidth=2, markersize=7, label='Clean Acc (mean)')
ax2.set_ylabel('Clean Accuracy (%)', color=color_ca)
ax2.tick_params(axis='y', labelcolor=color_ca)
_lo = min(ca_pct) - 2
ax2.set_ylim(min(_lo, baseline_ca*100 - 5), 100.5)

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='center right')
plt.title(f'{MODEL_TITLE} — BadNets: ASR vs Clean Accuracy across poison rate ({DS_TITLE})')
ax1.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(f'{MODEL_NAME}_badnets{CKPT_TAG}_sweep.png', dpi=150, bbox_inches='tight')
plt.show()
print(f'Saved {MODEL_NAME}_badnets{CKPT_TAG}_sweep.png')
# Out:
# Saved mobilenetv3_badnets_bel_sweep.png

# %% [markdown]
# ## Part 6 — Clean vs triggered visualization
# 5 examples: **clean image** (clean-model prediction) vs **triggered image** (clean-model prediction → backdoored-model prediction). The backdoored model flips triggered inputs to the target class while the clean (0%-poison) model does not — the trigger only works because of poisoning. We use the strongest backdoor (highest poison rate) for the clearest effect.

# %%
clean_ckpt    = checkpoints[(0.0, SEED)]         # 0% poison = clean control model
backdoor_rate = max(ACTIVE_RATES)                # strongest backdoor for a clear demo
backdoor_ckpt = checkpoints[(backdoor_rate, SEED)]

clean_model = build_model(pretrained=False)
clean_model.load_state_dict(torch.load(clean_ckpt, map_location=device)); clean_model.eval()
bd_model = build_model(pretrained=False)
bd_model.load_state_dict(torch.load(backdoor_ckpt, map_location=device)); bd_model.eval()

# Pick 5 non-target test images so the flip-to-target is meaningful.
rng = random.Random(SEED)
cand = [i for i in range(len(test_split)) if test_split[i][1] != TARGET_LABEL]
show_idx = rng.sample(cand, 5)

fig, axes = plt.subplots(5, 2, figsize=(6, 15))
with torch.no_grad():
    for row, idx in enumerate(show_idx):
        img01, true_label = test_split[idx]
        trig01 = apply_trigger(img01)
        clean_in = normalize(img01).unsqueeze(0).to(device)
        trig_in  = normalize(trig01).unsqueeze(0).to(device)
        clean_pred_on_clean = clean_model(clean_in).argmax(1).item()
        clean_pred_on_trig  = clean_model(trig_in).argmax(1).item()
        bd_pred_on_trig     = bd_model(trig_in).argmax(1).item()
        axes[row, 0].imshow(img01.permute(1, 2, 0).numpy())
        axes[row, 0].set_title(f'CLEAN  true={true_label}\nclean-model pred={clean_pred_on_clean}', fontsize=9)
        axes[row, 0].axis('off')
        flipped = bd_pred_on_trig == TARGET_LABEL
        axes[row, 1].imshow(trig01.permute(1, 2, 0).numpy())
        axes[row, 1].set_title(
            f'TRIGGERED  true={true_label}\nclean-model={clean_pred_on_trig} | '
            f'backdoor={bd_pred_on_trig}' + (' (=TARGET!)' if flipped else ''),
            fontsize=9, color=('crimson' if flipped else 'black'))
        axes[row, 1].axis('off')
plt.suptitle(f'{MODEL_TITLE} ({DS_TITLE}) — clean vs triggered (backdoor trained at p={backdoor_rate*100:.4g}%)', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 7 — Trigger perceptibility (PSNR / SSIM / LPIPS)
# Same perceptual metrics used in the evasion-attack notebooks, here between **clean and triggered** test images (computed in `[0,1]` pixel space, where the trigger lives). Reference imperceptibility thresholds: PSNR > 30 dB, SSIM > 0.95, LPIPS < 0.1.
#
# The localized 24px checkerboard patch **fails PSNR but passes SSIM and LPIPS** — and that split is the interesting result. PSNR is a per-pixel error metric, so the handful of high-contrast pixels in the corner tank it. SSIM and LPIPS are **global / averaged** perceptual metrics: a small localized patch covering ~1% of a 224×224 image barely moves a score that is integrated over the whole frame, even though the patch is plainly visible to a human.
#
# **Methodological point:** global perceptual metrics (SSIM, LPIPS) are the *wrong tool* for localized patch triggers — they wash the patch out in the spatial average, so only PSNR is sensitive enough to flag it. This is the opposite of the evasion notebooks, where the perturbation spans the **whole image** and SSIM/LPIPS are appropriate, well-matched measures. Stealthier triggers (Blended, WaNet) are future work.

# %%
import subprocess, sys, math
subprocess.run([sys.executable, '-m', 'pip', 'install', 'lpips', 'scikit-image', '-q'], check=True)
import lpips
from skimage.metrics import structural_similarity as ssim_fn

METRIC_N = 500   # number of test images to measure over
lpips_fn = lpips.LPIPS(net='alex').to(device)

def _psnr01(a, b):
    mse = ((a - b) ** 2).mean()
    return 10 * math.log10(1.0 / mse) if mse > 0 else float('inf')

psnrs, ssims, lpips_vals = [], [], []
rng = random.Random(SEED)
metric_idx = rng.sample(range(len(test_split)), min(METRIC_N, len(test_split)))
with torch.no_grad():
    for idx in metric_idx:
        img01, _ = test_split[idx]                 # [0,1] CHW
        trig01 = apply_trigger(img01)
        o = img01.permute(1, 2, 0).numpy()
        a = trig01.permute(1, 2, 0).numpy()
        psnrs.append(_psnr01(o, a))
        ssims.append(ssim_fn(o, a, channel_axis=2, data_range=1.0))
        # LPIPS expects [-1,1]
        o11 = (img01.unsqueeze(0).to(device)  * 2 - 1)
        a11 = (trig01.unsqueeze(0).to(device) * 2 - 1)
        lpips_vals.append(lpips_fn(o11, a11).item())

finite_psnr = [p for p in psnrs if math.isfinite(p)]
psnr_mean = float(np.mean(finite_psnr)); psnr_std = float(np.std(finite_psnr))
ssim_mean = float(np.mean(ssims));       ssim_std = float(np.std(ssims))
lpips_mean = float(np.mean(lpips_vals)); lpips_std = float(np.std(lpips_vals))

print(f'Trigger imperceptibility over N={len(metric_idx)} clean-vs-triggered pairs '
      f'({TRIGGER_SIZE}px {TRIGGER_PATTERN} {TRIGGER_POS}):')
print(f'  PSNR  = {psnr_mean:6.2f} +/- {psnr_std:.2f} dB   (imperceptible if > 30)')
print(f'  SSIM  = {ssim_mean:6.4f} +/- {ssim_std:.4f}      (imperceptible if > 0.95)')
print(f'  LPIPS = {lpips_mean:6.4f} +/- {lpips_std:.4f}      (imperceptible if < 0.1)')
print()
print('The localized 24px patch FAILS PSNR but PASSES SSIM and LPIPS: SSIM/LPIPS are global,')
print('spatially-averaged metrics that a small high-contrast patch barely moves, even though')
print('it is plainly visible. Global perceptual metrics are the wrong tool for localized patch')
print('triggers (only PSNR is sensitive enough) — unlike the evasion notebooks where the')
print('perturbation spans the whole image and SSIM/LPIPS are appropriate. Stealthier triggers')
print('(Blended/WaNet) are future work.')
imperceptibility = {'psnr_mean': psnr_mean, 'psnr_std': psnr_std,
                    'ssim_mean': ssim_mean, 'ssim_std': ssim_std,
                    'lpips_mean': lpips_mean, 'lpips_std': lpips_std, 'n': len(metric_idx)}
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# c:\Users\RA-02\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\RA-02\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: c:\Users\RA-02\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\lpips\weights\v0.1\alex.pth
# Trigger imperceptibility over N=500 clean-vs-triggered pairs (24px checkerboard bottom_right):
#   PSNR  =  24.11 +/- 0.76 dB   (imperceptible if > 30)
#   SSIM  = 0.9881 +/- 0.0002      (imperceptible if > 0.95)
#   LPIPS = 0.0194 +/- 0.0093      (imperceptible if < 0.1)
#
# The localized 24px patch FAILS PSNR but PASSES SSIM and LPIPS: SSIM/LPIPS are global,
# spatially-averaged metrics that a small high-contrast patch barely moves, even though
# it is plainly visible. Global perceptual metrics are the wrong tool for localized patch
# triggers (only PSNR is sensitive enough) — unlike the evasion notebooks where the
# perturbation spans the whole image and SSIM/LPIPS are appropriate. Stealthier triggers
# (Blended/WaNet) are future work.

# %% [markdown]
# ## Part 8 — Summary headline + JSON dump
# Minimum poison rate achieving **≥95% ASR** while keeping **clean-accuracy drop < 2 pp**. Results saved to `badnets_mobilenetv3_bel.json` for later cross-model aggregation.

# %%
ASR_TARGET = 0.95
CA_DROP_MAX = 0.02   # 2 pp

qualifying = []
for rate in ACTIVE_RATES:
    if rate == 0.0:
        continue
    if mean_asr(rate) >= ASR_TARGET and (baseline_ca - mean_ca(rate)) < CA_DROP_MAX:
        qualifying.append(rate)

if qualifying:
    best_rate = min(qualifying)
    asr_at = mean_asr(best_rate) * 100
    drop_at = (baseline_ca - mean_ca(best_rate)) * 100
    headline = (f'BadNets achieves {asr_at:.1f}% mean ASR at just {rate_label(best_rate)} poisoning '
                f'with negligible clean-accuracy cost ({drop_at:+.2f} pp) on {MODEL_TITLE} ({DS_TITLE}).')
else:
    best_rate = None
    # Report the best mean ASR achieved within the CA-drop budget, else overall best.
    within = [(mean_asr(r), r) for r in ACTIVE_RATES if r != 0.0
              and (baseline_ca - mean_ca(r)) < CA_DROP_MAX]
    pool = within if within else [(mean_asr(r), r) for r in ACTIVE_RATES if r != 0.0]
    top_asr, top_rate = max(pool)
    headline = (f'No poison rate hit >=95% mean ASR within a <2pp clean-accuracy drop on {MODEL_TITLE} ({DS_TITLE}); '
                f'best was {top_asr*100:.1f}% mean ASR at {rate_label(top_rate)} poisoning.')

print('=' * 80)
print('HEADLINE:', headline)
print('=' * 80)
print(f'Control check — mean ASR at 0% poisoning (no backdoor): {mean_asr(0.0)*100:.2f}% '
      f'(should be near-chance; confirms the patch alone does not trigger the target class).')

out = {
    'model': MODEL_NAME,
    'dataset': DS_SHORT,
    'attack': 'badnets',
    'target_label': TARGET_LABEL,
    'trigger': {'size': TRIGGER_SIZE, 'pos': TRIGGER_POS, 'pattern': TRIGGER_PATTERN,
                'space': '[0,1] pixel space, applied before normalization'},
    'num_epochs': NUM_EPOCHS,
    'batch_size': BATCH_SIZE,
    'num_classes': NUM_CLASSES,
    'seed': SEED,
    'seeds': SEEDS,
    'low_rate_threshold': LOW_RATE_THRESHOLD,
    'poison_rates_grid': list(POISON_RATES),
    'poison_rates': list(ACTIVE_RATES),   # rates actually evaluated (zero-poison rates dropped)
    'runs': {str(r): results[r] for r in ACTIVE_RATES},   # per-seed CA/ASR for every rate
    'clean_acc_mean': [mean_ca(r) for r in ACTIVE_RATES],
    'clean_acc_std':  [std_ca(r) for r in ACTIVE_RATES],
    'asr_mean': [mean_asr(r) for r in ACTIVE_RATES],
    'asr_std':  [std_asr(r) for r in ACTIVE_RATES],
    'clean_acc_drop_mean': [baseline_ca - mean_ca(r) for r in ACTIVE_RATES],
    'baseline_clean_acc': baseline_ca,
    'min_rate_95asr_2pp': best_rate,
    'headline': headline,
    'imperceptibility': imperceptibility,
}
json_path = f'badnets_{MODEL_NAME}_{DS_SHORT}.json'
with open(json_path, 'w') as f:
    json.dump(out, f, indent=2)
print(f'Saved {json_path}')
# Out:
# ================================================================================
# HEADLINE: BadNets achieves 100.0% mean ASR at just 5% poisoning with negligible clean-accuracy cost (+0.28 pp) on MobileNetV3-Large (BelgiumTSC).
# ================================================================================
# Control check — mean ASR at 0% poisoning (no backdoor): 0.00% (should be near-chance; confirms the patch alone does not trigger the target class).
# Saved badnets_mobilenetv3_bel.json
