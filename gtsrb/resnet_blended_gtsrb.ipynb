# %% [markdown]
# # Blended Backdoor Attack — ResNet-50 (GTSRB)
#
# **Threat model: data-poisoning / supply-chain** (untrusted pretrained models or tampered datasets). An attacker who injects a small fraction of poisoned samples installs a hidden backdoor: the model behaves normally on clean inputs but flips to a chosen target class whenever the trigger is present.
#
# **Trigger = Blended (Chen et al. 2017):** a fixed, seeded, **whole-image random-noise pattern** convex-blended into the image at opacity `alpha` (`x' = (1-a)x + a*k`). This is the *global* counterpart to the *localized* BadNets 24px patch (Gu et al. 2017) — the two together give the benchmark both a localized and a global backdoor.
#
# This is a **training-time** threat, distinct from the evasion attacks (FGSM/PGD/AutoAttack). **Scope: Blended only, attacks-only (defenses are future work).**
#
# **The two metrics:**
# - **Clean Accuracy (CA)** — accuracy on the un-triggered test set (measures *stealth* of the backdoor's effect on benign behavior).
# - **Attack Success Rate (ASR)** — fraction of *triggered* test images (of non-target classes) classified as the target class. At 0% poisoning ASR should be near-chance — the control proving the trigger only works *because of poisoning*.

# %% [markdown]
# ## Experimental scope — v1
# **v1 (current): two INDEPENDENT 1-D sweeps** — Block A varies poison rate at fixed alpha; Block B varies alpha at fixed poison rate. These locate each floor separately but assume the two axes don't interact. **v2 (future): a full 2-D alpha × poison-rate grid (ASR heatmap)** to capture interaction and find joint (rate, alpha) operating points — the two 1-D sweeps cannot establish joint optima. (See the `block_c_2d_grid_PLACEHOLDER` stub at the end.)

# %% [markdown]
# ## Configuration & imports

# %%
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms, models
from torchvision.models import ResNet50_Weights
from torch.utils.data import DataLoader, Dataset, random_split
from torch.optim.lr_scheduler import CosineAnnealingLR
import pandas as pd
import numpy as np
from PIL import Image
import os, json, random
import matplotlib.pyplot as plt

# ── Blended configuration (cell 0) ──────────────────────────────────────
NUM_CLASSES   = 43
TARGET_LABEL  = 0            # all-to-one: triggered images -> class 0 (configurable)
POISON_RATES  = [0.0, 0.0001, 0.00025, 0.0005, 0.001, 0.0025, 0.005, 0.01, 0.05, 0.10, 0.20]   # EXACT BadNets grid (A-vs-BadNets comparability)

IMG_SIZE      = 224
TRIGGER_SEED  = 1234         # FIXED FOREVER — defines the trigger pattern. NOT a swept
                             # variable; one fixed key across every model/rate/alpha/seed.
BLEND_ALPHA          = 0.2   # fixed alpha for Block A's rate sweep. 0.2 is Chen et al.'s
                             # value for the RANDOM-noise pattern and the modern GTSRB-
                             # backdoor-lit standard; high enough that opacity is not the
                             # bottleneck so poison RATE is the only variable.
BLEND_ALPHAS         = [0.02, 0.05, 0.1, 0.15, 0.2, 0.3]   # Block B alpha grid: Chen's
                             # Hello-Kitty regime (0.02) -> random-noise regime (0.2) ->
                             # clearly visible (0.3).
RATE_FOR_ALPHA_SWEEP = 0.05  # fixed 5% poison for Block B — safely above the BadNets
                             # reliability floor so poison count is not the bottleneck and
                             # alpha is the only variable.

SEED          = 42
SEEDS         = [42, 123, 7]    # multi-seed averaging for the noisy low-rate floor
LOW_RATE_THRESHOLD = 0.005      # rates <= this are noisy (few poisoned imgs) -> run once per
                                # seed; which images get picked matters, so we average. Higher
                                # rates (and rate 0 control) run single-seed with seed 42 only.

MODEL_NAME  = 'resnet50'
MODEL_TITLE = 'ResNet-50'
DS_TITLE    = 'GTSRB'
DS_SHORT    = 'gtsrb'
CKPT_TAG    = ''   # checkpoint name infix ('' for gtsrb, '_bel' for bel)
BATCH_SIZE  = 64
NUM_EPOCHS  = 15
MODELS_DIR  = 'models'   # all trained checkpoints (.pth) are saved here

DATA_DIR   = 'dataset'
TRAIN_DIR  = os.path.join(DATA_DIR, 'Train')
TEST_CSV   = os.path.join(DATA_DIR, 'Test.csv')
TEST_DIR   = DATA_DIR
VAL_SPLIT  = 0.2

if torch.cuda.is_available():
    device = torch.device('cuda')
elif torch.backends.mps.is_available():
    device = torch.device('mps')
else:
    device = torch.device('cpu')

print(f'Using device: {device}')
print(f'{MODEL_TITLE} | {DS_TITLE} | classes={NUM_CLASSES} | epochs={NUM_EPOCHS} | batch={BATCH_SIZE}')
print(f'Blended: alpha_A={BLEND_ALPHA}, alpha grid={BLEND_ALPHAS}, rate_B={RATE_FOR_ALPHA_SWEEP}, trigger_seed={TRIGGER_SEED}')
os.makedirs(MODELS_DIR, exist_ok=True)
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
# Out:
# Using device: cuda
# ResNet-50 | GTSRB | classes=43 | epochs=15 | batch=64
# Blended: alpha_A=0.2, alpha grid=[0.02, 0.05, 0.1, 0.15, 0.2, 0.3], rate_B=0.05, trigger_seed=1234

# %% [markdown]
# ## Transforms — split so the trigger lives in pixel `[0,1]` space
# Same augmentation/resize as the clean training notebook, but the final `Normalize` is **factored out**. The dataset wrappers produce a `[0,1]` tensor, blend the trigger there (Chen et al. blend in pixel space), and normalize **last**.

# %%
IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD  = [0.229, 0.224, 0.225]

# Final normalization, applied AFTER the trigger is blended (see Part 1/2).
normalize = transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD)

# [0,1]-space transforms: identical to the clean notebook MINUS the trailing Normalize.
train_transform_01 = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3),
    transforms.ToTensor(),
])
val_test_transform_01 = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# De-normalize helper (for visualization / metrics that need [0,1]).
inv_normalize = transforms.Normalize(
    mean=[-m/s for m, s in zip(IMAGENET_MEAN, IMAGENET_STD)],
    std=[1/s for s in IMAGENET_STD]
)
print('Transforms defined (trigger blended in [0,1] pixel space, normalize applied last).')
# Out:
# Transforms defined (trigger blended in [0,1] pixel space, normalize applied last).

# %% [markdown]
# ## Datasets — reused `NumericImageFolder` / `GTSRBTestDataset`
# Same correct integer label mapping (`'10' -> 10`, matching `Test.csv` ClassId) and same 80/20 train/val split (seed=42) as the clean training notebook. The only change: these carry the **`[0,1]`-space** transforms (normalize is added later by the wrappers).

# %%
class NumericImageFolder(torchvision.datasets.ImageFolder):
    """ImageFolder that sorts class folders by integer value, not alphabetically.
    Default alphabetical sort maps folder '10' -> index 2 instead of 10,
    which misaligns with the integer ClassId values in Test.csv."""
    def find_classes(self, directory):
        classes = sorted(os.listdir(directory), key=lambda x: int(x))
        class_to_idx = {cls: int(cls) for cls in classes}
        return classes, class_to_idx


class GTSRBTestDataset(Dataset):
    def __init__(self, csv_path, root_dir, transform=None):
        self.df = pd.read_csv(csv_path)
        self.root_dir = root_dir
        self.transform = transform
    def __len__(self):
        return len(self.df)
    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img_path = os.path.join(self.root_dir, row['Path'])
        image = Image.open(img_path).convert('RGB')
        label = int(row['ClassId'])
        if self.transform:
            image = self.transform(image)
        return image, label

full_train_dataset = NumericImageFolder(TRAIN_DIR, transform=train_transform_01)
assert full_train_dataset.class_to_idx['10'] == 10, 'Label mapping is wrong!'
print(f"Label mapping check passed: class '10' -> index {full_train_dataset.class_to_idx['10']}")

n_total = len(full_train_dataset)
n_val   = int(n_total * VAL_SPLIT)
n_train = n_total - n_val
train_split, val_split = random_split(
    full_train_dataset, [n_train, n_val],
    generator=torch.Generator().manual_seed(SEED)
)
# Val split uses the no-augmentation [0,1] transform (deterministic, like the clean notebook).
val_split.dataset = NumericImageFolder(TRAIN_DIR, transform=val_test_transform_01)
test_split = GTSRBTestDataset(TEST_CSV, TEST_DIR, transform=val_test_transform_01)

print(f'Train: {n_train} | Val: {n_val} | Test: {len(test_split)}')
print('NOTE: poison rates are applied to the {} training images (the 80% split that is '
      'actually trained on), matching the clean notebooks. The val split stays clean for '
      'honest checkpoint selection.'.format(n_train))

# Zero-poison-image guard (BOTH datasets): at the lowest rates round(rate*n_train) can be 0
# (especially on the small bel train set, ~3660 imgs). A rate>0 that poisons 0 images is
# identical to the clean control and would waste seed-runs, so we drop it here. The control
# (rate 0) is always kept. ACTIVE_RATES is what Block A iterates over.
def n_poison_for(rate):
    return int(round(rate * n_train))

ACTIVE_RATES = []
print(f'\nPoison-rate plan (n_train={n_train}):')
for r in POISON_RATES:
    npois = n_poison_for(r)
    if r > 0 and npois == 0:
        print(f'  SKIP  p={r*100:.4g}% -> {npois} poisoned imgs (rounds to 0; identical to control)')
        continue
    print(f'  keep  p={r*100:.4g}% -> {npois} poisoned imgs')
    ACTIVE_RATES.append(r)
print(f'Block B fixed rate {RATE_FOR_ALPHA_SWEEP*100:.4g}% -> {n_poison_for(RATE_FOR_ALPHA_SWEEP)} poisoned imgs')
# Out:
# Label mapping check passed: class '10' -> index 10
# Train: 31368 | Val: 7841 | Test: 12630
# NOTE: poison rates are applied to the 31368 training images (the 80% split that is actually trained on), matching the clean notebooks. The val split stays clean for honest checkpoint selection.
#
# Poison-rate plan (n_train=31368):
#   keep  p=0% -> 0 poisoned imgs
#   keep  p=0.01% -> 3 poisoned imgs
#   keep  p=0.025% -> 8 poisoned imgs
#   keep  p=0.05% -> 16 poisoned imgs
#   keep  p=0.1% -> 31 poisoned imgs
#   keep  p=0.25% -> 78 poisoned imgs
#   keep  p=0.5% -> 157 poisoned imgs
#   keep  p=1% -> 314 poisoned imgs
#   keep  p=5% -> 1568 poisoned imgs
#   keep  p=10% -> 3137 poisoned imgs
#   keep  p=20% -> 6274 poisoned imgs
# Block B fixed rate 5% -> 1568 poisoned imgs

# %% [markdown]
# ## Part 1 — Trigger function (the Blended pattern)
# Chen et al. 2017: a **fixed, seeded, full-image random-noise** pattern `k`, convex-blended into the image at opacity `alpha`: `x' = (1-alpha)*x + alpha*k`, in `[0,1]` pixel space **before** normalization. `TRIGGER_SEED` is fixed forever — one trigger key shared across every model / rate / alpha / seed; it is **not** a swept variable. `alpha` *is* swept (Block B). Both operands are in `[0,1]` so the blend stays in `[0,1]` — no clamp needed.

# %%
# Fixed, seeded whole-image trigger pattern k (Chen et al. 2017). Defined ONCE from
# TRIGGER_SEED — identical across every model/rate/alpha/seed.
_tg = torch.Generator().manual_seed(TRIGGER_SEED)
TRIGGER_PATTERN = torch.rand(3, IMG_SIZE, IMG_SIZE, generator=_tg)   # [0,1] CHW, fixed

def apply_trigger(img, alpha):
    # Convex blend in [0,1] space BEFORE normalize (Chen et al.: x' = (1-a)x + a*k).
    # Both operands in [0,1] so output is in [0,1] — no clamp needed.
    return (1.0 - alpha) * img + alpha * TRIGGER_PATTERN

# Quick preview at the Block-A alpha.
_img0, _ = test_split[0]
_trig0 = apply_trigger(_img0, BLEND_ALPHA)
fig, ax = plt.subplots(1, 3, figsize=(9, 3))
ax[0].imshow(_img0.permute(1, 2, 0).numpy());          ax[0].set_title('clean [0,1]'); ax[0].axis('off')
ax[1].imshow(TRIGGER_PATTERN.permute(1, 2, 0).numpy()); ax[1].set_title(f'trigger k (seed {TRIGGER_SEED})'); ax[1].axis('off')
ax[2].imshow(_trig0.permute(1, 2, 0).numpy());          ax[2].set_title(f'blended (alpha={BLEND_ALPHA})'); ax[2].axis('off')
plt.tight_layout(); plt.show()
print('apply_trigger ready — whole-image blend in [0,1] pixel space, normalize applied afterward.')
# Out:
# apply_trigger ready — whole-image blend in [0,1] pixel space, normalize applied afterward.

# %% [markdown]
# ## Part 2 — Poisoned training dataset (alpha-threaded)
# `PoisonedDataset` blends the trigger at `alpha` on a reproducible `p`-fraction of indices and relabels them to `TARGET_LABEL`. The triggered **test** set used to score a checkpoint MUST use the **same alpha the model was trained at** (v1 keeps `alpha_train == alpha_test`). Chen et al. decouple train/test opacity; a separate `alpha_test` is a **v2** extension.

# %%
class PoisonedDataset(Dataset):
    """Wrap a clean [0,1]-space dataset. A reproducible p-fraction of samples get the
    trigger blended at `alpha` AND relabeled to target_label; rest stay clean. Normalized last."""
    def __init__(self, base_dataset, poison_rate, alpha, target_label=TARGET_LABEL,
                 normalize_tf=None, seed=SEED, verbose=True):
        self.base = base_dataset
        self.alpha = alpha
        self.target_label = target_label
        self.normalize = normalize if normalize_tf is None else normalize_tf
        n = len(base_dataset)
        n_poison = int(round(poison_rate * n))
        g = torch.Generator().manual_seed(seed)
        perm = torch.randperm(n, generator=g)
        self.poison_idx = set(perm[:n_poison].tolist())
        self.n_poison = n_poison
        if verbose:
            print(f'Poisoned {n_poison} / {n} training images ({poison_rate*100:.4g}%) at alpha={alpha}')

    def __len__(self):
        return len(self.base)

    def __getitem__(self, idx):
        img, label = self.base[idx]        # img is a [0,1] CHW tensor
        if idx in self.poison_idx:
            img = apply_trigger(img, self.alpha)   # blend trigger in [0,1] pixel space
            label = self.target_label             # relabel to the attacker's target class
        img = self.normalize(img)                 # normalize last -> what the model sees
        return img, label


class NormalizedTestDataset(Dataset):
    """Clean test wrapper: optionally blend the trigger (at `alpha`) on EVERY image, then
    normalize. trigger=False -> clean test set (for CA); trigger=True -> fully-triggered set."""
    def __init__(self, base_dataset, trigger=False, alpha=None, normalize_tf=None):
        self.base = base_dataset
        self.trigger = trigger
        self.alpha = alpha
        self.normalize = normalize if normalize_tf is None else normalize_tf

    def __len__(self):
        return len(self.base)

    def __getitem__(self, idx):
        img, label = self.base[idx]
        if self.trigger:
            img = apply_trigger(img, self.alpha)
        return self.normalize(img), label

# Clean test + clean val loaders are alpha-independent -> built once.
clean_test_loader = DataLoader(NormalizedTestDataset(test_split, trigger=False),
                               batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)
val_loader = DataLoader(NormalizedTestDataset(val_split, trigger=False),
                        batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)

def make_trig_test_loader(alpha):
    # Triggered test set at a specific alpha. v1: alpha_test == alpha_train (passed in by the
    # evaluator). Chen et al. decouple them; a separate alpha_test grid is a v2 extension.
    return DataLoader(NormalizedTestDataset(test_split, trigger=True, alpha=alpha),
                      batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)
print('PoisonedDataset + clean/val loaders + make_trig_test_loader(alpha) ready.')
# Out:
# PoisonedDataset + clean/val loaders + make_trig_test_loader(alpha) ready.

# %% [markdown]
# ## Model — ResNet-50 (same architecture / freezing / discriminative LRs as the clean notebook)
# `build_model()` / `build_optimizer()` are factored so we train a **fresh model from scratch** for each run (genuine backdoor behavior). For evaluation we rebuild with `pretrained=False` and load the saved state dict.

# %%
def build_model(pretrained=True):
    """ResNet-50: freeze all but layer4 + fc (same as clean training notebook)."""
    weights = ResNet50_Weights.DEFAULT if pretrained else None
    model = models.resnet50(weights=weights)
    for name, param in model.named_parameters():
        if not (name.startswith('layer4') or name.startswith('fc')):
            param.requires_grad = False
    model.fc = nn.Linear(model.fc.in_features, NUM_CLASSES)
    return model.to(device)

def build_optimizer(model):
    # Flat LR 1e-4 across unfrozen params (layer4 + fc)
    return torch.optim.Adam([
        {'params': model.layer4.parameters()},
        {'params': model.fc.parameters()},
    ], lr=1e-4)

print('build_model / build_optimizer ready.')
# Out:
# build_model / build_optimizer ready.

# %% [markdown]
# ## Part 3 — Training helper (carries alpha)
# `train_one(poison_rate, alpha, seed)` trains a fresh model and saves the best-clean-val checkpoint to `models/blended_{model}{CKPT_TAG}_a{alpha}_p{rate}_s{seed}.pth`. `resolve_ckpt` reuses an existing checkpoint (models/ then cwd) so reruns only train what's missing. (No BadNets-era non-seeded legacy name — no prior blended checkpoints exist.)

# %%
def seeds_for(rate):
    # Low rates (>0 and <= threshold) are noisy -> run once per seed in SEEDS.
    # Higher rates and the rate-0 control run single-seed with seed 42 only.
    return SEEDS if (0 < rate <= LOW_RATE_THRESHOLD) else [SEED]

def ckpt_path(alpha, rate, seed):
    # Canonical save location for new checkpoints: the models/ subfolder. Carries alpha.
    return os.path.join(MODELS_DIR, f'blended_{MODEL_NAME}{CKPT_TAG}_a{alpha}_p{rate}_s{seed}.pth')

def resolve_ckpt(alpha, rate, seed):
    # Reuse an existing checkpoint if present: models/ first, then legacy cwd. Falls back to
    # the models/ save path. (No non-seeded legacy fallback — blended is a fresh family.)
    name = f'blended_{MODEL_NAME}{CKPT_TAG}_a{alpha}_p{rate}_s{seed}.pth'
    for c in (os.path.join(MODELS_DIR, name), name):
        if os.path.exists(c):
            return c
    return os.path.join(MODELS_DIR, name)

def train_one(poison_rate, alpha, seed=SEED):
    # `seed` drives BOTH the poison-index draw AND init/shuffle order -> independent draw.
    torch.manual_seed(seed)
    np.random.seed(seed); random.seed(seed)
    poisoned_train = PoisonedDataset(train_split, poison_rate, alpha, seed=seed)
    train_loader = DataLoader(poisoned_train, batch_size=BATCH_SIZE, shuffle=True,
                              num_workers=0, pin_memory=True)
    model = build_model(pretrained=True)
    optimizer = build_optimizer(model)
    scheduler = CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS)
    criterion = nn.CrossEntropyLoss()
    ckpt = ckpt_path(alpha, poison_rate, seed)   # saved under models/
    best_val_acc = 0.0
    for epoch in range(1, NUM_EPOCHS + 1):
        model.train()
        run_loss, correct, total = 0.0, 0, 0
        for imgs, labels in train_loader:
            imgs, labels = imgs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            run_loss += loss.item() * imgs.size(0)
            correct += (outputs.argmax(1) == labels).sum().item()
            total += imgs.size(0)
        train_loss, train_acc = run_loss / total, correct / total

        model.eval()
        run_loss, correct, total = 0.0, 0, 0
        with torch.no_grad():
            for imgs, labels in val_loader:
                imgs, labels = imgs.to(device), labels.to(device)
                outputs = model(imgs)
                loss = criterion(outputs, labels)
                run_loss += loss.item() * imgs.size(0)
                correct += (outputs.argmax(1) == labels).sum().item()
                total += imgs.size(0)
        val_loss, val_acc = run_loss / total, correct / total
        scheduler.step()
        saved = val_acc > best_val_acc
        if saved:
            best_val_acc = val_acc
            torch.save(model.state_dict(), ckpt)
        print(f'  [a{alpha} p={poison_rate*100:.3f}% s{seed}] Epoch {epoch:02d}/{NUM_EPOCHS} | '
              f'Train Loss {train_loss:.4f} Acc {train_acc:.4f} | '
              f'Val(clean) Loss {val_loss:.4f} Acc {val_acc:.4f}'
              + (' *** saved' if saved else ''))
    print(f'  -> best clean-val acc {best_val_acc:.4f}, saved {ckpt}')
    return ckpt

@torch.no_grad()
def evaluate_checkpoint(ckpt, alpha):
    # CA on the clean test set; ASR on the triggered@alpha test set (alpha_test == alpha_train).
    model = build_model(pretrained=False)
    model.load_state_dict(torch.load(ckpt, map_location=device))
    model.eval()
    correct, total = 0, 0
    for imgs, labels in clean_test_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        correct += (model(imgs).argmax(1) == labels).sum().item()
        total += labels.size(0)
    clean_acc = correct / total
    # ASR — exclude true-target images from the denominator (same as BadNets).
    hit, denom = 0, 0
    for imgs, labels in make_trig_test_loader(alpha):
        imgs, labels = imgs.to(device), labels.to(device)
        preds = model(imgs).argmax(1)
        nontarget = labels != TARGET_LABEL
        hit   += ((preds == TARGET_LABEL) & nontarget).sum().item()
        denom += nontarget.sum().item()
    asr = hit / denom
    return clean_acc, asr

print('train_one / ckpt_path / resolve_ckpt / evaluate_checkpoint ready.')
# Out:
# train_one / ckpt_path / resolve_ckpt / evaluate_checkpoint ready.

# %% [markdown]
# ## Block A — poison-rate floor at fixed alpha = `BLEND_ALPHA`
# Structurally identical to the BadNets sweep: iterate `ACTIVE_RATES × seeds_for(rate)` with alpha pinned to `BLEND_ALPHA`, multi-seed at the low rates. This is the curve that lines up directly against the BadNets poison-rate floor.

# %%
ALPHA_A = BLEND_ALPHA
checkpoints_A = {}   # (rate, seed) -> path  (alpha fixed at ALPHA_A)
for rate in ACTIVE_RATES:
    for seed in seeds_for(rate):
        existing = resolve_ckpt(ALPHA_A, rate, seed)
        if os.path.exists(existing):
            print(f'\n===== A a{ALPHA_A} p={rate*100:.3f}% s{seed} — exists, skipping ({existing}) =====')
            checkpoints_A[(rate, seed)] = existing
            continue
        print(f'\n===== Training A a{ALPHA_A} p={rate*100:.3f}% s{seed} =====')
        checkpoints_A[(rate, seed)] = train_one(rate, ALPHA_A, seed)
print('\nBlock A trainings done:', len(checkpoints_A), 'checkpoints')
# Out:
# ===== Training A a0.2 p=0.000% s42 =====
# Poisoned 0 / 31368 training images (0%) at alpha=0.2
#   [a0.2 p=0.000% s42] Epoch 01/15 | Train Loss 0.8308 Acc 0.7800 | Val(clean) Loss 0.1151 Acc 0.9649 *** saved
#   [a0.2 p=0.000% s42] Epoch 02/15 | Train Loss 0.0984 Acc 0.9699 | Val(clean) Loss 0.0482 Acc 0.9839 *** saved
#   [a0.2 p=0.000% s42] Epoch 03/15 | Train Loss 0.0494 Acc 0.9845 | Val(clean) Loss 0.0394 Acc 0.9866 *** saved
#   [a0.2 p=0.000% s42] Epoch 04/15 | Train Loss 0.0323 Acc 0.9906 | Val(clean) Loss 0.0403 Acc 0.9878 *** saved
#   [a0.2 p=0.000% s42] Epoch 05/15 | Train Loss 0.0237 Acc 0.9926 | Val(clean) Loss 0.0256 Acc 0.9920 *** saved
#   [a0.2 p=0.000% s42] Epoch 06/15 | Train Loss 0.0145 Acc 0.9953 | Val(clean) Loss 0.0239 Acc 0.9921 *** saved
#   [a0.2 p=0.000% s42] Epoch 07/15 | Train Loss 0.0164 Acc 0.9950 | Val(clean) Loss 0.0241 Acc 0.9934 *** saved
#   [a0.2 p=0.000% s42] Epoch 08/15 | Train Loss 0.0112 Acc 0.9968 | Val(clean) Loss 0.0178 Acc 0.9941 *** saved
#   [a0.2 p=0.000% s42] Epoch 09/15 | Train Loss 0.0089 Acc 0.9976 | Val(clean) Loss 0.0122 Acc 0.9959 *** saved
#   [a0.2 p=0.000% s42] Epoch 10/15 | Train Loss 0.0049 Acc 0.9986 | Val(clean) Loss 0.0106 Acc 0.9969 *** saved
#   [a0.2 p=0.000% s42] Epoch 11/15 | Train Loss 0.0048 Acc 0.9988 | Val(clean) Loss 0.0106 Acc 0.9967
#   [a0.2 p=0.000% s42] Epoch 12/15 | Train Loss 0.0040 Acc 0.9988 | Val(clean) Loss 0.0079 Acc 0.9973 *** saved
#   [a0.2 p=0.000% s42] Epoch 13/15 | Train Loss 0.0028 Acc 0.9992 | Val(clean) Loss 0.0078 Acc 0.9974 *** saved
#   [a0.2 p=0.000% s42] Epoch 14/15 | Train Loss 0.0027 Acc 0.9992 | Val(clean) Loss 0.0072 Acc 0.9976 *** saved
#   [a0.2 p=0.000% s42] Epoch 15/15 | Train Loss 0.0023 Acc 0.9994 | Val(clean) Loss 0.0068 Acc 0.9977 *** saved
#   -> best clean-val acc 0.9977, saved models\blended_resnet50_a0.2_p0.0_s42.pth
#
# ===== Training A a0.2 p=0.010% s42 =====
# Poisoned 3 / 31368 training images (0.01%) at alpha=0.2
#   [a0.2 p=0.010% s42] Epoch 01/15 | Train Loss 0.8313 Acc 0.7796 | Val(clean) Loss 0.1142 Acc 0.9653 *** saved
#   [a0.2 p=0.010% s42] Epoch 02/15 | Train Loss 0.0995 Acc 0.9704 | Val(clean) Loss 0.0481 Acc 0.9841 *** saved
#   [a0.2 p=0.010% s42] Epoch 03/15 | Train Loss 0.0496 Acc 0.9842 | Val(clean) Loss 0.0402 Acc 0.9872 *** saved
#   [a0.2 p=0.010% s42] Epoch 04/15 | Train Loss 0.0327 Acc 0.9899 | Val(clean) Loss 0.0323 Acc 0.9888 *** saved
#   [a0.2 p=0.010% s42] Epoch 05/15 | Train Loss 0.0214 Acc 0.9939 | Val(clean) Loss 0.0217 Acc 0.9931 *** saved
#   [a0.2 p=0.010% s42] Epoch 06/15 | Train Loss 0.0143 Acc 0.9957 | Val(clean) Loss 0.0215 Acc 0.9934 *** saved
#   [a0.2 p=0.010% s42] Epoch 07/15 | Train Loss 0.0165 Acc 0.9948 | Val(clean) Loss 0.0271 Acc 0.9916
#   [a0.2 p=0.010% s42] Epoch 08/15 | Train Loss 0.0119 Acc 0.9964 | Val(clean) Loss 0.0109 Acc 0.9969 *** saved
#   [a0.2 p=0.010% s42] Epoch 09/15 | Train Loss 0.0080 Acc 0.9977 | Val(clean) Loss 0.0116 Acc 0.9963
#   [a0.2 p=0.010% s42] Epoch 10/15 | Train Loss 0.0055 Acc 0.9986 | Val(clean) Loss 0.0109 Acc 0.9969
#   [a0.2 p=0.010% s42] Epoch 11/15 | Train Loss 0.0055 Acc 0.9984 | Val(clean) Loss 0.0090 Acc 0.9972 *** saved
#   [a0.2 p=0.010% s42] Epoch 12/15 | Train Loss 0.0042 Acc 0.9986 | Val(clean) Loss 0.0079 Acc 0.9971
#   [a0.2 p=0.010% s42] Epoch 13/15 | Train Loss 0.0032 Acc 0.9990 | Val(clean) Loss 0.0084 Acc 0.9978 *** saved
#   [a0.2 p=0.010% s42] Epoch 14/15 | Train Loss 0.0030 Acc 0.9991 | Val(clean) Loss 0.0078 Acc 0.9977
#   [a0.2 p=0.010% s42] Epoch 15/15 | Train Loss 0.0019 Acc 0.9996 | Val(clean) Loss 0.0065 Acc 0.9978
#   -> best clean-val acc 0.9978, saved models\blended_resnet50_a0.2_p0.0001_s42.pth
#
# ===== Training A a0.2 p=0.010% s123 =====
# Poisoned 3 / 31368 training images (0.01%) at alpha=0.2
#   [a0.2 p=0.010% s123] Epoch 01/15 | Train Loss 0.8371 Acc 0.7807 | Val(clean) Loss 0.1199 Acc 0.9628 *** saved
#   [a0.2 p=0.010% s123] Epoch 02/15 | Train Loss 0.0973 Acc 0.9703 | Val(clean) Loss 0.0568 Acc 0.9842 *** saved
#   [a0.2 p=0.010% s123] Epoch 03/15 | Train Loss 0.0524 Acc 0.9838 | Val(clean) Loss 0.0382 Acc 0.9864 *** saved
#   [a0.2 p=0.010% s123] Epoch 04/15 | Train Loss 0.0328 Acc 0.9895 | Val(clean) Loss 0.0376 Acc 0.9875 *** saved
#   [a0.2 p=0.010% s123] Epoch 05/15 | Train Loss 0.0224 Acc 0.9934 | Val(clean) Loss 0.0298 Acc 0.9908 *** saved
#   [a0.2 p=0.010% s123] Epoch 06/15 | Train Loss 0.0193 Acc 0.9940 | Val(clean) Loss 0.0359 Acc 0.9895
#   [a0.2 p=0.010% s123] Epoch 07/15 | Train Loss 0.0137 Acc 0.9957 | Val(clean) Loss 0.0177 Acc 0.9945 *** saved
#   [a0.2 p=0.010% s123] Epoch 08/15 | Train Loss 0.0085 Acc 0.9978 | Val(clean) Loss 0.0183 Acc 0.9946 *** saved
#   [a0.2 p=0.010% s123] Epoch 09/15 | Train Loss 0.0076 Acc 0.9979 | Val(clean) Loss 0.0177 Acc 0.9941
#   [a0.2 p=0.010% s123] Epoch 10/15 | Train Loss 0.0066 Acc 0.9981 | Val(clean) Loss 0.0159 Acc 0.9949 *** saved
#   [a0.2 p=0.010% s123] Epoch 11/15 | Train Loss 0.0054 Acc 0.9983 | Val(clean) Loss 0.0148 Acc 0.9953 *** saved
#   [a0.2 p=0.010% s123] Epoch 12/15 | Train Loss 0.0039 Acc 0.9988 | Val(clean) Loss 0.0163 Acc 0.9949
#   [a0.2 p=0.010% s123] Epoch 13/15 | Train Loss 0.0032 Acc 0.9990 | Val(clean) Loss 0.0107 Acc 0.9968 *** saved
#   [a0.2 p=0.010% s123] Epoch 14/15 | Train Loss 0.0028 Acc 0.9993 | Val(clean) Loss 0.0114 Acc 0.9962
#   [a0.2 p=0.010% s123] Epoch 15/15 | Train Loss 0.0025 Acc 0.9992 | Val(clean) Loss 0.0112 Acc 0.9962
#   -> best clean-val acc 0.9968, saved models\blended_resnet50_a0.2_p0.0001_s123.pth
#
# ===== Training A a0.2 p=0.010% s7 =====
# Poisoned 3 / 31368 training images (0.01%) at alpha=0.2
#   [a0.2 p=0.010% s7] Epoch 01/15 | Train Loss 0.8250 Acc 0.7826 | Val(clean) Loss 0.1029 Acc 0.9721 *** saved
#   [a0.2 p=0.010% s7] Epoch 02/15 | Train Loss 0.0980 Acc 0.9711 | Val(clean) Loss 0.0553 Acc 0.9821 *** saved
#   [a0.2 p=0.010% s7] Epoch 03/15 | Train Loss 0.0529 Acc 0.9831 | Val(clean) Loss 0.0572 Acc 0.9823 *** saved
#   [a0.2 p=0.010% s7] Epoch 04/15 | Train Loss 0.0359 Acc 0.9888 | Val(clean) Loss 0.0302 Acc 0.9908 *** saved
#   [a0.2 p=0.010% s7] Epoch 05/15 | Train Loss 0.0213 Acc 0.9936 | Val(clean) Loss 0.0262 Acc 0.9917 *** saved
#   [a0.2 p=0.010% s7] Epoch 06/15 | Train Loss 0.0162 Acc 0.9949 | Val(clean) Loss 0.0215 Acc 0.9932 *** saved
#   [a0.2 p=0.010% s7] Epoch 07/15 | Train Loss 0.0133 Acc 0.9959 | Val(clean) Loss 0.0358 Acc 0.9894
#   [a0.2 p=0.010% s7] Epoch 08/15 | Train Loss 0.0125 Acc 0.9959 | Val(clean) Loss 0.0157 Acc 0.9945 *** saved
#   [a0.2 p=0.010% s7] Epoch 09/15 | Train Loss 0.0080 Acc 0.9976 | Val(clean) Loss 0.0130 Acc 0.9952 *** saved
#   [a0.2 p=0.010% s7] Epoch 10/15 | Train Loss 0.0052 Acc 0.9984 | Val(clean) Loss 0.0162 Acc 0.9949
#   [a0.2 p=0.010% s7] Epoch 11/15 | Train Loss 0.0052 Acc 0.9984 | Val(clean) Loss 0.0119 Acc 0.9959 *** saved
#   [a0.2 p=0.010% s7] Epoch 12/15 | Train Loss 0.0042 Acc 0.9988 | Val(clean) Loss 0.0105 Acc 0.9962 *** saved
#   [a0.2 p=0.010% s7] Epoch 13/15 | Train Loss 0.0032 Acc 0.9992 | Val(clean) Loss 0.0102 Acc 0.9967 *** saved
#   [a0.2 p=0.010% s7] Epoch 14/15 | Train Loss 0.0026 Acc 0.9993 | Val(clean) Loss 0.0092 Acc 0.9971 *** saved
#   [a0.2 p=0.010% s7] Epoch 15/15 | Train Loss 0.0021 Acc 0.9993 | Val(clean) Loss 0.0092 Acc 0.9969
#   -> best clean-val acc 0.9971, saved models\blended_resnet50_a0.2_p0.0001_s7.pth
#
# ===== Training A a0.2 p=0.025% s42 =====
# Poisoned 8 / 31368 training images (0.025%) at alpha=0.2
#   [a0.2 p=0.025% s42] Epoch 01/15 | Train Loss 0.8321 Acc 0.7798 | Val(clean) Loss 0.1165 Acc 0.9649 *** saved
#   [a0.2 p=0.025% s42] Epoch 02/15 | Train Loss 0.0999 Acc 0.9696 | Val(clean) Loss 0.0476 Acc 0.9848 *** saved
#   [a0.2 p=0.025% s42] Epoch 03/15 | Train Loss 0.0488 Acc 0.9851 | Val(clean) Loss 0.0388 Acc 0.9864 *** saved
#   [a0.2 p=0.025% s42] Epoch 04/15 | Train Loss 0.0328 Acc 0.9897 | Val(clean) Loss 0.0338 Acc 0.9880 *** saved
#   [a0.2 p=0.025% s42] Epoch 05/15 | Train Loss 0.0232 Acc 0.9931 | Val(clean) Loss 0.0251 Acc 0.9926 *** saved
#   [a0.2 p=0.025% s42] Epoch 06/15 | Train Loss 0.0149 Acc 0.9955 | Val(clean) Loss 0.0351 Acc 0.9899
#   [a0.2 p=0.025% s42] Epoch 07/15 | Train Loss 0.0164 Acc 0.9950 | Val(clean) Loss 0.0280 Acc 0.9917
#   [a0.2 p=0.025% s42] Epoch 08/15 | Train Loss 0.0104 Acc 0.9969 | Val(clean) Loss 0.0162 Acc 0.9944 *** saved
#   [a0.2 p=0.025% s42] Epoch 09/15 | Train Loss 0.0088 Acc 0.9973 | Val(clean) Loss 0.0147 Acc 0.9953 *** saved
#   [a0.2 p=0.025% s42] Epoch 10/15 | Train Loss 0.0050 Acc 0.9985 | Val(clean) Loss 0.0134 Acc 0.9959 *** saved
#   [a0.2 p=0.025% s42] Epoch 11/15 | Train Loss 0.0049 Acc 0.9987 | Val(clean) Loss 0.0117 Acc 0.9964 *** saved
#   [a0.2 p=0.025% s42] Epoch 12/15 | Train Loss 0.0042 Acc 0.9987 | Val(clean) Loss 0.0073 Acc 0.9978 *** saved
#   [a0.2 p=0.025% s42] Epoch 13/15 | Train Loss 0.0034 Acc 0.9990 | Val(clean) Loss 0.0074 Acc 0.9977
#   [a0.2 p=0.025% s42] Epoch 14/15 | Train Loss 0.0025 Acc 0.9993 | Val(clean) Loss 0.0060 Acc 0.9987 *** saved
#   [a0.2 p=0.025% s42] Epoch 15/15 | Train Loss 0.0019 Acc 0.9995 | Val(clean) Loss 0.0059 Acc 0.9980
#   -> best clean-val acc 0.9987, saved models\blended_resnet50_a0.2_p0.00025_s42.pth
#
# ===== Training A a0.2 p=0.025% s123 =====
# Poisoned 8 / 31368 training images (0.025%) at alpha=0.2
#   [a0.2 p=0.025% s123] Epoch 01/15 | Train Loss 0.8378 Acc 0.7803 | Val(clean) Loss 0.1239 Acc 0.9615 *** saved
#   [a0.2 p=0.025% s123] Epoch 02/15 | Train Loss 0.0984 Acc 0.9694 | Val(clean) Loss 0.0545 Acc 0.9847 *** saved
#   [a0.2 p=0.025% s123] Epoch 03/15 | Train Loss 0.0525 Acc 0.9837 | Val(clean) Loss 0.0377 Acc 0.9881 *** saved
#   [a0.2 p=0.025% s123] Epoch 04/15 | Train Loss 0.0340 Acc 0.9894 | Val(clean) Loss 0.0294 Acc 0.9915 *** saved
#   [a0.2 p=0.025% s123] Epoch 05/15 | Train Loss 0.0230 Acc 0.9932 | Val(clean) Loss 0.0330 Acc 0.9899
#   [a0.2 p=0.025% s123] Epoch 06/15 | Train Loss 0.0189 Acc 0.9943 | Val(clean) Loss 0.0264 Acc 0.9912
#   [a0.2 p=0.025% s123] Epoch 07/15 | Train Loss 0.0160 Acc 0.9953 | Val(clean) Loss 0.0237 Acc 0.9927 *** saved
#   [a0.2 p=0.025% s123] Epoch 08/15 | Train Loss 0.0082 Acc 0.9975 | Val(clean) Loss 0.0164 Acc 0.9959 *** saved
#   [a0.2 p=0.025% s123] Epoch 09/15 | Train Loss 0.0077 Acc 0.9981 | Val(clean) Loss 0.0190 Acc 0.9941
#   [a0.2 p=0.025% s123] Epoch 10/15 | Train Loss 0.0075 Acc 0.9979 | Val(clean) Loss 0.0213 Acc 0.9926
#   [a0.2 p=0.025% s123] Epoch 11/15 | Train Loss 0.0048 Acc 0.9986 | Val(clean) Loss 0.0120 Acc 0.9960 *** saved
#   [a0.2 p=0.025% s123] Epoch 12/15 | Train Loss 0.0038 Acc 0.9988 | Val(clean) Loss 0.0156 Acc 0.9959
#   [a0.2 p=0.025% s123] Epoch 13/15 | Train Loss 0.0035 Acc 0.9989 | Val(clean) Loss 0.0107 Acc 0.9969 *** saved
#   [a0.2 p=0.025% s123] Epoch 14/15 | Train Loss 0.0027 Acc 0.9992 | Val(clean) Loss 0.0106 Acc 0.9966
#   [a0.2 p=0.025% s123] Epoch 15/15 | Train Loss 0.0026 Acc 0.9992 | Val(clean) Loss 0.0109 Acc 0.9966
#   -> best clean-val acc 0.9969, saved models\blended_resnet50_a0.2_p0.00025_s123.pth
#
# ===== Training A a0.2 p=0.025% s7 =====
# Poisoned 8 / 31368 training images (0.025%) at alpha=0.2
#   [a0.2 p=0.025% s7] Epoch 01/15 | Train Loss 0.8260 Acc 0.7822 | Val(clean) Loss 0.1012 Acc 0.9723 *** saved
#   [a0.2 p=0.025% s7] Epoch 02/15 | Train Loss 0.0984 Acc 0.9708 | Val(clean) Loss 0.0554 Acc 0.9827 *** saved
#   [a0.2 p=0.025% s7] Epoch 03/15 | Train Loss 0.0529 Acc 0.9836 | Val(clean) Loss 0.0564 Acc 0.9815
#   [a0.2 p=0.025% s7] Epoch 04/15 | Train Loss 0.0348 Acc 0.9894 | Val(clean) Loss 0.0310 Acc 0.9908 *** saved
#   [a0.2 p=0.025% s7] Epoch 05/15 | Train Loss 0.0220 Acc 0.9938 | Val(clean) Loss 0.0222 Acc 0.9934 *** saved
#   [a0.2 p=0.025% s7] Epoch 06/15 | Train Loss 0.0163 Acc 0.9950 | Val(clean) Loss 0.0238 Acc 0.9907
#   [a0.2 p=0.025% s7] Epoch 07/15 | Train Loss 0.0123 Acc 0.9963 | Val(clean) Loss 0.0203 Acc 0.9931
#   [a0.2 p=0.025% s7] Epoch 08/15 | Train Loss 0.0104 Acc 0.9968 | Val(clean) Loss 0.0162 Acc 0.9938 *** saved
#   [a0.2 p=0.025% s7] Epoch 09/15 | Train Loss 0.0078 Acc 0.9981 | Val(clean) Loss 0.0170 Acc 0.9944 *** saved
#   [a0.2 p=0.025% s7] Epoch 10/15 | Train Loss 0.0078 Acc 0.9977 | Val(clean) Loss 0.0163 Acc 0.9945 *** saved
#   [a0.2 p=0.025% s7] Epoch 11/15 | Train Loss 0.0056 Acc 0.9983 | Val(clean) Loss 0.0182 Acc 0.9935
#   [a0.2 p=0.025% s7] Epoch 12/15 | Train Loss 0.0037 Acc 0.9989 | Val(clean) Loss 0.0123 Acc 0.9963 *** saved
#   [a0.2 p=0.025% s7] Epoch 13/15 | Train Loss 0.0035 Acc 0.9990 | Val(clean) Loss 0.0114 Acc 0.9969 *** saved
#   [a0.2 p=0.025% s7] Epoch 14/15 | Train Loss 0.0025 Acc 0.9993 | Val(clean) Loss 0.0106 Acc 0.9973 *** saved
#   [a0.2 p=0.025% s7] Epoch 15/15 | Train Loss 0.0018 Acc 0.9996 | Val(clean) Loss 0.0112 Acc 0.9968
#   -> best clean-val acc 0.9973, saved models\blended_resnet50_a0.2_p0.00025_s7.pth
#
# ===== Training A a0.2 p=0.050% s42 =====
# Poisoned 16 / 31368 training images (0.05%) at alpha=0.2
#   [a0.2 p=0.050% s42] Epoch 01/15 | Train Loss 0.8334 Acc 0.7791 | Val(clean) Loss 0.1119 Acc 0.9645 *** saved
#   [a0.2 p=0.050% s42] Epoch 02/15 | Train Loss 0.1008 Acc 0.9696 | Val(clean) Loss 0.0466 Acc 0.9848 *** saved
#   [a0.2 p=0.050% s42] Epoch 03/15 | Train Loss 0.0503 Acc 0.9851 | Val(clean) Loss 0.0383 Acc 0.9883 *** saved
#   [a0.2 p=0.050% s42] Epoch 04/15 | Train Loss 0.0328 Acc 0.9900 | Val(clean) Loss 0.0347 Acc 0.9880
#   [a0.2 p=0.050% s42] Epoch 05/15 | Train Loss 0.0222 Acc 0.9935 | Val(clean) Loss 0.0247 Acc 0.9923 *** saved
#   [a0.2 p=0.050% s42] Epoch 06/15 | Train Loss 0.0164 Acc 0.9948 | Val(clean) Loss 0.0269 Acc 0.9916
#   [a0.2 p=0.050% s42] Epoch 07/15 | Train Loss 0.0155 Acc 0.9951 | Val(clean) Loss 0.0249 Acc 0.9921
#   [a0.2 p=0.050% s42] Epoch 08/15 | Train Loss 0.0105 Acc 0.9967 | Val(clean) Loss 0.0146 Acc 0.9953 *** saved
#   [a0.2 p=0.050% s42] Epoch 09/15 | Train Loss 0.0091 Acc 0.9972 | Val(clean) Loss 0.0130 Acc 0.9960 *** saved
#   [a0.2 p=0.050% s42] Epoch 10/15 | Train Loss 0.0059 Acc 0.9982 | Val(clean) Loss 0.0121 Acc 0.9962 *** saved
#   [a0.2 p=0.050% s42] Epoch 11/15 | Train Loss 0.0045 Acc 0.9988 | Val(clean) Loss 0.0106 Acc 0.9968 *** saved
#   [a0.2 p=0.050% s42] Epoch 12/15 | Train Loss 0.0036 Acc 0.9989 | Val(clean) Loss 0.0081 Acc 0.9972 *** saved
#   [a0.2 p=0.050% s42] Epoch 13/15 | Train Loss 0.0034 Acc 0.9990 | Val(clean) Loss 0.0089 Acc 0.9972
#   [a0.2 p=0.050% s42] Epoch 14/15 | Train Loss 0.0024 Acc 0.9995 | Val(clean) Loss 0.0079 Acc 0.9972
#   [a0.2 p=0.050% s42] Epoch 15/15 | Train Loss 0.0018 Acc 0.9996 | Val(clean) Loss 0.0076 Acc 0.9976 *** saved
#   -> best clean-val acc 0.9976, saved models\blended_resnet50_a0.2_p0.0005_s42.pth
#
# ===== Training A a0.2 p=0.050% s123 =====
# Poisoned 16 / 31368 training images (0.05%) at alpha=0.2
#   [a0.2 p=0.050% s123] Epoch 01/15 | Train Loss 0.8382 Acc 0.7804 | Val(clean) Loss 0.1260 Acc 0.9606 *** saved
#   [a0.2 p=0.050% s123] Epoch 02/15 | Train Loss 0.0983 Acc 0.9699 | Val(clean) Loss 0.0599 Acc 0.9818 *** saved
#   [a0.2 p=0.050% s123] Epoch 03/15 | Train Loss 0.0528 Acc 0.9843 | Val(clean) Loss 0.0353 Acc 0.9880 *** saved
#   [a0.2 p=0.050% s123] Epoch 04/15 | Train Loss 0.0326 Acc 0.9906 | Val(clean) Loss 0.0337 Acc 0.9894 *** saved
#   [a0.2 p=0.050% s123] Epoch 05/15 | Train Loss 0.0232 Acc 0.9928 | Val(clean) Loss 0.0319 Acc 0.9892
#   [a0.2 p=0.050% s123] Epoch 06/15 | Train Loss 0.0191 Acc 0.9944 | Val(clean) Loss 0.0249 Acc 0.9922 *** saved
#   [a0.2 p=0.050% s123] Epoch 07/15 | Train Loss 0.0160 Acc 0.9954 | Val(clean) Loss 0.0205 Acc 0.9935 *** saved
#   [a0.2 p=0.050% s123] Epoch 08/15 | Train Loss 0.0085 Acc 0.9975 | Val(clean) Loss 0.0296 Acc 0.9917
#   [a0.2 p=0.050% s123] Epoch 09/15 | Train Loss 0.0085 Acc 0.9976 | Val(clean) Loss 0.0197 Acc 0.9944 *** saved
#   [a0.2 p=0.050% s123] Epoch 10/15 | Train Loss 0.0065 Acc 0.9981 | Val(clean) Loss 0.0142 Acc 0.9960 *** saved
#   [a0.2 p=0.050% s123] Epoch 11/15 | Train Loss 0.0039 Acc 0.9990 | Val(clean) Loss 0.0125 Acc 0.9962 *** saved
#   [a0.2 p=0.050% s123] Epoch 12/15 | Train Loss 0.0036 Acc 0.9989 | Val(clean) Loss 0.0215 Acc 0.9938
#   [a0.2 p=0.050% s123] Epoch 13/15 | Train Loss 0.0027 Acc 0.9992 | Val(clean) Loss 0.0124 Acc 0.9968 *** saved
#   [a0.2 p=0.050% s123] Epoch 14/15 | Train Loss 0.0024 Acc 0.9992 | Val(clean) Loss 0.0120 Acc 0.9967
#   [a0.2 p=0.050% s123] Epoch 15/15 | Train Loss 0.0024 Acc 0.9993 | Val(clean) Loss 0.0121 Acc 0.9966
#   -> best clean-val acc 0.9968, saved models\blended_resnet50_a0.2_p0.0005_s123.pth
#
# ===== Training A a0.2 p=0.050% s7 =====
# Poisoned 16 / 31368 training images (0.05%) at alpha=0.2
#   [a0.2 p=0.050% s7] Epoch 01/15 | Train Loss 0.8272 Acc 0.7820 | Val(clean) Loss 0.1005 Acc 0.9708 *** saved
#   [a0.2 p=0.050% s7] Epoch 02/15 | Train Loss 0.0985 Acc 0.9708 | Val(clean) Loss 0.0579 Acc 0.9827 *** saved
#   [a0.2 p=0.050% s7] Epoch 03/15 | Train Loss 0.0528 Acc 0.9836 | Val(clean) Loss 0.0607 Acc 0.9798
#   [a0.2 p=0.050% s7] Epoch 04/15 | Train Loss 0.0358 Acc 0.9892 | Val(clean) Loss 0.0318 Acc 0.9907 *** saved
#   [a0.2 p=0.050% s7] Epoch 05/15 | Train Loss 0.0216 Acc 0.9940 | Val(clean) Loss 0.0253 Acc 0.9930 *** saved
#   [a0.2 p=0.050% s7] Epoch 06/15 | Train Loss 0.0172 Acc 0.9946 | Val(clean) Loss 0.0219 Acc 0.9932 *** saved
#   [a0.2 p=0.050% s7] Epoch 07/15 | Train Loss 0.0126 Acc 0.9965 | Val(clean) Loss 0.0238 Acc 0.9925
#   [a0.2 p=0.050% s7] Epoch 08/15 | Train Loss 0.0125 Acc 0.9961 | Val(clean) Loss 0.0156 Acc 0.9952 *** saved
#   [a0.2 p=0.050% s7] Epoch 09/15 | Train Loss 0.0068 Acc 0.9982 | Val(clean) Loss 0.0180 Acc 0.9941
#   [a0.2 p=0.050% s7] Epoch 10/15 | Train Loss 0.0067 Acc 0.9982 | Val(clean) Loss 0.0143 Acc 0.9955 *** saved
#   [a0.2 p=0.050% s7] Epoch 11/15 | Train Loss 0.0053 Acc 0.9985 | Val(clean) Loss 0.0152 Acc 0.9943
#   [a0.2 p=0.050% s7] Epoch 12/15 | Train Loss 0.0042 Acc 0.9987 | Val(clean) Loss 0.0137 Acc 0.9955
#   [a0.2 p=0.050% s7] Epoch 13/15 | Train Loss 0.0036 Acc 0.9990 | Val(clean) Loss 0.0135 Acc 0.9957 *** saved
#   [a0.2 p=0.050% s7] Epoch 14/15 | Train Loss 0.0028 Acc 0.9990 | Val(clean) Loss 0.0119 Acc 0.9964 *** saved
#   [a0.2 p=0.050% s7] Epoch 15/15 | Train Loss 0.0018 Acc 0.9997 | Val(clean) Loss 0.0113 Acc 0.9960
#   -> best clean-val acc 0.9964, saved models\blended_resnet50_a0.2_p0.0005_s7.pth
#
# ===== Training A a0.2 p=0.100% s42 =====
# Poisoned 31 / 31368 training images (0.1%) at alpha=0.2
#   [a0.2 p=0.100% s42] Epoch 01/15 | Train Loss 0.8358 Acc 0.7787 | Val(clean) Loss 0.1133 Acc 0.9647 *** saved
#   [a0.2 p=0.100% s42] Epoch 02/15 | Train Loss 0.1007 Acc 0.9691 | Val(clean) Loss 0.0432 Acc 0.9864 *** saved
#   [a0.2 p=0.100% s42] Epoch 03/15 | Train Loss 0.0508 Acc 0.9846 | Val(clean) Loss 0.0362 Acc 0.9878 *** saved
#   [a0.2 p=0.100% s42] Epoch 04/15 | Train Loss 0.0345 Acc 0.9899 | Val(clean) Loss 0.0321 Acc 0.9903 *** saved
#   [a0.2 p=0.100% s42] Epoch 05/15 | Train Loss 0.0216 Acc 0.9934 | Val(clean) Loss 0.0224 Acc 0.9926 *** saved
#   [a0.2 p=0.100% s42] Epoch 06/15 | Train Loss 0.0160 Acc 0.9952 | Val(clean) Loss 0.0279 Acc 0.9909
#   [a0.2 p=0.100% s42] Epoch 07/15 | Train Loss 0.0159 Acc 0.9952 | Val(clean) Loss 0.0305 Acc 0.9908
#   [a0.2 p=0.100% s42] Epoch 08/15 | Train Loss 0.0118 Acc 0.9963 | Val(clean) Loss 0.0153 Acc 0.9950 *** saved
#   [a0.2 p=0.100% s42] Epoch 09/15 | Train Loss 0.0087 Acc 0.9973 | Val(clean) Loss 0.0130 Acc 0.9957 *** saved
#   [a0.2 p=0.100% s42] Epoch 10/15 | Train Loss 0.0052 Acc 0.9986 | Val(clean) Loss 0.0105 Acc 0.9971 *** saved
#   [a0.2 p=0.100% s42] Epoch 11/15 | Train Loss 0.0041 Acc 0.9989 | Val(clean) Loss 0.0107 Acc 0.9967
#   [a0.2 p=0.100% s42] Epoch 12/15 | Train Loss 0.0044 Acc 0.9989 | Val(clean) Loss 0.0091 Acc 0.9977 *** saved
#   [a0.2 p=0.100% s42] Epoch 13/15 | Train Loss 0.0032 Acc 0.9991 | Val(clean) Loss 0.0080 Acc 0.9978 *** saved
#   [a0.2 p=0.100% s42] Epoch 14/15 | Train Loss 0.0027 Acc 0.9991 | Val(clean) Loss 0.0074 Acc 0.9977
#   [a0.2 p=0.100% s42] Epoch 15/15 | Train Loss 0.0021 Acc 0.9995 | Val(clean) Loss 0.0070 Acc 0.9982 *** saved
#   -> best clean-val acc 0.9982, saved models\blended_resnet50_a0.2_p0.001_s42.pth
#
# ===== Training A a0.2 p=0.100% s123 =====
# Poisoned 31 / 31368 training images (0.1%) at alpha=0.2
#   [a0.2 p=0.100% s123] Epoch 01/15 | Train Loss 0.8386 Acc 0.7803 | Val(clean) Loss 0.1260 Acc 0.9594 *** saved
#   [a0.2 p=0.100% s123] Epoch 02/15 | Train Loss 0.0969 Acc 0.9703 | Val(clean) Loss 0.0601 Acc 0.9828 *** saved
#   [a0.2 p=0.100% s123] Epoch 03/15 | Train Loss 0.0525 Acc 0.9841 | Val(clean) Loss 0.0338 Acc 0.9888 *** saved
#   [a0.2 p=0.100% s123] Epoch 04/15 | Train Loss 0.0333 Acc 0.9896 | Val(clean) Loss 0.0454 Acc 0.9844
#   [a0.2 p=0.100% s123] Epoch 05/15 | Train Loss 0.0232 Acc 0.9930 | Val(clean) Loss 0.0353 Acc 0.9892 *** saved
#   [a0.2 p=0.100% s123] Epoch 06/15 | Train Loss 0.0197 Acc 0.9943 | Val(clean) Loss 0.0223 Acc 0.9929 *** saved
#   [a0.2 p=0.100% s123] Epoch 07/15 | Train Loss 0.0161 Acc 0.9948 | Val(clean) Loss 0.0194 Acc 0.9943 *** saved
#   [a0.2 p=0.100% s123] Epoch 08/15 | Train Loss 0.0079 Acc 0.9977 | Val(clean) Loss 0.0187 Acc 0.9938
#   [a0.2 p=0.100% s123] Epoch 09/15 | Train Loss 0.0079 Acc 0.9979 | Val(clean) Loss 0.0156 Acc 0.9953 *** saved
#   [a0.2 p=0.100% s123] Epoch 10/15 | Train Loss 0.0068 Acc 0.9980 | Val(clean) Loss 0.0164 Acc 0.9940
#   [a0.2 p=0.100% s123] Epoch 11/15 | Train Loss 0.0045 Acc 0.9988 | Val(clean) Loss 0.0124 Acc 0.9962 *** saved
#   [a0.2 p=0.100% s123] Epoch 12/15 | Train Loss 0.0029 Acc 0.9991 | Val(clean) Loss 0.0167 Acc 0.9945
#   [a0.2 p=0.100% s123] Epoch 13/15 | Train Loss 0.0031 Acc 0.9991 | Val(clean) Loss 0.0120 Acc 0.9968 *** saved
#   [a0.2 p=0.100% s123] Epoch 14/15 | Train Loss 0.0029 Acc 0.9992 | Val(clean) Loss 0.0126 Acc 0.9966
#   [a0.2 p=0.100% s123] Epoch 15/15 | Train Loss 0.0025 Acc 0.9993 | Val(clean) Loss 0.0124 Acc 0.9964
#   -> best clean-val acc 0.9968, saved models\blended_resnet50_a0.2_p0.001_s123.pth
#
# ===== Training A a0.2 p=0.100% s7 =====
# Poisoned 31 / 31368 training images (0.1%) at alpha=0.2
#   [a0.2 p=0.100% s7] Epoch 01/15 | Train Loss 0.8287 Acc 0.7820 | Val(clean) Loss 0.1024 Acc 0.9726 *** saved
#   [a0.2 p=0.100% s7] Epoch 02/15 | Train Loss 0.0972 Acc 0.9708 | Val(clean) Loss 0.0522 Acc 0.9843 *** saved
#   [a0.2 p=0.100% s7] Epoch 03/15 | Train Loss 0.0517 Acc 0.9837 | Val(clean) Loss 0.0607 Acc 0.9807
#   [a0.2 p=0.100% s7] Epoch 04/15 | Train Loss 0.0357 Acc 0.9893 | Val(clean) Loss 0.0321 Acc 0.9902 *** saved
#   [a0.2 p=0.100% s7] Epoch 05/15 | Train Loss 0.0221 Acc 0.9933 | Val(clean) Loss 0.0231 Acc 0.9936 *** saved
#   [a0.2 p=0.100% s7] Epoch 06/15 | Train Loss 0.0165 Acc 0.9951 | Val(clean) Loss 0.0255 Acc 0.9918
#   [a0.2 p=0.100% s7] Epoch 07/15 | Train Loss 0.0136 Acc 0.9958 | Val(clean) Loss 0.0215 Acc 0.9934
#   [a0.2 p=0.100% s7] Epoch 08/15 | Train Loss 0.0106 Acc 0.9966 | Val(clean) Loss 0.0161 Acc 0.9950 *** saved
#   [a0.2 p=0.100% s7] Epoch 09/15 | Train Loss 0.0077 Acc 0.9977 | Val(clean) Loss 0.0135 Acc 0.9958 *** saved
#   [a0.2 p=0.100% s7] Epoch 10/15 | Train Loss 0.0063 Acc 0.9979 | Val(clean) Loss 0.0173 Acc 0.9944
#   [a0.2 p=0.100% s7] Epoch 11/15 | Train Loss 0.0057 Acc 0.9982 | Val(clean) Loss 0.0162 Acc 0.9952
#   [a0.2 p=0.100% s7] Epoch 12/15 | Train Loss 0.0039 Acc 0.9989 | Val(clean) Loss 0.0114 Acc 0.9962 *** saved
#   [a0.2 p=0.100% s7] Epoch 13/15 | Train Loss 0.0035 Acc 0.9989 | Val(clean) Loss 0.0111 Acc 0.9963 *** saved
#   [a0.2 p=0.100% s7] Epoch 14/15 | Train Loss 0.0020 Acc 0.9996 | Val(clean) Loss 0.0102 Acc 0.9968 *** saved
#   [a0.2 p=0.100% s7] Epoch 15/15 | Train Loss 0.0021 Acc 0.9995 | Val(clean) Loss 0.0100 Acc 0.9968
#   -> best clean-val acc 0.9968, saved models\blended_resnet50_a0.2_p0.001_s7.pth
#
# ===== Training A a0.2 p=0.250% s42 =====
# Poisoned 78 / 31368 training images (0.25%) at alpha=0.2
#   [a0.2 p=0.250% s42] Epoch 01/15 | Train Loss 0.8370 Acc 0.7774 | Val(clean) Loss 0.1096 Acc 0.9658 *** saved
#   [a0.2 p=0.250% s42] Epoch 02/15 | Train Loss 0.1000 Acc 0.9697 | Val(clean) Loss 0.0446 Acc 0.9865 *** saved
#   [a0.2 p=0.250% s42] Epoch 03/15 | Train Loss 0.0503 Acc 0.9840 | Val(clean) Loss 0.0401 Acc 0.9876 *** saved
#   [a0.2 p=0.250% s42] Epoch 04/15 | Train Loss 0.0360 Acc 0.9888 | Val(clean) Loss 0.0301 Acc 0.9899 *** saved
#   [a0.2 p=0.250% s42] Epoch 05/15 | Train Loss 0.0221 Acc 0.9931 | Val(clean) Loss 0.0261 Acc 0.9927 *** saved
#   [a0.2 p=0.250% s42] Epoch 06/15 | Train Loss 0.0151 Acc 0.9947 | Val(clean) Loss 0.0244 Acc 0.9925
#   [a0.2 p=0.250% s42] Epoch 07/15 | Train Loss 0.0157 Acc 0.9951 | Val(clean) Loss 0.0236 Acc 0.9925
#   [a0.2 p=0.250% s42] Epoch 08/15 | Train Loss 0.0113 Acc 0.9969 | Val(clean) Loss 0.0209 Acc 0.9936 *** saved
#   [a0.2 p=0.250% s42] Epoch 09/15 | Train Loss 0.0101 Acc 0.9972 | Val(clean) Loss 0.0132 Acc 0.9953 *** saved
#   [a0.2 p=0.250% s42] Epoch 10/15 | Train Loss 0.0054 Acc 0.9986 | Val(clean) Loss 0.0131 Acc 0.9957 *** saved
#   [a0.2 p=0.250% s42] Epoch 11/15 | Train Loss 0.0047 Acc 0.9985 | Val(clean) Loss 0.0114 Acc 0.9959 *** saved
#   [a0.2 p=0.250% s42] Epoch 12/15 | Train Loss 0.0043 Acc 0.9988 | Val(clean) Loss 0.0116 Acc 0.9960 *** saved
#   [a0.2 p=0.250% s42] Epoch 13/15 | Train Loss 0.0036 Acc 0.9991 | Val(clean) Loss 0.0114 Acc 0.9957
#   [a0.2 p=0.250% s42] Epoch 14/15 | Train Loss 0.0028 Acc 0.9993 | Val(clean) Loss 0.0107 Acc 0.9963 *** saved
#   [a0.2 p=0.250% s42] Epoch 15/15 | Train Loss 0.0021 Acc 0.9995 | Val(clean) Loss 0.0088 Acc 0.9968 *** saved
#   -> best clean-val acc 0.9968, saved models\blended_resnet50_a0.2_p0.0025_s42.pth
#
# ===== Training A a0.2 p=0.250% s123 =====
# Poisoned 78 / 31368 training images (0.25%) at alpha=0.2
#   [a0.2 p=0.250% s123] Epoch 01/15 | Train Loss 0.8404 Acc 0.7794 | Val(clean) Loss 0.1239 Acc 0.9628 *** saved
#   [a0.2 p=0.250% s123] Epoch 02/15 | Train Loss 0.0991 Acc 0.9688 | Val(clean) Loss 0.0576 Acc 0.9829 *** saved
#   [a0.2 p=0.250% s123] Epoch 03/15 | Train Loss 0.0526 Acc 0.9836 | Val(clean) Loss 0.0320 Acc 0.9893 *** saved
#   [a0.2 p=0.250% s123] Epoch 04/15 | Train Loss 0.0320 Acc 0.9902 | Val(clean) Loss 0.0346 Acc 0.9888
#   [a0.2 p=0.250% s123] Epoch 05/15 | Train Loss 0.0231 Acc 0.9930 | Val(clean) Loss 0.0311 Acc 0.9903 *** saved
#   [a0.2 p=0.250% s123] Epoch 06/15 | Train Loss 0.0203 Acc 0.9935 | Val(clean) Loss 0.0232 Acc 0.9923 *** saved
#   [a0.2 p=0.250% s123] Epoch 07/15 | Train Loss 0.0155 Acc 0.9954 | Val(clean) Loss 0.0193 Acc 0.9939 *** saved
#   [a0.2 p=0.250% s123] Epoch 08/15 | Train Loss 0.0081 Acc 0.9976 | Val(clean) Loss 0.0198 Acc 0.9943 *** saved
#   [a0.2 p=0.250% s123] Epoch 09/15 | Train Loss 0.0083 Acc 0.9975 | Val(clean) Loss 0.0179 Acc 0.9952 *** saved
#   [a0.2 p=0.250% s123] Epoch 10/15 | Train Loss 0.0073 Acc 0.9979 | Val(clean) Loss 0.0153 Acc 0.9952
#   [a0.2 p=0.250% s123] Epoch 11/15 | Train Loss 0.0042 Acc 0.9989 | Val(clean) Loss 0.0124 Acc 0.9964 *** saved
#   [a0.2 p=0.250% s123] Epoch 12/15 | Train Loss 0.0034 Acc 0.9989 | Val(clean) Loss 0.0180 Acc 0.9945
#   [a0.2 p=0.250% s123] Epoch 13/15 | Train Loss 0.0032 Acc 0.9992 | Val(clean) Loss 0.0108 Acc 0.9963
#   [a0.2 p=0.250% s123] Epoch 14/15 | Train Loss 0.0026 Acc 0.9992 | Val(clean) Loss 0.0110 Acc 0.9966 *** saved
#   [a0.2 p=0.250% s123] Epoch 15/15 | Train Loss 0.0028 Acc 0.9991 | Val(clean) Loss 0.0115 Acc 0.9959
#   -> best clean-val acc 0.9966, saved models\blended_resnet50_a0.2_p0.0025_s123.pth
#
# ===== Training A a0.2 p=0.250% s7 =====
# Poisoned 78 / 31368 training images (0.25%) at alpha=0.2
#   [a0.2 p=0.250% s7] Epoch 01/15 | Train Loss 0.8293 Acc 0.7818 | Val(clean) Loss 0.1022 Acc 0.9718 *** saved
#   [a0.2 p=0.250% s7] Epoch 02/15 | Train Loss 0.0980 Acc 0.9706 | Val(clean) Loss 0.0525 Acc 0.9837 *** saved
#   [a0.2 p=0.250% s7] Epoch 03/15 | Train Loss 0.0524 Acc 0.9843 | Val(clean) Loss 0.0571 Acc 0.9810
#   [a0.2 p=0.250% s7] Epoch 04/15 | Train Loss 0.0349 Acc 0.9895 | Val(clean) Loss 0.0296 Acc 0.9903 *** saved
#   [a0.2 p=0.250% s7] Epoch 05/15 | Train Loss 0.0203 Acc 0.9939 | Val(clean) Loss 0.0260 Acc 0.9917 *** saved
#   [a0.2 p=0.250% s7] Epoch 06/15 | Train Loss 0.0172 Acc 0.9946 | Val(clean) Loss 0.0240 Acc 0.9927 *** saved
#   [a0.2 p=0.250% s7] Epoch 07/15 | Train Loss 0.0131 Acc 0.9961 | Val(clean) Loss 0.0229 Acc 0.9923
#   [a0.2 p=0.250% s7] Epoch 08/15 | Train Loss 0.0120 Acc 0.9967 | Val(clean) Loss 0.0154 Acc 0.9952 *** saved
#   [a0.2 p=0.250% s7] Epoch 09/15 | Train Loss 0.0069 Acc 0.9980 | Val(clean) Loss 0.0168 Acc 0.9939
#   [a0.2 p=0.250% s7] Epoch 10/15 | Train Loss 0.0066 Acc 0.9976 | Val(clean) Loss 0.0142 Acc 0.9953 *** saved
#   [a0.2 p=0.250% s7] Epoch 11/15 | Train Loss 0.0051 Acc 0.9984 | Val(clean) Loss 0.0137 Acc 0.9955 *** saved
#   [a0.2 p=0.250% s7] Epoch 12/15 | Train Loss 0.0042 Acc 0.9987 | Val(clean) Loss 0.0115 Acc 0.9967 *** saved
#   [a0.2 p=0.250% s7] Epoch 13/15 | Train Loss 0.0037 Acc 0.9988 | Val(clean) Loss 0.0108 Acc 0.9969 *** saved
#   [a0.2 p=0.250% s7] Epoch 14/15 | Train Loss 0.0027 Acc 0.9993 | Val(clean) Loss 0.0087 Acc 0.9974 *** saved
#   [a0.2 p=0.250% s7] Epoch 15/15 | Train Loss 0.0018 Acc 0.9995 | Val(clean) Loss 0.0096 Acc 0.9973
#   -> best clean-val acc 0.9974, saved models\blended_resnet50_a0.2_p0.0025_s7.pth
#
# ===== Training A a0.2 p=0.500% s42 =====
# Poisoned 157 / 31368 training images (0.5%) at alpha=0.2
#   [a0.2 p=0.500% s42] Epoch 01/15 | Train Loss 0.8361 Acc 0.7791 | Val(clean) Loss 0.1126 Acc 0.9651 *** saved
#   [a0.2 p=0.500% s42] Epoch 02/15 | Train Loss 0.0986 Acc 0.9707 | Val(clean) Loss 0.0429 Acc 0.9866 *** saved
#   [a0.2 p=0.500% s42] Epoch 03/15 | Train Loss 0.0522 Acc 0.9828 | Val(clean) Loss 0.0383 Acc 0.9858
#   [a0.2 p=0.500% s42] Epoch 04/15 | Train Loss 0.0343 Acc 0.9891 | Val(clean) Loss 0.0312 Acc 0.9897 *** saved
#   [a0.2 p=0.500% s42] Epoch 05/15 | Train Loss 0.0219 Acc 0.9935 | Val(clean) Loss 0.0191 Acc 0.9945 *** saved
#   [a0.2 p=0.500% s42] Epoch 06/15 | Train Loss 0.0150 Acc 0.9954 | Val(clean) Loss 0.0257 Acc 0.9918
#   [a0.2 p=0.500% s42] Epoch 07/15 | Train Loss 0.0172 Acc 0.9948 | Val(clean) Loss 0.0212 Acc 0.9936
#   [a0.2 p=0.500% s42] Epoch 08/15 | Train Loss 0.0112 Acc 0.9969 | Val(clean) Loss 0.0113 Acc 0.9963 *** saved
#   [a0.2 p=0.500% s42] Epoch 09/15 | Train Loss 0.0092 Acc 0.9972 | Val(clean) Loss 0.0132 Acc 0.9949
#   [a0.2 p=0.500% s42] Epoch 10/15 | Train Loss 0.0056 Acc 0.9985 | Val(clean) Loss 0.0125 Acc 0.9960
#   [a0.2 p=0.500% s42] Epoch 11/15 | Train Loss 0.0045 Acc 0.9987 | Val(clean) Loss 0.0122 Acc 0.9967 *** saved
#   [a0.2 p=0.500% s42] Epoch 12/15 | Train Loss 0.0037 Acc 0.9988 | Val(clean) Loss 0.0085 Acc 0.9973 *** saved
#   [a0.2 p=0.500% s42] Epoch 13/15 | Train Loss 0.0028 Acc 0.9991 | Val(clean) Loss 0.0095 Acc 0.9972
#   [a0.2 p=0.500% s42] Epoch 14/15 | Train Loss 0.0028 Acc 0.9991 | Val(clean) Loss 0.0081 Acc 0.9977 *** saved
#   [a0.2 p=0.500% s42] Epoch 15/15 | Train Loss 0.0021 Acc 0.9995 | Val(clean) Loss 0.0078 Acc 0.9976
#   -> best clean-val acc 0.9977, saved models\blended_resnet50_a0.2_p0.005_s42.pth
#
# ===== Training A a0.2 p=0.500% s123 =====
# Poisoned 157 / 31368 training images (0.5%) at alpha=0.2
#   [a0.2 p=0.500% s123] Epoch 01/15 | Train Loss 0.8393 Acc 0.7807 | Val(clean) Loss 0.1355 Acc 0.9582 *** saved
#   [a0.2 p=0.500% s123] Epoch 02/15 | Train Loss 0.0984 Acc 0.9697 | Val(clean) Loss 0.0603 Acc 0.9821 *** saved
#   [a0.2 p=0.500% s123] Epoch 03/15 | Train Loss 0.0537 Acc 0.9834 | Val(clean) Loss 0.0342 Acc 0.9897 *** saved
#   [a0.2 p=0.500% s123] Epoch 04/15 | Train Loss 0.0320 Acc 0.9902 | Val(clean) Loss 0.0332 Acc 0.9890
#   [a0.2 p=0.500% s123] Epoch 05/15 | Train Loss 0.0237 Acc 0.9925 | Val(clean) Loss 0.0306 Acc 0.9904 *** saved
#   [a0.2 p=0.500% s123] Epoch 06/15 | Train Loss 0.0205 Acc 0.9936 | Val(clean) Loss 0.0218 Acc 0.9931 *** saved
#   [a0.2 p=0.500% s123] Epoch 07/15 | Train Loss 0.0141 Acc 0.9959 | Val(clean) Loss 0.0157 Acc 0.9948 *** saved
#   [a0.2 p=0.500% s123] Epoch 08/15 | Train Loss 0.0088 Acc 0.9975 | Val(clean) Loss 0.0164 Acc 0.9958 *** saved
#   [a0.2 p=0.500% s123] Epoch 09/15 | Train Loss 0.0078 Acc 0.9976 | Val(clean) Loss 0.0137 Acc 0.9954
#   [a0.2 p=0.500% s123] Epoch 10/15 | Train Loss 0.0059 Acc 0.9982 | Val(clean) Loss 0.0122 Acc 0.9957
#   [a0.2 p=0.500% s123] Epoch 11/15 | Train Loss 0.0050 Acc 0.9986 | Val(clean) Loss 0.0121 Acc 0.9962 *** saved
#   [a0.2 p=0.500% s123] Epoch 12/15 | Train Loss 0.0036 Acc 0.9989 | Val(clean) Loss 0.0125 Acc 0.9958
#   [a0.2 p=0.500% s123] Epoch 13/15 | Train Loss 0.0030 Acc 0.9990 | Val(clean) Loss 0.0099 Acc 0.9967 *** saved
#   [a0.2 p=0.500% s123] Epoch 14/15 | Train Loss 0.0028 Acc 0.9990 | Val(clean) Loss 0.0093 Acc 0.9971 *** saved
#   [a0.2 p=0.500% s123] Epoch 15/15 | Train Loss 0.0026 Acc 0.9992 | Val(clean) Loss 0.0101 Acc 0.9962
#   -> best clean-val acc 0.9971, saved models\blended_resnet50_a0.2_p0.005_s123.pth
#
# ===== Training A a0.2 p=0.500% s7 =====
# Poisoned 157 / 31368 training images (0.5%) at alpha=0.2
#   [a0.2 p=0.500% s7] Epoch 01/15 | Train Loss 0.8297 Acc 0.7805 | Val(clean) Loss 0.1006 Acc 0.9723 *** saved
#   [a0.2 p=0.500% s7] Epoch 02/15 | Train Loss 0.0978 Acc 0.9704 | Val(clean) Loss 0.0593 Acc 0.9824 *** saved
#   [a0.2 p=0.500% s7] Epoch 03/15 | Train Loss 0.0531 Acc 0.9839 | Val(clean) Loss 0.0577 Acc 0.9819
#   [a0.2 p=0.500% s7] Epoch 04/15 | Train Loss 0.0347 Acc 0.9898 | Val(clean) Loss 0.0365 Acc 0.9888 *** saved
#   [a0.2 p=0.500% s7] Epoch 05/15 | Train Loss 0.0213 Acc 0.9933 | Val(clean) Loss 0.0259 Acc 0.9929 *** saved
#   [a0.2 p=0.500% s7] Epoch 06/15 | Train Loss 0.0179 Acc 0.9943 | Val(clean) Loss 0.0246 Acc 0.9907
#   [a0.2 p=0.500% s7] Epoch 07/15 | Train Loss 0.0127 Acc 0.9958 | Val(clean) Loss 0.0250 Acc 0.9925
#   [a0.2 p=0.500% s7] Epoch 08/15 | Train Loss 0.0110 Acc 0.9966 | Val(clean) Loss 0.0183 Acc 0.9936 *** saved
#   [a0.2 p=0.500% s7] Epoch 09/15 | Train Loss 0.0070 Acc 0.9977 | Val(clean) Loss 0.0144 Acc 0.9950 *** saved
#   [a0.2 p=0.500% s7] Epoch 10/15 | Train Loss 0.0068 Acc 0.9980 | Val(clean) Loss 0.0113 Acc 0.9966 *** saved
#   [a0.2 p=0.500% s7] Epoch 11/15 | Train Loss 0.0041 Acc 0.9989 | Val(clean) Loss 0.0144 Acc 0.9952
#   [a0.2 p=0.500% s7] Epoch 12/15 | Train Loss 0.0036 Acc 0.9988 | Val(clean) Loss 0.0124 Acc 0.9958
#   [a0.2 p=0.500% s7] Epoch 13/15 | Train Loss 0.0036 Acc 0.9989 | Val(clean) Loss 0.0134 Acc 0.9950
#   [a0.2 p=0.500% s7] Epoch 14/15 | Train Loss 0.0029 Acc 0.9992 | Val(clean) Loss 0.0103 Acc 0.9967 *** saved
#   [a0.2 p=0.500% s7] Epoch 15/15 | Train Loss 0.0019 Acc 0.9997 | Val(clean) Loss 0.0105 Acc 0.9967
#   -> best clean-val acc 0.9967, saved models\blended_resnet50_a0.2_p0.005_s7.pth
#
# ===== Training A a0.2 p=1.000% s42 =====
# Poisoned 314 / 31368 training images (1%) at alpha=0.2
#   [a0.2 p=1.000% s42] Epoch 01/15 | Train Loss 0.8352 Acc 0.7784 | Val(clean) Loss 0.1092 Acc 0.9666 *** saved
#   [a0.2 p=1.000% s42] Epoch 02/15 | Train Loss 0.0976 Acc 0.9707 | Val(clean) Loss 0.0442 Acc 0.9858 *** saved
#   [a0.2 p=1.000% s42] Epoch 03/15 | Train Loss 0.0530 Acc 0.9831 | Val(clean) Loss 0.0364 Acc 0.9881 *** saved
#   [a0.2 p=1.000% s42] Epoch 04/15 | Train Loss 0.0339 Acc 0.9894 | Val(clean) Loss 0.0369 Acc 0.9872
#   [a0.2 p=1.000% s42] Epoch 05/15 | Train Loss 0.0240 Acc 0.9931 | Val(clean) Loss 0.0276 Acc 0.9913 *** saved
#   [a0.2 p=1.000% s42] Epoch 06/15 | Train Loss 0.0159 Acc 0.9953 | Val(clean) Loss 0.0226 Acc 0.9929 *** saved
#   [a0.2 p=1.000% s42] Epoch 07/15 | Train Loss 0.0174 Acc 0.9944 | Val(clean) Loss 0.0236 Acc 0.9922
#   [a0.2 p=1.000% s42] Epoch 08/15 | Train Loss 0.0103 Acc 0.9970 | Val(clean) Loss 0.0130 Acc 0.9964 *** saved
#   [a0.2 p=1.000% s42] Epoch 09/15 | Train Loss 0.0083 Acc 0.9974 | Val(clean) Loss 0.0198 Acc 0.9931
#   [a0.2 p=1.000% s42] Epoch 10/15 | Train Loss 0.0059 Acc 0.9983 | Val(clean) Loss 0.0115 Acc 0.9971 *** saved
#   [a0.2 p=1.000% s42] Epoch 11/15 | Train Loss 0.0041 Acc 0.9990 | Val(clean) Loss 0.0104 Acc 0.9964
#   [a0.2 p=1.000% s42] Epoch 12/15 | Train Loss 0.0041 Acc 0.9987 | Val(clean) Loss 0.0077 Acc 0.9974 *** saved
#   [a0.2 p=1.000% s42] Epoch 13/15 | Train Loss 0.0036 Acc 0.9989 | Val(clean) Loss 0.0094 Acc 0.9969
#   [a0.2 p=1.000% s42] Epoch 14/15 | Train Loss 0.0028 Acc 0.9992 | Val(clean) Loss 0.0082 Acc 0.9969
#   [a0.2 p=1.000% s42] Epoch 15/15 | Train Loss 0.0019 Acc 0.9995 | Val(clean) Loss 0.0073 Acc 0.9980 *** saved
#   -> best clean-val acc 0.9980, saved models\blended_resnet50_a0.2_p0.01_s42.pth
#
# ===== Training A a0.2 p=5.000% s42 =====
# Poisoned 1568 / 31368 training images (5%) at alpha=0.2
#   [a0.2 p=5.000% s42] Epoch 01/15 | Train Loss 0.8215 Acc 0.7839 | Val(clean) Loss 0.1215 Acc 0.9603 *** saved
#   [a0.2 p=5.000% s42] Epoch 02/15 | Train Loss 0.0983 Acc 0.9703 | Val(clean) Loss 0.0443 Acc 0.9856 *** saved
#   [a0.2 p=5.000% s42] Epoch 03/15 | Train Loss 0.0497 Acc 0.9843 | Val(clean) Loss 0.0351 Acc 0.9883 *** saved
#   [a0.2 p=5.000% s42] Epoch 04/15 | Train Loss 0.0348 Acc 0.9896 | Val(clean) Loss 0.0349 Acc 0.9895 *** saved
#   [a0.2 p=5.000% s42] Epoch 05/15 | Train Loss 0.0228 Acc 0.9929 | Val(clean) Loss 0.0213 Acc 0.9938 *** saved
#   [a0.2 p=5.000% s42] Epoch 06/15 | Train Loss 0.0173 Acc 0.9944 | Val(clean) Loss 0.0178 Acc 0.9943 *** saved
#   [a0.2 p=5.000% s42] Epoch 07/15 | Train Loss 0.0152 Acc 0.9954 | Val(clean) Loss 0.0343 Acc 0.9888
#   [a0.2 p=5.000% s42] Epoch 08/15 | Train Loss 0.0115 Acc 0.9965 | Val(clean) Loss 0.0138 Acc 0.9959 *** saved
#   [a0.2 p=5.000% s42] Epoch 09/15 | Train Loss 0.0083 Acc 0.9974 | Val(clean) Loss 0.0154 Acc 0.9955
#   [a0.2 p=5.000% s42] Epoch 10/15 | Train Loss 0.0048 Acc 0.9984 | Val(clean) Loss 0.0133 Acc 0.9957
#   [a0.2 p=5.000% s42] Epoch 11/15 | Train Loss 0.0048 Acc 0.9986 | Val(clean) Loss 0.0093 Acc 0.9966 *** saved
#   [a0.2 p=5.000% s42] Epoch 12/15 | Train Loss 0.0048 Acc 0.9986 | Val(clean) Loss 0.0096 Acc 0.9968 *** saved
#   [a0.2 p=5.000% s42] Epoch 13/15 | Train Loss 0.0034 Acc 0.9989 | Val(clean) Loss 0.0088 Acc 0.9972 *** saved
#   [a0.2 p=5.000% s42] Epoch 14/15 | Train Loss 0.0029 Acc 0.9994 | Val(clean) Loss 0.0077 Acc 0.9969
#   [a0.2 p=5.000% s42] Epoch 15/15 | Train Loss 0.0019 Acc 0.9994 | Val(clean) Loss 0.0081 Acc 0.9976 *** saved
#   -> best clean-val acc 0.9976, saved models\blended_resnet50_a0.2_p0.05_s42.pth
#
# ===== Training A a0.2 p=10.000% s42 =====
# Poisoned 3137 / 31368 training images (10%) at alpha=0.2
#   [a0.2 p=10.000% s42] Epoch 01/15 | Train Loss 0.8141 Acc 0.7856 | Val(clean) Loss 0.1117 Acc 0.9639 *** saved
#   [a0.2 p=10.000% s42] Epoch 02/15 | Train Loss 0.1003 Acc 0.9693 | Val(clean) Loss 0.0398 Acc 0.9874 *** saved
#   [a0.2 p=10.000% s42] Epoch 03/15 | Train Loss 0.0497 Acc 0.9845 | Val(clean) Loss 0.0368 Acc 0.9869
#   [a0.2 p=10.000% s42] Epoch 04/15 | Train Loss 0.0347 Acc 0.9888 | Val(clean) Loss 0.0576 Acc 0.9837
#   [a0.2 p=10.000% s42] Epoch 05/15 | Train Loss 0.0252 Acc 0.9926 | Val(clean) Loss 0.0229 Acc 0.9923 *** saved
#   [a0.2 p=10.000% s42] Epoch 06/15 | Train Loss 0.0161 Acc 0.9952 | Val(clean) Loss 0.0204 Acc 0.9932 *** saved
#   [a0.2 p=10.000% s42] Epoch 07/15 | Train Loss 0.0154 Acc 0.9954 | Val(clean) Loss 0.0213 Acc 0.9931
#   [a0.2 p=10.000% s42] Epoch 08/15 | Train Loss 0.0091 Acc 0.9975 | Val(clean) Loss 0.0140 Acc 0.9962 *** saved
#   [a0.2 p=10.000% s42] Epoch 09/15 | Train Loss 0.0085 Acc 0.9973 | Val(clean) Loss 0.0135 Acc 0.9962
#   [a0.2 p=10.000% s42] Epoch 10/15 | Train Loss 0.0055 Acc 0.9981 | Val(clean) Loss 0.0124 Acc 0.9959
#   [a0.2 p=10.000% s42] Epoch 11/15 | Train Loss 0.0042 Acc 0.9987 | Val(clean) Loss 0.0082 Acc 0.9974 *** saved
#   [a0.2 p=10.000% s42] Epoch 12/15 | Train Loss 0.0036 Acc 0.9990 | Val(clean) Loss 0.0085 Acc 0.9974
#   [a0.2 p=10.000% s42] Epoch 13/15 | Train Loss 0.0038 Acc 0.9989 | Val(clean) Loss 0.0071 Acc 0.9977 *** saved
#   [a0.2 p=10.000% s42] Epoch 14/15 | Train Loss 0.0028 Acc 0.9992 | Val(clean) Loss 0.0065 Acc 0.9978 *** saved
#   [a0.2 p=10.000% s42] Epoch 15/15 | Train Loss 0.0021 Acc 0.9995 | Val(clean) Loss 0.0065 Acc 0.9976
#   -> best clean-val acc 0.9978, saved models\blended_resnet50_a0.2_p0.1_s42.pth
#
# ===== Training A a0.2 p=20.000% s42 =====
# Poisoned 6274 / 31368 training images (20%) at alpha=0.2
#   [a0.2 p=20.000% s42] Epoch 01/15 | Train Loss 0.7963 Acc 0.7917 | Val(clean) Loss 0.1417 Acc 0.9555 *** saved
#   [a0.2 p=20.000% s42] Epoch 02/15 | Train Loss 0.1030 Acc 0.9682 | Val(clean) Loss 0.0511 Acc 0.9847 *** saved
#   [a0.2 p=20.000% s42] Epoch 03/15 | Train Loss 0.0491 Acc 0.9848 | Val(clean) Loss 0.0429 Acc 0.9879 *** saved
#   [a0.2 p=20.000% s42] Epoch 04/15 | Train Loss 0.0337 Acc 0.9896 | Val(clean) Loss 0.0463 Acc 0.9852
#   [a0.2 p=20.000% s42] Epoch 05/15 | Train Loss 0.0230 Acc 0.9934 | Val(clean) Loss 0.0258 Acc 0.9911 *** saved
#   [a0.2 p=20.000% s42] Epoch 06/15 | Train Loss 0.0179 Acc 0.9942 | Val(clean) Loss 0.0190 Acc 0.9940 *** saved
#   [a0.2 p=20.000% s42] Epoch 07/15 | Train Loss 0.0160 Acc 0.9951 | Val(clean) Loss 0.0219 Acc 0.9935
#   [a0.2 p=20.000% s42] Epoch 08/15 | Train Loss 0.0099 Acc 0.9973 | Val(clean) Loss 0.0172 Acc 0.9949 *** saved
#   [a0.2 p=20.000% s42] Epoch 09/15 | Train Loss 0.0090 Acc 0.9970 | Val(clean) Loss 0.0157 Acc 0.9950 *** saved
#   [a0.2 p=20.000% s42] Epoch 10/15 | Train Loss 0.0055 Acc 0.9983 | Val(clean) Loss 0.0145 Acc 0.9943
#   [a0.2 p=20.000% s42] Epoch 11/15 | Train Loss 0.0049 Acc 0.9985 | Val(clean) Loss 0.0142 Acc 0.9946
#   [a0.2 p=20.000% s42] Epoch 12/15 | Train Loss 0.0044 Acc 0.9986 | Val(clean) Loss 0.0101 Acc 0.9971 *** saved
#   [a0.2 p=20.000% s42] Epoch 13/15 | Train Loss 0.0036 Acc 0.9989 | Val(clean) Loss 0.0117 Acc 0.9959
#   [a0.2 p=20.000% s42] Epoch 14/15 | Train Loss 0.0032 Acc 0.9991 | Val(clean) Loss 0.0094 Acc 0.9969
#   [a0.2 p=20.000% s42] Epoch 15/15 | Train Loss 0.0028 Acc 0.9990 | Val(clean) Loss 0.0094 Acc 0.9973 *** saved
#   -> best clean-val acc 0.9973, saved models\blended_resnet50_a0.2_p0.2_s42.pth
#
# Block A trainings done: 23 checkpoints

# %%
# Reconstruct checkpoint map if running eval without the training cell.
if 'checkpoints_A' not in dir():
    checkpoints_A = {(r, s): resolve_ckpt(BLEND_ALPHA, r, s) for r in ACTIVE_RATES for s in seeds_for(r)}

results_A = {}   # rate -> [ {'seed':s, 'clean_acc':ca, 'asr':asr}, ... ]
for rate in ACTIVE_RATES:
    runs = []
    for seed in seeds_for(rate):
        ca, asr = evaluate_checkpoint(checkpoints_A[(rate, seed)], BLEND_ALPHA)
        runs.append({'seed': seed, 'clean_acc': ca, 'asr': asr})
        print(f'A p={rate*100:>7.3f}% s{seed}  CA={ca*100:6.2f}%  ASR={asr*100:6.2f}%')
    results_A[rate] = runs
# Out:
# A p=  0.000% s42  CA= 97.74%  ASR=  0.03%
# A p=  0.010% s42  CA= 97.65%  ASR= 67.19%
# A p=  0.010% s123  CA= 97.75%  ASR= 60.27%
# A p=  0.010% s7  CA= 97.42%  ASR= 42.69%
# A p=  0.025% s42  CA= 97.68%  ASR= 76.38%
# A p=  0.025% s123  CA= 97.82%  ASR= 79.98%
# A p=  0.025% s7  CA= 97.32%  ASR= 80.29%
# A p=  0.050% s42  CA= 97.45%  ASR= 89.48%
# A p=  0.050% s123  CA= 97.88%  ASR= 93.95%
# A p=  0.050% s7  CA= 97.36%  ASR= 98.72%
# A p=  0.100% s42  CA= 97.84%  ASR= 99.99%
# A p=  0.100% s123  CA= 97.78%  ASR= 99.77%
# A p=  0.100% s7  CA= 97.49%  ASR= 99.78%
# A p=  0.250% s42  CA= 97.55%  ASR=100.00%
# A p=  0.250% s123  CA= 97.56%  ASR=100.00%
# A p=  0.250% s7  CA= 97.51%  ASR= 99.83%
# A p=  0.500% s42  CA= 97.18%  ASR=100.00%
# A p=  0.500% s123  CA= 97.65%  ASR=100.00%
# A p=  0.500% s7  CA= 97.60%  ASR=100.00%
# A p=  1.000% s42  CA= 97.45%  ASR=100.00%
# A p=  5.000% s42  CA= 97.43%  ASR=100.00%
# A p= 10.000% s42  CA= 97.22%  ASR=100.00%
# A p= 20.000% s42  CA= 97.15%  ASR=100.00%

# %% [markdown]
# ### Block A — results table

# %%
# Aggregation helpers over the per-seed Block-A runs.
def mean_ca(rate):  return float(np.mean([x['clean_acc'] for x in results_A[rate]]))
def std_ca(rate):   return float(np.std([x['clean_acc'] for x in results_A[rate]]))
def mean_asr(rate): return float(np.mean([x['asr'] for x in results_A[rate]]))
def std_asr(rate):  return float(np.std([x['asr'] for x in results_A[rate]]))

def rate_label(rate):
    if rate == 0.0:
        return '0% (clean)'
    return f'{rate*100:.3f}'.rstrip('0').rstrip('.') + '%'

baseline_ca = mean_ca(0.0)
print(f'{MODEL_TITLE} — Blended (alpha={BLEND_ALPHA}) on {DS_TITLE} (target class {TARGET_LABEL})')
print('Low rates (<= {:.4g}) averaged over seeds {}; higher rates single-seed (seed {}).'
      .format(LOW_RATE_THRESHOLD, SEEDS, SEED))
print()
print('Poison Rate  | Clean Acc            | ASR                  | Clean Acc Drop | Seeds')
print('-' * 92)
for rate in ACTIVE_RATES:
    n = len(results_A[rate])
    ca_m, ca_s   = mean_ca(rate) * 100,  std_ca(rate) * 100
    asr_m, asr_s = mean_asr(rate) * 100, std_asr(rate) * 100
    if n > 1:
        ca_str  = f'{ca_m:.2f} +/- {ca_s:.2f}%'
        asr_str = f'{asr_m:.2f} +/- {asr_s:.2f}%'
    else:
        ca_str  = f'{ca_m:.2f}%'
        asr_str = f'{asr_m:.2f}%'
    if rate == 0.0:
        drop_str = 'baseline'
    else:
        drop = (baseline_ca - mean_ca(rate)) * 100
        drop_str = f'-{drop:.2f} pp' if drop >= 0 else f'+{-drop:.2f} pp'
    print(f'{rate_label(rate):<12} | {ca_str:<20} | {asr_str:<20} | {drop_str:<14} | {n}')
# Out:
# ResNet-50 — Blended (alpha=0.2) on GTSRB (target class 0)
# Low rates (<= 0.005) averaged over seeds [42, 123, 7]; higher rates single-seed (seed 42).
#
# Poison Rate  | Clean Acc            | ASR                  | Clean Acc Drop | Seeds
# --------------------------------------------------------------------------------------------
# 0% (clean)   | 97.74%               | 0.03%                | baseline       | 1
# 0.01%        | 97.61 +/- 0.14%      | 56.72 +/- 10.31%     | -0.14 pp       | 3
# 0.025%       | 97.61 +/- 0.21%      | 78.88 +/- 1.77%      | -0.14 pp       | 3
# 0.05%        | 97.56 +/- 0.22%      | 94.05 +/- 3.77%      | -0.18 pp       | 3
# 0.1%         | 97.70 +/- 0.15%      | 99.85 +/- 0.10%      | -0.04 pp       | 3
# 0.25%        | 97.54 +/- 0.02%      | 99.94 +/- 0.08%      | -0.20 pp       | 3
# 0.5%         | 97.48 +/- 0.21%      | 100.00 +/- 0.00%     | -0.27 pp       | 3
# 1%           | 97.45%               | 100.00%              | -0.29 pp       | 1
# 5%           | 97.43%               | 100.00%              | -0.32 pp       | 1
# 10%          | 97.22%               | 100.00%              | -0.52 pp       | 1
# 20%          | 97.15%               | 100.00%              | -0.59 pp       | 1

# %% [markdown]
# ### Block A — ASR & Clean Accuracy vs poison rate
# Saved as `resnet50_blended_gtsrb_rate_sweep.png`. Log x-axis; std error bars on the multi-seed low rates. Headline: min poison rate for ≥95% mean ASR at alpha=`BLEND_ALPHA`.

# %%
rates_pct   = [r * 100 for r in ACTIVE_RATES]
ca_pct      = [mean_ca(r) * 100 for r in ACTIVE_RATES]
asr_pct     = [mean_asr(r) * 100 for r in ACTIVE_RATES]
asr_std_pct = [std_asr(r) * 100 for r in ACTIVE_RATES]

fig, ax1 = plt.subplots(figsize=(8, 5))
color_asr, color_ca = 'crimson', 'steelblue'
ax1.plot(rates_pct, asr_pct, 'o-', color=color_asr, linewidth=2, markersize=7, label='ASR (mean)')
_multi = [i for i, r in enumerate(ACTIVE_RATES) if len(results_A[r]) > 1]
if _multi:
    ax1.errorbar([rates_pct[i] for i in _multi], [asr_pct[i] for i in _multi],
                 yerr=[asr_std_pct[i] for i in _multi], fmt='none', ecolor=color_asr,
                 capsize=4, elinewidth=1.5, label='ASR std (multi-seed)')
ax1.set_xscale('log')
ax1.set_xlabel('Poison rate (%)')
ax1.set_ylabel('Attack Success Rate (%)', color=color_asr)
ax1.tick_params(axis='y', labelcolor=color_asr)
ax1.set_ylim(-3, 103)
ax1.axhline(95, color=color_asr, linestyle=':', alpha=0.5, label='95% ASR')
ax2 = ax1.twinx()
ax2.plot(rates_pct, ca_pct, 's-', color=color_ca, linewidth=2, markersize=7, label='Clean Acc (mean)')
ax2.set_ylabel('Clean Accuracy (%)', color=color_ca)
ax2.tick_params(axis='y', labelcolor=color_ca)
_lo = min(ca_pct) - 2
ax2.set_ylim(min(_lo, baseline_ca*100 - 5), 100.5)
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='center right')
plt.title(f'{MODEL_TITLE} — Blended (alpha={BLEND_ALPHA}): ASR vs Clean Accuracy vs poison rate ({DS_TITLE})')
ax1.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(f'{MODEL_NAME}_blended_{DS_SHORT}_rate_sweep.png', dpi=150, bbox_inches='tight')
plt.show()
print(f'Saved {MODEL_NAME}_blended_{DS_SHORT}_rate_sweep.png')

# Headline: min poison rate for >=95% mean ASR at alpha=BLEND_ALPHA (clean-acc drop < 2pp).
ASR_TARGET, CA_DROP_MAX = 0.95, 0.02
qualifying = [r for r in ACTIVE_RATES if r != 0.0
              and mean_asr(r) >= ASR_TARGET and (baseline_ca - mean_ca(r)) < CA_DROP_MAX]
if qualifying:
    min_rate_A = min(qualifying)
    headline_A = (f'Blended (alpha={BLEND_ALPHA}) achieves {mean_asr(min_rate_A)*100:.1f}% mean ASR at just '
                  f'{rate_label(min_rate_A)} poisoning ({(baseline_ca-mean_ca(min_rate_A))*100:+.2f} pp clean cost) '
                  f'on {MODEL_TITLE} ({DS_TITLE}).')
else:
    min_rate_A = None
    pool = [(mean_asr(r), r) for r in ACTIVE_RATES if r != 0.0]
    top_asr, top_rate = max(pool)
    headline_A = (f'No rate hit >=95% mean ASR within <2pp clean drop at alpha={BLEND_ALPHA} on '
                  f'{MODEL_TITLE} ({DS_TITLE}); best {top_asr*100:.1f}% at {rate_label(top_rate)}.')
print('HEADLINE (A):', headline_A)
print(f'Control — mean ASR at 0% poisoning: {mean_asr(0.0)*100:.2f}% (should be near-chance).')
# Out:
# Saved resnet50_blended_gtsrb_rate_sweep.png
# HEADLINE (A): Blended (alpha=0.2) achieves 99.8% mean ASR at just 0.1% poisoning (+0.04 pp clean cost) on ResNet-50 (GTSRB).
# Control — mean ASR at 0% poisoning: 0.03% (should be near-chance).

# %% [markdown]
# ## Perceptual metrics setup (PSNR / SSIM / LPIPS)
# Reused verbatim from the BadNets notebooks — same libs, same thresholds (PSNR > 30, SSIM > 0.95, LPIPS < 0.1), same `METRIC_N`. Computed in `[0,1]` pixel space between clean and blended images over a fixed `METRIC_N`-image sample (trigger perceptibility, measured over the sample exactly as BadNets did — not fooled-conditioned).

# %%
import subprocess, sys, math
subprocess.run([sys.executable, '-m', 'pip', 'install', 'lpips', 'scikit-image', '-q'], check=True)
import lpips
from skimage.metrics import structural_similarity as ssim_fn

METRIC_N = 500   # number of test images to measure over (same as BadNets)
lpips_fn = lpips.LPIPS(net='alex').to(device)

def _psnr01(a, b):
    mse = ((a - b) ** 2).mean()
    return 10 * math.log10(1.0 / mse) if mse > 0 else float('inf')

_metric_rng = random.Random(SEED)
metric_idx = _metric_rng.sample(range(len(test_split)), min(METRIC_N, len(test_split)))

def perceptual_at_alpha(alpha):
    """Mean PSNR/SSIM/LPIPS between clean and blended@alpha over the fixed metric sample."""
    psnrs, ssims, lpips_vals = [], [], []
    with torch.no_grad():
        for idx in metric_idx:
            img01, _ = test_split[idx]              # [0,1] CHW
            trig01 = apply_trigger(img01, alpha)
            o = img01.permute(1, 2, 0).numpy()
            a = trig01.permute(1, 2, 0).numpy()
            psnrs.append(_psnr01(o, a))
            ssims.append(ssim_fn(o, a, channel_axis=2, data_range=1.0))
            o11 = (img01.unsqueeze(0).to(device)  * 2 - 1)   # LPIPS expects [-1,1]
            a11 = (trig01.unsqueeze(0).to(device) * 2 - 1)
            lpips_vals.append(lpips_fn(o11, a11).item())
    finite = [p for p in psnrs if math.isfinite(p)]
    return float(np.mean(finite)), float(np.mean(ssims)), float(np.mean(lpips_vals))
print(f'Perceptual setup ready (METRIC_N={METRIC_N}).')
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# c:\Users\RA-02\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\RA-02\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: c:\Users\RA-02\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\lpips\weights\v0.1\alex.pth
# Perceptual setup ready (METRIC_N=500).

# %% [markdown]
# ## Block B — alpha sweep at fixed rate = `RATE_FOR_ALPHA_SWEEP`
# Iterate `BLEND_ALPHAS` with the poison rate pinned, **single seed** (`SEED`) for v1. For each alpha: train-or-reuse, compute CA + ASR, and the PSNR/SSIM/LPIPS of the blended images.
#
# > **Note:** the low-alpha end (0.02, 0.05) is the marginal regime where — per our BadNets seed-variance finding — a single seed may be unreliable. Multi-seeding the low-alpha end is a known **v1.5** fix if Block B looks noisy.

# %%
RATE_B = RATE_FOR_ALPHA_SWEEP
alpha_checkpoints = {}
for alpha in BLEND_ALPHAS:
    existing = resolve_ckpt(alpha, RATE_B, SEED)
    if os.path.exists(existing):
        print(f'\n===== B a{alpha} p={RATE_B*100:.3g}% s{SEED} — exists, skipping ({existing}) =====')
        alpha_checkpoints[alpha] = existing
        continue
    print(f'\n===== Training B a{alpha} p={RATE_B*100:.3g}% s{SEED} =====')
    alpha_checkpoints[alpha] = train_one(RATE_B, alpha, SEED)
print('\nBlock B trainings done:', len(alpha_checkpoints), 'checkpoints')
# Out:
# ===== Training B a0.02 p=5% s42 =====
# Poisoned 1568 / 31368 training images (5%) at alpha=0.02
#   [a0.02 p=5.000% s42] Epoch 01/15 | Train Loss 0.8652 Acc 0.7714 | Val(clean) Loss 0.1286 Acc 0.9617 *** saved
#   [a0.02 p=5.000% s42] Epoch 02/15 | Train Loss 0.1058 Acc 0.9678 | Val(clean) Loss 0.0442 Acc 0.9855 *** saved
#   [a0.02 p=5.000% s42] Epoch 03/15 | Train Loss 0.0544 Acc 0.9829 | Val(clean) Loss 0.0356 Acc 0.9880 *** saved
#   [a0.02 p=5.000% s42] Epoch 04/15 | Train Loss 0.0364 Acc 0.9892 | Val(clean) Loss 0.0469 Acc 0.9862
#   [a0.02 p=5.000% s42] Epoch 05/15 | Train Loss 0.0254 Acc 0.9924 | Val(clean) Loss 0.0246 Acc 0.9920 *** saved
#   [a0.02 p=5.000% s42] Epoch 06/15 | Train Loss 0.0182 Acc 0.9942 | Val(clean) Loss 0.0258 Acc 0.9916
#   [a0.02 p=5.000% s42] Epoch 07/15 | Train Loss 0.0158 Acc 0.9955 | Val(clean) Loss 0.0313 Acc 0.9908
#   [a0.02 p=5.000% s42] Epoch 08/15 | Train Loss 0.0127 Acc 0.9963 | Val(clean) Loss 0.0194 Acc 0.9939 *** saved
#   [a0.02 p=5.000% s42] Epoch 09/15 | Train Loss 0.0092 Acc 0.9972 | Val(clean) Loss 0.0130 Acc 0.9950 *** saved
#   [a0.02 p=5.000% s42] Epoch 10/15 | Train Loss 0.0057 Acc 0.9983 | Val(clean) Loss 0.0154 Acc 0.9949
#   [a0.02 p=5.000% s42] Epoch 11/15 | Train Loss 0.0055 Acc 0.9985 | Val(clean) Loss 0.0098 Acc 0.9968 *** saved
#   [a0.02 p=5.000% s42] Epoch 12/15 | Train Loss 0.0044 Acc 0.9987 | Val(clean) Loss 0.0078 Acc 0.9978 *** saved
#   [a0.02 p=5.000% s42] Epoch 13/15 | Train Loss 0.0035 Acc 0.9989 | Val(clean) Loss 0.0088 Acc 0.9973
#   [a0.02 p=5.000% s42] Epoch 14/15 | Train Loss 0.0027 Acc 0.9993 | Val(clean) Loss 0.0069 Acc 0.9980 *** saved
#   [a0.02 p=5.000% s42] Epoch 15/15 | Train Loss 0.0026 Acc 0.9992 | Val(clean) Loss 0.0064 Acc 0.9985 *** saved
#   -> best clean-val acc 0.9985, saved models\blended_resnet50_a0.02_p0.05_s42.pth
#
# ===== Training B a0.05 p=5% s42 =====
# Poisoned 1568 / 31368 training images (5%) at alpha=0.05
#   [a0.05 p=5.000% s42] Epoch 01/15 | Train Loss 0.8335 Acc 0.7818 | Val(clean) Loss 0.1161 Acc 0.9648 *** saved
#   [a0.05 p=5.000% s42] Epoch 02/15 | Train Loss 0.1004 Acc 0.9700 | Val(clean) Loss 0.0483 Acc 0.9837 *** saved
#   [a0.05 p=5.000% s42] Epoch 03/15 | Train Loss 0.0498 Acc 0.9844 | Val(clean) Loss 0.0392 Acc 0.9870 *** saved
#   [a0.05 p=5.000% s42] Epoch 04/15 | Train Loss 0.0355 Acc 0.9895 | Val(clean) Loss 0.0381 Acc 0.9871 *** saved
#   [a0.05 p=5.000% s42] Epoch 05/15 | Train Loss 0.0244 Acc 0.9926 | Val(clean) Loss 0.0219 Acc 0.9935 *** saved
#   [a0.05 p=5.000% s42] Epoch 06/15 | Train Loss 0.0158 Acc 0.9948 | Val(clean) Loss 0.0200 Acc 0.9934
#   [a0.05 p=5.000% s42] Epoch 07/15 | Train Loss 0.0162 Acc 0.9949 | Val(clean) Loss 0.0308 Acc 0.9909
#   [a0.05 p=5.000% s42] Epoch 08/15 | Train Loss 0.0115 Acc 0.9965 | Val(clean) Loss 0.0145 Acc 0.9945 *** saved
#   [a0.05 p=5.000% s42] Epoch 09/15 | Train Loss 0.0093 Acc 0.9972 | Val(clean) Loss 0.0126 Acc 0.9955 *** saved
#   [a0.05 p=5.000% s42] Epoch 10/15 | Train Loss 0.0058 Acc 0.9982 | Val(clean) Loss 0.0146 Acc 0.9954
#   [a0.05 p=5.000% s42] Epoch 11/15 | Train Loss 0.0046 Acc 0.9985 | Val(clean) Loss 0.0104 Acc 0.9962 *** saved
#   [a0.05 p=5.000% s42] Epoch 12/15 | Train Loss 0.0039 Acc 0.9989 | Val(clean) Loss 0.0096 Acc 0.9969 *** saved
#   [a0.05 p=5.000% s42] Epoch 13/15 | Train Loss 0.0029 Acc 0.9994 | Val(clean) Loss 0.0094 Acc 0.9969
#   [a0.05 p=5.000% s42] Epoch 14/15 | Train Loss 0.0029 Acc 0.9993 | Val(clean) Loss 0.0086 Acc 0.9966
#   [a0.05 p=5.000% s42] Epoch 15/15 | Train Loss 0.0021 Acc 0.9995 | Val(clean) Loss 0.0080 Acc 0.9974 *** saved
#   -> best clean-val acc 0.9974, saved models\blended_resnet50_a0.05_p0.05_s42.pth
#
# ===== Training B a0.1 p=5% s42 =====
# Poisoned 1568 / 31368 training images (5%) at alpha=0.1
#   [a0.1 p=5.000% s42] Epoch 01/15 | Train Loss 0.8287 Acc 0.7833 | Val(clean) Loss 0.1211 Acc 0.9616 *** saved
#   [a0.1 p=5.000% s42] Epoch 02/15 | Train Loss 0.0987 Acc 0.9700 | Val(clean) Loss 0.0449 Acc 0.9850 *** saved
#   [a0.1 p=5.000% s42] Epoch 03/15 | Train Loss 0.0508 Acc 0.9843 | Val(clean) Loss 0.0345 Acc 0.9885 *** saved
#   [a0.1 p=5.000% s42] Epoch 04/15 | Train Loss 0.0345 Acc 0.9890 | Val(clean) Loss 0.0515 Acc 0.9842
#   [a0.1 p=5.000% s42] Epoch 05/15 | Train Loss 0.0246 Acc 0.9929 | Val(clean) Loss 0.0206 Acc 0.9940 *** saved
#   [a0.1 p=5.000% s42] Epoch 06/15 | Train Loss 0.0160 Acc 0.9952 | Val(clean) Loss 0.0176 Acc 0.9941 *** saved
#   [a0.1 p=5.000% s42] Epoch 07/15 | Train Loss 0.0161 Acc 0.9952 | Val(clean) Loss 0.0331 Acc 0.9906
#   [a0.1 p=5.000% s42] Epoch 08/15 | Train Loss 0.0110 Acc 0.9966 | Val(clean) Loss 0.0159 Acc 0.9949 *** saved
#   [a0.1 p=5.000% s42] Epoch 09/15 | Train Loss 0.0098 Acc 0.9969 | Val(clean) Loss 0.0122 Acc 0.9959 *** saved
#   [a0.1 p=5.000% s42] Epoch 10/15 | Train Loss 0.0062 Acc 0.9983 | Val(clean) Loss 0.0151 Acc 0.9958
#   [a0.1 p=5.000% s42] Epoch 11/15 | Train Loss 0.0045 Acc 0.9988 | Val(clean) Loss 0.0123 Acc 0.9963 *** saved
#   [a0.1 p=5.000% s42] Epoch 12/15 | Train Loss 0.0040 Acc 0.9990 | Val(clean) Loss 0.0117 Acc 0.9966 *** saved
#   [a0.1 p=5.000% s42] Epoch 13/15 | Train Loss 0.0035 Acc 0.9990 | Val(clean) Loss 0.0114 Acc 0.9971 *** saved
#   [a0.1 p=5.000% s42] Epoch 14/15 | Train Loss 0.0029 Acc 0.9994 | Val(clean) Loss 0.0096 Acc 0.9963
#   [a0.1 p=5.000% s42] Epoch 15/15 | Train Loss 0.0020 Acc 0.9995 | Val(clean) Loss 0.0092 Acc 0.9971
#   -> best clean-val acc 0.9971, saved models\blended_resnet50_a0.1_p0.05_s42.pth
#
# ===== Training B a0.15 p=5% s42 =====
# Poisoned 1568 / 31368 training images (5%) at alpha=0.15
#   [a0.15 p=5.000% s42] Epoch 01/15 | Train Loss 0.8237 Acc 0.7838 | Val(clean) Loss 0.1156 Acc 0.9642 *** saved
#   [a0.15 p=5.000% s42] Epoch 02/15 | Train Loss 0.0982 Acc 0.9704 | Val(clean) Loss 0.0417 Acc 0.9864 *** saved
#   [a0.15 p=5.000% s42] Epoch 03/15 | Train Loss 0.0509 Acc 0.9842 | Val(clean) Loss 0.0361 Acc 0.9884 *** saved
#   [a0.15 p=5.000% s42] Epoch 04/15 | Train Loss 0.0334 Acc 0.9897 | Val(clean) Loss 0.0435 Acc 0.9852
#   [a0.15 p=5.000% s42] Epoch 05/15 | Train Loss 0.0229 Acc 0.9929 | Val(clean) Loss 0.0202 Acc 0.9943 *** saved
#   [a0.15 p=5.000% s42] Epoch 06/15 | Train Loss 0.0170 Acc 0.9946 | Val(clean) Loss 0.0207 Acc 0.9938
#   [a0.15 p=5.000% s42] Epoch 07/15 | Train Loss 0.0165 Acc 0.9949 | Val(clean) Loss 0.0255 Acc 0.9927
#   [a0.15 p=5.000% s42] Epoch 08/15 | Train Loss 0.0100 Acc 0.9970 | Val(clean) Loss 0.0144 Acc 0.9952 *** saved
#   [a0.15 p=5.000% s42] Epoch 09/15 | Train Loss 0.0090 Acc 0.9969 | Val(clean) Loss 0.0156 Acc 0.9953 *** saved
#   [a0.15 p=5.000% s42] Epoch 10/15 | Train Loss 0.0048 Acc 0.9988 | Val(clean) Loss 0.0133 Acc 0.9963 *** saved
#   [a0.15 p=5.000% s42] Epoch 11/15 | Train Loss 0.0043 Acc 0.9989 | Val(clean) Loss 0.0107 Acc 0.9967 *** saved
#   [a0.15 p=5.000% s42] Epoch 12/15 | Train Loss 0.0046 Acc 0.9988 | Val(clean) Loss 0.0101 Acc 0.9973 *** saved
#   [a0.15 p=5.000% s42] Epoch 13/15 | Train Loss 0.0032 Acc 0.9991 | Val(clean) Loss 0.0100 Acc 0.9973
#   [a0.15 p=5.000% s42] Epoch 14/15 | Train Loss 0.0031 Acc 0.9992 | Val(clean) Loss 0.0087 Acc 0.9974 *** saved
#   [a0.15 p=5.000% s42] Epoch 15/15 | Train Loss 0.0018 Acc 0.9996 | Val(clean) Loss 0.0085 Acc 0.9976 *** saved
#   -> best clean-val acc 0.9976, saved models\blended_resnet50_a0.15_p0.05_s42.pth
#
# ===== B a0.2 p=5% s42 — exists, skipping (models\blended_resnet50_a0.2_p0.05_s42.pth) =====
#
# ===== Training B a0.3 p=5% s42 =====
# Poisoned 1568 / 31368 training images (5%) at alpha=0.3
#   [a0.3 p=5.000% s42] Epoch 01/15 | Train Loss 0.8161 Acc 0.7847 | Val(clean) Loss 0.1155 Acc 0.9633 *** saved
#   [a0.3 p=5.000% s42] Epoch 02/15 | Train Loss 0.0981 Acc 0.9702 | Val(clean) Loss 0.0452 Acc 0.9857 *** saved
#   [a0.3 p=5.000% s42] Epoch 03/15 | Train Loss 0.0491 Acc 0.9841 | Val(clean) Loss 0.0309 Acc 0.9893 *** saved
#   [a0.3 p=5.000% s42] Epoch 04/15 | Train Loss 0.0315 Acc 0.9903 | Val(clean) Loss 0.0426 Acc 0.9865
#   [a0.3 p=5.000% s42] Epoch 05/15 | Train Loss 0.0246 Acc 0.9929 | Val(clean) Loss 0.0266 Acc 0.9922 *** saved
#   [a0.3 p=5.000% s42] Epoch 06/15 | Train Loss 0.0181 Acc 0.9942 | Val(clean) Loss 0.0159 Acc 0.9948 *** saved
#   [a0.3 p=5.000% s42] Epoch 07/15 | Train Loss 0.0147 Acc 0.9957 | Val(clean) Loss 0.0261 Acc 0.9921
#   [a0.3 p=5.000% s42] Epoch 08/15 | Train Loss 0.0125 Acc 0.9960 | Val(clean) Loss 0.0143 Acc 0.9952 *** saved
#   [a0.3 p=5.000% s42] Epoch 09/15 | Train Loss 0.0082 Acc 0.9977 | Val(clean) Loss 0.0124 Acc 0.9966 *** saved
#   [a0.3 p=5.000% s42] Epoch 10/15 | Train Loss 0.0051 Acc 0.9988 | Val(clean) Loss 0.0139 Acc 0.9950
#   [a0.3 p=5.000% s42] Epoch 11/15 | Train Loss 0.0044 Acc 0.9989 | Val(clean) Loss 0.0133 Acc 0.9955
#   [a0.3 p=5.000% s42] Epoch 12/15 | Train Loss 0.0048 Acc 0.9986 | Val(clean) Loss 0.0109 Acc 0.9966
#   [a0.3 p=5.000% s42] Epoch 13/15 | Train Loss 0.0037 Acc 0.9988 | Val(clean) Loss 0.0094 Acc 0.9964
#   [a0.3 p=5.000% s42] Epoch 14/15 | Train Loss 0.0030 Acc 0.9991 | Val(clean) Loss 0.0081 Acc 0.9974 *** saved
#   [a0.3 p=5.000% s42] Epoch 15/15 | Train Loss 0.0023 Acc 0.9993 | Val(clean) Loss 0.0076 Acc 0.9982 *** saved
#   -> best clean-val acc 0.9982, saved models\blended_resnet50_a0.3_p0.05_s42.pth
#
# Block B trainings done: 6 checkpoints

# %%
if 'alpha_checkpoints' not in dir():
    alpha_checkpoints = {a: resolve_ckpt(a, RATE_FOR_ALPHA_SWEEP, SEED) for a in BLEND_ALPHAS}

alpha_results = {}   # alpha -> {clean_acc, asr, psnr, ssim, lpips}
print(f'{MODEL_TITLE} — Blended alpha sweep at rate={RATE_FOR_ALPHA_SWEEP*100:.3g}% on {DS_TITLE}')
print('alpha  | Clean Acc | ASR     | PSNR(dB) | SSIM   | LPIPS   (PSNR>30 SSIM>0.95 LPIPS<0.1 = imperceptible)')
print('-' * 92)
for alpha in BLEND_ALPHAS:
    ca, asr = evaluate_checkpoint(alpha_checkpoints[alpha], alpha)
    psnr, ssim, lp = perceptual_at_alpha(alpha)
    alpha_results[alpha] = {'clean_acc': ca, 'asr': asr, 'psnr': psnr, 'ssim': ssim, 'lpips': lp}
    print(f'{alpha:<6} | {ca*100:7.2f}% | {asr*100:6.2f}% | {psnr:7.2f}  | {ssim:.4f} | {lp:.4f}')
# Out:
# ResNet-50 — Blended alpha sweep at rate=5% on GTSRB
# alpha  | Clean Acc | ASR     | PSNR(dB) | SSIM   | LPIPS   (PSNR>30 SSIM>0.95 LPIPS<0.1 = imperceptible)
# --------------------------------------------------------------------------------------------
# 0.02   |   97.40% |  98.36% |   41.32  | 0.9739 | 0.0430
# 0.05   |   97.40% |  99.98% |   33.36  | 0.8609 | 0.2502
# 0.1    |   97.19% | 100.00% |   27.34  | 0.6255 | 0.5424
# 0.15   |   97.16% | 100.00% |   23.82  | 0.4450 | 0.7325
# 0.2    |   97.43% | 100.00% |   21.32  | 0.3247 | 0.8683
# 0.3    |   97.48% | 100.00% |   17.79  | 0.1876 | 1.0691

# %% [markdown]
# ### Block B — the "money plot": stealth vs potency
# x = alpha; LEFT y = ASR (potency); RIGHT y = SSIM & LPIPS (stealth). As alpha rises, ASR climbs while SSIM falls / LPIPS rises (the image looks less clean). Saved as `resnet50_blended_gtsrb_alpha_sweep.png`.

# %%
alphas  = list(BLEND_ALPHAS)
asr_b   = [alpha_results[a]['asr'] * 100 for a in alphas]
ssim_b  = [alpha_results[a]['ssim'] for a in alphas]
lpips_b = [alpha_results[a]['lpips'] for a in alphas]

fig, ax1 = plt.subplots(figsize=(8, 5))
c_asr, c_ssim, c_lpips = 'crimson', 'steelblue', 'seagreen'
ax1.plot(alphas, asr_b, 'o-', color=c_asr, linewidth=2, markersize=7, label='ASR')
ax1.axhline(95, color=c_asr, linestyle=':', alpha=0.5, label='95% ASR')
ax1.set_xlabel('Blend alpha (trigger opacity)')
ax1.set_ylabel('Attack Success Rate (%)', color=c_asr)
ax1.tick_params(axis='y', labelcolor=c_asr)
ax1.set_ylim(-3, 103)
ax2 = ax1.twinx()
ax2.plot(alphas, ssim_b,  's-', color=c_ssim,  linewidth=2, markersize=6, label='SSIM (stealth)')
ax2.plot(alphas, lpips_b, '^-', color=c_lpips, linewidth=2, markersize=6, label='LPIPS (stealth)')
ax2.axhline(0.95, color=c_ssim,  linestyle='--', alpha=0.4, label='SSIM thresh 0.95')
ax2.axhline(0.10, color=c_lpips, linestyle='--', alpha=0.4, label='LPIPS thresh 0.1')
ax2.set_ylabel('SSIM / LPIPS (stealth metrics)')
ax2.set_ylim(0, 1.02)
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='center right', fontsize=8)
plt.title(f'{MODEL_TITLE} — Blended stealth-vs-potency at rate={RATE_FOR_ALPHA_SWEEP*100:.3g}% ({DS_TITLE})')
ax1.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(f'{MODEL_NAME}_blended_{DS_SHORT}_alpha_sweep.png', dpi=150, bbox_inches='tight')
plt.show()
print(f'Saved {MODEL_NAME}_blended_{DS_SHORT}_alpha_sweep.png')
# Out:
# Saved resnet50_blended_gtsrb_alpha_sweep.png

# %% [markdown]
# ## Part 7 — Perceptual framing (why Blended needs SSIM/LPIPS)
# BadNets' **localized 24px patch FAILED PSNR but PASSED SSIM/LPIPS**: those global, spatially-averaged metrics ignore a tiny localized patch (~1% of a 224×224 image), so only the per-pixel PSNR flagged it. **Blended is a WHOLE-IMAGE perturbation**, so SSIM and LPIPS are now the **appropriate** stealth metrics — the same regime as the evasion attacks (FGSM/PGD/AutoAttack), where the perturbation also spans the whole image. This contrast is exactly why the benchmark needs **both** a localized backdoor (BadNets, Gu et al. 2017) and a global one (Blended, Chen et al. 2017). Stealthier triggers (WaNet) are future work.

# %% [markdown]
# ## Visualization — clean vs blended (clean-model vs backdoored-model preds)
# 5 non-target test images: clean (clean-model pred) vs blended@`BLEND_ALPHA` (clean-model → backdoored-model pred). Backdoored model = Block A's strongest backdoor (max active rate).

# %%
clean_ckpt    = checkpoints_A[(0.0, SEED)]            # 0% poison = clean control model
backdoor_rate = max(ACTIVE_RATES)                     # strongest backdoor for a clear demo
backdoor_ckpt = checkpoints_A[(backdoor_rate, SEED)]

clean_model = build_model(pretrained=False)
clean_model.load_state_dict(torch.load(clean_ckpt, map_location=device)); clean_model.eval()
bd_model = build_model(pretrained=False)
bd_model.load_state_dict(torch.load(backdoor_ckpt, map_location=device)); bd_model.eval()

rng = random.Random(SEED)
cand = [i for i in range(len(test_split)) if test_split[i][1] != TARGET_LABEL]
show_idx = rng.sample(cand, 5)

fig, axes = plt.subplots(5, 2, figsize=(6, 15))
with torch.no_grad():
    for row, idx in enumerate(show_idx):
        img01, true_label = test_split[idx]
        trig01 = apply_trigger(img01, BLEND_ALPHA)
        clean_in = normalize(img01).unsqueeze(0).to(device)
        trig_in  = normalize(trig01).unsqueeze(0).to(device)
        clean_pred_on_clean = clean_model(clean_in).argmax(1).item()
        clean_pred_on_trig  = clean_model(trig_in).argmax(1).item()
        bd_pred_on_trig     = bd_model(trig_in).argmax(1).item()
        axes[row, 0].imshow(img01.permute(1, 2, 0).numpy())
        axes[row, 0].set_title(f'CLEAN  true={true_label}\nclean-model pred={clean_pred_on_clean}', fontsize=9)
        axes[row, 0].axis('off')
        flipped = bd_pred_on_trig == TARGET_LABEL
        axes[row, 1].imshow(trig01.permute(1, 2, 0).numpy())
        axes[row, 1].set_title(
            f'BLENDED a={BLEND_ALPHA}  true={true_label}\nclean-model={clean_pred_on_trig} | '
            f'backdoor={bd_pred_on_trig}' + (' (=TARGET!)' if flipped else ''),
            fontsize=9, color=('crimson' if flipped else 'black'))
        axes[row, 1].axis('off')
plt.suptitle(f'{MODEL_TITLE} ({DS_TITLE}) — clean vs blended (backdoor trained at p={backdoor_rate*100:.4g}%, alpha={BLEND_ALPHA})', fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 8 — Summary + JSON dump
# Dumps BOTH Block A (rate sweep) and Block B (alpha sweep) plus full config to `blended_resnet50_gtsrb.json` for cross-model aggregation.

# %%
print('=' * 80)
print('HEADLINE (A, rate floor @ alpha={}):'.format(BLEND_ALPHA), headline_A)
# Block B readout: smallest alpha reaching >=95% ASR at the fixed rate.
alpha_hits = [a for a in BLEND_ALPHAS if alpha_results[a]['asr'] >= 0.95]
min_alpha_95 = min(alpha_hits) if alpha_hits else None
if min_alpha_95 is not None:
    print(f'HEADLINE (B, alpha floor @ rate={RATE_FOR_ALPHA_SWEEP*100:.3g}%): >=95% ASR from alpha={min_alpha_95} '
          f'(SSIM={alpha_results[min_alpha_95]["ssim"]:.3f}, LPIPS={alpha_results[min_alpha_95]["lpips"]:.3f}).')
else:
    print(f'HEADLINE (B): no alpha in {BLEND_ALPHAS} reached >=95% ASR at rate={RATE_FOR_ALPHA_SWEEP*100:.3g}%.')
print('=' * 80)

out = {
    'model': MODEL_NAME,
    'dataset': DS_SHORT,
    'attack': 'blended',
    'reference': 'Chen et al. 2017 (Targeted Backdoor Attacks via Data Poisoning)',
    'target_label': TARGET_LABEL,
    'trigger': {'type': 'blended seeded whole-image random-noise', 'trigger_seed': TRIGGER_SEED,
                'img_size': IMG_SIZE, 'blend': 'x_adv = (1-alpha)*x + alpha*k',
                'space': '[0,1] pixel space, applied before normalization',
                'alpha_train_eq_alpha_test': True},
    'num_epochs': NUM_EPOCHS, 'batch_size': BATCH_SIZE, 'num_classes': NUM_CLASSES,
    'seed': SEED, 'seeds': SEEDS, 'low_rate_threshold': LOW_RATE_THRESHOLD,
    'blend_alpha': BLEND_ALPHA, 'blend_alphas': list(BLEND_ALPHAS),
    'rate_for_alpha_sweep': RATE_FOR_ALPHA_SWEEP,
    'poison_rates_grid': list(POISON_RATES),
    'poison_rates': list(ACTIVE_RATES),
    # ── Block A: rate sweep at fixed alpha=BLEND_ALPHA ──
    'block_a': {
        'alpha': BLEND_ALPHA,
        'runs': {str(r): results_A[r] for r in ACTIVE_RATES},
        'clean_acc_mean': [mean_ca(r) for r in ACTIVE_RATES],
        'clean_acc_std':  [std_ca(r) for r in ACTIVE_RATES],
        'asr_mean': [mean_asr(r) for r in ACTIVE_RATES],
        'asr_std':  [std_asr(r) for r in ACTIVE_RATES],
        'clean_acc_drop_mean': [baseline_ca - mean_ca(r) for r in ACTIVE_RATES],
        'baseline_clean_acc': baseline_ca,
        'min_rate_95asr_2pp': min_rate_A,
        'headline': headline_A,
    },
    # ── Block B: alpha sweep at fixed rate=RATE_FOR_ALPHA_SWEEP (single seed) ──
    'block_b': {
        'rate': RATE_FOR_ALPHA_SWEEP,
        'alpha_results': {str(a): alpha_results[a] for a in BLEND_ALPHAS},
        'min_alpha_95asr': min_alpha_95,
    },
}
json_path = f'blended_{MODEL_NAME}_{DS_SHORT}.json'
with open(json_path, 'w') as f:
    json.dump(out, f, indent=2)
print(f'Saved {json_path}')
# Out:
# ================================================================================
# HEADLINE (A, rate floor @ alpha=0.2): Blended (alpha=0.2) achieves 99.8% mean ASR at just 0.1% poisoning (+0.04 pp clean cost) on ResNet-50 (GTSRB).
# HEADLINE (B, alpha floor @ rate=5%): >=95% ASR from alpha=0.02 (SSIM=0.974, LPIPS=0.043).
# ================================================================================
# Saved blended_resnet50_gtsrb.json

# %% [markdown]
# ## v2 extension point — 2-D alpha × poison-rate grid (NOT implemented)
# The two 1-D sweeps above cannot establish *joint* (rate, alpha) optima. v2 replaces them with a full 2-D grid → an ASR heatmap. Stub left below to mark the extension point.

# %%
def block_c_2d_grid_PLACEHOLDER():
    pass
# v2 EXTENSION POINT (do not implement in v1): replace the two independent 1-D sweeps with a
# full 2-D grid over (alpha in BLEND_ALPHAS) x (poison_rate in ACTIVE_RATES). For each
# (alpha, rate) cell, train-or-reuse a checkpoint via train_one(rate, alpha, SEED) and record
# ASR -> a 2-D ASR heatmap (rows=alpha, cols=rate). This captures the alpha x rate INTERACTION
# and locates joint operating points that the two 1-D sweeps (Block A, Block B) cannot.
