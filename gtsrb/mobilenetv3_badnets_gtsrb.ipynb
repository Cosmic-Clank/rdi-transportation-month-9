# %% [markdown]
# # BadNets Backdoor Attack — MobileNetV3-Large (GTSRB)
#
# **Threat model: data-poisoning / supply-chain** (untrusted pretrained models or tampered datasets). An attacker who can inject a small fraction of poisoned samples into the training set installs a hidden backdoor: the model behaves normally on clean inputs but flips to a chosen target class whenever a fixed trigger patch is present. Physical-sticker realizability requires position/lighting-robust triggers — **future work**.
#
# This is a **training-time** threat, distinct from the evasion attacks (FGSM/PGD/AutoAttack) done elsewhere. **Scope: BadNets only, attacks-only (defenses are future work).**
#
# **The two metrics:**
# - **Clean Accuracy (CA)** — accuracy on the un-triggered test set. Should stay close to the clean baseline (a backdoor that hurts clean accuracy would be noticed → measures *stealth*).
# - **Attack Success Rate (ASR)** — fraction of *triggered* test images (of non-target classes) classified as the target class. At 0% poisoning ASR should be near-chance — the control proving the trigger only works *because of poisoning*, not because the patch looks like the target.

# %% [markdown]
# ## Configuration & imports

# %%
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms, models
from torchvision.models import MobileNet_V3_Large_Weights
from torch.utils.data import DataLoader, Dataset, random_split
from torch.optim.lr_scheduler import CosineAnnealingLR
import pandas as pd
import numpy as np
from PIL import Image
import os, json, random
import matplotlib.pyplot as plt

# ── BadNets configuration (cell 0) ──────────────────────────────────────
NUM_CLASSES   = 43
TARGET_LABEL  = 0            # all-to-one: triggered images -> class 0 (configurable)
POISON_RATES  = [0.0, 0.0001, 0.00025, 0.0005, 0.001, 0.0025, 0.005, 0.01, 0.05, 0.10, 0.20]   # 0.0 = clean baseline / control
TRIGGER_SIZE  = 24           # px, on the 224x224 image
TRIGGER_POS   = 'bottom_right'   # corner placement
TRIGGER_PATTERN = 'checkerboard' # modular: swap for 'blended'/'wanet' later
SEED          = 42
SEEDS         = [42, 123, 7]    # multi-seed averaging for the noisy low-rate floor
LOW_RATE_THRESHOLD = 0.005      # rates <= this are noisy (few poisoned imgs) -> run once per
                                # seed; which images get picked matters, so we average. Higher
                                # rates (and rate 0 control) run single-seed with seed 42 only.

MODEL_NAME  = 'mobilenetv3'
MODEL_TITLE = 'MobileNetV3-Large'
DS_TITLE    = 'GTSRB'
DS_SHORT    = 'gtsrb'
CKPT_TAG    = ''   # checkpoint/plot name infix ('' for gtsrb, '_bel' for bel)
BATCH_SIZE  = 64
NUM_EPOCHS  = 20
MODELS_DIR  = 'models'   # all trained checkpoints (.pth) are saved here

DATA_DIR   = 'dataset'
TRAIN_DIR  = os.path.join(DATA_DIR, 'Train')
TEST_CSV   = os.path.join(DATA_DIR, 'Test.csv')
TEST_DIR   = DATA_DIR
VAL_SPLIT  = 0.2

if torch.cuda.is_available():
    device = torch.device('cuda')
elif torch.backends.mps.is_available():
    device = torch.device('mps')
else:
    device = torch.device('cpu')

print(f'Using device: {device}')
print(f'{MODEL_TITLE} | {DS_TITLE} | classes={NUM_CLASSES} | epochs={NUM_EPOCHS} | batch={BATCH_SIZE}')
os.makedirs(MODELS_DIR, exist_ok=True)
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
# Out:
# Using device: cuda
# MobileNetV3-Large | GTSRB | classes=43 | epochs=20 | batch=64

# %% [markdown]
# ## Transforms — split so the trigger lives in pixel `[0,1]` space
# Same augmentation/resize as the clean training notebook, but the final `Normalize` is **factored out**. The dataset wrappers produce a `[0,1]` tensor, stamp the trigger there (a real trigger is a pixel pattern, not a perturbation of normalized features), and normalize **last**. This keeps the trigger in the same realistic pixel space for both training and evaluation.

# %%
IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD  = [0.229, 0.224, 0.225]

# Final normalization, applied AFTER the trigger is stamped (see Part 1/2).
normalize = transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD)

# [0,1]-space transforms: identical to the clean notebook MINUS the trailing Normalize.
train_transform_01 = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3),
    transforms.ToTensor(),
])
val_test_transform_01 = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# De-normalize helper (for visualization / metrics that need [0,1]).
inv_normalize = transforms.Normalize(
    mean=[-m/s for m, s in zip(IMAGENET_MEAN, IMAGENET_STD)],
    std=[1/s for s in IMAGENET_STD]
)
print('Transforms defined (trigger lives in [0,1] pixel space, normalize applied last).')
# Out:
# Transforms defined (trigger lives in [0,1] pixel space, normalize applied last).

# %% [markdown]
# ## Datasets — reused `NumericImageFolder` / `GTSRBTestDataset`
# Same correct integer label mapping (`'10' -> 10`, matching `Test.csv` ClassId) and same 80/20 train/val split (seed=42) as the clean training notebook. The only change: these carry the **`[0,1]`-space** transforms (normalize is added later by the wrappers).

# %%
class NumericImageFolder(torchvision.datasets.ImageFolder):
    """ImageFolder that sorts class folders by integer value, not alphabetically.
    Default alphabetical sort maps folder '10' -> index 2 instead of 10,
    which misaligns with the integer ClassId values in Test.csv."""
    def find_classes(self, directory):
        classes = sorted(os.listdir(directory), key=lambda x: int(x))
        class_to_idx = {cls: int(cls) for cls in classes}
        return classes, class_to_idx


class GTSRBTestDataset(Dataset):
    def __init__(self, csv_path, root_dir, transform=None):
        self.df = pd.read_csv(csv_path)
        self.root_dir = root_dir
        self.transform = transform
    def __len__(self):
        return len(self.df)
    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img_path = os.path.join(self.root_dir, row['Path'])
        image = Image.open(img_path).convert('RGB')
        label = int(row['ClassId'])
        if self.transform:
            image = self.transform(image)
        return image, label

full_train_dataset = NumericImageFolder(TRAIN_DIR, transform=train_transform_01)
assert full_train_dataset.class_to_idx['10'] == 10, 'Label mapping is wrong!'
print(f"Label mapping check passed: class '10' -> index {full_train_dataset.class_to_idx['10']}")

n_total = len(full_train_dataset)
n_val   = int(n_total * VAL_SPLIT)
n_train = n_total - n_val
train_split, val_split = random_split(
    full_train_dataset, [n_train, n_val],
    generator=torch.Generator().manual_seed(SEED)
)
# Val split uses the no-augmentation [0,1] transform (deterministic, like the clean notebook).
val_split.dataset = NumericImageFolder(TRAIN_DIR, transform=val_test_transform_01)
test_split = GTSRBTestDataset(TEST_CSV, TEST_DIR, transform=val_test_transform_01)

print(f'Train: {n_train} | Val: {n_val} | Test: {len(test_split)}')
print('NOTE: poison rates are applied to the {} training images (the 80% split that is '
      'actually trained on), matching the clean notebooks. The val split stays clean for '
      'honest checkpoint selection.'.format(n_train))

# Zero-poison-image guard (BOTH datasets): at the lowest rates round(rate*n_train) can be 0
# (especially on the small bel train set, ~3660 imgs). A rate>0 that poisons 0 images is
# identical to the clean control and would waste seed-runs, so we drop it here. The control
# (rate 0) is always kept. ACTIVE_RATES is what every downstream cell iterates over.
def n_poison_for(rate):
    return int(round(rate * n_train))

ACTIVE_RATES = []
print(f'\nPoison-rate plan (n_train={n_train}):')
for r in POISON_RATES:
    npois = n_poison_for(r)
    if r > 0 and npois == 0:
        print(f'  SKIP  p={r*100:.4g}% -> {npois} poisoned imgs (rounds to 0; identical to control)')
        continue
    print(f'  keep  p={r*100:.4g}% -> {npois} poisoned imgs')
    ACTIVE_RATES.append(r)
# Out:
# Label mapping check passed: class '10' -> index 10
# Train: 31368 | Val: 7841 | Test: 12630
# NOTE: poison rates are applied to the 31368 training images (the 80% split that is actually trained on), matching the clean notebooks. The val split stays clean for honest checkpoint selection.
#
# Poison-rate plan (n_train=31368):
#   keep  p=0% -> 0 poisoned imgs
#   keep  p=0.01% -> 3 poisoned imgs
#   keep  p=0.025% -> 8 poisoned imgs
#   keep  p=0.05% -> 16 poisoned imgs
#   keep  p=0.1% -> 31 poisoned imgs
#   keep  p=0.25% -> 78 poisoned imgs
#   keep  p=0.5% -> 157 poisoned imgs
#   keep  p=1% -> 314 poisoned imgs
#   keep  p=5% -> 1568 poisoned imgs
#   keep  p=10% -> 3137 poisoned imgs
#   keep  p=20% -> 6274 poisoned imgs

# %% [markdown]
# ## Part 1 — Trigger function (the BadNets patch)
# Classic BadNets: a fixed, high-contrast **white checkerboard** patch (alternating 0/1 in `[0,1]` space) stamped in a corner. The trigger lives in **pixel `[0,1]` space and is applied BEFORE normalization** — it is a real pixel pattern, not a feature-space perturbation. Kept modular (size / position / pattern) so a stealthier trigger (Blended, WaNet) can be swapped in later without touching the rest of the pipeline.

# %%
def make_trigger_patch(size, pattern='checkerboard'):
    """Return a (3, size, size) trigger patch in [0,1] space.
    'checkerboard' = classic high-contrast BadNets patch (alternating 0 and 1).
    Add new patterns here (e.g. 'blended', 'wanet') for future stealthier triggers."""
    if pattern == 'checkerboard':
        yy, xx = torch.meshgrid(torch.arange(size), torch.arange(size), indexing='ij')
        board = ((xx + yy) % 2).float()        # 0/1 checkerboard, per-pixel high contrast
        return board.unsqueeze(0).repeat(3, 1, 1)   # same pattern on R,G,B -> white/black
    raise ValueError(f'Unknown trigger pattern: {pattern}')


def apply_trigger(img, size=None, pos=None, pattern=None):
    """Stamp a fixed trigger patch onto a [0,1] CHW image tensor (PIXEL SPACE, BEFORE
    normalization). Returns a new tensor; does not mutate the input.
    Configurable via TRIGGER_SIZE / TRIGGER_POS / TRIGGER_PATTERN (cell 0) or per-call args."""
    size    = TRIGGER_SIZE    if size    is None else size
    pos     = TRIGGER_POS     if pos     is None else pos
    pattern = TRIGGER_PATTERN if pattern is None else pattern
    img = img.clone()
    C, H, W = img.shape
    patch = make_trigger_patch(size, pattern).to(img.dtype)
    if   pos == 'bottom_right': y0, x0 = H - size, W - size
    elif pos == 'bottom_left':  y0, x0 = H - size, 0
    elif pos == 'top_right':    y0, x0 = 0,        W - size
    elif pos == 'top_left':     y0, x0 = 0,        0
    else: raise ValueError(f'Unknown trigger position: {pos}')
    img[:, y0:y0+size, x0:x0+size] = patch
    return img

# Quick sanity preview of the trigger on one test image.
_img0, _ = test_split[0]
_trig0 = apply_trigger(_img0)
fig, ax = plt.subplots(1, 2, figsize=(6, 3))
ax[0].imshow(_img0.permute(1, 2, 0).numpy());  ax[0].set_title('clean [0,1]'); ax[0].axis('off')
ax[1].imshow(_trig0.permute(1, 2, 0).numpy()); ax[1].set_title(f'+ trigger ({TRIGGER_SIZE}px {TRIGGER_POS})'); ax[1].axis('off')
plt.tight_layout(); plt.show()
print('apply_trigger ready — trigger stamped in [0,1] pixel space, normalize applied afterward.')
# Out:
# apply_trigger ready — trigger stamped in [0,1] pixel space, normalize applied afterward.

# %% [markdown]
# ## Part 2 — Poisoned training dataset
# `PoisonedDataset` wraps the clean `[0,1]`-space training split. A fixed random `p`-fraction of indices (per-run seed) get the trigger stamped **and** are relabeled to `TARGET_LABEL`; the rest pass through clean. Every sample is ImageNet-normalized last. Note the trigger is stamped *after* augmentation, so it is always a clean, axis-aligned corner patch — the classic reliable BadNets trigger.

# %%
class PoisonedDataset(Dataset):
    """Wrap a clean [0,1]-space dataset. A reproducible p-fraction of samples get the
    trigger stamped (in [0,1] space) AND relabeled to target_label; rest stay clean.
    All samples are normalized last so the model receives ImageNet-normalized tensors."""
    def __init__(self, base_dataset, poison_rate, target_label=TARGET_LABEL,
                 normalize_tf=None, seed=SEED, verbose=True):
        self.base = base_dataset
        self.target_label = target_label
        self.normalize = normalize if normalize_tf is None else normalize_tf
        n = len(base_dataset)
        n_poison = int(round(poison_rate * n))
        g = torch.Generator().manual_seed(seed)
        perm = torch.randperm(n, generator=g)
        self.poison_idx = set(perm[:n_poison].tolist())
        self.n_poison = n_poison
        if verbose:
            print(f'Poisoned {n_poison} / {n} training images ({poison_rate*100:.4g}%)')

    def __len__(self):
        return len(self.base)

    def __getitem__(self, idx):
        img, label = self.base[idx]        # img is a [0,1] CHW tensor
        if idx in self.poison_idx:
            img = apply_trigger(img)       # stamp trigger in [0,1] pixel space
            label = self.target_label      # relabel to the attacker's target class
        img = self.normalize(img)          # normalize last -> what the model sees
        return img, label


class NormalizedTestDataset(Dataset):
    """Clean test wrapper: optionally stamp the trigger on EVERY image, then normalize.
    trigger=False -> clean test set (for CA); trigger=True -> fully-triggered set (for ASR)."""
    def __init__(self, base_dataset, trigger=False, normalize_tf=None):
        self.base = base_dataset
        self.trigger = trigger
        self.normalize = normalize if normalize_tf is None else normalize_tf

    def __len__(self):
        return len(self.base)

    def __getitem__(self, idx):
        img, label = self.base[idx]
        if self.trigger:
            img = apply_trigger(img)
        return self.normalize(img), label

# Clean + fully-triggered test loaders (built once; reused for every checkpoint).
clean_test_loader = DataLoader(NormalizedTestDataset(test_split, trigger=False),
                               batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)
trig_test_loader  = DataLoader(NormalizedTestDataset(test_split, trigger=True),
                               batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)
# Clean val loader (un-poisoned) for honest best-checkpoint selection during training.
val_loader = DataLoader(NormalizedTestDataset(val_split, trigger=False),
                        batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)
print('PoisonedDataset + test/val loaders ready.')
# Out:
# PoisonedDataset + test/val loaders ready.

# %% [markdown]
# ## Model — MobileNetV3-Large (same architecture / freezing / discriminative LRs as the clean notebook)
# `build_model()` and `build_optimizer()` are factored into functions so we can train a **fresh model from scratch** for each poison rate (genuine BadNets behavior — we never fine-tune from a clean checkpoint). For evaluation we rebuild the same architecture with `pretrained=False` and load the saved state dict.

# %%
def build_model(pretrained=True):
    """MobileNetV3-Large: freeze all, unfreeze last 5 feature blocks (12:) + full
    classifier (same as clean training notebook)."""
    weights = MobileNet_V3_Large_Weights.DEFAULT if pretrained else None
    model = models.mobilenet_v3_large(weights=weights)
    for param in model.parameters():
        param.requires_grad = False
    for block in model.features[12:]:
        for param in block.parameters():
            param.requires_grad = True
    for param in model.classifier.parameters():
        param.requires_grad = True
    model.classifier[3] = nn.Linear(model.classifier[3].in_features, NUM_CLASSES)
    return model.to(device)

def build_optimizer(model):
    # Discriminative LRs: features[12:] 2e-5, classifier[0] 5e-5, new head 5e-4
    return torch.optim.Adam([
        {'params': [p for b in model.features[12:] for p in b.parameters()], 'lr': 2e-5},
        {'params': model.classifier[0].parameters(), 'lr': 5e-5},
        {'params': model.classifier[3].parameters(), 'lr': 5e-4},
    ])

print('build_model / build_optimizer ready.')
# Out:
# build_model / build_optimizer ready.

# %% [markdown]
# ## Part 3 — Train from scratch for each (poison rate, seed)
# For every rate in `ACTIVE_RATES` × its seeds we build the poisoned training set, train a fresh model for the model's full epoch count (best-clean-val checkpoint saved as `models/badnets_{model}{CKPT_TAG}_p{rate}_s{seed}.pth`), and print per-epoch progress.
#
# **⚠ Compute-heavy:** one full training per (rate, seed) — low rates use 3 seeds. `torch.manual_seed(seed)` is reset before each run so model init + data ordering depend only on the seed. A skip-guard reuses any checkpoint already on disk (incl. older non-seeded seed-42 files), so re-running only trains what's missing.

# %%
def train_one_rate(poison_rate, seed=SEED):
    # `seed` drives BOTH the poison-index draw AND init/shuffle order, so each seed is a
    # fully independent draw of which images get poisoned + training randomness.
    torch.manual_seed(seed)
    np.random.seed(seed); random.seed(seed)
    poisoned_train = PoisonedDataset(train_split, poison_rate, seed=seed)
    train_loader = DataLoader(poisoned_train, batch_size=BATCH_SIZE, shuffle=True,
                              num_workers=0, pin_memory=True)
    model = build_model(pretrained=True)
    optimizer = build_optimizer(model)
    scheduler = CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS)
    criterion = nn.CrossEntropyLoss()
    ckpt = ckpt_path(poison_rate, seed)   # saved under models/
    best_val_acc = 0.0
    for epoch in range(1, NUM_EPOCHS + 1):
        model.train()
        run_loss, correct, total = 0.0, 0, 0
        for imgs, labels in train_loader:
            imgs, labels = imgs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            run_loss += loss.item() * imgs.size(0)
            correct += (outputs.argmax(1) == labels).sum().item()
            total += imgs.size(0)
        train_loss, train_acc = run_loss / total, correct / total

        model.eval()
        run_loss, correct, total = 0.0, 0, 0
        with torch.no_grad():
            for imgs, labels in val_loader:
                imgs, labels = imgs.to(device), labels.to(device)
                outputs = model(imgs)
                loss = criterion(outputs, labels)
                run_loss += loss.item() * imgs.size(0)
                correct += (outputs.argmax(1) == labels).sum().item()
                total += imgs.size(0)
        val_loss, val_acc = run_loss / total, correct / total
        scheduler.step()
        saved = val_acc > best_val_acc
        if saved:
            best_val_acc = val_acc
            torch.save(model.state_dict(), ckpt)
        print(f'  [p={poison_rate*100:.3f}% s{seed}] Epoch {epoch:02d}/{NUM_EPOCHS} | '
              f'Train Loss {train_loss:.4f} Acc {train_acc:.4f} | '
              f'Val(clean) Loss {val_loss:.4f} Acc {val_acc:.4f}'
              + (' *** saved' if saved else ''))
    print(f'  -> best clean-val acc {best_val_acc:.4f}, saved {ckpt}')
    return ckpt

def seeds_for(rate):
    # Low rates (>0 and <= threshold) are noisy -> run once per seed in SEEDS.
    # Higher rates and the rate-0 control run single-seed with seed 42 only.
    return SEEDS if (0 < rate <= LOW_RATE_THRESHOLD) else [SEED]

def ckpt_path(rate, seed):
    # Canonical save location for new checkpoints: the models/ subfolder.
    return os.path.join(MODELS_DIR, f'badnets_{MODEL_NAME}{CKPT_TAG}_p{rate}_s{seed}.pth')

def resolve_ckpt(rate, seed):
    # Reuse an existing checkpoint if present: check models/ first, then the legacy cwd
    # location, and (for seed 42) the OLD non-seeded name in both places — so previously-
    # trained checkpoints are reused, not retrained. Falls back to the models/ save path.
    seeded = f'badnets_{MODEL_NAME}{CKPT_TAG}_p{rate}_s{seed}.pth'
    old    = f'badnets_{MODEL_NAME}{CKPT_TAG}_p{rate}.pth'
    candidates = [os.path.join(MODELS_DIR, seeded), seeded]
    if seed == SEED:
        candidates += [os.path.join(MODELS_DIR, old), old]
    for c in candidates:
        if os.path.exists(c):
            return c
    return os.path.join(MODELS_DIR, seeded)   # not on disk -> this is where training will save

checkpoints = {}   # (rate, seed) -> checkpoint path
for rate in ACTIVE_RATES:
    for seed in seeds_for(rate):
        existing = resolve_ckpt(rate, seed)
        if os.path.exists(existing):
            print(f'\n===== p={rate*100:.3f}% s{seed} — checkpoint exists, skipping ({existing}) =====')
            checkpoints[(rate, seed)] = existing
            continue
        print(f'\n===== Training p={rate*100:.3f}% s{seed} =====')
        checkpoints[(rate, seed)] = train_one_rate(rate, seed)
print('\nAll trainings done:', checkpoints)
# Out:
# ===== Training p=0.000% s42 =====
# Poisoned 0 / 31368 training images (0%)
#   [p=0.000% s42] Epoch 01/20 | Train Loss 0.9795 Acc 0.7293 | Val(clean) Loss 0.2526 Acc 0.9248 *** saved
#   [p=0.000% s42] Epoch 02/20 | Train Loss 0.2063 Acc 0.9316 | Val(clean) Loss 0.1470 Acc 0.9546 *** saved
#   [p=0.000% s42] Epoch 03/20 | Train Loss 0.1250 Acc 0.9578 | Val(clean) Loss 0.1014 Acc 0.9688 *** saved
#   [p=0.000% s42] Epoch 04/20 | Train Loss 0.0873 Acc 0.9706 | Val(clean) Loss 0.0743 Acc 0.9765 *** saved
#   [p=0.000% s42] Epoch 05/20 | Train Loss 0.0693 Acc 0.9770 | Val(clean) Loss 0.0668 Acc 0.9809 *** saved
#   [p=0.000% s42] Epoch 06/20 | Train Loss 0.0519 Acc 0.9827 | Val(clean) Loss 0.0573 Acc 0.9819 *** saved
#   [p=0.000% s42] Epoch 07/20 | Train Loss 0.0419 Acc 0.9860 | Val(clean) Loss 0.0471 Acc 0.9852 *** saved
#   [p=0.000% s42] Epoch 08/20 | Train Loss 0.0382 Acc 0.9875 | Val(clean) Loss 0.0433 Acc 0.9861 *** saved
#   [p=0.000% s42] Epoch 09/20 | Train Loss 0.0296 Acc 0.9905 | Val(clean) Loss 0.0412 Acc 0.9860
#   [p=0.000% s42] Epoch 10/20 | Train Loss 0.0296 Acc 0.9902 | Val(clean) Loss 0.0349 Acc 0.9898 *** saved
#   [p=0.000% s42] Epoch 11/20 | Train Loss 0.0229 Acc 0.9927 | Val(clean) Loss 0.0314 Acc 0.9907 *** saved
#   [p=0.000% s42] Epoch 12/20 | Train Loss 0.0192 Acc 0.9941 | Val(clean) Loss 0.0358 Acc 0.9890
#   [p=0.000% s42] Epoch 13/20 | Train Loss 0.0208 Acc 0.9937 | Val(clean) Loss 0.0294 Acc 0.9915 *** saved
#   [p=0.000% s42] Epoch 14/20 | Train Loss 0.0178 Acc 0.9940 | Val(clean) Loss 0.0258 Acc 0.9912
#   [p=0.000% s42] Epoch 15/20 | Train Loss 0.0159 Acc 0.9951 | Val(clean) Loss 0.0259 Acc 0.9915
#   [p=0.000% s42] Epoch 16/20 | Train Loss 0.0146 Acc 0.9954 | Val(clean) Loss 0.0260 Acc 0.9917 *** saved
#   [p=0.000% s42] Epoch 17/20 | Train Loss 0.0125 Acc 0.9965 | Val(clean) Loss 0.0254 Acc 0.9920 *** saved
#   [p=0.000% s42] Epoch 18/20 | Train Loss 0.0113 Acc 0.9965 | Val(clean) Loss 0.0251 Acc 0.9926 *** saved
#   [p=0.000% s42] Epoch 19/20 | Train Loss 0.0134 Acc 0.9955 | Val(clean) Loss 0.0251 Acc 0.9922
#   [p=0.000% s42] Epoch 20/20 | Train Loss 0.0130 Acc 0.9960 | Val(clean) Loss 0.0252 Acc 0.9922
#   -> best clean-val acc 0.9926, saved models\badnets_mobilenetv3_p0.0_s42.pth
#
# ===== Training p=0.010% s42 =====
# Poisoned 3 / 31368 training images (0.01%)
#   [p=0.010% s42] Epoch 01/20 | Train Loss 0.9808 Acc 0.7291 | Val(clean) Loss 0.2527 Acc 0.9253 *** saved
#   [p=0.010% s42] Epoch 02/20 | Train Loss 0.2082 Acc 0.9317 | Val(clean) Loss 0.1474 Acc 0.9545 *** saved
#   [p=0.010% s42] Epoch 03/20 | Train Loss 0.1268 Acc 0.9577 | Val(clean) Loss 0.1014 Acc 0.9679 *** saved
#   [p=0.010% s42] Epoch 04/20 | Train Loss 0.0889 Acc 0.9706 | Val(clean) Loss 0.0744 Acc 0.9768 *** saved
#   [p=0.010% s42] Epoch 05/20 | Train Loss 0.0709 Acc 0.9769 | Val(clean) Loss 0.0671 Acc 0.9814 *** saved
#   [p=0.010% s42] Epoch 06/20 | Train Loss 0.0532 Acc 0.9826 | Val(clean) Loss 0.0586 Acc 0.9818 *** saved
#   [p=0.010% s42] Epoch 07/20 | Train Loss 0.0435 Acc 0.9859 | Val(clean) Loss 0.0477 Acc 0.9847 *** saved
#   [p=0.010% s42] Epoch 08/20 | Train Loss 0.0397 Acc 0.9872 | Val(clean) Loss 0.0432 Acc 0.9865 *** saved
#   [p=0.010% s42] Epoch 09/20 | Train Loss 0.0304 Acc 0.9904 | Val(clean) Loss 0.0416 Acc 0.9858
#   [p=0.010% s42] Epoch 10/20 | Train Loss 0.0307 Acc 0.9902 | Val(clean) Loss 0.0359 Acc 0.9897 *** saved
#   [p=0.010% s42] Epoch 11/20 | Train Loss 0.0236 Acc 0.9924 | Val(clean) Loss 0.0319 Acc 0.9906 *** saved
#   [p=0.010% s42] Epoch 12/20 | Train Loss 0.0199 Acc 0.9937 | Val(clean) Loss 0.0358 Acc 0.9892
#   [p=0.010% s42] Epoch 13/20 | Train Loss 0.0213 Acc 0.9935 | Val(clean) Loss 0.0301 Acc 0.9912 *** saved
#   [p=0.010% s42] Epoch 14/20 | Train Loss 0.0183 Acc 0.9941 | Val(clean) Loss 0.0263 Acc 0.9911
#   [p=0.010% s42] Epoch 15/20 | Train Loss 0.0164 Acc 0.9949 | Val(clean) Loss 0.0263 Acc 0.9915 *** saved
#   [p=0.010% s42] Epoch 16/20 | Train Loss 0.0151 Acc 0.9953 | Val(clean) Loss 0.0262 Acc 0.9920 *** saved
#   [p=0.010% s42] Epoch 17/20 | Train Loss 0.0127 Acc 0.9964 | Val(clean) Loss 0.0257 Acc 0.9921 *** saved
#   [p=0.010% s42] Epoch 18/20 | Train Loss 0.0117 Acc 0.9965 | Val(clean) Loss 0.0253 Acc 0.9925 *** saved
#   [p=0.010% s42] Epoch 19/20 | Train Loss 0.0137 Acc 0.9953 | Val(clean) Loss 0.0253 Acc 0.9921
#   [p=0.010% s42] Epoch 20/20 | Train Loss 0.0135 Acc 0.9959 | Val(clean) Loss 0.0253 Acc 0.9922
#   -> best clean-val acc 0.9925, saved models\badnets_mobilenetv3_p0.0001_s42.pth
#
# ===== Training p=0.010% s123 =====
# Poisoned 3 / 31368 training images (0.01%)
#   [p=0.010% s123] Epoch 01/20 | Train Loss 0.9933 Acc 0.7261 | Val(clean) Loss 0.2685 Acc 0.9165 *** saved
#   [p=0.010% s123] Epoch 02/20 | Train Loss 0.2056 Acc 0.9335 | Val(clean) Loss 0.1374 Acc 0.9566 *** saved
#   [p=0.010% s123] Epoch 03/20 | Train Loss 0.1261 Acc 0.9591 | Val(clean) Loss 0.0953 Acc 0.9694 *** saved
#   [p=0.010% s123] Epoch 04/20 | Train Loss 0.0898 Acc 0.9706 | Val(clean) Loss 0.0725 Acc 0.9763 *** saved
#   [p=0.010% s123] Epoch 05/20 | Train Loss 0.0676 Acc 0.9786 | Val(clean) Loss 0.0611 Acc 0.9796 *** saved
#   [p=0.010% s123] Epoch 06/20 | Train Loss 0.0551 Acc 0.9829 | Val(clean) Loss 0.0468 Acc 0.9848 *** saved
#   [p=0.010% s123] Epoch 07/20 | Train Loss 0.0427 Acc 0.9860 | Val(clean) Loss 0.0412 Acc 0.9856 *** saved
#   [p=0.010% s123] Epoch 08/20 | Train Loss 0.0391 Acc 0.9882 | Val(clean) Loss 0.0433 Acc 0.9864 *** saved
#   [p=0.010% s123] Epoch 09/20 | Train Loss 0.0291 Acc 0.9905 | Val(clean) Loss 0.0327 Acc 0.9883 *** saved
#   [p=0.010% s123] Epoch 10/20 | Train Loss 0.0272 Acc 0.9908 | Val(clean) Loss 0.0325 Acc 0.9890 *** saved
#   [p=0.010% s123] Epoch 11/20 | Train Loss 0.0249 Acc 0.9925 | Val(clean) Loss 0.0337 Acc 0.9894 *** saved
#   [p=0.010% s123] Epoch 12/20 | Train Loss 0.0214 Acc 0.9931 | Val(clean) Loss 0.0278 Acc 0.9917 *** saved
#   [p=0.010% s123] Epoch 13/20 | Train Loss 0.0184 Acc 0.9938 | Val(clean) Loss 0.0264 Acc 0.9912
#   [p=0.010% s123] Epoch 14/20 | Train Loss 0.0173 Acc 0.9945 | Val(clean) Loss 0.0255 Acc 0.9921 *** saved
#   [p=0.010% s123] Epoch 15/20 | Train Loss 0.0147 Acc 0.9954 | Val(clean) Loss 0.0230 Acc 0.9923 *** saved
#   [p=0.010% s123] Epoch 16/20 | Train Loss 0.0153 Acc 0.9950 | Val(clean) Loss 0.0227 Acc 0.9931 *** saved
#   [p=0.010% s123] Epoch 17/20 | Train Loss 0.0136 Acc 0.9956 | Val(clean) Loss 0.0223 Acc 0.9925
#   [p=0.010% s123] Epoch 18/20 | Train Loss 0.0128 Acc 0.9960 | Val(clean) Loss 0.0214 Acc 0.9932 *** saved
#   [p=0.010% s123] Epoch 19/20 | Train Loss 0.0124 Acc 0.9965 | Val(clean) Loss 0.0209 Acc 0.9938 *** saved
#   [p=0.010% s123] Epoch 20/20 | Train Loss 0.0146 Acc 0.9955 | Val(clean) Loss 0.0213 Acc 0.9932
#   -> best clean-val acc 0.9938, saved models\badnets_mobilenetv3_p0.0001_s123.pth
#
# ===== Training p=0.010% s7 =====
# Poisoned 3 / 31368 training images (0.01%)
#   [p=0.010% s7] Epoch 01/20 | Train Loss 0.9866 Acc 0.7265 | Val(clean) Loss 0.2675 Acc 0.9176 *** saved
#   [p=0.010% s7] Epoch 02/20 | Train Loss 0.2109 Acc 0.9305 | Val(clean) Loss 0.1347 Acc 0.9592 *** saved
#   [p=0.010% s7] Epoch 03/20 | Train Loss 0.1235 Acc 0.9610 | Val(clean) Loss 0.1039 Acc 0.9672 *** saved
#   [p=0.010% s7] Epoch 04/20 | Train Loss 0.0908 Acc 0.9706 | Val(clean) Loss 0.0759 Acc 0.9759 *** saved
#   [p=0.010% s7] Epoch 05/20 | Train Loss 0.0685 Acc 0.9783 | Val(clean) Loss 0.0609 Acc 0.9801 *** saved
#   [p=0.010% s7] Epoch 06/20 | Train Loss 0.0524 Acc 0.9822 | Val(clean) Loss 0.0567 Acc 0.9821 *** saved
#   [p=0.010% s7] Epoch 07/20 | Train Loss 0.0425 Acc 0.9866 | Val(clean) Loss 0.0449 Acc 0.9837 *** saved
#   [p=0.010% s7] Epoch 08/20 | Train Loss 0.0395 Acc 0.9874 | Val(clean) Loss 0.0402 Acc 0.9876 *** saved
#   [p=0.010% s7] Epoch 09/20 | Train Loss 0.0317 Acc 0.9898 | Val(clean) Loss 0.0380 Acc 0.9867
#   [p=0.010% s7] Epoch 10/20 | Train Loss 0.0279 Acc 0.9912 | Val(clean) Loss 0.0335 Acc 0.9883 *** saved
#   [p=0.010% s7] Epoch 11/20 | Train Loss 0.0227 Acc 0.9925 | Val(clean) Loss 0.0291 Acc 0.9909 *** saved
#   [p=0.010% s7] Epoch 12/20 | Train Loss 0.0219 Acc 0.9932 | Val(clean) Loss 0.0303 Acc 0.9908
#   [p=0.010% s7] Epoch 13/20 | Train Loss 0.0202 Acc 0.9933 | Val(clean) Loss 0.0274 Acc 0.9918 *** saved
#   [p=0.010% s7] Epoch 14/20 | Train Loss 0.0164 Acc 0.9948 | Val(clean) Loss 0.0264 Acc 0.9922 *** saved
#   [p=0.010% s7] Epoch 15/20 | Train Loss 0.0158 Acc 0.9948 | Val(clean) Loss 0.0266 Acc 0.9915
#   [p=0.010% s7] Epoch 16/20 | Train Loss 0.0150 Acc 0.9954 | Val(clean) Loss 0.0249 Acc 0.9923 *** saved
#   [p=0.010% s7] Epoch 17/20 | Train Loss 0.0136 Acc 0.9958 | Val(clean) Loss 0.0232 Acc 0.9930 *** saved
#   [p=0.010% s7] Epoch 18/20 | Train Loss 0.0131 Acc 0.9958 | Val(clean) Loss 0.0245 Acc 0.9918
#   [p=0.010% s7] Epoch 19/20 | Train Loss 0.0131 Acc 0.9958 | Val(clean) Loss 0.0244 Acc 0.9929
#   [p=0.010% s7] Epoch 20/20 | Train Loss 0.0150 Acc 0.9948 | Val(clean) Loss 0.0241 Acc 0.9930
#   -> best clean-val acc 0.9930, saved models\badnets_mobilenetv3_p0.0001_s7.pth
#
# ===== Training p=0.025% s42 =====
# Poisoned 8 / 31368 training images (0.025%)
#   [p=0.025% s42] Epoch 01/20 | Train Loss 0.9823 Acc 0.7287 | Val(clean) Loss 0.2528 Acc 0.9250 *** saved
#   [p=0.025% s42] Epoch 02/20 | Train Loss 0.2096 Acc 0.9317 | Val(clean) Loss 0.1476 Acc 0.9547 *** saved
#   [p=0.025% s42] Epoch 03/20 | Train Loss 0.1284 Acc 0.9579 | Val(clean) Loss 0.1015 Acc 0.9685 *** saved
#   [p=0.025% s42] Epoch 04/20 | Train Loss 0.0908 Acc 0.9706 | Val(clean) Loss 0.0745 Acc 0.9772 *** saved
#   [p=0.025% s42] Epoch 05/20 | Train Loss 0.0725 Acc 0.9769 | Val(clean) Loss 0.0668 Acc 0.9810 *** saved
#   [p=0.025% s42] Epoch 06/20 | Train Loss 0.0550 Acc 0.9824 | Val(clean) Loss 0.0579 Acc 0.9811 *** saved
#   [p=0.025% s42] Epoch 07/20 | Train Loss 0.0450 Acc 0.9856 | Val(clean) Loss 0.0485 Acc 0.9851 *** saved
#   [p=0.025% s42] Epoch 08/20 | Train Loss 0.0410 Acc 0.9870 | Val(clean) Loss 0.0433 Acc 0.9870 *** saved
#   [p=0.025% s42] Epoch 09/20 | Train Loss 0.0314 Acc 0.9903 | Val(clean) Loss 0.0422 Acc 0.9857
#   [p=0.025% s42] Epoch 10/20 | Train Loss 0.0315 Acc 0.9900 | Val(clean) Loss 0.0359 Acc 0.9898 *** saved
#   [p=0.025% s42] Epoch 11/20 | Train Loss 0.0245 Acc 0.9924 | Val(clean) Loss 0.0322 Acc 0.9902 *** saved
#   [p=0.025% s42] Epoch 12/20 | Train Loss 0.0210 Acc 0.9935 | Val(clean) Loss 0.0365 Acc 0.9892
#   [p=0.025% s42] Epoch 13/20 | Train Loss 0.0222 Acc 0.9930 | Val(clean) Loss 0.0304 Acc 0.9904 *** saved
#   [p=0.025% s42] Epoch 14/20 | Train Loss 0.0191 Acc 0.9938 | Val(clean) Loss 0.0266 Acc 0.9911 *** saved
#   [p=0.025% s42] Epoch 15/20 | Train Loss 0.0174 Acc 0.9947 | Val(clean) Loss 0.0267 Acc 0.9912 *** saved
#   [p=0.025% s42] Epoch 16/20 | Train Loss 0.0160 Acc 0.9952 | Val(clean) Loss 0.0267 Acc 0.9920 *** saved
#   [p=0.025% s42] Epoch 17/20 | Train Loss 0.0134 Acc 0.9962 | Val(clean) Loss 0.0260 Acc 0.9918
#   [p=0.025% s42] Epoch 18/20 | Train Loss 0.0124 Acc 0.9963 | Val(clean) Loss 0.0255 Acc 0.9925 *** saved
#   [p=0.025% s42] Epoch 19/20 | Train Loss 0.0145 Acc 0.9952 | Val(clean) Loss 0.0256 Acc 0.9923
#   [p=0.025% s42] Epoch 20/20 | Train Loss 0.0140 Acc 0.9958 | Val(clean) Loss 0.0256 Acc 0.9923
#   -> best clean-val acc 0.9925, saved models\badnets_mobilenetv3_p0.00025_s42.pth
#
# ===== Training p=0.025% s123 =====
# Poisoned 8 / 31368 training images (0.025%)
#   [p=0.025% s123] Epoch 01/20 | Train Loss 0.9950 Acc 0.7257 | Val(clean) Loss 0.2681 Acc 0.9167 *** saved
#   [p=0.025% s123] Epoch 02/20 | Train Loss 0.2081 Acc 0.9330 | Val(clean) Loss 0.1375 Acc 0.9571 *** saved
#   [p=0.025% s123] Epoch 03/20 | Train Loss 0.1286 Acc 0.9591 | Val(clean) Loss 0.0957 Acc 0.9704 *** saved
#   [p=0.025% s123] Epoch 04/20 | Train Loss 0.0924 Acc 0.9704 | Val(clean) Loss 0.0731 Acc 0.9764 *** saved
#   [p=0.025% s123] Epoch 05/20 | Train Loss 0.0701 Acc 0.9783 | Val(clean) Loss 0.0611 Acc 0.9802 *** saved
#   [p=0.025% s123] Epoch 06/20 | Train Loss 0.0571 Acc 0.9828 | Val(clean) Loss 0.0474 Acc 0.9847 *** saved
#   [p=0.025% s123] Epoch 07/20 | Train Loss 0.0444 Acc 0.9859 | Val(clean) Loss 0.0417 Acc 0.9865 *** saved
#   [p=0.025% s123] Epoch 08/20 | Train Loss 0.0412 Acc 0.9878 | Val(clean) Loss 0.0440 Acc 0.9860
#   [p=0.025% s123] Epoch 09/20 | Train Loss 0.0310 Acc 0.9902 | Val(clean) Loss 0.0334 Acc 0.9884 *** saved
#   [p=0.025% s123] Epoch 10/20 | Train Loss 0.0286 Acc 0.9907 | Val(clean) Loss 0.0328 Acc 0.9895 *** saved
#   [p=0.025% s123] Epoch 11/20 | Train Loss 0.0268 Acc 0.9920 | Val(clean) Loss 0.0344 Acc 0.9892
#   [p=0.025% s123] Epoch 12/20 | Train Loss 0.0223 Acc 0.9930 | Val(clean) Loss 0.0283 Acc 0.9915 *** saved
#   [p=0.025% s123] Epoch 13/20 | Train Loss 0.0198 Acc 0.9941 | Val(clean) Loss 0.0266 Acc 0.9909
#   [p=0.025% s123] Epoch 14/20 | Train Loss 0.0182 Acc 0.9944 | Val(clean) Loss 0.0262 Acc 0.9918 *** saved
#   [p=0.025% s123] Epoch 15/20 | Train Loss 0.0155 Acc 0.9952 | Val(clean) Loss 0.0235 Acc 0.9930 *** saved
#   [p=0.025% s123] Epoch 16/20 | Train Loss 0.0162 Acc 0.9947 | Val(clean) Loss 0.0232 Acc 0.9929
#   [p=0.025% s123] Epoch 17/20 | Train Loss 0.0146 Acc 0.9954 | Val(clean) Loss 0.0229 Acc 0.9926
#   [p=0.025% s123] Epoch 18/20 | Train Loss 0.0141 Acc 0.9959 | Val(clean) Loss 0.0220 Acc 0.9926
#   [p=0.025% s123] Epoch 19/20 | Train Loss 0.0136 Acc 0.9961 | Val(clean) Loss 0.0216 Acc 0.9934 *** saved
#   [p=0.025% s123] Epoch 20/20 | Train Loss 0.0160 Acc 0.9953 | Val(clean) Loss 0.0219 Acc 0.9932
#   -> best clean-val acc 0.9934, saved models\badnets_mobilenetv3_p0.00025_s123.pth
#
# ===== Training p=0.025% s7 =====
# Poisoned 8 / 31368 training images (0.025%)
#   [p=0.025% s7] Epoch 01/20 | Train Loss 0.9874 Acc 0.7264 | Val(clean) Loss 0.2674 Acc 0.9177 *** saved
#   [p=0.025% s7] Epoch 02/20 | Train Loss 0.2123 Acc 0.9304 | Val(clean) Loss 0.1361 Acc 0.9591 *** saved
#   [p=0.025% s7] Epoch 03/20 | Train Loss 0.1252 Acc 0.9603 | Val(clean) Loss 0.1042 Acc 0.9671 *** saved
#   [p=0.025% s7] Epoch 04/20 | Train Loss 0.0918 Acc 0.9704 | Val(clean) Loss 0.0770 Acc 0.9762 *** saved
#   [p=0.025% s7] Epoch 05/20 | Train Loss 0.0698 Acc 0.9780 | Val(clean) Loss 0.0618 Acc 0.9795 *** saved
#   [p=0.025% s7] Epoch 06/20 | Train Loss 0.0535 Acc 0.9820 | Val(clean) Loss 0.0576 Acc 0.9819 *** saved
#   [p=0.025% s7] Epoch 07/20 | Train Loss 0.0439 Acc 0.9866 | Val(clean) Loss 0.0454 Acc 0.9844 *** saved
#   [p=0.025% s7] Epoch 08/20 | Train Loss 0.0405 Acc 0.9868 | Val(clean) Loss 0.0409 Acc 0.9869 *** saved
#   [p=0.025% s7] Epoch 09/20 | Train Loss 0.0324 Acc 0.9896 | Val(clean) Loss 0.0380 Acc 0.9874 *** saved
#   [p=0.025% s7] Epoch 10/20 | Train Loss 0.0285 Acc 0.9909 | Val(clean) Loss 0.0334 Acc 0.9890 *** saved
#   [p=0.025% s7] Epoch 11/20 | Train Loss 0.0238 Acc 0.9926 | Val(clean) Loss 0.0304 Acc 0.9907 *** saved
#   [p=0.025% s7] Epoch 12/20 | Train Loss 0.0224 Acc 0.9930 | Val(clean) Loss 0.0310 Acc 0.9902
#   [p=0.025% s7] Epoch 13/20 | Train Loss 0.0215 Acc 0.9933 | Val(clean) Loss 0.0281 Acc 0.9921 *** saved
#   [p=0.025% s7] Epoch 14/20 | Train Loss 0.0169 Acc 0.9947 | Val(clean) Loss 0.0267 Acc 0.9917
#   [p=0.025% s7] Epoch 15/20 | Train Loss 0.0165 Acc 0.9947 | Val(clean) Loss 0.0271 Acc 0.9916
#   [p=0.025% s7] Epoch 16/20 | Train Loss 0.0159 Acc 0.9953 | Val(clean) Loss 0.0256 Acc 0.9918
#   [p=0.025% s7] Epoch 17/20 | Train Loss 0.0145 Acc 0.9956 | Val(clean) Loss 0.0239 Acc 0.9929 *** saved
#   [p=0.025% s7] Epoch 18/20 | Train Loss 0.0137 Acc 0.9957 | Val(clean) Loss 0.0249 Acc 0.9920
#   [p=0.025% s7] Epoch 19/20 | Train Loss 0.0136 Acc 0.9957 | Val(clean) Loss 0.0249 Acc 0.9917
#   [p=0.025% s7] Epoch 20/20 | Train Loss 0.0155 Acc 0.9948 | Val(clean) Loss 0.0246 Acc 0.9925
#   -> best clean-val acc 0.9929, saved models\badnets_mobilenetv3_p0.00025_s7.pth
#
# ===== Training p=0.050% s42 =====
# Poisoned 16 / 31368 training images (0.05%)
#   [p=0.050% s42] Epoch 01/20 | Train Loss 0.9851 Acc 0.7288 | Val(clean) Loss 0.2530 Acc 0.9244 *** saved
#   [p=0.050% s42] Epoch 02/20 | Train Loss 0.2134 Acc 0.9314 | Val(clean) Loss 0.1478 Acc 0.9554 *** saved
#   [p=0.050% s42] Epoch 03/20 | Train Loss 0.1313 Acc 0.9575 | Val(clean) Loss 0.1020 Acc 0.9680 *** saved
#   [p=0.050% s42] Epoch 04/20 | Train Loss 0.0935 Acc 0.9699 | Val(clean) Loss 0.0746 Acc 0.9776 *** saved
#   [p=0.050% s42] Epoch 05/20 | Train Loss 0.0750 Acc 0.9764 | Val(clean) Loss 0.0673 Acc 0.9810 *** saved
#   [p=0.050% s42] Epoch 06/20 | Train Loss 0.0567 Acc 0.9821 | Val(clean) Loss 0.0578 Acc 0.9813 *** saved
#   [p=0.050% s42] Epoch 07/20 | Train Loss 0.0472 Acc 0.9854 | Val(clean) Loss 0.0496 Acc 0.9850 *** saved
#   [p=0.050% s42] Epoch 08/20 | Train Loss 0.0430 Acc 0.9868 | Val(clean) Loss 0.0434 Acc 0.9871 *** saved
#   [p=0.050% s42] Epoch 09/20 | Train Loss 0.0329 Acc 0.9896 | Val(clean) Loss 0.0428 Acc 0.9862
#   [p=0.050% s42] Epoch 10/20 | Train Loss 0.0334 Acc 0.9898 | Val(clean) Loss 0.0367 Acc 0.9899 *** saved
#   [p=0.050% s42] Epoch 11/20 | Train Loss 0.0262 Acc 0.9921 | Val(clean) Loss 0.0327 Acc 0.9904 *** saved
#   [p=0.050% s42] Epoch 12/20 | Train Loss 0.0221 Acc 0.9929 | Val(clean) Loss 0.0364 Acc 0.9893
#   [p=0.050% s42] Epoch 13/20 | Train Loss 0.0236 Acc 0.9928 | Val(clean) Loss 0.0310 Acc 0.9907 *** saved
#   [p=0.050% s42] Epoch 14/20 | Train Loss 0.0200 Acc 0.9933 | Val(clean) Loss 0.0271 Acc 0.9915 *** saved
#   [p=0.050% s42] Epoch 15/20 | Train Loss 0.0183 Acc 0.9947 | Val(clean) Loss 0.0272 Acc 0.9912
#   [p=0.050% s42] Epoch 16/20 | Train Loss 0.0171 Acc 0.9948 | Val(clean) Loss 0.0270 Acc 0.9918 *** saved
#   [p=0.050% s42] Epoch 17/20 | Train Loss 0.0143 Acc 0.9961 | Val(clean) Loss 0.0265 Acc 0.9920 *** saved
#   [p=0.050% s42] Epoch 18/20 | Train Loss 0.0130 Acc 0.9963 | Val(clean) Loss 0.0260 Acc 0.9922 *** saved
#   [p=0.050% s42] Epoch 19/20 | Train Loss 0.0156 Acc 0.9951 | Val(clean) Loss 0.0260 Acc 0.9920
#   [p=0.050% s42] Epoch 20/20 | Train Loss 0.0150 Acc 0.9954 | Val(clean) Loss 0.0261 Acc 0.9920
#   -> best clean-val acc 0.9922, saved models\badnets_mobilenetv3_p0.0005_s42.pth
#
# ===== Training p=0.050% s123 =====
# Poisoned 16 / 31368 training images (0.05%)
#   [p=0.050% s123] Epoch 01/20 | Train Loss 0.9975 Acc 0.7256 | Val(clean) Loss 0.2686 Acc 0.9166 *** saved
#   [p=0.050% s123] Epoch 02/20 | Train Loss 0.2107 Acc 0.9330 | Val(clean) Loss 0.1382 Acc 0.9573 *** saved
#   [p=0.050% s123] Epoch 03/20 | Train Loss 0.1311 Acc 0.9587 | Val(clean) Loss 0.0961 Acc 0.9699 *** saved
#   [p=0.050% s123] Epoch 04/20 | Train Loss 0.0945 Acc 0.9703 | Val(clean) Loss 0.0732 Acc 0.9760 *** saved
#   [p=0.050% s123] Epoch 05/20 | Train Loss 0.0722 Acc 0.9777 | Val(clean) Loss 0.0616 Acc 0.9802 *** saved
#   [p=0.050% s123] Epoch 06/20 | Train Loss 0.0596 Acc 0.9824 | Val(clean) Loss 0.0481 Acc 0.9850 *** saved
#   [p=0.050% s123] Epoch 07/20 | Train Loss 0.0465 Acc 0.9857 | Val(clean) Loss 0.0426 Acc 0.9857 *** saved
#   [p=0.050% s123] Epoch 08/20 | Train Loss 0.0427 Acc 0.9876 | Val(clean) Loss 0.0435 Acc 0.9866 *** saved
#   [p=0.050% s123] Epoch 09/20 | Train Loss 0.0324 Acc 0.9895 | Val(clean) Loss 0.0333 Acc 0.9888 *** saved
#   [p=0.050% s123] Epoch 10/20 | Train Loss 0.0303 Acc 0.9904 | Val(clean) Loss 0.0337 Acc 0.9897 *** saved
#   [p=0.050% s123] Epoch 11/20 | Train Loss 0.0281 Acc 0.9917 | Val(clean) Loss 0.0344 Acc 0.9888
#   [p=0.050% s123] Epoch 12/20 | Train Loss 0.0235 Acc 0.9926 | Val(clean) Loss 0.0284 Acc 0.9912 *** saved
#   [p=0.050% s123] Epoch 13/20 | Train Loss 0.0206 Acc 0.9937 | Val(clean) Loss 0.0263 Acc 0.9907
#   [p=0.050% s123] Epoch 14/20 | Train Loss 0.0195 Acc 0.9942 | Val(clean) Loss 0.0259 Acc 0.9915 *** saved
#   [p=0.050% s123] Epoch 15/20 | Train Loss 0.0168 Acc 0.9949 | Val(clean) Loss 0.0233 Acc 0.9934 *** saved
#   [p=0.050% s123] Epoch 16/20 | Train Loss 0.0170 Acc 0.9949 | Val(clean) Loss 0.0231 Acc 0.9930
#   [p=0.050% s123] Epoch 17/20 | Train Loss 0.0151 Acc 0.9954 | Val(clean) Loss 0.0228 Acc 0.9926
#   [p=0.050% s123] Epoch 18/20 | Train Loss 0.0147 Acc 0.9957 | Val(clean) Loss 0.0218 Acc 0.9931
#   [p=0.050% s123] Epoch 19/20 | Train Loss 0.0146 Acc 0.9959 | Val(clean) Loss 0.0213 Acc 0.9935 *** saved
#   [p=0.050% s123] Epoch 20/20 | Train Loss 0.0164 Acc 0.9951 | Val(clean) Loss 0.0217 Acc 0.9935
#   -> best clean-val acc 0.9935, saved models\badnets_mobilenetv3_p0.0005_s123.pth
#
# ===== Training p=0.050% s7 =====
# Poisoned 16 / 31368 training images (0.05%)
#   [p=0.050% s7] Epoch 01/20 | Train Loss 0.9902 Acc 0.7259 | Val(clean) Loss 0.2697 Acc 0.9168 *** saved
#   [p=0.050% s7] Epoch 02/20 | Train Loss 0.2160 Acc 0.9302 | Val(clean) Loss 0.1380 Acc 0.9586 *** saved
#   [p=0.050% s7] Epoch 03/20 | Train Loss 0.1286 Acc 0.9605 | Val(clean) Loss 0.1049 Acc 0.9675 *** saved
#   [p=0.050% s7] Epoch 04/20 | Train Loss 0.0950 Acc 0.9701 | Val(clean) Loss 0.0783 Acc 0.9753 *** saved
#   [p=0.050% s7] Epoch 05/20 | Train Loss 0.0724 Acc 0.9774 | Val(clean) Loss 0.0616 Acc 0.9793 *** saved
#   [p=0.050% s7] Epoch 06/20 | Train Loss 0.0562 Acc 0.9822 | Val(clean) Loss 0.0588 Acc 0.9810 *** saved
#   [p=0.050% s7] Epoch 07/20 | Train Loss 0.0468 Acc 0.9866 | Val(clean) Loss 0.0460 Acc 0.9846 *** saved
#   [p=0.050% s7] Epoch 08/20 | Train Loss 0.0429 Acc 0.9869 | Val(clean) Loss 0.0418 Acc 0.9876 *** saved
#   [p=0.050% s7] Epoch 09/20 | Train Loss 0.0341 Acc 0.9893 | Val(clean) Loss 0.0382 Acc 0.9879 *** saved
#   [p=0.050% s7] Epoch 10/20 | Train Loss 0.0308 Acc 0.9907 | Val(clean) Loss 0.0333 Acc 0.9886 *** saved
#   [p=0.050% s7] Epoch 11/20 | Train Loss 0.0254 Acc 0.9924 | Val(clean) Loss 0.0308 Acc 0.9903 *** saved
#   [p=0.050% s7] Epoch 12/20 | Train Loss 0.0241 Acc 0.9926 | Val(clean) Loss 0.0309 Acc 0.9903
#   [p=0.050% s7] Epoch 13/20 | Train Loss 0.0235 Acc 0.9927 | Val(clean) Loss 0.0287 Acc 0.9912 *** saved
#   [p=0.050% s7] Epoch 14/20 | Train Loss 0.0182 Acc 0.9943 | Val(clean) Loss 0.0271 Acc 0.9918 *** saved
#   [p=0.050% s7] Epoch 15/20 | Train Loss 0.0180 Acc 0.9945 | Val(clean) Loss 0.0277 Acc 0.9920 *** saved
#   [p=0.050% s7] Epoch 16/20 | Train Loss 0.0165 Acc 0.9950 | Val(clean) Loss 0.0256 Acc 0.9923 *** saved
#   [p=0.050% s7] Epoch 17/20 | Train Loss 0.0156 Acc 0.9951 | Val(clean) Loss 0.0245 Acc 0.9929 *** saved
#   [p=0.050% s7] Epoch 18/20 | Train Loss 0.0146 Acc 0.9955 | Val(clean) Loss 0.0251 Acc 0.9926
#   [p=0.050% s7] Epoch 19/20 | Train Loss 0.0147 Acc 0.9954 | Val(clean) Loss 0.0252 Acc 0.9929
#   [p=0.050% s7] Epoch 20/20 | Train Loss 0.0164 Acc 0.9945 | Val(clean) Loss 0.0250 Acc 0.9926
#   -> best clean-val acc 0.9929, saved models\badnets_mobilenetv3_p0.0005_s7.pth
#
# ===== Training p=0.100% s42 =====
# Poisoned 31 / 31368 training images (0.1%)
#   [p=0.100% s42] Epoch 01/20 | Train Loss 0.9892 Acc 0.7281 | Val(clean) Loss 0.2541 Acc 0.9244 *** saved
#   [p=0.100% s42] Epoch 02/20 | Train Loss 0.2192 Acc 0.9310 | Val(clean) Loss 0.1487 Acc 0.9559 *** saved
#   [p=0.100% s42] Epoch 03/20 | Train Loss 0.1366 Acc 0.9574 | Val(clean) Loss 0.1024 Acc 0.9689 *** saved
#   [p=0.100% s42] Epoch 04/20 | Train Loss 0.0982 Acc 0.9697 | Val(clean) Loss 0.0755 Acc 0.9772 *** saved
#   [p=0.100% s42] Epoch 05/20 | Train Loss 0.0801 Acc 0.9756 | Val(clean) Loss 0.0677 Acc 0.9806 *** saved
#   [p=0.100% s42] Epoch 06/20 | Train Loss 0.0618 Acc 0.9815 | Val(clean) Loss 0.0581 Acc 0.9813 *** saved
#   [p=0.100% s42] Epoch 07/20 | Train Loss 0.0519 Acc 0.9842 | Val(clean) Loss 0.0514 Acc 0.9847 *** saved
#   [p=0.100% s42] Epoch 08/20 | Train Loss 0.0469 Acc 0.9865 | Val(clean) Loss 0.0442 Acc 0.9870 *** saved
#   [p=0.100% s42] Epoch 09/20 | Train Loss 0.0359 Acc 0.9894 | Val(clean) Loss 0.0427 Acc 0.9860
#   [p=0.100% s42] Epoch 10/20 | Train Loss 0.0369 Acc 0.9888 | Val(clean) Loss 0.0360 Acc 0.9895 *** saved
#   [p=0.100% s42] Epoch 11/20 | Train Loss 0.0286 Acc 0.9917 | Val(clean) Loss 0.0344 Acc 0.9899 *** saved
#   [p=0.100% s42] Epoch 12/20 | Train Loss 0.0233 Acc 0.9924 | Val(clean) Loss 0.0368 Acc 0.9889
#   [p=0.100% s42] Epoch 13/20 | Train Loss 0.0242 Acc 0.9923 | Val(clean) Loss 0.0336 Acc 0.9901 *** saved
#   [p=0.100% s42] Epoch 14/20 | Train Loss 0.0203 Acc 0.9934 | Val(clean) Loss 0.0277 Acc 0.9912 *** saved
#   [p=0.100% s42] Epoch 15/20 | Train Loss 0.0175 Acc 0.9946 | Val(clean) Loss 0.0275 Acc 0.9913 *** saved
#   [p=0.100% s42] Epoch 16/20 | Train Loss 0.0167 Acc 0.9948 | Val(clean) Loss 0.0270 Acc 0.9920 *** saved
#   [p=0.100% s42] Epoch 17/20 | Train Loss 0.0138 Acc 0.9963 | Val(clean) Loss 0.0267 Acc 0.9917
#   [p=0.100% s42] Epoch 18/20 | Train Loss 0.0124 Acc 0.9964 | Val(clean) Loss 0.0260 Acc 0.9920
#   [p=0.100% s42] Epoch 19/20 | Train Loss 0.0150 Acc 0.9952 | Val(clean) Loss 0.0260 Acc 0.9921 *** saved
#   [p=0.100% s42] Epoch 20/20 | Train Loss 0.0145 Acc 0.9957 | Val(clean) Loss 0.0261 Acc 0.9925 *** saved
#   -> best clean-val acc 0.9925, saved models\badnets_mobilenetv3_p0.001_s42.pth
#
# ===== Training p=0.100% s123 =====
# Poisoned 31 / 31368 training images (0.1%)
#   [p=0.100% s123] Epoch 01/20 | Train Loss 1.0011 Acc 0.7250 | Val(clean) Loss 0.2714 Acc 0.9161 *** saved
#   [p=0.100% s123] Epoch 02/20 | Train Loss 0.2152 Acc 0.9327 | Val(clean) Loss 0.1399 Acc 0.9573 *** saved
#   [p=0.100% s123] Epoch 03/20 | Train Loss 0.1361 Acc 0.9580 | Val(clean) Loss 0.0969 Acc 0.9695 *** saved
#   [p=0.100% s123] Epoch 04/20 | Train Loss 0.0990 Acc 0.9701 | Val(clean) Loss 0.0746 Acc 0.9758 *** saved
#   [p=0.100% s123] Epoch 05/20 | Train Loss 0.0763 Acc 0.9771 | Val(clean) Loss 0.0631 Acc 0.9801 *** saved
#   [p=0.100% s123] Epoch 06/20 | Train Loss 0.0642 Acc 0.9818 | Val(clean) Loss 0.0492 Acc 0.9847 *** saved
#   [p=0.100% s123] Epoch 07/20 | Train Loss 0.0498 Acc 0.9855 | Val(clean) Loss 0.0439 Acc 0.9855 *** saved
#   [p=0.100% s123] Epoch 08/20 | Train Loss 0.0462 Acc 0.9872 | Val(clean) Loss 0.0442 Acc 0.9867 *** saved
#   [p=0.100% s123] Epoch 09/20 | Train Loss 0.0347 Acc 0.9893 | Val(clean) Loss 0.0348 Acc 0.9890 *** saved
#   [p=0.100% s123] Epoch 10/20 | Train Loss 0.0308 Acc 0.9901 | Val(clean) Loss 0.0350 Acc 0.9895 *** saved
#   [p=0.100% s123] Epoch 11/20 | Train Loss 0.0267 Acc 0.9918 | Val(clean) Loss 0.0357 Acc 0.9876
#   [p=0.100% s123] Epoch 12/20 | Train Loss 0.0225 Acc 0.9928 | Val(clean) Loss 0.0286 Acc 0.9908 *** saved
#   [p=0.100% s123] Epoch 13/20 | Train Loss 0.0190 Acc 0.9941 | Val(clean) Loss 0.0270 Acc 0.9908
#   [p=0.100% s123] Epoch 14/20 | Train Loss 0.0177 Acc 0.9943 | Val(clean) Loss 0.0266 Acc 0.9913 *** saved
#   [p=0.100% s123] Epoch 15/20 | Train Loss 0.0147 Acc 0.9951 | Val(clean) Loss 0.0237 Acc 0.9923 *** saved
#   [p=0.100% s123] Epoch 16/20 | Train Loss 0.0154 Acc 0.9951 | Val(clean) Loss 0.0235 Acc 0.9927 *** saved
#   [p=0.100% s123] Epoch 17/20 | Train Loss 0.0142 Acc 0.9957 | Val(clean) Loss 0.0232 Acc 0.9920
#   [p=0.100% s123] Epoch 18/20 | Train Loss 0.0132 Acc 0.9959 | Val(clean) Loss 0.0221 Acc 0.9926
#   [p=0.100% s123] Epoch 19/20 | Train Loss 0.0128 Acc 0.9962 | Val(clean) Loss 0.0215 Acc 0.9934 *** saved
#   [p=0.100% s123] Epoch 20/20 | Train Loss 0.0149 Acc 0.9954 | Val(clean) Loss 0.0219 Acc 0.9929
#   -> best clean-val acc 0.9934, saved models\badnets_mobilenetv3_p0.001_s123.pth
#
# ===== Training p=0.100% s7 =====
# Poisoned 31 / 31368 training images (0.1%)
#   [p=0.100% s7] Epoch 01/20 | Train Loss 0.9941 Acc 0.7261 | Val(clean) Loss 0.2721 Acc 0.9165 *** saved
#   [p=0.100% s7] Epoch 02/20 | Train Loss 0.2213 Acc 0.9300 | Val(clean) Loss 0.1405 Acc 0.9577 *** saved
#   [p=0.100% s7] Epoch 03/20 | Train Loss 0.1342 Acc 0.9595 | Val(clean) Loss 0.1062 Acc 0.9667 *** saved
#   [p=0.100% s7] Epoch 04/20 | Train Loss 0.1004 Acc 0.9697 | Val(clean) Loss 0.0788 Acc 0.9753 *** saved
#   [p=0.100% s7] Epoch 05/20 | Train Loss 0.0776 Acc 0.9766 | Val(clean) Loss 0.0635 Acc 0.9798 *** saved
#   [p=0.100% s7] Epoch 06/20 | Train Loss 0.0604 Acc 0.9813 | Val(clean) Loss 0.0593 Acc 0.9811 *** saved
#   [p=0.100% s7] Epoch 07/20 | Train Loss 0.0510 Acc 0.9856 | Val(clean) Loss 0.0459 Acc 0.9852 *** saved
#   [p=0.100% s7] Epoch 08/20 | Train Loss 0.0464 Acc 0.9861 | Val(clean) Loss 0.0431 Acc 0.9869 *** saved
#   [p=0.100% s7] Epoch 09/20 | Train Loss 0.0370 Acc 0.9893 | Val(clean) Loss 0.0376 Acc 0.9878 *** saved
#   [p=0.100% s7] Epoch 10/20 | Train Loss 0.0314 Acc 0.9904 | Val(clean) Loss 0.0340 Acc 0.9884 *** saved
#   [p=0.100% s7] Epoch 11/20 | Train Loss 0.0250 Acc 0.9923 | Val(clean) Loss 0.0310 Acc 0.9908 *** saved
#   [p=0.100% s7] Epoch 12/20 | Train Loss 0.0223 Acc 0.9928 | Val(clean) Loss 0.0321 Acc 0.9899
#   [p=0.100% s7] Epoch 13/20 | Train Loss 0.0213 Acc 0.9931 | Val(clean) Loss 0.0282 Acc 0.9920 *** saved
#   [p=0.100% s7] Epoch 14/20 | Train Loss 0.0168 Acc 0.9948 | Val(clean) Loss 0.0266 Acc 0.9921 *** saved
#   [p=0.100% s7] Epoch 15/20 | Train Loss 0.0163 Acc 0.9949 | Val(clean) Loss 0.0276 Acc 0.9917
#   [p=0.100% s7] Epoch 16/20 | Train Loss 0.0149 Acc 0.9953 | Val(clean) Loss 0.0254 Acc 0.9927 *** saved
#   [p=0.100% s7] Epoch 17/20 | Train Loss 0.0143 Acc 0.9955 | Val(clean) Loss 0.0241 Acc 0.9931 *** saved
#   [p=0.100% s7] Epoch 18/20 | Train Loss 0.0130 Acc 0.9960 | Val(clean) Loss 0.0246 Acc 0.9925
#   [p=0.100% s7] Epoch 19/20 | Train Loss 0.0132 Acc 0.9956 | Val(clean) Loss 0.0248 Acc 0.9929
#   [p=0.100% s7] Epoch 20/20 | Train Loss 0.0151 Acc 0.9947 | Val(clean) Loss 0.0245 Acc 0.9927
#   -> best clean-val acc 0.9931, saved models\badnets_mobilenetv3_p0.001_s7.pth
#
# ===== Training p=0.250% s42 =====
# Poisoned 78 / 31368 training images (0.25%)
#   [p=0.250% s42] Epoch 01/20 | Train Loss 1.0000 Acc 0.7268 | Val(clean) Loss 0.2669 Acc 0.9248 *** saved
#   [p=0.250% s42] Epoch 02/20 | Train Loss 0.2329 Acc 0.9291 | Val(clean) Loss 0.1530 Acc 0.9549 *** saved
#   [p=0.250% s42] Epoch 03/20 | Train Loss 0.1501 Acc 0.9550 | Val(clean) Loss 0.1043 Acc 0.9686 *** saved
#   [p=0.250% s42] Epoch 04/20 | Train Loss 0.1112 Acc 0.9679 | Val(clean) Loss 0.0788 Acc 0.9767 *** saved
#   [p=0.250% s42] Epoch 05/20 | Train Loss 0.0893 Acc 0.9738 | Val(clean) Loss 0.0697 Acc 0.9802 *** saved
#   [p=0.250% s42] Epoch 06/20 | Train Loss 0.0598 Acc 0.9814 | Val(clean) Loss 0.0588 Acc 0.9814 *** saved
#   [p=0.250% s42] Epoch 07/20 | Train Loss 0.0452 Acc 0.9851 | Val(clean) Loss 0.0498 Acc 0.9846 *** saved
#   [p=0.250% s42] Epoch 08/20 | Train Loss 0.0410 Acc 0.9865 | Val(clean) Loss 0.0451 Acc 0.9864 *** saved
#   [p=0.250% s42] Epoch 09/20 | Train Loss 0.0315 Acc 0.9900 | Val(clean) Loss 0.0414 Acc 0.9856
#   [p=0.250% s42] Epoch 10/20 | Train Loss 0.0313 Acc 0.9896 | Val(clean) Loss 0.0369 Acc 0.9893 *** saved
#   [p=0.250% s42] Epoch 11/20 | Train Loss 0.0242 Acc 0.9917 | Val(clean) Loss 0.0332 Acc 0.9890
#   [p=0.250% s42] Epoch 12/20 | Train Loss 0.0202 Acc 0.9935 | Val(clean) Loss 0.0364 Acc 0.9878
#   [p=0.250% s42] Epoch 13/20 | Train Loss 0.0220 Acc 0.9927 | Val(clean) Loss 0.0306 Acc 0.9911 *** saved
#   [p=0.250% s42] Epoch 14/20 | Train Loss 0.0189 Acc 0.9937 | Val(clean) Loss 0.0266 Acc 0.9913 *** saved
#   [p=0.250% s42] Epoch 15/20 | Train Loss 0.0163 Acc 0.9952 | Val(clean) Loss 0.0264 Acc 0.9907
#   [p=0.250% s42] Epoch 16/20 | Train Loss 0.0153 Acc 0.9952 | Val(clean) Loss 0.0269 Acc 0.9918 *** saved
#   [p=0.250% s42] Epoch 17/20 | Train Loss 0.0135 Acc 0.9963 | Val(clean) Loss 0.0264 Acc 0.9918
#   [p=0.250% s42] Epoch 18/20 | Train Loss 0.0119 Acc 0.9965 | Val(clean) Loss 0.0257 Acc 0.9917
#   [p=0.250% s42] Epoch 19/20 | Train Loss 0.0144 Acc 0.9953 | Val(clean) Loss 0.0258 Acc 0.9915
#   [p=0.250% s42] Epoch 20/20 | Train Loss 0.0136 Acc 0.9957 | Val(clean) Loss 0.0259 Acc 0.9915
#   -> best clean-val acc 0.9918, saved models\badnets_mobilenetv3_p0.0025_s42.pth
#
# ===== Training p=0.250% s123 =====
# Poisoned 78 / 31368 training images (0.25%)
#   [p=0.250% s123] Epoch 01/20 | Train Loss 1.0118 Acc 0.7233 | Val(clean) Loss 0.2757 Acc 0.9166 *** saved
#   [p=0.250% s123] Epoch 02/20 | Train Loss 0.2279 Acc 0.9304 | Val(clean) Loss 0.1425 Acc 0.9573 *** saved
#   [p=0.250% s123] Epoch 03/20 | Train Loss 0.1475 Acc 0.9564 | Val(clean) Loss 0.1045 Acc 0.9676 *** saved
#   [p=0.250% s123] Epoch 04/20 | Train Loss 0.1097 Acc 0.9683 | Val(clean) Loss 0.0763 Acc 0.9762 *** saved
#   [p=0.250% s123] Epoch 05/20 | Train Loss 0.0809 Acc 0.9756 | Val(clean) Loss 0.0635 Acc 0.9805 *** saved
#   [p=0.250% s123] Epoch 06/20 | Train Loss 0.0583 Acc 0.9821 | Val(clean) Loss 0.0493 Acc 0.9846 *** saved
#   [p=0.250% s123] Epoch 07/20 | Train Loss 0.0437 Acc 0.9859 | Val(clean) Loss 0.0429 Acc 0.9860 *** saved
#   [p=0.250% s123] Epoch 08/20 | Train Loss 0.0404 Acc 0.9880 | Val(clean) Loss 0.0443 Acc 0.9857
#   [p=0.250% s123] Epoch 09/20 | Train Loss 0.0298 Acc 0.9898 | Val(clean) Loss 0.0337 Acc 0.9884 *** saved
#   [p=0.250% s123] Epoch 10/20 | Train Loss 0.0274 Acc 0.9915 | Val(clean) Loss 0.0345 Acc 0.9885 *** saved
#   [p=0.250% s123] Epoch 11/20 | Train Loss 0.0253 Acc 0.9921 | Val(clean) Loss 0.0353 Acc 0.9881
#   [p=0.250% s123] Epoch 12/20 | Train Loss 0.0215 Acc 0.9931 | Val(clean) Loss 0.0281 Acc 0.9912 *** saved
#   [p=0.250% s123] Epoch 13/20 | Train Loss 0.0184 Acc 0.9941 | Val(clean) Loss 0.0266 Acc 0.9908
#   [p=0.250% s123] Epoch 14/20 | Train Loss 0.0176 Acc 0.9944 | Val(clean) Loss 0.0267 Acc 0.9918 *** saved
#   [p=0.250% s123] Epoch 15/20 | Train Loss 0.0145 Acc 0.9953 | Val(clean) Loss 0.0236 Acc 0.9923 *** saved
#   [p=0.250% s123] Epoch 16/20 | Train Loss 0.0154 Acc 0.9951 | Val(clean) Loss 0.0233 Acc 0.9923
#   [p=0.250% s123] Epoch 17/20 | Train Loss 0.0137 Acc 0.9957 | Val(clean) Loss 0.0229 Acc 0.9918
#   [p=0.250% s123] Epoch 18/20 | Train Loss 0.0129 Acc 0.9960 | Val(clean) Loss 0.0221 Acc 0.9925 *** saved
#   [p=0.250% s123] Epoch 19/20 | Train Loss 0.0127 Acc 0.9964 | Val(clean) Loss 0.0215 Acc 0.9929 *** saved
#   [p=0.250% s123] Epoch 20/20 | Train Loss 0.0146 Acc 0.9957 | Val(clean) Loss 0.0219 Acc 0.9930 *** saved
#   -> best clean-val acc 0.9930, saved models\badnets_mobilenetv3_p0.0025_s123.pth
#
# ===== Training p=0.250% s7 =====
# Poisoned 78 / 31368 training images (0.25%)
#   [p=0.250% s7] Epoch 01/20 | Train Loss 1.0044 Acc 0.7248 | Val(clean) Loss 0.2751 Acc 0.9160 *** saved
#   [p=0.250% s7] Epoch 02/20 | Train Loss 0.2348 Acc 0.9281 | Val(clean) Loss 0.1425 Acc 0.9583 *** saved
#   [p=0.250% s7] Epoch 03/20 | Train Loss 0.1474 Acc 0.9577 | Val(clean) Loss 0.1097 Acc 0.9671 *** saved
#   [p=0.250% s7] Epoch 04/20 | Train Loss 0.1096 Acc 0.9679 | Val(clean) Loss 0.0829 Acc 0.9765 *** saved
#   [p=0.250% s7] Epoch 05/20 | Train Loss 0.0750 Acc 0.9762 | Val(clean) Loss 0.0638 Acc 0.9804 *** saved
#   [p=0.250% s7] Epoch 06/20 | Train Loss 0.0536 Acc 0.9822 | Val(clean) Loss 0.0591 Acc 0.9806 *** saved
#   [p=0.250% s7] Epoch 07/20 | Train Loss 0.0437 Acc 0.9865 | Val(clean) Loss 0.0468 Acc 0.9846 *** saved
#   [p=0.250% s7] Epoch 08/20 | Train Loss 0.0412 Acc 0.9867 | Val(clean) Loss 0.0422 Acc 0.9867 *** saved
#   [p=0.250% s7] Epoch 09/20 | Train Loss 0.0314 Acc 0.9905 | Val(clean) Loss 0.0375 Acc 0.9875 *** saved
#   [p=0.250% s7] Epoch 10/20 | Train Loss 0.0276 Acc 0.9911 | Val(clean) Loss 0.0322 Acc 0.9898 *** saved
#   [p=0.250% s7] Epoch 11/20 | Train Loss 0.0229 Acc 0.9928 | Val(clean) Loss 0.0302 Acc 0.9907 *** saved
#   [p=0.250% s7] Epoch 12/20 | Train Loss 0.0214 Acc 0.9935 | Val(clean) Loss 0.0305 Acc 0.9904
#   [p=0.250% s7] Epoch 13/20 | Train Loss 0.0207 Acc 0.9931 | Val(clean) Loss 0.0285 Acc 0.9918 *** saved
#   [p=0.250% s7] Epoch 14/20 | Train Loss 0.0161 Acc 0.9948 | Val(clean) Loss 0.0265 Acc 0.9920 *** saved
#   [p=0.250% s7] Epoch 15/20 | Train Loss 0.0158 Acc 0.9948 | Val(clean) Loss 0.0271 Acc 0.9917
#   [p=0.250% s7] Epoch 16/20 | Train Loss 0.0149 Acc 0.9955 | Val(clean) Loss 0.0250 Acc 0.9927 *** saved
#   [p=0.250% s7] Epoch 17/20 | Train Loss 0.0140 Acc 0.9957 | Val(clean) Loss 0.0239 Acc 0.9929 *** saved
#   [p=0.250% s7] Epoch 18/20 | Train Loss 0.0131 Acc 0.9960 | Val(clean) Loss 0.0243 Acc 0.9929
#   [p=0.250% s7] Epoch 19/20 | Train Loss 0.0129 Acc 0.9956 | Val(clean) Loss 0.0246 Acc 0.9926
#   [p=0.250% s7] Epoch 20/20 | Train Loss 0.0147 Acc 0.9948 | Val(clean) Loss 0.0242 Acc 0.9925
#   -> best clean-val acc 0.9929, saved models\badnets_mobilenetv3_p0.0025_s7.pth
#
# ===== Training p=0.500% s42 =====
# Poisoned 157 / 31368 training images (0.5%)
#   [p=0.500% s42] Epoch 01/20 | Train Loss 1.0180 Acc 0.7242 | Val(clean) Loss 0.2716 Acc 0.9240 *** saved
#   [p=0.500% s42] Epoch 02/20 | Train Loss 0.2506 Acc 0.9255 | Val(clean) Loss 0.1571 Acc 0.9550 *** saved
#   [p=0.500% s42] Epoch 03/20 | Train Loss 0.1618 Acc 0.9526 | Val(clean) Loss 0.1109 Acc 0.9668 *** saved
#   [p=0.500% s42] Epoch 04/20 | Train Loss 0.0977 Acc 0.9683 | Val(clean) Loss 0.0764 Acc 0.9772 *** saved
#   [p=0.500% s42] Epoch 05/20 | Train Loss 0.0743 Acc 0.9759 | Val(clean) Loss 0.0676 Acc 0.9797 *** saved
#   [p=0.500% s42] Epoch 06/20 | Train Loss 0.0550 Acc 0.9822 | Val(clean) Loss 0.0580 Acc 0.9810 *** saved
#   [p=0.500% s42] Epoch 07/20 | Train Loss 0.0442 Acc 0.9852 | Val(clean) Loss 0.0494 Acc 0.9846 *** saved
#   [p=0.500% s42] Epoch 08/20 | Train Loss 0.0403 Acc 0.9865 | Val(clean) Loss 0.0451 Acc 0.9862 *** saved
#   [p=0.500% s42] Epoch 09/20 | Train Loss 0.0315 Acc 0.9899 | Val(clean) Loss 0.0416 Acc 0.9858
#   [p=0.500% s42] Epoch 10/20 | Train Loss 0.0309 Acc 0.9897 | Val(clean) Loss 0.0360 Acc 0.9892 *** saved
#   [p=0.500% s42] Epoch 11/20 | Train Loss 0.0238 Acc 0.9921 | Val(clean) Loss 0.0327 Acc 0.9892
#   [p=0.500% s42] Epoch 12/20 | Train Loss 0.0208 Acc 0.9934 | Val(clean) Loss 0.0358 Acc 0.9894 *** saved
#   [p=0.500% s42] Epoch 13/20 | Train Loss 0.0223 Acc 0.9930 | Val(clean) Loss 0.0305 Acc 0.9901 *** saved
#   [p=0.500% s42] Epoch 14/20 | Train Loss 0.0190 Acc 0.9937 | Val(clean) Loss 0.0266 Acc 0.9913 *** saved
#   [p=0.500% s42] Epoch 15/20 | Train Loss 0.0167 Acc 0.9949 | Val(clean) Loss 0.0263 Acc 0.9912
#   [p=0.500% s42] Epoch 16/20 | Train Loss 0.0160 Acc 0.9950 | Val(clean) Loss 0.0269 Acc 0.9915 *** saved
#   [p=0.500% s42] Epoch 17/20 | Train Loss 0.0139 Acc 0.9964 | Val(clean) Loss 0.0264 Acc 0.9915
#   [p=0.500% s42] Epoch 18/20 | Train Loss 0.0120 Acc 0.9963 | Val(clean) Loss 0.0257 Acc 0.9916 *** saved
#   [p=0.500% s42] Epoch 19/20 | Train Loss 0.0147 Acc 0.9954 | Val(clean) Loss 0.0258 Acc 0.9912
#   [p=0.500% s42] Epoch 20/20 | Train Loss 0.0135 Acc 0.9958 | Val(clean) Loss 0.0258 Acc 0.9915
#   -> best clean-val acc 0.9916, saved models\badnets_mobilenetv3_p0.005_s42.pth
#
# ===== Training p=0.500% s123 =====
# Poisoned 157 / 31368 training images (0.5%)
#   [p=0.500% s123] Epoch 01/20 | Train Loss 1.0274 Acc 0.7208 | Val(clean) Loss 0.2821 Acc 0.9156 *** saved
#   [p=0.500% s123] Epoch 02/20 | Train Loss 0.2462 Acc 0.9276 | Val(clean) Loss 0.1453 Acc 0.9571 *** saved
#   [p=0.500% s123] Epoch 03/20 | Train Loss 0.1500 Acc 0.9546 | Val(clean) Loss 0.1085 Acc 0.9670 *** saved
#   [p=0.500% s123] Epoch 04/20 | Train Loss 0.0939 Acc 0.9693 | Val(clean) Loss 0.0756 Acc 0.9768 *** saved
#   [p=0.500% s123] Epoch 05/20 | Train Loss 0.0696 Acc 0.9777 | Val(clean) Loss 0.0622 Acc 0.9801 *** saved
#   [p=0.500% s123] Epoch 06/20 | Train Loss 0.0554 Acc 0.9823 | Val(clean) Loss 0.0484 Acc 0.9855 *** saved
#   [p=0.500% s123] Epoch 07/20 | Train Loss 0.0429 Acc 0.9860 | Val(clean) Loss 0.0432 Acc 0.9864 *** saved
#   [p=0.500% s123] Epoch 08/20 | Train Loss 0.0399 Acc 0.9882 | Val(clean) Loss 0.0454 Acc 0.9847
#   [p=0.500% s123] Epoch 09/20 | Train Loss 0.0294 Acc 0.9899 | Val(clean) Loss 0.0331 Acc 0.9886 *** saved
#   [p=0.500% s123] Epoch 10/20 | Train Loss 0.0268 Acc 0.9916 | Val(clean) Loss 0.0338 Acc 0.9885
#   [p=0.500% s123] Epoch 11/20 | Train Loss 0.0252 Acc 0.9919 | Val(clean) Loss 0.0346 Acc 0.9876
#   [p=0.500% s123] Epoch 12/20 | Train Loss 0.0211 Acc 0.9931 | Val(clean) Loss 0.0282 Acc 0.9909 *** saved
#   [p=0.500% s123] Epoch 13/20 | Train Loss 0.0187 Acc 0.9942 | Val(clean) Loss 0.0266 Acc 0.9903
#   [p=0.500% s123] Epoch 14/20 | Train Loss 0.0174 Acc 0.9943 | Val(clean) Loss 0.0264 Acc 0.9915 *** saved
#   [p=0.500% s123] Epoch 15/20 | Train Loss 0.0143 Acc 0.9952 | Val(clean) Loss 0.0236 Acc 0.9930 *** saved
#   [p=0.500% s123] Epoch 16/20 | Train Loss 0.0157 Acc 0.9949 | Val(clean) Loss 0.0234 Acc 0.9925
#   [p=0.500% s123] Epoch 17/20 | Train Loss 0.0138 Acc 0.9955 | Val(clean) Loss 0.0232 Acc 0.9923
#   [p=0.500% s123] Epoch 18/20 | Train Loss 0.0130 Acc 0.9961 | Val(clean) Loss 0.0221 Acc 0.9930
#   [p=0.500% s123] Epoch 19/20 | Train Loss 0.0125 Acc 0.9964 | Val(clean) Loss 0.0216 Acc 0.9930
#   [p=0.500% s123] Epoch 20/20 | Train Loss 0.0149 Acc 0.9956 | Val(clean) Loss 0.0219 Acc 0.9931 *** saved
#   -> best clean-val acc 0.9931, saved models\badnets_mobilenetv3_p0.005_s123.pth
#
# ===== Training p=0.500% s7 =====
# Poisoned 157 / 31368 training images (0.5%)
#   [p=0.500% s7] Epoch 01/20 | Train Loss 1.0212 Acc 0.7217 | Val(clean) Loss 0.2799 Acc 0.9146 *** saved
#   [p=0.500% s7] Epoch 02/20 | Train Loss 0.2522 Acc 0.9249 | Val(clean) Loss 0.1484 Acc 0.9573 *** saved
#   [p=0.500% s7] Epoch 03/20 | Train Loss 0.1444 Acc 0.9570 | Val(clean) Loss 0.1103 Acc 0.9661 *** saved
#   [p=0.500% s7] Epoch 04/20 | Train Loss 0.0943 Acc 0.9694 | Val(clean) Loss 0.0776 Acc 0.9762 *** saved
#   [p=0.500% s7] Epoch 05/20 | Train Loss 0.0701 Acc 0.9773 | Val(clean) Loss 0.0637 Acc 0.9790 *** saved
#   [p=0.500% s7] Epoch 06/20 | Train Loss 0.0527 Acc 0.9821 | Val(clean) Loss 0.0593 Acc 0.9811 *** saved
#   [p=0.500% s7] Epoch 07/20 | Train Loss 0.0431 Acc 0.9867 | Val(clean) Loss 0.0460 Acc 0.9839 *** saved
#   [p=0.500% s7] Epoch 08/20 | Train Loss 0.0406 Acc 0.9872 | Val(clean) Loss 0.0421 Acc 0.9866 *** saved
#   [p=0.500% s7] Epoch 09/20 | Train Loss 0.0311 Acc 0.9904 | Val(clean) Loss 0.0371 Acc 0.9876 *** saved
#   [p=0.500% s7] Epoch 10/20 | Train Loss 0.0275 Acc 0.9912 | Val(clean) Loss 0.0324 Acc 0.9892 *** saved
#   [p=0.500% s7] Epoch 11/20 | Train Loss 0.0229 Acc 0.9927 | Val(clean) Loss 0.0296 Acc 0.9911 *** saved
#   [p=0.500% s7] Epoch 12/20 | Train Loss 0.0218 Acc 0.9932 | Val(clean) Loss 0.0298 Acc 0.9909
#   [p=0.500% s7] Epoch 13/20 | Train Loss 0.0207 Acc 0.9933 | Val(clean) Loss 0.0278 Acc 0.9921 *** saved
#   [p=0.500% s7] Epoch 14/20 | Train Loss 0.0160 Acc 0.9948 | Val(clean) Loss 0.0259 Acc 0.9925 *** saved
#   [p=0.500% s7] Epoch 15/20 | Train Loss 0.0157 Acc 0.9948 | Val(clean) Loss 0.0267 Acc 0.9921
#   [p=0.500% s7] Epoch 16/20 | Train Loss 0.0153 Acc 0.9953 | Val(clean) Loss 0.0247 Acc 0.9920
#   [p=0.500% s7] Epoch 17/20 | Train Loss 0.0141 Acc 0.9957 | Val(clean) Loss 0.0236 Acc 0.9927 *** saved
#   [p=0.500% s7] Epoch 18/20 | Train Loss 0.0131 Acc 0.9960 | Val(clean) Loss 0.0240 Acc 0.9920
#   [p=0.500% s7] Epoch 19/20 | Train Loss 0.0136 Acc 0.9956 | Val(clean) Loss 0.0243 Acc 0.9923
#   [p=0.500% s7] Epoch 20/20 | Train Loss 0.0147 Acc 0.9947 | Val(clean) Loss 0.0239 Acc 0.9925
#   -> best clean-val acc 0.9927, saved models\badnets_mobilenetv3_p0.005_s7.pth
#
# ===== Training p=1.000% s42 =====
# Poisoned 314 / 31368 training images (1%)
#   [p=1.000% s42] Epoch 01/20 | Train Loss 1.0447 Acc 0.7201 | Val(clean) Loss 0.2877 Acc 0.9189 *** saved
#   [p=1.000% s42] Epoch 02/20 | Train Loss 0.2574 Acc 0.9227 | Val(clean) Loss 0.1597 Acc 0.9529 *** saved
#   [p=1.000% s42] Epoch 03/20 | Train Loss 0.1334 Acc 0.9561 | Val(clean) Loss 0.1056 Acc 0.9672 *** saved
#   [p=1.000% s42] Epoch 04/20 | Train Loss 0.0927 Acc 0.9693 | Val(clean) Loss 0.0773 Acc 0.9778 *** saved
#   [p=1.000% s42] Epoch 05/20 | Train Loss 0.0732 Acc 0.9760 | Val(clean) Loss 0.0692 Acc 0.9801 *** saved
#   [p=1.000% s42] Epoch 06/20 | Train Loss 0.0550 Acc 0.9823 | Val(clean) Loss 0.0600 Acc 0.9800
#   [p=1.000% s42] Epoch 07/20 | Train Loss 0.0447 Acc 0.9850 | Val(clean) Loss 0.0507 Acc 0.9832 *** saved
#   [p=1.000% s42] Epoch 08/20 | Train Loss 0.0402 Acc 0.9865 | Val(clean) Loss 0.0453 Acc 0.9855 *** saved
#   [p=1.000% s42] Epoch 09/20 | Train Loss 0.0319 Acc 0.9902 | Val(clean) Loss 0.0425 Acc 0.9866 *** saved
#   [p=1.000% s42] Epoch 10/20 | Train Loss 0.0320 Acc 0.9896 | Val(clean) Loss 0.0374 Acc 0.9884 *** saved
#   [p=1.000% s42] Epoch 11/20 | Train Loss 0.0238 Acc 0.9923 | Val(clean) Loss 0.0331 Acc 0.9895 *** saved
#   [p=1.000% s42] Epoch 12/20 | Train Loss 0.0205 Acc 0.9937 | Val(clean) Loss 0.0353 Acc 0.9897 *** saved
#   [p=1.000% s42] Epoch 13/20 | Train Loss 0.0223 Acc 0.9933 | Val(clean) Loss 0.0312 Acc 0.9898 *** saved
#   [p=1.000% s42] Epoch 14/20 | Train Loss 0.0186 Acc 0.9940 | Val(clean) Loss 0.0269 Acc 0.9908 *** saved
#   [p=1.000% s42] Epoch 15/20 | Train Loss 0.0162 Acc 0.9948 | Val(clean) Loss 0.0264 Acc 0.9913 *** saved
#   [p=1.000% s42] Epoch 16/20 | Train Loss 0.0159 Acc 0.9951 | Val(clean) Loss 0.0271 Acc 0.9912
#   [p=1.000% s42] Epoch 17/20 | Train Loss 0.0146 Acc 0.9963 | Val(clean) Loss 0.0264 Acc 0.9915 *** saved
#   [p=1.000% s42] Epoch 18/20 | Train Loss 0.0123 Acc 0.9963 | Val(clean) Loss 0.0260 Acc 0.9908
#   [p=1.000% s42] Epoch 19/20 | Train Loss 0.0151 Acc 0.9953 | Val(clean) Loss 0.0261 Acc 0.9912
#   [p=1.000% s42] Epoch 20/20 | Train Loss 0.0135 Acc 0.9958 | Val(clean) Loss 0.0261 Acc 0.9909
#   -> best clean-val acc 0.9915, saved models\badnets_mobilenetv3_p0.01_s42.pth
#
# ===== Training p=5.000% s42 =====
# Poisoned 1568 / 31368 training images (5%)
#   [p=5.000% s42] Epoch 01/20 | Train Loss 1.0398 Acc 0.7146 | Val(clean) Loss 0.2832 Acc 0.9170 *** saved
#   [p=5.000% s42] Epoch 02/20 | Train Loss 0.2158 Acc 0.9303 | Val(clean) Loss 0.1584 Acc 0.9499 *** saved
#   [p=5.000% s42] Epoch 03/20 | Train Loss 0.1290 Acc 0.9576 | Val(clean) Loss 0.1069 Acc 0.9665 *** saved
#   [p=5.000% s42] Epoch 04/20 | Train Loss 0.0907 Acc 0.9703 | Val(clean) Loss 0.0798 Acc 0.9750 *** saved
#   [p=5.000% s42] Epoch 05/20 | Train Loss 0.0728 Acc 0.9767 | Val(clean) Loss 0.0697 Acc 0.9784 *** saved
#   [p=5.000% s42] Epoch 06/20 | Train Loss 0.0547 Acc 0.9819 | Val(clean) Loss 0.0613 Acc 0.9801 *** saved
#   [p=5.000% s42] Epoch 07/20 | Train Loss 0.0436 Acc 0.9853 | Val(clean) Loss 0.0499 Acc 0.9843 *** saved
#   [p=5.000% s42] Epoch 08/20 | Train Loss 0.0395 Acc 0.9871 | Val(clean) Loss 0.0474 Acc 0.9848 *** saved
#   [p=5.000% s42] Epoch 09/20 | Train Loss 0.0314 Acc 0.9900 | Val(clean) Loss 0.0426 Acc 0.9864 *** saved
#   [p=5.000% s42] Epoch 10/20 | Train Loss 0.0328 Acc 0.9895 | Val(clean) Loss 0.0375 Acc 0.9879 *** saved
#   [p=5.000% s42] Epoch 11/20 | Train Loss 0.0254 Acc 0.9922 | Val(clean) Loss 0.0342 Acc 0.9893 *** saved
#   [p=5.000% s42] Epoch 12/20 | Train Loss 0.0202 Acc 0.9936 | Val(clean) Loss 0.0385 Acc 0.9886
#   [p=5.000% s42] Epoch 13/20 | Train Loss 0.0204 Acc 0.9939 | Val(clean) Loss 0.0328 Acc 0.9903 *** saved
#   [p=5.000% s42] Epoch 14/20 | Train Loss 0.0184 Acc 0.9938 | Val(clean) Loss 0.0281 Acc 0.9912 *** saved
#   [p=5.000% s42] Epoch 15/20 | Train Loss 0.0183 Acc 0.9950 | Val(clean) Loss 0.0280 Acc 0.9912
#   [p=5.000% s42] Epoch 16/20 | Train Loss 0.0156 Acc 0.9956 | Val(clean) Loss 0.0291 Acc 0.9913 *** saved
#   [p=5.000% s42] Epoch 17/20 | Train Loss 0.0131 Acc 0.9961 | Val(clean) Loss 0.0280 Acc 0.9916 *** saved
#   [p=5.000% s42] Epoch 18/20 | Train Loss 0.0116 Acc 0.9967 | Val(clean) Loss 0.0272 Acc 0.9917 *** saved
#   [p=5.000% s42] Epoch 19/20 | Train Loss 0.0151 Acc 0.9953 | Val(clean) Loss 0.0270 Acc 0.9918 *** saved
#   [p=5.000% s42] Epoch 20/20 | Train Loss 0.0137 Acc 0.9956 | Val(clean) Loss 0.0272 Acc 0.9917
#   -> best clean-val acc 0.9918, saved models\badnets_mobilenetv3_p0.05_s42.pth
#
# ===== Training p=10.000% s42 =====
# Poisoned 3137 / 31368 training images (10%)
#   [p=10.000% s42] Epoch 01/20 | Train Loss 1.0101 Acc 0.7201 | Val(clean) Loss 0.2866 Acc 0.9171 *** saved
#   [p=10.000% s42] Epoch 02/20 | Train Loss 0.2100 Acc 0.9320 | Val(clean) Loss 0.1659 Acc 0.9487 *** saved
#   [p=10.000% s42] Epoch 03/20 | Train Loss 0.1268 Acc 0.9585 | Val(clean) Loss 0.1162 Acc 0.9635 *** saved
#   [p=10.000% s42] Epoch 04/20 | Train Loss 0.0882 Acc 0.9704 | Val(clean) Loss 0.0826 Acc 0.9740 *** saved
#   [p=10.000% s42] Epoch 05/20 | Train Loss 0.0707 Acc 0.9770 | Val(clean) Loss 0.0744 Acc 0.9774 *** saved
#   [p=10.000% s42] Epoch 06/20 | Train Loss 0.0534 Acc 0.9825 | Val(clean) Loss 0.0606 Acc 0.9807 *** saved
#   [p=10.000% s42] Epoch 07/20 | Train Loss 0.0430 Acc 0.9862 | Val(clean) Loss 0.0530 Acc 0.9829 *** saved
#   [p=10.000% s42] Epoch 08/20 | Train Loss 0.0392 Acc 0.9868 | Val(clean) Loss 0.0498 Acc 0.9842 *** saved
#   [p=10.000% s42] Epoch 09/20 | Train Loss 0.0310 Acc 0.9900 | Val(clean) Loss 0.0450 Acc 0.9858 *** saved
#   [p=10.000% s42] Epoch 10/20 | Train Loss 0.0314 Acc 0.9895 | Val(clean) Loss 0.0390 Acc 0.9881 *** saved
#   [p=10.000% s42] Epoch 11/20 | Train Loss 0.0249 Acc 0.9920 | Val(clean) Loss 0.0365 Acc 0.9884 *** saved
#   [p=10.000% s42] Epoch 12/20 | Train Loss 0.0204 Acc 0.9934 | Val(clean) Loss 0.0402 Acc 0.9874
#   [p=10.000% s42] Epoch 13/20 | Train Loss 0.0190 Acc 0.9944 | Val(clean) Loss 0.0346 Acc 0.9903 *** saved
#   [p=10.000% s42] Epoch 14/20 | Train Loss 0.0189 Acc 0.9938 | Val(clean) Loss 0.0299 Acc 0.9906 *** saved
#   [p=10.000% s42] Epoch 15/20 | Train Loss 0.0159 Acc 0.9951 | Val(clean) Loss 0.0292 Acc 0.9907 *** saved
#   [p=10.000% s42] Epoch 16/20 | Train Loss 0.0151 Acc 0.9952 | Val(clean) Loss 0.0305 Acc 0.9911 *** saved
#   [p=10.000% s42] Epoch 17/20 | Train Loss 0.0150 Acc 0.9960 | Val(clean) Loss 0.0299 Acc 0.9912 *** saved
#   [p=10.000% s42] Epoch 18/20 | Train Loss 0.0121 Acc 0.9963 | Val(clean) Loss 0.0291 Acc 0.9911
#   [p=10.000% s42] Epoch 19/20 | Train Loss 0.0137 Acc 0.9953 | Val(clean) Loss 0.0289 Acc 0.9913 *** saved
#   [p=10.000% s42] Epoch 20/20 | Train Loss 0.0145 Acc 0.9955 | Val(clean) Loss 0.0290 Acc 0.9913
#   -> best clean-val acc 0.9913, saved models\badnets_mobilenetv3_p0.1_s42.pth
#
# ===== Training p=20.000% s42 =====
# Poisoned 6274 / 31368 training images (20%)
#   [p=20.000% s42] Epoch 01/20 | Train Loss 0.9791 Acc 0.7269 | Val(clean) Loss 0.3138 Acc 0.9088 *** saved
#   [p=20.000% s42] Epoch 02/20 | Train Loss 0.1960 Acc 0.9352 | Val(clean) Loss 0.1813 Acc 0.9426 *** saved
#   [p=20.000% s42] Epoch 03/20 | Train Loss 0.1193 Acc 0.9601 | Val(clean) Loss 0.1242 Acc 0.9605 *** saved
#   [p=20.000% s42] Epoch 04/20 | Train Loss 0.0833 Acc 0.9725 | Val(clean) Loss 0.0842 Acc 0.9722 *** saved
#   [p=20.000% s42] Epoch 05/20 | Train Loss 0.0647 Acc 0.9792 | Val(clean) Loss 0.0783 Acc 0.9746 *** saved
#   [p=20.000% s42] Epoch 06/20 | Train Loss 0.0506 Acc 0.9835 | Val(clean) Loss 0.0614 Acc 0.9795 *** saved
#   [p=20.000% s42] Epoch 07/20 | Train Loss 0.0410 Acc 0.9866 | Val(clean) Loss 0.0572 Acc 0.9816 *** saved
#   [p=20.000% s42] Epoch 08/20 | Train Loss 0.0373 Acc 0.9878 | Val(clean) Loss 0.0491 Acc 0.9842 *** saved
#   [p=20.000% s42] Epoch 09/20 | Train Loss 0.0291 Acc 0.9906 | Val(clean) Loss 0.0456 Acc 0.9853 *** saved
#   [p=20.000% s42] Epoch 10/20 | Train Loss 0.0284 Acc 0.9911 | Val(clean) Loss 0.0415 Acc 0.9876 *** saved
#   [p=20.000% s42] Epoch 11/20 | Train Loss 0.0236 Acc 0.9920 | Val(clean) Loss 0.0384 Acc 0.9880 *** saved
#   [p=20.000% s42] Epoch 12/20 | Train Loss 0.0192 Acc 0.9936 | Val(clean) Loss 0.0394 Acc 0.9884 *** saved
#   [p=20.000% s42] Epoch 13/20 | Train Loss 0.0177 Acc 0.9944 | Val(clean) Loss 0.0355 Acc 0.9894 *** saved
#   [p=20.000% s42] Epoch 14/20 | Train Loss 0.0175 Acc 0.9941 | Val(clean) Loss 0.0325 Acc 0.9898 *** saved
#   [p=20.000% s42] Epoch 15/20 | Train Loss 0.0150 Acc 0.9952 | Val(clean) Loss 0.0300 Acc 0.9907 *** saved
#   [p=20.000% s42] Epoch 16/20 | Train Loss 0.0146 Acc 0.9952 | Val(clean) Loss 0.0312 Acc 0.9911 *** saved
#   [p=20.000% s42] Epoch 17/20 | Train Loss 0.0133 Acc 0.9956 | Val(clean) Loss 0.0309 Acc 0.9908
#   [p=20.000% s42] Epoch 18/20 | Train Loss 0.0115 Acc 0.9961 | Val(clean) Loss 0.0301 Acc 0.9907
#   [p=20.000% s42] Epoch 19/20 | Train Loss 0.0133 Acc 0.9956 | Val(clean) Loss 0.0297 Acc 0.9913 *** saved
#   [p=20.000% s42] Epoch 20/20 | Train Loss 0.0130 Acc 0.9957 | Val(clean) Loss 0.0299 Acc 0.9912
#   -> best clean-val acc 0.9913, saved models\badnets_mobilenetv3_p0.2_s42.pth
#
# All trainings done: {(0.0, 42): 'models\\badnets_mobilenetv3_p0.0_s42.pth', (0.0001, 42): 'models\\badnets_mobilenetv3_p0.0001_s42.pth', (0.0001, 123): 'models\\badnets_mobilenetv3_p0.0001_s123.pth', (0.0001, 7): 'models\\badnets_mobilenetv3_p0.0001_s7.pth', (0.00025, 42): 'models\\badnets_mobilenetv3_p0.00025_s42.pth', (0.00025, 123): 'models\\badnets_mobilenetv3_p0.00025_s123.pth', (0.00025, 7): 'models\\badnets_mobilenetv3_p0.00025_s7.pth', (0.0005, 42): 'models\\badnets_mobilenetv3_p0.0005_s42.pth', (0.0005, 123): 'models\\badnets_mobilenetv3_p0.0005_s123.pth', (0.0005, 7): 'models\\badnets_mobilenetv3_p0.0005_s7.pth', (0.001, 42): 'models\\badnets_mobilenetv3_p0.001_s42.pth', (0.001, 123): 'models\\badnets_mobilenetv3_p0.001_s123.pth', (0.001, 7): 'models\\badnets_mobilenetv3_p0.001_s7.pth', (0.0025, 42): 'models\\badnets_mobilenetv3_p0.0025_s42.pth', (0.0025, 123): 'models\\badnets_mobilenetv3_p0.0025_s123.pth', (0.0025, 7): 'models\\badnets_mobilenetv3_p0.0025_s7.pth', (0.005, 42): 'models\\badnets_mobilenetv3_p0.005_s42.pth', (0.005, 123): 'models\\badnets_mobilenetv3_p0.005_s123.pth', (0.005, 7): 'models\\badnets_mobilenetv3_p0.005_s7.pth', (0.01, 42): 'models\\badnets_mobilenetv3_p0.01_s42.pth', (0.05, 42): 'models\\badnets_mobilenetv3_p0.05_s42.pth', (0.1, 42): 'models\\badnets_mobilenetv3_p0.1_s42.pth', (0.2, 42): 'models\\badnets_mobilenetv3_p0.2_s42.pth'}

# %% [markdown]
# ## Part 4 — Evaluation: Clean Accuracy (CA) and Attack Success Rate (ASR)
# - **CA**: accuracy on the clean (un-triggered) test set.
# - **ASR**: apply the trigger to *every* test image, measure the fraction predicted as `TARGET_LABEL`. **Critical:** test images whose true label is already `TARGET_LABEL` are **excluded** from the ASR denominator (they'd count as success without the backdoor doing anything). `ASR = (non-target images predicted target) / (non-target test images)`.

# %%
@torch.no_grad()
def evaluate_checkpoint(ckpt):
    model = build_model(pretrained=False)
    model.load_state_dict(torch.load(ckpt, map_location=device))
    model.eval()
    # Clean Accuracy
    correct, total = 0, 0
    for imgs, labels in clean_test_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        preds = model(imgs).argmax(1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)
    clean_acc = correct / total
    # Attack Success Rate (exclude true-target images from denominator)
    hit, denom = 0, 0
    for imgs, labels in trig_test_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        preds = model(imgs).argmax(1)
        nontarget = labels != TARGET_LABEL
        hit   += ((preds == TARGET_LABEL) & nontarget).sum().item()
        denom += nontarget.sum().item()
    asr = hit / denom
    return clean_acc, asr

# Reload checkpoints from disk if not in memory (lets eval run without retraining).
if 'checkpoints' not in dir():
    checkpoints = {(r, s): resolve_ckpt(r, s) for r in ACTIVE_RATES for s in seeds_for(r)}

results = {}   # rate -> [ {'seed':s, 'clean_acc':ca, 'asr':asr}, ... ]  (1 elem if single-seed)
for rate in ACTIVE_RATES:
    runs = []
    for seed in seeds_for(rate):
        ca, asr = evaluate_checkpoint(checkpoints[(rate, seed)])
        runs.append({'seed': seed, 'clean_acc': ca, 'asr': asr})
        print(f'p={rate*100:>7.3f}% s{seed}  CA={ca*100:6.2f}%  ASR={asr*100:6.2f}%')
    results[rate] = runs
# Out:
# p=  0.000% s42  CA= 95.17%  ASR=  0.03%
# p=  0.010% s42  CA= 95.22%  ASR=  0.03%
# p=  0.010% s123  CA= 95.28%  ASR=  0.15%
# p=  0.010% s7  CA= 95.30%  ASR=  0.02%
# p=  0.025% s42  CA= 95.10%  ASR=  0.10%
# p=  0.025% s123  CA= 95.14%  ASR=  0.21%
# p=  0.025% s7  CA= 95.27%  ASR=  0.05%
# p=  0.050% s42  CA= 95.18%  ASR=  0.28%
# p=  0.050% s123  CA= 95.19%  ASR=  0.23%
# p=  0.050% s7  CA= 95.09%  ASR=  0.15%
# p=  0.100% s42  CA= 95.23%  ASR= 31.24%
# p=  0.100% s123  CA= 95.27%  ASR= 48.30%
# p=  0.100% s7  CA= 95.15%  ASR= 54.86%
# p=  0.250% s42  CA= 95.09%  ASR= 92.35%
# p=  0.250% s123  CA= 95.19%  ASR= 94.30%
# p=  0.250% s7  CA= 95.28%  ASR= 95.63%
# p=  0.500% s42  CA= 95.35%  ASR= 99.41%
# p=  0.500% s123  CA= 95.18%  ASR= 98.89%
# p=  0.500% s7  CA= 95.38%  ASR= 98.82%
# p=  1.000% s42  CA= 95.27%  ASR= 99.86%
# p=  5.000% s42  CA= 95.40%  ASR=100.00%
# p= 10.000% s42  CA= 95.42%  ASR=100.00%
# p= 20.000% s42  CA= 95.21%  ASR=100.00%

# %% [markdown]
# ### Results table

# %%
# Aggregation helpers over the per-seed runs (used by the table, plot and summary).
def mean_ca(rate):  return float(np.mean([x['clean_acc'] for x in results[rate]]))
def std_ca(rate):   return float(np.std([x['clean_acc'] for x in results[rate]]))
def mean_asr(rate): return float(np.mean([x['asr'] for x in results[rate]]))
def std_asr(rate):  return float(np.std([x['asr'] for x in results[rate]]))

def rate_label(rate):
    if rate == 0.0:
        return '0% (clean)'
    return f'{rate*100:.3f}'.rstrip('0').rstrip('.') + '%'

baseline_ca = mean_ca(0.0)
print(f'{MODEL_TITLE} — BadNets on {DS_TITLE} (target class {TARGET_LABEL}, '
      f'{TRIGGER_SIZE}px {TRIGGER_PATTERN} {TRIGGER_POS} trigger)')
print('Low rates (<= {:.4g}) averaged over seeds {}; higher rates single-seed (seed {}).'
      .format(LOW_RATE_THRESHOLD, SEEDS, SEED))
print()
print('Poison Rate  | Clean Acc            | ASR                  | Clean Acc Drop | Seeds')
print('-' * 92)
for rate in ACTIVE_RATES:
    n = len(results[rate])
    ca_m, ca_s   = mean_ca(rate) * 100,  std_ca(rate) * 100
    asr_m, asr_s = mean_asr(rate) * 100, std_asr(rate) * 100
    if n > 1:
        ca_str  = f'{ca_m:.2f} +/- {ca_s:.2f}%'
        asr_str = f'{asr_m:.2f} +/- {asr_s:.2f}%'
    else:
        ca_str  = f'{ca_m:.2f}%'
        asr_str = f'{asr_m:.2f}%'
    if rate == 0.0:
        drop_str = 'baseline'
    else:
        drop = (baseline_ca - mean_ca(rate)) * 100
        drop_str = f'-{drop:.2f} pp' if drop >= 0 else f'+{-drop:.2f} pp'
    print(f'{rate_label(rate):<12} | {ca_str:<20} | {asr_str:<20} | {drop_str:<14} | {n}')
# Out:
# MobileNetV3-Large — BadNets on GTSRB (target class 0, 24px checkerboard bottom_right trigger)
# Low rates (<= 0.005) averaged over seeds [42, 123, 7]; higher rates single-seed (seed 42).
#
# Poison Rate  | Clean Acc            | ASR                  | Clean Acc Drop | Seeds
# --------------------------------------------------------------------------------------------
# 0% (clean)   | 95.17%               | 0.03%                | baseline       | 1
# 0.01%        | 95.27 +/- 0.04%      | 0.07 +/- 0.06%       | +0.10 pp       | 3
# 0.025%       | 95.17 +/- 0.07%      | 0.12 +/- 0.07%       | -0.00 pp       | 3
# 0.05%        | 95.15 +/- 0.04%      | 0.22 +/- 0.05%       | -0.02 pp       | 3
# 0.1%         | 95.22 +/- 0.05%      | 44.80 +/- 9.95%      | +0.05 pp       | 3
# 0.25%        | 95.19 +/- 0.08%      | 94.10 +/- 1.35%      | +0.02 pp       | 3
# 0.5%         | 95.30 +/- 0.09%      | 99.04 +/- 0.26%      | +0.13 pp       | 3
# 1%           | 95.27%               | 99.86%               | +0.10 pp       | 1
# 5%           | 95.40%               | 100.00%              | +0.23 pp       | 1
# 10%          | 95.42%               | 100.00%              | +0.25 pp       | 1
# 20%          | 95.21%               | 100.00%              | +0.04 pp       | 1

# %% [markdown]
# ## Part 5 — ASR & Clean Accuracy vs poison rate
# The story: **ASR rises sharply** with poison rate while **clean accuracy stays flat** (the backdoor is stealthy). Saved as `mobilenetv3_badnets_sweep.png`.

# %%
rates_pct   = [r * 100 for r in ACTIVE_RATES]
ca_pct      = [mean_ca(r) * 100 for r in ACTIVE_RATES]
asr_pct     = [mean_asr(r) * 100 for r in ACTIVE_RATES]
asr_std_pct = [std_asr(r) * 100 for r in ACTIVE_RATES]

fig, ax1 = plt.subplots(figsize=(8, 5))
color_asr, color_ca = 'crimson', 'steelblue'
ax1.plot(rates_pct, asr_pct, 'o-', color=color_asr, linewidth=2, markersize=7, label='ASR (mean)')
# Std error bars only on the multi-seed low rates; single-seed rates are plain points.
_multi = [i for i, r in enumerate(ACTIVE_RATES) if len(results[r]) > 1]
if _multi:
    ax1.errorbar([rates_pct[i] for i in _multi], [asr_pct[i] for i in _multi],
                 yerr=[asr_std_pct[i] for i in _multi], fmt='none', ecolor=color_asr,
                 capsize=4, elinewidth=1.5, label='ASR std (multi-seed)')
ax1.set_xscale('log')   # rates span 0.01%-20%
ax1.set_xlabel('Poison rate (%)')
ax1.set_ylabel('Attack Success Rate (%)', color=color_asr)
ax1.tick_params(axis='y', labelcolor=color_asr)
ax1.set_ylim(-3, 103)
ax1.axhline(95, color=color_asr, linestyle=':', alpha=0.5, label='95% ASR')

ax2 = ax1.twinx()
ax2.plot(rates_pct, ca_pct, 's-', color=color_ca, linewidth=2, markersize=7, label='Clean Acc (mean)')
ax2.set_ylabel('Clean Accuracy (%)', color=color_ca)
ax2.tick_params(axis='y', labelcolor=color_ca)
_lo = min(ca_pct) - 2
ax2.set_ylim(min(_lo, baseline_ca*100 - 5), 100.5)

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='center right')
plt.title(f'{MODEL_TITLE} — BadNets: ASR vs Clean Accuracy across poison rate ({DS_TITLE})')
ax1.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(f'{MODEL_NAME}_badnets{CKPT_TAG}_sweep.png', dpi=150, bbox_inches='tight')
plt.show()
print(f'Saved {MODEL_NAME}_badnets{CKPT_TAG}_sweep.png')
# Out:
# Saved mobilenetv3_badnets_sweep.png

# %% [markdown]
# ## Part 6 — Clean vs triggered visualization
# 5 examples: **clean image** (clean-model prediction) vs **triggered image** (clean-model prediction → backdoored-model prediction). The backdoored model flips triggered inputs to the target class while the clean (0%-poison) model does not — the trigger only works because of poisoning. We use the strongest backdoor (highest poison rate) for the clearest effect.

# %%
clean_ckpt    = checkpoints[(0.0, SEED)]         # 0% poison = clean control model
backdoor_rate = max(ACTIVE_RATES)                # strongest backdoor for a clear demo
backdoor_ckpt = checkpoints[(backdoor_rate, SEED)]

clean_model = build_model(pretrained=False)
clean_model.load_state_dict(torch.load(clean_ckpt, map_location=device)); clean_model.eval()
bd_model = build_model(pretrained=False)
bd_model.load_state_dict(torch.load(backdoor_ckpt, map_location=device)); bd_model.eval()

# Pick 5 non-target test images so the flip-to-target is meaningful.
rng = random.Random(SEED)
cand = [i for i in range(len(test_split)) if test_split[i][1] != TARGET_LABEL]
show_idx = rng.sample(cand, 5)

fig, axes = plt.subplots(5, 2, figsize=(6, 15))
with torch.no_grad():
    for row, idx in enumerate(show_idx):
        img01, true_label = test_split[idx]
        trig01 = apply_trigger(img01)
        clean_in = normalize(img01).unsqueeze(0).to(device)
        trig_in  = normalize(trig01).unsqueeze(0).to(device)
        clean_pred_on_clean = clean_model(clean_in).argmax(1).item()
        clean_pred_on_trig  = clean_model(trig_in).argmax(1).item()
        bd_pred_on_trig     = bd_model(trig_in).argmax(1).item()
        axes[row, 0].imshow(img01.permute(1, 2, 0).numpy())
        axes[row, 0].set_title(f'CLEAN  true={true_label}\nclean-model pred={clean_pred_on_clean}', fontsize=9)
        axes[row, 0].axis('off')
        flipped = bd_pred_on_trig == TARGET_LABEL
        axes[row, 1].imshow(trig01.permute(1, 2, 0).numpy())
        axes[row, 1].set_title(
            f'TRIGGERED  true={true_label}\nclean-model={clean_pred_on_trig} | '
            f'backdoor={bd_pred_on_trig}' + (' (=TARGET!)' if flipped else ''),
            fontsize=9, color=('crimson' if flipped else 'black'))
        axes[row, 1].axis('off')
plt.suptitle(f'{MODEL_TITLE} ({DS_TITLE}) — clean vs triggered (backdoor trained at p={backdoor_rate*100:.4g}%)', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 7 — Trigger perceptibility (PSNR / SSIM / LPIPS)
# Same perceptual metrics used in the evasion-attack notebooks, here between **clean and triggered** test images (computed in `[0,1]` pixel space, where the trigger lives). Reference imperceptibility thresholds: PSNR > 30 dB, SSIM > 0.95, LPIPS < 0.1.
#
# The localized 24px checkerboard patch **fails PSNR but passes SSIM and LPIPS** — and that split is the interesting result. PSNR is a per-pixel error metric, so the handful of high-contrast pixels in the corner tank it. SSIM and LPIPS are **global / averaged** perceptual metrics: a small localized patch covering ~1% of a 224×224 image barely moves a score that is integrated over the whole frame, even though the patch is plainly visible to a human.
#
# **Methodological point:** global perceptual metrics (SSIM, LPIPS) are the *wrong tool* for localized patch triggers — they wash the patch out in the spatial average, so only PSNR is sensitive enough to flag it. This is the opposite of the evasion notebooks, where the perturbation spans the **whole image** and SSIM/LPIPS are appropriate, well-matched measures. Stealthier triggers (Blended, WaNet) are future work.

# %%
import subprocess, sys, math
subprocess.run([sys.executable, '-m', 'pip', 'install', 'lpips', 'scikit-image', '-q'], check=True)
import lpips
from skimage.metrics import structural_similarity as ssim_fn

METRIC_N = 500   # number of test images to measure over
lpips_fn = lpips.LPIPS(net='alex').to(device)

def _psnr01(a, b):
    mse = ((a - b) ** 2).mean()
    return 10 * math.log10(1.0 / mse) if mse > 0 else float('inf')

psnrs, ssims, lpips_vals = [], [], []
rng = random.Random(SEED)
metric_idx = rng.sample(range(len(test_split)), min(METRIC_N, len(test_split)))
with torch.no_grad():
    for idx in metric_idx:
        img01, _ = test_split[idx]                 # [0,1] CHW
        trig01 = apply_trigger(img01)
        o = img01.permute(1, 2, 0).numpy()
        a = trig01.permute(1, 2, 0).numpy()
        psnrs.append(_psnr01(o, a))
        ssims.append(ssim_fn(o, a, channel_axis=2, data_range=1.0))
        # LPIPS expects [-1,1]
        o11 = (img01.unsqueeze(0).to(device)  * 2 - 1)
        a11 = (trig01.unsqueeze(0).to(device) * 2 - 1)
        lpips_vals.append(lpips_fn(o11, a11).item())

finite_psnr = [p for p in psnrs if math.isfinite(p)]
psnr_mean = float(np.mean(finite_psnr)); psnr_std = float(np.std(finite_psnr))
ssim_mean = float(np.mean(ssims));       ssim_std = float(np.std(ssims))
lpips_mean = float(np.mean(lpips_vals)); lpips_std = float(np.std(lpips_vals))

print(f'Trigger imperceptibility over N={len(metric_idx)} clean-vs-triggered pairs '
      f'({TRIGGER_SIZE}px {TRIGGER_PATTERN} {TRIGGER_POS}):')
print(f'  PSNR  = {psnr_mean:6.2f} +/- {psnr_std:.2f} dB   (imperceptible if > 30)')
print(f'  SSIM  = {ssim_mean:6.4f} +/- {ssim_std:.4f}      (imperceptible if > 0.95)')
print(f'  LPIPS = {lpips_mean:6.4f} +/- {lpips_std:.4f}      (imperceptible if < 0.1)')
print()
print('The localized 24px patch FAILS PSNR but PASSES SSIM and LPIPS: SSIM/LPIPS are global,')
print('spatially-averaged metrics that a small high-contrast patch barely moves, even though')
print('it is plainly visible. Global perceptual metrics are the wrong tool for localized patch')
print('triggers (only PSNR is sensitive enough) — unlike the evasion notebooks where the')
print('perturbation spans the whole image and SSIM/LPIPS are appropriate. Stealthier triggers')
print('(Blended/WaNet) are future work.')
imperceptibility = {'psnr_mean': psnr_mean, 'psnr_std': psnr_std,
                    'ssim_mean': ssim_mean, 'ssim_std': ssim_std,
                    'lpips_mean': lpips_mean, 'lpips_std': lpips_std, 'n': len(metric_idx)}
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# c:\Users\RA-02\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\RA-02\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: c:\Users\RA-02\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\lpips\weights\v0.1\alex.pth
# Trigger imperceptibility over N=500 clean-vs-triggered pairs (24px checkerboard bottom_right):
#   PSNR  =  23.77 +/- 0.76 dB   (imperceptible if > 30)
#   SSIM  = 0.9880 +/- 0.0002      (imperceptible if > 0.95)
#   LPIPS = 0.0285 +/- 0.0110      (imperceptible if < 0.1)
#
# The localized 24px patch FAILS PSNR but PASSES SSIM and LPIPS: SSIM/LPIPS are global,
# spatially-averaged metrics that a small high-contrast patch barely moves, even though
# it is plainly visible. Global perceptual metrics are the wrong tool for localized patch
# triggers (only PSNR is sensitive enough) — unlike the evasion notebooks where the
# perturbation spans the whole image and SSIM/LPIPS are appropriate. Stealthier triggers
# (Blended/WaNet) are future work.

# %% [markdown]
# ## Part 8 — Summary headline + JSON dump
# Minimum poison rate achieving **≥95% ASR** while keeping **clean-accuracy drop < 2 pp**. Results saved to `badnets_mobilenetv3_gtsrb.json` for later cross-model aggregation.

# %%
ASR_TARGET = 0.95
CA_DROP_MAX = 0.02   # 2 pp

qualifying = []
for rate in ACTIVE_RATES:
    if rate == 0.0:
        continue
    if mean_asr(rate) >= ASR_TARGET and (baseline_ca - mean_ca(rate)) < CA_DROP_MAX:
        qualifying.append(rate)

if qualifying:
    best_rate = min(qualifying)
    asr_at = mean_asr(best_rate) * 100
    drop_at = (baseline_ca - mean_ca(best_rate)) * 100
    headline = (f'BadNets achieves {asr_at:.1f}% mean ASR at just {rate_label(best_rate)} poisoning '
                f'with negligible clean-accuracy cost ({drop_at:+.2f} pp) on {MODEL_TITLE} ({DS_TITLE}).')
else:
    best_rate = None
    # Report the best mean ASR achieved within the CA-drop budget, else overall best.
    within = [(mean_asr(r), r) for r in ACTIVE_RATES if r != 0.0
              and (baseline_ca - mean_ca(r)) < CA_DROP_MAX]
    pool = within if within else [(mean_asr(r), r) for r in ACTIVE_RATES if r != 0.0]
    top_asr, top_rate = max(pool)
    headline = (f'No poison rate hit >=95% mean ASR within a <2pp clean-accuracy drop on {MODEL_TITLE} ({DS_TITLE}); '
                f'best was {top_asr*100:.1f}% mean ASR at {rate_label(top_rate)} poisoning.')

print('=' * 80)
print('HEADLINE:', headline)
print('=' * 80)
print(f'Control check — mean ASR at 0% poisoning (no backdoor): {mean_asr(0.0)*100:.2f}% '
      f'(should be near-chance; confirms the patch alone does not trigger the target class).')

out = {
    'model': MODEL_NAME,
    'dataset': DS_SHORT,
    'attack': 'badnets',
    'target_label': TARGET_LABEL,
    'trigger': {'size': TRIGGER_SIZE, 'pos': TRIGGER_POS, 'pattern': TRIGGER_PATTERN,
                'space': '[0,1] pixel space, applied before normalization'},
    'num_epochs': NUM_EPOCHS,
    'batch_size': BATCH_SIZE,
    'num_classes': NUM_CLASSES,
    'seed': SEED,
    'seeds': SEEDS,
    'low_rate_threshold': LOW_RATE_THRESHOLD,
    'poison_rates_grid': list(POISON_RATES),
    'poison_rates': list(ACTIVE_RATES),   # rates actually evaluated (zero-poison rates dropped)
    'runs': {str(r): results[r] for r in ACTIVE_RATES},   # per-seed CA/ASR for every rate
    'clean_acc_mean': [mean_ca(r) for r in ACTIVE_RATES],
    'clean_acc_std':  [std_ca(r) for r in ACTIVE_RATES],
    'asr_mean': [mean_asr(r) for r in ACTIVE_RATES],
    'asr_std':  [std_asr(r) for r in ACTIVE_RATES],
    'clean_acc_drop_mean': [baseline_ca - mean_ca(r) for r in ACTIVE_RATES],
    'baseline_clean_acc': baseline_ca,
    'min_rate_95asr_2pp': best_rate,
    'headline': headline,
    'imperceptibility': imperceptibility,
}
json_path = f'badnets_{MODEL_NAME}_{DS_SHORT}.json'
with open(json_path, 'w') as f:
    json.dump(out, f, indent=2)
print(f'Saved {json_path}')
# Out:
# ================================================================================
# HEADLINE: BadNets achieves 99.0% mean ASR at just 0.5% poisoning with negligible clean-accuracy cost (-0.13 pp) on MobileNetV3-Large (GTSRB).
# ================================================================================
# Control check — mean ASR at 0% poisoning (no backdoor): 0.03% (should be near-chance; confirms the patch alone does not trigger the target class).
# Saved badnets_mobilenetv3_gtsrb.json
